# %% [markdown]
# Working on adding a lot of features just to see if it can get the score up regardless of how complicated or where the data is coming from
#
# Features that I will be adding
#
# * Taget given surface counts
# * words from the target and source document
#   * possible back prop into these vectors, idea is to replace tf-idf with some nn and back prop here
# * the extra feature are going in with the target vec when approperate

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from theano import *
from lasagne.layers import InputLayer, get_output
import lasagne
import lasagne.layers
import theano.tensor as T
import theano
import numpy as np
from helpers import SimpleMaxingLayer, SimpleAverageLayer
from wordvecs import WordVectors, EmbeddingLayer, WordTokenizer
import json
import re
import random

theano.config.floatX = 'float32'
#theano.config.linker = 'cvm_nogc'
theano.config.openmp = True
theano.config.openmp_elemwise_minsize = 20000
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
with open('/data/matthew/external-wiki2.json') as f:
    queries = json.load(f)['queries']

# %%
len(queries)
# Out:
# 9915

# %%
sum([any([g['gold'] for g in v.values()]) for v in queries.values()])
# Out:
# 8917

# %%
wordvectors = WordVectors(
    fname="/data/matthew/enwiki-20141208-pages-articles-multistream-links7-output1.bin",
    redir_fname='/data/matthew/enwiki-20141208-pages-articles-multistream-redirect7.json',
    negvectors=False,
    sentence_length=200,
)
wordvectors.add_unknown_words = False

# %%
# with open('/data/matthew/enwiki-20141208-pages-articles-multistream-redirects5.json') as f:
#     page_redirects = json.load(f)
page_redirects = wordvectors.redirects

# %%
len(wordvectors.vectors)
# Out:
# 4056055

# %%
with open('/data/matthew/enwiki-20141208-pages-articles-multistream-surface-counts7.json') as f:
    surface_counts = json.load(f)

# %%
# try and make the surfaces items match what we are looking for
surface_counts_re = re.compile('([\.,!\?])')
for sk in surface_counts.keys():
    nsk = sk.replace('(', '-lrb-').replace(')', '-rrb-')
    nsk = surface_counts_re.sub(' \\1', nsk)
    if nsk != sk:
        surface_counts[nsk] = surface_counts[sk]

# %%
from wikireader import WikiRegexes, WikipediaReader

# %%
def PreProcessedQueries(wikipedia_dump_fname, vectors=wordvectors, queries=queries, redirects=page_redirects, surface=surface_counts):
    
    get_words = re.compile('[^a-zA-Z0-9 ]')
    get_link = re.compile('.*?\[(.*?)\].*?')
    
    wordvec = WordTokenizer(vectors, sentence_length=200)
    documentvec = WordTokenizer(vectors, sentence_length=1)
    
    queried_pages = set()
    for docs, q in queries.iteritems():
        wordvec.tokenize(docs)
        for sur, v in q.iteritems():
            wrds_sur = get_words.sub(' ', sur)
            wordvec.tokenize(wrds_sur)
            link_sur = get_link.match(sur).group(1)
            wordvec.tokenize(link_sur)
            for link in v['vals'].keys():
                wrds = get_words.sub(' ', link)
                wordvec.tokenize(wrds)
                tt = WikiRegexes.convertToTitle(link)
                documentvec.get_location(tt)
                queried_pages.add(tt)

    added_pages = set()
    for title in queried_pages:
        if title in redirects:
            #wordvec.tokenize(self.redirects[title])
            documentvec.get_location(redirects[title])
            added_pages.add(redirects[title])
    queried_pages |= added_pages

    page_content = {}

#     class GetWikipediaWords(WikipediaReader, WikiRegexes):

#         def readPage(ss, title, content):
#             tt = ss.convertToTitle(title)
#             if tt in queried_pages:
#                 cnt = ss._wikiToText(content)
#                 page_content[tt] = wordvec.tokenize(cnt)

#     GetWikipediaWords(wikipedia_dump_fname).read()
    
    rr = redirects
    rq = queried_pages
    rc = page_content
    rs = surface

    class PreProcessedQueriesCls(object):
        
        wordvecs = wordvec
        documentvecs = documentvec
        queries = queries
        redirects = rr
        queried_pages = rq
        page_content = rc
        surface_counts = rs
        
        
    return PreProcessedQueriesCls

# %%
basePreProcessedQueries = PreProcessedQueries('/data/matthew/enwiki-20141208-pages-articles-multistream.xml')

# %%
len(basePreProcessedQueries.wordvecs.reverse_word_location)
# Out:
# 145739

# %%
len(basePreProcessedQueries.documentvecs.reverse_word_location)
# Out:
# 443223

# %%
class EntityVectorLinkExp(basePreProcessedQueries):

    batch_size = 1000 #20000
    num_training_items = 500000 #200000

    def __init__(self):
        self.sentence_length = self.wordvecs.sentence_length
        self.document_length = 100
        self.num_words_to_use_conv = 2

        self._setup()


    def _setup(self):
        #self.x_document_input = T.imatrix('x_doc')

        #self.x_document_id = T.ivector('x_doc_id')
        self.x_surface_text_input = T.imatrix('x_surface_link')
        self.x_surface_context_input = T.imatrix('x_surface_cxt')  # TODO

        self.x_target_input = T.ivector('x_target')
        self.x_target_words = T.imatrix('x_target_words')
        self.x_matches_surface = T.ivector('x_match_surface')
        self.x_matches_counts = T.imatrix('x_matches_counts')
        self.x_link_id = T.ivector('x_link_id')

        #self.y_score = T.vector('y')
        self.y_answer = T.ivector('y_ans')  # contains the location of the gold answer so we can compute the loss
        self.y_grouping = T.imatrix('y_grouping')


        self.embedding_W = theano.shared(self.wordvecs.get_numpy_matrix().astype(theano.config.floatX))
        self.embedding_W_docs = theano.shared(self.documentvecs.get_numpy_matrix()).astype(theano.config.floatX)
        
#         self.document_l = lasagne.layers.InputLayer(
#             (None,self.document_length),
#             input_var=self.x_document_input
#         )

#         self.document_embedding_l = EmbeddingLayer(
#             self.document_l,
#             W=self.embedding_W,
#             add_word_params=False,
#         )

#         self.document_conv1_l = lasagne.layers.Conv2DLayer(
#             self.document_embedding_l,
#             num_filters=500,
#             filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
#             name='document_conv1',
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.document_max_l = lasagne.layers.Pool2DLayer(
#             self.document_conv1_l,
#             name='document_pool1',
#             pool_size=(self.document_length - self.num_words_to_use_conv, 1),
#             mode='sum',
#         )

#         self.document_dens1 = lasagne.layers.DenseLayer(
#             self.document_max_l,
#             num_units=250,
#             name='doucment_dens1',
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.document_drop1 = lasagne.layers.DropoutLayer(
#             self.document_dens1,
#             p=.25,
#         )

#         document_output_length = 200

#         self.document_dens2 = lasagne.layers.DenseLayer(
#             self.document_drop1,
#             num_units=225,
#             name='document_dens2',
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.document_drop2 = lasagne.layers.DropoutLayer(
#             self.document_dens2,
#             p=.25,
#         )

#         self.document_dens3 = lasagne.layers.DenseLayer(
#             self.document_drop2,
#             num_units=document_output_length,
#             name='document_dens3',
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.document_output = lasagne.layers.get_output(self.document_dens3)

        self.surface_context_l = lasagne.layers.InputLayer(
            (None, self.sentence_length),
            input_var=self.x_surface_context_input,
        )

        self.surface_context_embedding_l = EmbeddingLayer(
            self.surface_context_l,
            W=self.embedding_W,
            add_word_params=False,
        )

        self.surface_context_conv1_l = lasagne.layers.Conv2DLayer(
            self.surface_context_embedding_l,
            num_filters=300,
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            name='surface_cxt_conv1',
            nonlinearity=lasagne.nonlinearities.tanh,
        )

#         self.surface_context_avg1_l = SimpleAverageLayer(
#             [self.surface_context_conv1_l, self.surface_context_l],
#             #name='surface_context_avg'
#         )

        self.surface_context_pool1_l = lasagne.layers.Pool2DLayer(
            self.surface_context_conv1_l,
            name='surface_cxt_pool1',
            pool_size=(self.sentence_length - self.num_words_to_use_conv, 1),
            mode='sum',
        )

        self.surface_input_l = lasagne.layers.InputLayer(
            (None, self.sentence_length),
            input_var=self.x_surface_text_input
        )

        self.surface_embedding_l = EmbeddingLayer(
            self.surface_input_l,
            W=self.embedding_W,
            add_word_params=False,
        )

        self.surface_conv1_l = lasagne.layers.Conv2DLayer(
            self.surface_embedding_l,
            num_filters=300,
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            name='surface_conv1',
            nonlinearity=lasagne.nonlinearities.tanh,
        )

#         self.surface_avg1_l = SimpleAverageLayer(
#             [self.surface_conv1_l, self.surface_input_l],
#             #name='surface_avg'
#         )

        self.surface_pool1_l = lasagne.layers.Pool2DLayer(
            self.surface_conv1_l,
            name='surface_pool1',
            pool_size=(self.sentence_length - self.num_words_to_use_conv, 1),
            mode='sum',
        )

        self.surface_merged_l = lasagne.layers.ConcatLayer(
            [self.surface_context_pool1_l, self.surface_pool1_l]
        )

        self.surface_dens1 = lasagne.layers.DenseLayer(
            self.surface_merged_l,
            name='surface_dens1',
            num_units=250,
            nonlinearity=lasagne.nonlinearities.tanh,
        )

#         self.surface_drop1 = lasagne.layers.DropoutLayer(
#             self.surface_dens1,
#             p=.25,
#         )

#         self.surface_dens2 = lasagne.layers.DenseLayer(
#             self.surface_drop1,
#             name='surface_dens2',
#             num_units=200,
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.document_aligned_l = InputLayer(
#             (None, document_output_length),
#             input_var=self.document_output[self.x_document_id,:]
#         )

        ##############################################
        ## changed to not use the documented

#         self.source_l = lasagne.layers.ConcatLayer(
#             [self.document_aligned_l, self.surface_dens1]
#         )

        self.source_dens1 = lasagne.layers.DenseLayer(
            self.surface_dens1,   # CHANGED
            num_units=300,
            name='source_dens1',
            nonlinearity=lasagne.nonlinearities.tanh,
        )

        self.source_drop1 = lasagne.layers.DropoutLayer(
            self.source_dens1,
            p=.25,
        )

        self.source_dens12 = lasagne.layers.DenseLayer(
            self.source_drop1,
            num_units=250,
            name='source_dens12',
            nonlinearity=lasagne.nonlinearities.tanh,
        )

        self.source_drop12 = lasagne.layers.DropoutLayer(
            self.source_dens12,
            p=.25,
        )

        compared_vector_size = self.wordvecs.vector_size #+ 2 # extra space for if it matches the surface text

        self.source_dens2 = lasagne.layers.DenseLayer(
            self.source_drop12,
            num_units=compared_vector_size,  # this is the same size as the learned wikipedia vectors
            name='source_dens2',
            nonlinearity=lasagne.nonlinearities.linear,
        )

        self.source_out = lasagne.layers.get_output(self.source_dens2)

        matched_surface_reshaped = self.x_matches_surface.reshape(
            (self.x_matches_surface.shape[0], 1, 1, 1)).astype(theano.config.floatX)

        self.target_input_l = lasagne.layers.InputLayer(
            (None,),
            input_var=self.x_target_input
        )

        self.target_matched_surface_input_l = lasagne.layers.InputLayer(
            (None,1,1,1),
            input_var=matched_surface_reshaped,
        )
        
        self.target_matched_counts_input_l = lasagne.layers.InputLayer(
            (None,4),
            input_var=self.x_matches_counts.astype(theano.config.floatX),
        )

        self.target_embedding_l = EmbeddingLayer(
            lasagne.layers.reshape(self.target_input_l, ([0], 1)),
            W=self.embedding_W_docs,
            add_word_params=False,
        )

        self.target_combined_feats_l = lasagne.layers.ConcatLayer(
            [self.target_embedding_l, self.target_matched_surface_input_l,
            lasagne.layers.reshape(self.target_matched_counts_input_l, ([0],1,1,[1]))],
            axis=3
        )

        self.target_words_input_l = lasagne.layers.InputLayer(
            (None,self.sentence_length),
            input_var=self.x_target_words,
        )

        self.target_words_embedding_l = EmbeddingLayer(
            self.target_words_input_l,
            W=self.embedding_W,
            add_word_params=False,
        )

        self.target_words_conv1_l = lasagne.layers.Conv2DLayer(
            self.target_words_embedding_l,
            name='target_wrds_conv1',
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            num_filters=350,
            nonlinearity=lasagne.nonlinearities.tanh,
        )

        self.target_words_pool1_l = lasagne.layers.Pool2DLayer(
            self.target_words_conv1_l,
            name='target_wrds_pool1',
            pool_size=(self.sentence_length - self.num_words_to_use_conv, 1),
            mode='sum',
        )

        self.target_merge_l = lasagne.layers.ConcatLayer(
            [lasagne.layers.reshape(self.target_words_pool1_l, ([0], [1])),
             lasagne.layers.reshape(self.target_embedding_l, ([0], [3]))]
        )

        self.target_dens1 = lasagne.layers.DenseLayer(
            self.target_merge_l,
            name='target_wrds_dens1',
            num_units=400,
            nonlinearity=lasagne.nonlinearities.tanh,
        )

        self.target_drop1 = lasagne.layers.DropoutLayer(
            self.target_dens1,
            p=.25,
        )

        self.target_dens2 = lasagne.layers.DenseLayer(
            self.target_drop1,
            name='target_wrds_dens1',
            num_units=compared_vector_size,
            nonlinearity=lasagne.nonlinearities.linear,
        )

        self.target_simple = lasagne.layers.DenseLayer(
            self.target_combined_feats_l,
            name='target_simple1',
            num_units=compared_vector_size,
            nonlinearity=lasagne.nonlinearities.linear,
        )

#         self.target_dens1 = lasagne.layers.DenseLayer(
#             self.target_conv1_l,
#             name='target_dens1',
#             num_units=300,
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.target_drop1 = lasagne.layers.DropoutLayer(
#             self.target_dens1,
#             p=.25,
#         )

#         self.target_dens2 = lasagne.layers.DenseLayer(
#             self.target_drop1,
#             name='target_dens2',
#             num_units=300,
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )



        #self.target_out = lasagne.layers.get_output(self.target_embedding_l)


#         self.target_out = T.concatenate(
#             [self.embedding_W[self.x_target_input],
#              matched_surface_reshaped,
#             1-matched_surface_reshaped],
#              axis=1)


        #self.target_out = self.embedding_W[self.x_target_input]
        #self.target_out = lasagne.layers.get_output(self.target_dens2)

        self.target_out = lasagne.layers.get_output(self.target_simple)

        # compute the cosine distance between the two layers
        self.source_aligned_l = self.source_out[self.x_link_id, :]

        # this uses scan internally, which means that it comes back into python code to run the loop.....fml
        self.dotted_vectors =  T.batched_dot(self.target_out, self.source_aligned_l)
        # diag also does not support a C version.........
        #self.dotted_vectors = T.dot(self.target_out, self.source_aligned_l.T).diagonal()

        def augNorm(v):
            return T.maximum(T.basic.pow(T.basic.pow(T.basic.abs_(v), 2).sum(axis=1) + .001, .5), .001)

        self.res_l = self.dotted_vectors / (augNorm(self.target_out) * augNorm(self.source_aligned_l) + .001)
#         self.res_l = self.dotted_vectors / ((self.target_out.norm(1, axis=1) + .001) *
#                                             (self.source_aligned_l.norm(1, axis=1) + .001))

        self.res_cap = T.clip((T.tanh(self.res_l) + 1) / 2, .001, .999)

        #self.golds = self.res_cap[self.y_answer]

#         def maxOverRange(indx):
#             #return T.max(self.res_cap[T.arange(indx[0],indx[1])]) - self.res_cap[indx[2]]
#             #return -( self.res_l[indx[2]] - T.log(T.exp(self.res_l[T.arange(indx[0],indx[1])]).sum()) )
#             return -( self.res_l[indx[2]] - self.res_l[indx[0]])

#         # build a tensor to make a matrix with one set on each dimention
#         self.grouped, grouped_update = theano.scan(maxOverRange, sequences=self.y_grouping)

        def setSubSelector(indx, outputs):
            return T.set_subtensor(outputs[T.arange(indx[0], indx[1]), indx[3]], 1)

        num_target_samples = self.res_l.shape[0]

        select_seq = T.concatenate([
            self.y_grouping,
            T.arange(self.y_grouping.shape[0]).reshape((self.y_grouping.shape[0], 1))
        ], axis=1)

        self.selecting_matrix, _ = theano.scan(
            setSubSelector,
            outputs_info=T.zeros((num_target_samples, num_target_samples)),
            #n_steps=self.y_grouping.shape[0]
            sequences=select_seq,
        )

        self.groupped_elems = T.dot(self.selecting_matrix[-1], T.diag(T.exp(self.res_l)))
        self.groupped_res = T.log(self.groupped_elems.sum(axis=0)[T.arange(self.y_grouping.shape[0])])
        self.loss_vec = self.groupped_res - self.res_l[self.y_grouping[:,2]]

        self.all_params = (
            #lasagne.layers.get_all_params(self.target_dens2) +
            # TODO: add params for the target stuff,
            lasagne.layers.get_all_params(self.target_simple) +
            lasagne.layers.get_all_params(self.source_dens2)
            #lasagne.layers.get_all_params(self.document_dens2)
        )

        # weight the positive samples more since there are fewer of them,
        # freaking hack
        #self.loss_vec = -(10 * self.y_score * T.log(self.res_cap) + (1.0 - self.y_score) * T.log(1.0 - self.res_cap))

        #self.loss_vec = T.nnet.binary_crossentropy(self.res_cap, self.y_score)

        #self.loss_vec = T.exp(T.max(self.res_cap - self.res_cap[self.y_answer] + .1, 0)) - 1  # TODO: maybe have some squared term here or something?

        # this one works reasonably well
        #self.loss_vec = - T.log((T.clip(self.res_cap[self.y_answer] - self.res_cap, -1.0, 0.4) + 1.0) / 1.5)

        #self.loss_vec = self.grouped

        #self.loss_vec = - T.log((T.clip(self.res_l[self.y_answer] - self.res_l, -40.0, 10.0) + 40.0) / 51.0)
        #self.loss_vec = T.max(self.res_l[self.y_answer] - self.res_l + .1, 0)

        self.updates = lasagne.updates.adadelta(self.loss_vec.mean(), self.all_params)

        self.func_inputs = [
            #self.x_document_input,
            self.x_surface_text_input, self.x_surface_context_input, #self.x_document_id,
            self.x_target_input, self.x_matches_surface, self.x_matches_counts, self.x_link_id,
            self.y_answer, self.y_grouping
        ]  # self.x_target_words,

        self.train_func = theano.function(
            self.func_inputs,
            [self.res_cap, self.loss_vec.sum(), self.loss_vec],
            updates=self.updates,
            on_unused_input='ignore',
        )

        self.test_func = theano.function(
            self.func_inputs,
            [self.res_cap, self.loss_vec.sum(), self.loss_vec],
            on_unused_input='ignore',
        )

    def reset_accums(self):
        self.current_documents = []
        self.current_surface_context = []
        self.current_surface_link = []
        self.current_link_id = []
        self.current_target_input = []
        self.current_target_words = []
        self.current_target_matches_surface = []
        self.current_target_id = []
        self.current_target_goal = []
        self.current_learning_groups = []
        self.learning_targets = []
        self.current_surface_target_counts = []
        
        
            
    def compute_batch(self, isTraining=True, useTrainingFunc=True):
        if isTraining and useTrainingFunc:
            func = self.train_func
        else:
            func = self.test_func
        self.reset_accums()
        self.total_links = 0
        self.total_loss = 0.0
        
        self.failed_match = []
        self.failed_page_match = []

        get_words = re.compile('[^a-zA-Z0-9 ]')
        get_link = re.compile('.*?\[(.*?)\].*?')

        for doc, queries in self.queries.iteritems():
            # skip the testing documents while training and vice versa
            if queries.values()[0]['training'] != isTraining:
                continue
            docid = len(self.current_documents)
            self.current_documents.append(self.wordvecs.tokenize(doc, length=self.document_length))
            for surtxt, targets in queries.iteritems():
                self.current_link_id.append(docid)
                surid = len(self.current_surface_link)
                self.current_surface_context.append(self.wordvecs.tokenize(get_words.sub(' ' , surtxt)))
                surlink = get_link.match(surtxt).group(1)
                self.current_surface_link.append(self.wordvecs.tokenize(surlink))
                surmatch = surlink.lower()
                surcounts = self.surface_counts.get(surmatch)
                if not surcounts:
                    self.failed_match.append(surmatch)
                    surcounts = {}
                #target_page_input = []
                target_words_input = []
                target_matches_surface = []
                target_inputs = []
                target_learings = []
                target_match_counts = []
                target_gold_loc = -1
                target_group_start = len(self.current_target_input)
                for target in set(targets['vals'].keys() + random.sample(self.documentvecs.reverse_word_location, 1)) - {None,}:
                    # skip the items that we don't know the gold for
                    if not targets['gold'] and isTraining:
                        continue
                    isGold = target == targets['gold']
                    #cnt = self.page_content.get(WikiRegexes.convertToTitle(target))
                    wiki_title = WikiRegexes.convertToTitle(target)
                    cnt = self.documentvecs.get_location(wiki_title)
                    if wiki_title == 'nil':
                        cnt = 0  # this is the stop symbol location
                    if cnt is None: # or wiki_title == 'nil':
                        # were not able to find this wikipedia document
                        # so just ignore tihs result since trying to train on it will cause
                        # issues
                        # 
                        # there are also nil queries that are generated for every document
                        # but we actually have a nil page that is getting referenced
                        # so just filter it out for now
                        continue
                    if isGold:
                        target_gold_loc = len(target_inputs)
                    #target_page_input.append(cnt)
                    target_words_input.append(self.wordvecs.tokenize(get_words.sub(' ', target)))
                    target_inputs.append(cnt)  # page_content already tokenized
                    target_matches_surface.append(int(surmatch == target.lower()))
                    target_learings.append((targets, target))
                    tmc = surcounts.get(wiki_title, 0)
                    if tmc is 0:
                        self.failed_page_match.append((surcounts, wiki_title))
                    target_match_counts.append(tmc)
                    #if wiki_title not in surcounts:
                    #    print surcounts, wiki_title
                if target_gold_loc is not -1 or not isTraining:  # if we can't get the gold item
                    # contain the index of the gold item for these items, so it can be less then it
                    gold_loc = (len(self.current_target_goal) + target_gold_loc)
                    sorted_match_counts = [-4,-3,-2,-1] + sorted(set(target_match_counts))
                    #print sorted_match_counts
                    target_match_counts_indicators = [
                        [
                            int(s == sorted_match_counts[-1]),
                            int(s == sorted_match_counts[-2]),
                            int(s == sorted_match_counts[-3]),
                            int(s <= sorted_match_counts[-4]),
                            int(s == 0),  # this link has never been seen with this surface
                        ]
                        for s in target_match_counts
                    ]
                    self.current_target_goal += [gold_loc] * len(target_inputs)
                    self.current_target_input += target_inputs
                    self.current_target_id += [surid] * len(target_inputs)
                    self.current_target_words += target_words_input   # TODO: add
                    self.current_target_matches_surface += target_matches_surface
                    self.current_surface_target_counts += target_match_counts_indicators
                    target_group_end = len(self.current_target_input)
                    self.current_learning_groups.append(
                        [target_group_start, target_group_end,
                         gold_loc])

                #self.current_target_goal.append(isGold)
                self.learning_targets += target_learings
            if len(self.current_target_id) > self.batch_size:
                self.run_batch(func)
                if self.total_links > self.num_training_items:
                    return self.total_loss / self.total_links

        if len(self.current_target_id) > 0:
            self.run_batch(func)

        return self.total_loss / self.total_links

    def run_batch(self, func):
        res_vec, loss_sum, loss_vec = func(
            #self.current_documents,
            self.current_surface_link, self.current_surface_context, #self.current_link_id,
            self.current_target_input, self.current_target_matches_surface, self.current_surface_target_counts, self.current_target_id,
            self.current_target_goal, self.current_learning_groups,
            # self.current_target_words,
        )
        self.check_params()
        self.total_links += len(self.current_target_id)
        self.total_loss += loss_sum
        for i in xrange(len(res_vec)):
            # save the results from this pass
            l = self.learning_targets[i]
            if l[1] in l[0]['vals']:
                l[0]['vals'][ l[1] ] = float(res_vec[i])
        self.reset_accums()

    def check_params(self):
        if any([np.isnan(v.get_value(borrow=True)).any() for v in self.all_params]):
            raise RuntimeError('nan in some of the parameters')



queries_exp = EntityVectorLinkExp()

# %%
def evalCurrentState(trainingData=True, numSamples=50000):
    all_measured = 0
    all_correct = 0
    all_trained = 0
    for qu in queries.values():
        for en in qu.values():
            if en['training'] != trainingData:
                continue
            for e in en:
                if en['gold']:
                    if all_trained > numSamples:
                        break
                    all_measured += 1
                    all_trained += len(en['vals'].values())
                    m = max(en['vals'].values())
                    if en['vals'][en['gold']] == m and m != 0:
                        all_correct += 1
           
    r = all_measured, float(all_correct) / all_measured
    print r
    return r

# %%
import random
def augmentTrainingData():
    for quk in queries.keys():
        qu = queries[quk]
        for enk in qu.keys():
            en = qu[enk]
            if not en['gold']:
                del qu[enk]
        if not qu:
            del queries[quk]
    for qu in queries.values():
        training = random.random() > .15
        for en in qu.values():
            en['training'] = training
augmentTrainingData()

# %%
def findWrongItems(trainingData=True, numSamples=50):
    ret = {}
    for qu in queries.values():
        for ek, en in qu.items():
            if en['training'] != trainingData:
                continue
            for e in en:
                if en['gold']:
                    if len(ret) > numSamples:
                        return ret
                    m = max(en['vals'].values())
                    g = en['vals'][en['gold']]
                    if g != m and g != 0:
                        ret[ek] = en
    return ret

# %%
queries_exp.check_params()

# %%
queries_exp.num_training_items = 50000

# %%
# %time print queries_exp.compute_batch()
# Out:
# 0.174694755739
# CPU times: user 5min 1s, sys: 1.62 s, total: 5min 3s
# Wall time: 41.3 s

# %%
len(queries_exp.current_surface_target_counts)
# Out:
# 1192

# %%
evalCurrentState(False, 500000)

# %%
evalCurrentState(True, 500000)

# %%
queries_exp.embedding_W_docs.get_value(borrow=True).shape, len(queries_exp.documentvecs.reverse_word_location)
# Out:
# ((443223, 300), 443223)

# %%
exp_results = []

for i in xrange(5):
    res = (i, queries_exp.compute_batch())
    print res
    exp_results.append(res)
exp_results.append(('testing run', queries_exp.compute_batch(False)))
exp_results.append(('training state', evalCurrentState(True, queries_exp.num_training_items)))
exp_results.append(('testing state', evalCurrentState(False, queries_exp.num_training_items)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-dad567c7a634> in <module>()
#       2
#       3 for i in xrange(5):
# ----> 4     res = (i, queries_exp.compute_batch())
#       5     print res
#       6     exp_results.append(res)
#
# <ipython-input-73-83898ffca30a> in compute_batch(self, isTraining, useTrainingFunc)
#     560                 self.learning_targets += target_learings
#     561             if len(self.current_target_id) > self.batch_size:
# --> 562                 self.run_batch(func)
#     563                 if self.total_links > self.num_training_items:
#     564                     return self.total_loss / self.total_links
#
# <ipython-input-73-83898ffca30a> in run_batch(self, func)
#     574             self.current_surface_link, self.current_surface_context, #self.current_link_id,
#     575             self.current_target_input, self.current_target_matches_surface, self.current_surface_target_counts, self.current_target_id,
# --> 576             self.current_target_goal, self.current_learning_groups,
#     577             # self.current_target_words,
#     578         )
#
# /home/matthew/.virtualenvs/nlp-convnet/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     616                         self.fn.nodes[self.fn.position_of_error],
#     617                         self.fn.thunks[self.fn.position_of_error],
# --> 618                         storage_map=self.fn.storage_map)
#     619                 else:
#     620                     # For the c linker We don't have access from
#
# /home/matthew/.virtualenvs/nlp-convnet/lib/python2.7/site-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     295     exc_value = exc_type(str(exc_value) + detailed_err_msg +
#     296                          '\n' + '\n'.join(hints))
# --> 297     reraise(exc_type, exc_value, exc_trace)
#     298
#     299
#
# /home/matthew/.virtualenvs/nlp-convnet/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     605         t0_fn = time.time()
#     606         try:
# --> 607             outputs = self.fn()
#     608         except Exception:
#     609             if hasattr(self.fn, 'position_of_error'):
#
# ValueError: Shape mismatch: x has 306 cols (and 1171 rows) but y has 305 rows (and 300 cols)
# Apply node that caused the error: Dot22(Flatten{2}.0, target_simple1.W)
# Toposort index: 117
# Inputs types: [TensorType(float32, matrix), TensorType(float32, matrix)]
# Inputs shapes: [(1171, 306), (305, 300)]
# Inputs strides: [(1224, 4), (1200, 4)]
# Inputs values: ['not shown', 'not shown']
# Outputs clients: [[Elemwise{Add}[(0, 0)](Dot22.0, InplaceDimShuffle{x,0}.0)]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %%
exp_results
# Out:
# [(0, 0.15946863750190246),
#  (1, 0.14354439461208524),
#  (2, 0.13453909171886852),
#  (3, 0.12813660094679058),
#  (4, 0.12271951852324518),
#  ('testing run', 0.13356538229420903),
#  ('training state', (2879, 0.3261549149010073)),
#  ('testing state', (2936, 0.5217983651226158))]

# %%
findWrongItems(False)  # testing set
# Out:
# {u' [Muslim mathematicians] developed spherical trigonometry which was used in these calculations .': {u'gold': u'Mathematics in medieval Islam',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12409600615501404,
#    u'Applied mathematics': 0.29027414321899414,
#    u'Babylonian mathematics': 0.31433790922164917,
#    u'Chinese mathematics': 0.28549909591674805,
#    u'Greek mathematics': 0.411783903837204,
#    u'Hartley transform': 0.14748913049697876,
#    u'Indian mathematics': 0.69034743309021,
#    u'Islamic mathematician': 0.5812787413597107,
#    u'Islamic mathematics': 0.5812787413597107,
#    u'Lists of mathematicians': 0.19155961275100708,
#    u'Mathematician': 0.8341688513755798,
#    u'Mathematicians': 0.8341688513755798,
#    u'Mathematics': 0.4196942448616028,
#    u'Mathematics in medieval Islam': 0.6838878393173218,
#    u'Muslim mathematicians': 0.6391451358795166,
#    u'XXNILXX': 0,
#    u'list of mathematicians': 0.19155961275100708,
#    u'mathematician': 0.8341688513755798,
#    u'mathematicians': 0.8341688513755798,
#    u'mathematics': 0.4196942448616028}},
#  u', 280 lb -LRB- 2.13 m , 125 kg -RRB- [center] played four seasons in the NBA before being forced to': {u'gold': u'Center (basketball)',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12506410479545593,
#    u'Basketball position': 0.749434769153595,
#    u'Basketball positions': 0.749434769153595,
#    u'Center': 0.2429826259613037,
#    u'Center (American and Canadian football)': 0.6181748509407043,
#    u'Center (American football)': 0.6181748509407043,
#    u'Center (algebra)': 0.20443058013916016,
#    u'Center (basketball)': 0.716295599937439,
#    u'Center (gridiron football)': 0.6190576553344727,
#    u'Center (group theory)': 0.2911992073059082,
#    u'Center (ice hockey)': 0.17102164030075073,
#    u'Center, Colorado': 0.14897599816322327,
#    u'Center, Texas': 0.15792465209960938,
#    u'Centre (geometry)': 0.1606692671775818,
#    u'Centre (ice hockey)': 0.17458194494247437,
#    u'XXNILXX': 0,
#    u'center (American football)': 0.6181748509407043,
#    u'center (basketball)': 0.716295599937439,
#    u'center (group theory)': 0.2911992073059082,
#    u'center (ice hockey)': 0.17102164030075073}},
#  u', a forested peninsula off south Seattle that juts into [Lake Washington] .': {u'gold': u'Lake Washington',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12336233258247375,
#    u'Lake Washington': 0.6324709057807922,
#    u'Lake Washington (Florida)': 0.18640777468681335,
#    u'Lake Washington (Melbourne)': 0.15733984112739563,
#    u'Lake Washington (Mississippi)': 0.14442047476768494,
#    u'Lake Washington (New York)': 0.1633588969707489,
#    u'Lake Washington High School': 0.270962655544281,
#    u'Lake Washington steamboats and ferries': 0.2200409471988678,
#    u'Lake Washington, FL': 0.18542933464050293,
#    u'Steamboats of Lake Washington': 0.2200409471988678,
#    u'University of Washington': 0.791854202747345,
#    u'Washington': 0.8288960456848145,
#    u'Washington (U.S. state)': 0.8586748838424683,
#    u'Washington (state)': 0.8586748838424683,
#    u'Washington County, New York': 0.40251654386520386,
#    u'Washington Huskies football': 0.756345808506012,
#    u'Washington Mystics': 0.5473150014877319,
#    u'Washington Wizards': 0.8031911849975586,
#    u'Washington, D.C.': 0.8673362731933594,
#    u'XXNILXX': 0}},
#  u"-LRB- Pickering , and St. Andrew 's -RRB- and the [Urban District] of Haltemprice . 1955-1983 : The constituency lost the Kingston": {u'gold': u'Urban District',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12544912099838257,
#    u'Bakhsh': 0.7203884720802307,
#    u'Banstead': 0.18592026829719543,
#    u'Chengqu, Changzhi': 0,
#    u'Districts of England': 0.1612512469291687,
#    u'Districts of Serbia': 0.25758999586105347,
#    u'Districts of Sri Lanka': 0.16798517107963562,
#    u'Districts of Turkey': 0.2005937397480011,
#    u'Districts of the Czech Republic': 0.20357736945152283,
#    u'Independent cities of Germany': 0.1536092758178711,
#    u'List of districts of Nepal': 0.2166684865951538,
#    u'List of districts of Serbia': 0.25758999586105347,
#    u'List of districts of Turkey': 0.2005937397480011,
#    u'List of districts of the Czech Republic': 0.20357736945152283,
#    u'List of urban districts of Vietnam': 0.13625329732894897,
#    u'Urban District': 0.278057724237442,
#    u'Urban district': 0.278057724237442,
#    u'Urban district (Great Britain and Ireland)': 0.2453623116016388,
#    u'Urban districts of Germany': 0.15368708968162537,
#    u'XXNILXX': 0}},
#  u'-RRB- park in Seattle , Washington that occupies all of [Bailey Peninsula] , a forested peninsula off south Seattle that juts into': {u'gold': u'Bailey Peninsula',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12465983629226685,
#    u'Bailey Peninsula': 0.3155444264411926,
#    u'Bailey Peninsula (Antarctica)': 0.5660134553909302,
#    u'Cape Peninsula': 0.28974753618240356,
#    u'Iberian Peninsula': 0.7512129545211792,
#    u'Monash University, Peninsula campus': 0.15880441665649414,
#    u'PenAir': 0.5835431218147278,
#    u'Peninsula': 0.48576095700263977,
#    u'Peninsula (New Zealand electorate)': 0.25778651237487793,
#    u'Peninsula / F\xe9lsziget Festival': 0.2719060480594635,
#    u'Peninsula Campaign': 0.6126417517662048,
#    u'Peninsula Eastern Sami languages': 0,
#    u'Peninsula Panthers': 0,
#    u'Peninsula Pilots': 0.16058483719825745,
#    u'Peninsula War': 0.6660807132720947,
#    u'Peninsula, Ohio': 0.6720591187477112,
#    u'Peninsular War': 0.6660807132720947,
#    u'San Francisco Peninsula': 0.4101003408432007,
#    u'Virginia Peninsula': 0.34589970111846924,
#    u'XXNILXX': 0}},
#  u'. 1950-1955 : The constituency comprised two wards of the [County Borough] of Kingston upon Hull -LRB- Pickering , and St. Andrew': {u'gold': u'County borough',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12326997518539429,
#    u'Borough': 0.18780294060707092,
#    u'Borough (New Jersey)': 0.2478857934474945,
#    u'Borough (New York City)': 0.16000708937644958,
#    u'Borough (Pennsylvania)': 0.20067867636680603,
#    u'Borough constituency': 0.171970397233963,
#    u'Borough status in the United Kingdom': 0.18166539072990417,
#    u'Borough tube station': 0.1611722707748413,
#    u'Boroughs of Montreal': 0.1396772265434265,
#    u'County Borough': 0.22579562664031982,
#    u'County Borough of Croydon': 0.2360086739063263,
#    u'County Borough of Dudley': 0.15973278880119324,
#    u'County borough': 0.22579562664031982,
#    u'Derry': 0.6434953212738037,
#    u'Merthyr Tydfil County Borough': 0.22715365886688232,
#    u'Northern Ireland Parliament constituencies': 0.14348456263542175,
#    u'Parliamentary Borough': 0.171970397233963,
#    u'United Kingdom constituencies': 0.17203357815742493,
#    u'XXNILXX': 0,
#    u'county borough': 0.22579562664031982}},
#  u'1.1 % , Buddhism 1 % , other non - [Christian] 1.5 % , unspecified 0.5 % , none 0.2 %': {u'gold': u'Christian',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12360697984695435,
#    u'Arab Christians': 0.5615602135658264,
#    u'Christian': 0.8109757900238037,
#    u'Christian (wrestler)': 0.33780521154403687,
#    u'Christian Corr\xeaa Dionisio': 0.1439032256603241,
#    u'Christian County, Illinois': 0.20193606615066528,
#    u'Christian County, Kentucky': 0.18105220794677734,
#    u'Christian County, Missouri': 0.2410026490688324,
#    u'Christian Fern\xe1ndez Salas': 0,
#    u'Christian denomination': 0.7667306065559387,
#    u'Christian metal': 0.3474527895450592,
#    u'Christian music': 0.47120264172554016,
#    u'Christian radio': 0.3639238476753235,
#    u'Christian rock': 0.5354669690132141,
#    u'Christian school': 0.22053062915802002,
#    u'Christianity': 0.8442738056182861,
#    u'Christianity in Lebanon': 0.731093168258667,
#    u'Christianity in Sri Lanka': 0.20329177379608154,
#    u'Contemporary Christian music': 0.705868124961853,
#    u'XXNILXX': 0}},
#  u'Abul-Hasan ibn al-Manaadi , [Abu Muhammad Ibn Hazm] , and Abul-Faraj Ibn Al-Jawzi have said that the Muslim': {u'gold': u'Ibn Hazm',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.8321545124053955,
#    u'Abu Muhammad Ibn Hazm': 0,
#    u'Al Hazm (football club)': 0.4825435280799866,
#    u'Hazem': 0.34460577368736267,
#    u'Hazm': 0.34460577368736267,
#    u'Hazm, Hama': 0,
#    u'Ibn Hazm': 0.8055557608604431,
#    u'Muhammad Ibn Hazm': 0,
#    u'XXNILXX': 0}},
#  u"All examples in this section assume the [WGS 84] datum , with an equatorial radius '' a '' of": {u'gold': u'World Geodetic System',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.1242106556892395,
#    u'WGS': 0.7637437582015991,
#    u'WGS 84': 0.5485287308692932,
#    u'Wideband Global SATCOM': 0.16489574313163757,
#    u'Wideband Global SATCOM system': 0.16489574313163757,
#    u'Wideband Global Satcom': 0.16489574313163757,
#    u'Wideband Global System': 0,
#    u'World Geodetic System': 0.5969204902648926,
#    u'XXNILXX': 0}},
#  u'Anglican 6.4 % , Seventh-day Adventist 1.1 % , other [Christian] 3.4 % , Hindu 2.1 % , Muslim 1.1 %': {u'gold': u'Christian',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12436041235923767,
#    u'Arab Christians': 0.5558668971061707,
#    u'Christian': 0.8073558807373047,
#    u'Christian (wrestler)': 0.3378678560256958,
#    u'Christian Corr\xeaa Dionisio': 0.1427922248840332,
#    u'Christian County, Illinois': 0.19852489233016968,
#    u'Christian County, Kentucky': 0.18008756637573242,
#    u'Christian County, Missouri': 0.23824027180671692,
#    u'Christian Fern\xe1ndez Salas': 0,
#    u'Christian denomination': 0.765442967414856,
#    u'Christian metal': 0.3486102223396301,
#    u'Christian music': 0.4662778973579407,
#    u'Christian radio': 0.3658328056335449,
#    u'Christian rock': 0.5331107378005981,
#    u'Christian school': 0.223038911819458,
#    u'Christianity': 0.8412708640098572,
#    u'Christianity in Lebanon': 0.729966402053833,
#    u'Christianity in Sri Lanka': 0.20633786916732788,
#    u'Contemporary Christian music': 0.7007945775985718,
#    u'XXNILXX': 0}},
#  u'Ashharatsuyts reports details and mapping of the ancient homeland of [Bulgars] in the Mount Imeon area of Central Asia .': {u'gold': u'Bulgars',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12460198998451233,
#    u'Bogomilism': 0.7566210031509399,
#    u'Bolghar': 0.6493263244628906,
#    u'Bulgar': 0.3248382806777954,
#    u'Bulgar (music)': 0,
#    u'Bulgar (newspaper)': 0,
#    u'Bulgar (tabloid)': 0,
#    u'Bulgar calendar': 0.16593942046165466,
#    u'Bulgar language': 0.24892425537109375,
#    u'Bulgarians': 0.7741538286209106,
#    u'Bulgarians in Romania': 0.45713353157043457,
#    u'Bulgars': 0.6488401889801025,
#    u'First Bulgarian Empire': 0.7039670944213867,
#    u'Medieval Bulgarian Army': 0.28871089220046997,
#    u'Medieval Bulgarian army': 0.28871089220046997,
#    u'Military history of Bulgaria during World War II': 0.449883371591568,
#    u'Oghur languages': 0.33837002515792847,
#    u'Second Bulgarian Empire': 0.40519407391548157,
#    u'Volga Bulgaria': 0.7621972560882568,
#    u'XXNILXX': 0}},
#  u"CE , Caliph al-Ma ' mun commissioned a group of [Muslim astronomers] and geographers to measure the distance from Tadmur -LRB- Palmyra": {u'gold': u'Astronomy in medieval Islam',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.1271335780620575,
#    u'Ancient Greek astronomy': 0.6402540802955627,
#    u'Astrology and astronomy': 0.21062049269676208,
#    u'Astronomer': 0.849202036857605,
#    u'Astronomer (comics)': 0.19628256559371948,
#    u'Astronomers': 0.849202036857605,
#    u'Astronomy': 0.7539719939231873,
#    u'Astronomy in medieval Islam': 0.7609851360321045,
#    u'Astronomy in medieval Islam ': 0,
#    u'Chinese astronomy': 0.21179524064064026,
#    u'Indian astronomy': 0.24133726954460144,
#    u'Islamic astronomy': 0.7200488448143005,
#    u'List of Muslim astronomers': 0.1507929563522339,
#    u'List of Wild Cards characters': 0.6528047323226929,
#    u'Muslim astronomers': 0.2155497670173645,
#    u'The Astronomer (Wild Cards)': 0.6528047323226929,
#    u'XXNILXX': 0,
#    u'astronomer': 0.849202036857605,
#    u'astronomers': 0.849202036857605,
#    u'astronomy': 0.7539719939231873}},
#  u"Especially in the [German] speaking world , geodesy is divided into geomensuration -LRB- ''": {u'gold': u'German language',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12391027808189392,
#    u'Cinema of Germany': 0.4278409779071808,
#    u'German': 0.8256109356880188,
#    u'German (language)': 0.4919510781764984,
#    u'German American': 0.8489240407943726,
#    u'German Empire': 0.7848407030105591,
#    u'German Language': 0.4926564693450928,
#    u'German language': 0.4926564693450928,
#    u'German literature': 0.7704876661300659,
#    u'German people': 0.8173393607139587,
#    u'German poetry': 0.7704876661300659,
#    u'Germans': 0.8208804726600647,
#    u'Germany': 0.8610596656799316,
#    u'GfK Entertainment': 0.21047979593276978,
#    u'Kriegsmarine': 0.474618136882782,
#    u'Nazi Germany': 0.8377581834793091,
#    u'Wehrmacht': 0.8287162780761719,
#    u'XXNILXX': 0,
#    u'german people': 0.8173393607139587,
#    u'germans': 0.8208804726600647}},
#  u'French , African , India n , Chinese , and [Arab] Roman Catholic 82.2 % , Anglican 6.4 % , Seventh-day': {u'gold': u'Arab people',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12331733107566833,
#    u'Arab': 0.8268610239028931,
#    u'Arab American': 0.8247870206832886,
#    u'Arab Canadian': 0.23263609409332275,
#    u'Arab Canadians': 0.23263609409332275,
#    u'Arab League': 0.8257236480712891,
#    u'Arab citizens of Israel': 0.5689276456832886,
#    u'Arab cuisine': 0.33302193880081177,
#    u'Arab culture': 0.6730080246925354,
#    u'Arab people': 0.8183478116989136,
#    u'Arab world': 0.8324273824691772,
#    u'Arab, Alabama': 0.2100287675857544,
#    u'Arabian horse': 0.4514043927192688,
#    u'Arabic language': 0.800075352191925,
#    u'Arabic music': 0.3861478567123413,
#    u'Arabs': 0.8328899145126343,
#    u'British Arabs': 0.30844271183013916,
#    u'History of Arabs in Afghanistan': 0.3077554702758789,
#    u'Palestinian people': 0.8426039814949036,
#    u'XXNILXX': 0}},
#  u'His estimate of 6,339.9 km for the [Earth radius] was only 16.8 km less than the modern value of': {u'gold': u'Earth radius',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.1279948353767395,
#    u'Distance (graph theory)': 0.19262272119522095,
#    u'Earth': 0.381351113319397,
#    u'Earth radius': 0.2890002727508545,
#    u'Minimum railway curve radius': 0.6573425531387329,
#    u'Planetary radius': 0,
#    u'Radiu': 0,
#    u'Radius': 0.2413005828857422,
#    u'Radius (bone)': 0.15479865670204163,
#    u'Radius (comics)': 0.1774705946445465,
#    u'Radius (company)': 0.1391029953956604,
#    u'Radius (computer)': 0.15524661540985107,
#    u'Radius (music ensemble)': 0,
#    u'Radius_(company)': 0.1391029953956604,
#    u'Solar radius': 0.17026865482330322,
#    u'XXNILXX': 0,
#    u'radiu': 0,
#    u'radius': 0.2413005828857422,
#    u'radius (bone)': 0.15479865670204163,
#    u'solar radius': 0.17026865482330322}},
#  u'It gained the Metropolitan Borough of Beverley and the [Rural District] of Beverley -LRB- from the former Beverley constituency -RRB- .': {u'gold': u'Rural district',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12294229865074158,
#    u'Administrative divisions of Iran': 0.19831478595733643,
#    u'Bakhsh': 0.7239425778388977,
#    u'Districts of Serbia': 0.25551915168762207,
#    u'Districts of Sri Lanka': 0.16883182525634766,
#    u'Districts of Turkey': 0.19716095924377441,
#    u'Districts of the Czech Republic': 0.1981143057346344,
#    u'List of districts of Nepal': 0.22476941347122192,
#    u'List of districts of Serbia': 0.25551915168762207,
#    u'List of districts of Turkey': 0.19716095924377441,
#    u'List of districts of the Czech Republic': 0.1981143057346344,
#    u'Rural District': 0.1869603991508484,
#    u'Rural District (kermanshah Province)': 0,
#    u'Rural Districts of Iran': 0.183138906955719,
#    u'Rural Districts of Pakistan': 0,
#    u'Rural district': 0.1869603991508484,
#    u'Warmley Rural District': 0,
#    u'Western Area Rural District': 0.3062232732772827,
#    u'XXNILXX': 0,
#    u'Zwickauer Land': 0.18618816137313843}},
#  u'It gained the Metropolitan Borough of [Beverley] and the Rural District of Beverley -LRB- from the former': {u'gold': u'Beverley',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12403929233551025,
#    u'Beverley': 0.25576406717300415,
#    u'Beverley (UK Parliament constituency)': 0.15209582448005676,
#    u'Beverley (borough)': 0.15267685055732727,
#    u'Beverley Minster': 0.15360483527183533,
#    u'Beverley RUFC': 0.1356486976146698,
#    u'Beverley Racecourse': 0.15954148769378662,
#    u'Beverley Rural District': 0.14824160933494568,
#    u'Beverley Uranium Mine': 0.1941940188407898,
#    u'Beverley railway station': 0.15027236938476562,
#    u'Beverley, Saskatchewan': 0,
#    u'Beverley, South Australia': 0.211463063955307,
#    u'Beverley, Western Australia': 0.4119758605957031,
#    u'Blackburn Beverley': 0.5909945964813232,
#    u'Cliff Beverley': 0.49553382396698,
#    u'Diocese of Beverley': 0.16582882404327393,
#    u'Electoral district of Beverley': 0.20537623763084412,
#    u'Patrick Beverley': 0.21978631615638733,
#    u'Shire of Beverley': 0.14076170325279236,
#    u'XXNILXX': 0}},
#  u'It gained the [Metropolitan Borough] of Beverley and the Rural District of Beverley -LRB- from': {u'gold': u'Metropolitan borough',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12432911992073059,
#    u'Borough': 0.18601948022842407,
#    u'Borough (New Jersey)': 0.24590831995010376,
#    u'Borough (New York City)': 0.16101250052452087,
#    u'Borough (Pennsylvania)': 0.1982138752937317,
#    u'Borough constituency': 0.17243307828903198,
#    u'Borough status in the United Kingdom': 0.17994391918182373,
#    u'Borough tube station': 0.16472670435905457,
#    u'Boroughs of Montreal': 0.13962861895561218,
#    u'Metropolitan Borough': 0.18268778920173645,
#    u'Metropolitan Borough of Bolton': 0.20772120356559753,
#    u'Metropolitan Borough of Hackney': 0.4249066114425659,
#    u'Metropolitan Borough of Rochdale': 0.15069082379341125,
#    u'Metropolitan Borough of Westminster': 0.16773012280464172,
#    u'Metropolitan Borough of Wigan': 0.17947986721992493,
#    u'Metropolitan borough': 0.18268778920173645,
#    u'Metropolitan boroughs of the County of London': 0.16276419162750244,
#    u'Northern Ireland Parliament constituencies': 0.14352846145629883,
#    u'United Kingdom constituencies': 0.17243307828903198,
#    u'XXNILXX': 0}},
#  u'It returned one Member of Parliament to the [House of Commons] of the Parliament of the United Kingdom .': {u'gold': u'House of Commons of the United Kingdom',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12437611818313599,
#    u'British House of Commons': 0.5319228172302246,
#    u'Canadian House of Commons': 0.37095826864242554,
#    u'Chambers of parliament': 0.17857292294502258,
#    u'Dynasty': 0.3330432176589966,
#    u'Gregory House': 0.4800487756729126,
#    u'House': 0.22570589184761047,
#    u'House (TV series)': 0.5791049599647522,
#    u'House Commons': 0,
#    u'House music': 0.5445082187652588,
#    u'House of': 0.3330432176589966,
#    u'House of Commons': 0.19876718521118164,
#    u'House of Commons of Canada': 0.3867841362953186,
#    u'House of Commons of England': 0.20375707745552063,
#    u'House of Commons of Great Britain': 0.23908406496047974,
#    u'House of Commons of the United Kingdom': 0.6230002641677856,
#    u'Minnesota House of Representatives': 0.6197094321250916,
#    u'Oklahoma House of Representatives': 0.5128757357597351,
#    u'United States House of Representatives': 0.8524812459945679,
#    u'XXNILXX': 0}},
#  u'It returned one [Member of Parliament] to the House of Commons of the Parliament of the': {u'gold': u'Member of parliament',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12444093823432922,
#    u'Deputies of the 12th French National Assembly': 0.1730472445487976,
#    u'List of members of the National Assembly of France, 2002\u201307': 0.1730472445487976,
#    u'Member': 0.8154033422470093,
#    u'Member Parliament': 0,
#    u'Member of': 0.18675929307937622,
#    u'Member of Parliament': 0.764003574848175,
#    u'Member of Parliament (Tanzania)': 0.6097142696380615,
#    u'Member of Parliament (UK)': 0.6951558589935303,
#    u'Member of Parliament (United Kingdom)': 0.6951558589935303,
#    u'Member of parliament': 0.764003574848175,
#    u'Member of the Legislative Assembly': 0.39134326577186584,
#    u'Member of the Legislative Assembly (India)': 0.4499255120754242,
#    u'Member of the Provincial Assembly': 0.48788487911224365,
#    u'Member of the Scottish Parliament': 0.7050343751907349,
#    u'National Assembly (Tanzania)': 0.6350789070129395,
#    u'Parliament of India': 0.7244483232498169,
#    u'Set (mathematics)': 0.18569490313529968,
#    u'XXNILXX': 0,
#    u'set (mathematics)': 0.18569490313529968}},
#  u'It was created for the [1950 general election] , and abolished for the 1983 general election .': {u'gold': u'United Kingdom general election, 1950',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12444135546684265,
#    u'British Virgin Islands general election, 1950': 0.31123876571655273,
#    u'Election': 0.33108142018318176,
#    u'Election (1999 film)': 0.2396630048751831,
#    u'Election (2005 film)': 0.20955711603164673,
#    u'Election (horse)': 0.18901658058166504,
#    u'General election': 0.6605079770088196,
#    u'Greek legislative election, 1950': 0.297859251499176,
#    u'Irish general election, 2007': 0.4960463345050812,
#    u'Philippine general election, 2007': 0.4164070188999176,
#    u'Royal elections in Poland': 0.41810500621795654,
#    u'Turkish general election, 1950': 0.20898398756980896,
#    u'UK general election, 1950': 0.4355851411819458,
#    u'United Kingdom general election, 1950': 0.5373879075050354,
#    u'United Kingdom general election, 1979': 0.4326973855495453,
#    u'United Kingdom general election, 2005': 0.26892024278640747,
#    u'United Kingdom general election, 2010': 0.20302227139472961,
#    u'XXNILXX': 0,
#    u'election': 0.33108142018318176,
#    u'general election': 0.6605079770088196}},
#  u"J. O'Connor and Edmund F. Robertson write in the '' [MacTutor History of Mathematics archive] '' : Many Islamic scholars declared a mutual agreement -LRB-": {u'gold': u'MacTutor History of Mathematics archive',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12396353483200073,
#    u'History': 0.3925125002861023,
#    u'History (European TV channel)': 0.7850311398506165,
#    u'History (Exo song)': 0.1623811423778534,
#    u'History (TV channel)': 0.7850311398506165,
#    u'History (U.S. TV channel)': 0.7850311398506165,
#    u'History (journal)': 0.19862860441207886,
#    u'History of': 0,
#    u'History of Arda': 0.2208859622478485,
#    u'History of Indiana': 0.3658474087715149,
#    u'History of Ireland': 0.5228725671768188,
#    u'History of Mathematics': 0.2788046598434448,
#    u'History of communism': 0.3533862829208374,
#    u'History of mathematics': 0.2788046598434448,
#    u'History of the Israeli\u2013Palestinian conflict': 0.14248305559158325,
#    u'MacTutor History': 0,
#    u'MacTutor History Mathematics archive': 0,
#    u'MacTutor History of Mathematics archive': 0.3193128705024719,
#    u'Pulitzer Prize for History': 0.3739914298057556,
#    u'XXNILXX': 0}},
#  u'Member of Parliament to the House of Commons of the [Parliament of the United Kingdom] .': {u'gold': u'Parliament of the United Kingdom',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12757137417793274,
#    u'British Parliament': 0.45157939195632935,
#    u'New Zealand Parliament': 0.6989654302597046,
#    u'Palace of Westminster': 0.557335376739502,
#    u'Parliament': 0.5526946187019348,
#    u'Parliament (band)': 0.7627198696136475,
#    u'Parliament United Kingdom': 0,
#    u'Parliament of': 0,
#    u'Parliament of Canada': 0.45316919684410095,
#    u'Parliament of England': 0.2868674397468567,
#    u'Parliament of Great Britain': 0.38228079676628113,
#    u'Parliament of India': 0.7260957956314087,
#    u'Parliament of Northern Ireland': 0.7102828025817871,
#    u'Parliament of the': 0,
#    u'Parliament of the Czech Republic': 0.5215817093849182,
#    u'Parliament of the United': 0,
#    u'Parliament of the United Kingdom': 0.6006091833114624,
#    u'UK Parliament': 0.45157939195632935,
#    u'Waterford City (UK Parliament constituency)': 0.20075711607933044,
#    u'XXNILXX': 0}},
#  u'Seward Park is a 300 acre -LRB- 120 ha -RRB- [park] in Seattle , Washington that occupies all of Bailey Peninsula': {u'gold': u'Park',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12374043464660645,
#    u'Baseball park': 0.283577561378479,
#    u'Black Moshannon State Park': 0.1945466697216034,
#    u'Chan Ho Park': 0.4452110826969147,
#    u'Deer park (England)': 0.1648229956626892,
#    u'Park': 0.19712120294570923,
#    u'Park (Korean name)': 0.3244275450706482,
#    u'Park (Korean surname)': 0.3244275450706482,
#    u'Park County, Colorado': 0.2336006462574005,
#    u'Park County, Montana': 0.20447522401809692,
#    u'Park County, Wyoming': 0.1694066822528839,
#    u'Park Ji-Sung': 0.18934795260429382,
#    u'Park Ji-sung': 0.18934795260429382,
#    u'Stadium': 0.29489871859550476,
#    u'Urban park': 0.17616671323776245,
#    u'XXNILXX': 0,
#    u'baseball park': 0.283577561378479,
#    u'medieval deer park': 0.16244390606880188,
#    u'park': 0.19712120294570923,
#    u'stadium': 0.29489871859550476}},
#  u'South Asian and [Chinese] -LRB- 1.1 % of the population -RRB- account for the': {u'gold': u'Overseas Chinese',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12365695834159851,
#    u'China': 0.8537060618400574,
#    u'Chinese': 0.7919838428497314,
#    u'Chinese American': 0.8293789625167847,
#    u'Chinese Canadian': 0.25318217277526855,
#    u'Chinese character': 0.32178017497062683,
#    u'Chinese characters': 0.32178017497062683,
#    u'Chinese cuisine': 0.6402035355567932,
#    u'Chinese language': 0.6002007126808167,
#    u'Chinese languages': 0.5988889336585999,
#    u'Chinese people': 0.8261846303939819,
#    u'Han Chinese': 0.7465208172798157,
#    u'History of China': 0.5846633911132812,
#    u'Overseas Chinese': 0.8127821087837219,
#    u'PR China': 0.8462018966674805,
#    u"People's Republic of China": 0.8462018966674805,
#    u'Simplified Chinese': 0.2954261302947998,
#    u'Simplified Chinese characters': 0.2954261302947998,
#    u'Varieties of Chinese': 0.7212744355201721,
#    u'XXNILXX': 0}},
#  u"The local [Seychellois Creole -LRB- '' Kreol] '' -RRB- , a creole language derived from French and": {u'gold': u'Seychellois Creole',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.8309327363967896,
#    u'Creole': 0.4559946060180664,
#    u'Creole (markup)': 0.4574899673461914,
#    u'Creole -LRB-': 0,
#    u"Creole -LRB- ''": 0,
#    u'Creole language': 0.548554539680481,
#    u'Creole peoples': 0.7923132181167603,
#    u'Criollo people': 0.8115092515945435,
#    u'Haitian Creole': 0.3312227129936218,
#    u'Haitian Creole language': 0.3312227129936218,
#    u'Louisiana Creole cuisine': 0.4897262752056122,
#    u'Louisiana Creole people': 0.7279937267303467,
#    u'Mauritian Creole': 0.513650119304657,
#    u'Mauritian creole': 0.513650119304657,
#    u'Seychellois Creole': 0.36800283193588257,
#    u"Seychellois Creole -LRB- '' Kreol": 0,
#    u'Seychellois Creole -LRB- Kreol': 0,
#    u'Seychellois Creole people': 0,
#    u'Sierra Leone Creole people': 0.7333327531814575,
#    u'XXNILXX': 0}},
#  u'They fly between Seward Park and [Maple Leaf] in northeast Seattle .': {u'gold': u'Maple Leaf, Seattle',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12416166067123413,
#    u'Flag of Canada': 0.3832632899284363,
#    u'Henry Leaf': 0,
#    u'Leaf': 0.7568734884262085,
#    u'Leaf (Israeli company)': 0.17615655064582825,
#    u'Leaf (Japanese company)': 0.17332962155342102,
#    u'Leaf (company)': 0.17332962155342102,
#    u'Leaf International': 0.7249834537506104,
#    u'Maple Leaf': 0.22418686747550964,
#    u'Maple Leaf (Amtrak)': 0.25933313369750977,
#    u'Maple Leaf (Amtrak/VIA)': 0.25933313369750977,
#    u'Maple Leaf (train)': 0.26043784618377686,
#    u'Maple Leaf, Seattle': 0.2638646960258484,
#    u'Maple Leaf, Seattle, Washington': 0.2236359715461731,
#    u'Maple Leaf, Toronto': 0.15666311979293823,
#    u'Maple leaf': 0.22418686747550964,
#    u'Nissan Leaf': 0.5894378423690796,
#    u'Ryan Leaf': 0.7386301755905151,
#    u'The Leaf Label': 0.14220938086509705,
#    u'XXNILXX': 0}},
#  u'This determined the [Qibla] , or Muslim direction of prayer .': {u'gold': u'Qibla',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12616181373596191,
#    u'Kaaba': 0.4763949513435364,
#    u'Qibla': 0.36686766147613525,
#    u'Qibla (group)': 0,
#    u'XXNILXX': 0}},
#  u'al field and geodynamic phenomena -LRB- polar motion , earth [tide] s , and crustal motion -RRB- in three-dimensional time-varying space': {u'gold': u'Tide',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12402382493019104,
#    u'Tidal force': 0.36463040113449097,
#    u'Tidal power': 0.20335379242897034,
#    u'Tide': 0.1863771378993988,
#    u'Tide (Suzuki novel)': 0,
#    u'Tide (album)': 0,
#    u'Tide (brand)': 0.6494296789169312,
#    u'Tide (detergent)': 0.4700626730918884,
#    u'Tide (time)': 0.13667571544647217,
#    u'Tide (transportation company)': 0.17310848832130432,
#    u'Tide Light Rail': 0.19256123900413513,
#    u'Tide, Oregon': 0,
#    u'Tideway': 0.19072023034095764,
#    u'XXNILXX': 0,
#    u'storm tide': 0.5372363328933716,
#    u'tidal': 0.17760968208312988,
#    u'tidal force': 0.36463040113449097,
#    u'tidal power': 0.20335379242897034,
#    u'tide': 0.1863771378993988,
#    u'tides': 0.17760968208312988}},
#  u"al-Ma ' mun commissioned a group of Muslim astronomers and [geographers] to measure the distance from Tadmur -LRB- Palmyra -RRB- to": {u'gold': u'Geography and cartography in medieval Islam',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12424087524414062,
#    u'Chinese geography': 0.4251836836338043,
#    u'Geographer': 0.8288356065750122,
#    u'Geographer (Band)': 0.14459830522537231,
#    u'Geographer (band)': 0.14459830522537231,
#    u'Geographers': 0.8219489455223083,
#    u'Geography': 0.19108334183692932,
#    u'Geography and cartography in medieval Islam': 0.7669507265090942,
#    u'Geography in medieval Islam': 0.7536126375198364,
#    u'History of geography': 0.24347388744354248,
#    u'Human geography': 0.22740569710731506,
#    u'Islamic geography': 0.7536126375198364,
#    u'List of Graeco-Roman geographers': 0.24462488293647766,
#    u'Physical geography': 0.2139683961868286,
#    u'Ptolemy': 0.5368584394454956,
#    u'XXNILXX': 0,
#    u'geographer': 0.8288356065750122,
#    u'geographers': 0.8219489455223083,
#    u'geography': 0.19108334183692932,
#    u'human geography': 0.22740569710731506}},
#  u"although it can also include the study of Earth 's [magnetic field] .": {u'gold': u'Magnetic field',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.1237059235572815,
#    u"Earth's magnetic field": 0,
#    u'Field': 0.2639966905117035,
#    u'Field (agriculture)': 0.1865251660346985,
#    u'Field (heraldry)': 0.14361408352851868,
#    u'Field (mathematics)': 0.33969348669052124,
#    u'Field (physics)': 0.20005905628204346,
#    u'Field, British Columbia': 0.31786978244781494,
#    u'John Field (composer)': 0.5814542174339294,
#    u'Magnetic field': 0.343924343585968,
#    u'Magnetic field of the Moon': 0.16350796818733215,
#    u'Magnetosphere': 0.1826590597629547,
#    u"Mercury's magnetic field": 0.167527437210083,
#    u'Orders of magnitude (magnetic field)': 0.1414606273174286,
#    u'Stellar magnetic field': 0.16725966334342957,
#    u'XXNILXX': 0,
#    u'field (mathematics)': 0.33969348669052124,
#    u'field (physics)': 0.20005905628204346,
#    u'magnetic field': 0.343924343585968,
#    u'stellar magnetic field': 0.16725966334342957}},
#  u'and the Rural District of Beverley -LRB- from the former [Beverley] constituency -RRB- .': {u'gold': u'Beverley (UK Parliament constituency)',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12384474277496338,
#    u'Beverley': 0.2634236514568329,
#    u'Beverley (UK Parliament constituency)': 0.15017420053482056,
#    u'Beverley (borough)': 0.15440300107002258,
#    u'Beverley Minster': 0.15838146209716797,
#    u'Beverley RUFC': 0.13484978675842285,
#    u'Beverley Racecourse': 0.15957576036453247,
#    u'Beverley Rural District': 0.1498681604862213,
#    u'Beverley Uranium Mine': 0.20034554600715637,
#    u'Beverley railway station': 0.1509353220462799,
#    u'Beverley, Saskatchewan': 0,
#    u'Beverley, South Australia': 0.207095205783844,
#    u'Beverley, Western Australia': 0.4128127694129944,
#    u'Blackburn Beverley': 0.5933326482772827,
#    u'Cliff Beverley': 0.4918387532234192,
#    u'Diocese of Beverley': 0.16683578491210938,
#    u'Electoral district of Beverley': 0.19961535930633545,
#    u'Patrick Beverley': 0.22156193852424622,
#    u'Shire of Beverley': 0.14030039310455322,
#    u'XXNILXX': 0}},
#  u'changes , most of Haltemprice became a new seat of [Beverley] .': {u'gold': u'Beverley (UK Parliament constituency)',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.1249159574508667,
#    u'Beverley': 0.2604568898677826,
#    u'Beverley (UK Parliament constituency)': 0.15349146723747253,
#    u'Beverley (borough)': 0.15686967968940735,
#    u'Beverley Minster': 0.15704581141471863,
#    u'Beverley RUFC': 0.1353074610233307,
#    u'Beverley Racecourse': 0.15885666012763977,
#    u'Beverley Rural District': 0.15159636735916138,
#    u'Beverley Uranium Mine': 0.19895991683006287,
#    u'Beverley railway station': 0.15202859044075012,
#    u'Beverley, Saskatchewan': 0,
#    u'Beverley, South Australia': 0.21062341332435608,
#    u'Beverley, Western Australia': 0.4197567403316498,
#    u'Blackburn Beverley': 0.5832306742668152,
#    u'Cliff Beverley': 0.4987774193286896,
#    u'Diocese of Beverley': 0.16824623942375183,
#    u'Electoral district of Beverley': 0.20193901658058167,
#    u'Patrick Beverley': 0.2251759171485901,
#    u'Shire of Beverley': 0.14120185375213623,
#    u'XXNILXX': 0}},
#  u'feature of the true Earth in order to compute the [radius] of the spherical model .': {u'gold': u'Radius',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12312307953834534,
#    u'Distance (graph theory)': 0.18632078170776367,
#    u'Earth radius': 0.19139820337295532,
#    u'Minimum railway curve radius': 0.6256519556045532,
#    u'Planetary radius': 0,
#    u'Radiu': 0,
#    u'Radius': 0.2991175651550293,
#    u'Radius (bone)': 0.15163591504096985,
#    u'Radius (comics)': 0.1569909155368805,
#    u'Radius (company)': 0.13506585359573364,
#    u'Radius (computer)': 0.1460517942905426,
#    u'Radius (music ensemble)': 0,
#    u'Radius_(company)': 0.13506585359573364,
#    u'Solar radius': 0.17275017499923706,
#    u'Star': 0.2752874791622162,
#    u'XXNILXX': 0,
#    u'radiu': 0,
#    u'radius': 0.2991175651550293,
#    u'radius (bone)': 0.15163591504096985,
#    u'solar radius': 0.17275017499923706}},
#  u'for the 1950 general election , and abolished for the [1983 general election] .': {u'gold': u'United Kingdom general election, 1983',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12534043192863464,
#    u'Argentine general election, 1983': 0.29406964778900146,
#    u'British Virgin Islands general election, 1983': 0,
#    u'Election': 0.3201194405555725,
#    u'Election (1999 film)': 0.24158287048339844,
#    u'Election (2005 film)': 0.20282256603240967,
#    u'Election (horse)': 0.1889432668685913,
#    u'General election': 0.6489084959030151,
#    u'Irish general election, 2007': 0.48614370822906494,
#    u'Italian general election, 1983': 0.1691575050354004,
#    u'Philippine general election, 2007': 0.4206330180168152,
#    u'Royal elections in Poland': 0.4187917709350586,
#    u'Turkish general election, 1983': 0.39509040117263794,
#    u'United Kingdom general election, 1979': 0.41707494854927063,
#    u'United Kingdom general election, 1983': 0.4217853248119354,
#    u'United Kingdom general election, 2005': 0.26581233739852905,
#    u'United Kingdom general election, 2010': 0.20183908939361572,
#    u'XXNILXX': 0,
#    u'election': 0.3201194405555725,
#    u'general election': 0.6489084959030151}},
#  u'in the 2nd round -LRB- 47th overall -RRB- of the [1999 NBA Draft] .': {u'gold': u'1999 NBA draft',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12413182854652405,
#    u'1999 NBA Draft': 0.2777741849422455,
#    u'1999 NBA draft': 0.2777741849422455,
#    u'2009 MLS SuperDraft': 0.17025643587112427,
#    u'2010 NBA Draft': 0.43286219239234924,
#    u'2010 NBA draft': 0.43286219239234924,
#    u'2012 NBA Draft': 0.34164124727249146,
#    u'2012 NBA draft': 0.34164124727249146,
#    u'2013 NBA Draft': 0.4093278646469116,
#    u'2013 NBA draft': 0.4093278646469116,
#    u'Conscription in the United States': 0.7935250997543335,
#    u'Draft': 0.14516282081604004,
#    u'Draft (hull)': 0.27287477254867554,
#    u'Draft (sports)': 0.5555024743080139,
#    u'NBA Draft': 0.4466470777988434,
#    u'NBA draft': 0.4466470777988434,
#    u'National Basketball Association Draft': 0.4466470777988434,
#    u'National Football League draft': 0.6315141320228577,
#    u'XXNILXX': 0,
#    u'draft (hull)': 0.27287477254867554}},
#  u'known as Kingston upon Hull , Haltemprice -RRB- was a [constituency] in the East Riding of Yorkshire , which was a': {u'gold': u'United Kingdom constituencies',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12337231636047363,
#    u'Constituencies in Solomon Islands': 0.18745434284210205,
#    u'Constituencies in the Solomon Islands': 0.18745434284210205,
#    u'Constituencies of Belize': 0.17525705695152283,
#    u'Constituencies of Iceland': 0.22767412662506104,
#    u'Constituencies of Kenya': 0.21312180161476135,
#    u'Constituencies of Namibia': 0.14487287402153015,
#    u'Constituencies of Singapore': 0.17778292298316956,
#    u'Constituency': 0.15400689840316772,
#    u'Constituency (France)': 0.15840384364128113,
#    u'Constituency Labour Party': 0.5091251134872437,
#    u'Electoral district': 0.15734657645225525,
#    u'European Parliament constituency': 0.17866799235343933,
#    u'List of constituencies of Kenya': 0.21312180161476135,
#    u'National apportionment of MP seats in the Swedish Parliament': 0.138950377702713,
#    u'Parliament of Uganda': 0.5077539682388306,
#    u'Scottish Parliament constituencies and regions': 0.2253168821334839,
#    u'United Kingdom constituencies': 0.17445969581604004,
#    u'XXNILXX': 0,
#    u'constituency': 0.15400689840316772}},
#  u'mixed -LRB- 70 % -RRB- , French , African , [India] n , Chinese , and Arab Roman Catholic 82.2 %': {u'gold': u'India',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12401586771011353,
#    u'A1 Team India': 0.17533189058303833,
#    u'All India Football Federation': 0.2777140736579895,
#    u'British India': 0.8585453033447266,
#    u'British Raj': 0.8349051475524902,
#    u'Cinema of India': 0.288939505815506,
#    u'Company Rule in India': 0.37911921739578247,
#    u'Company rule in India': 0.37911921739578247,
#    u'History of India': 0.7383820414543152,
#    u'India': 0.8575422167778015,
#    u'India cricket team': 0.7834923267364502,
#    u"India men's national field hockey team": 0.238399475812912,
#    u'India national cricket team': 0.783793568611145,
#    u'India national football team': 0.2454686462879181,
#    u"India national women's cricket team": 0.537169337272644,
#    u'Indian cricket team': 0.7834923267364502,
#    u'Indian poetry': 0.400043249130249,
#    u'Indian subcontinent': 0.8513616919517517,
#    u'Presidencies and provinces of British India': 0.8585453033447266,
#    u'XXNILXX': 0}},
#  u'not to be a perfect sphere but to approximate an [oblate spheroid] , a specific type of ellipsoid .': {u'gold': u'Spheroid',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12722760438919067,
#    u'Bulge (astronomy)': 0.19719216227531433,
#    u'Oblate': 0.5457828044891357,
#    u'Oblate spheroid': 0.3639830946922302,
#    u'Sphere': 0.23477402329444885,
#    u'Spheroid': 0.24999794363975525,
#    u'XXNILXX': 0,
#    u'galactic bulge': 0.2543066442012787,
#    u'oblate': 0.5457828044891357,
#    u'oblate spheroid': 0.3639830946922302,
#    u'sphere': 0.23477402329444885,
#    u'spheroid': 0.24999794363975525}},
#  u'notably at the 2000 Sydney Olympics where the Canadians topped [Yugoslavia] to win their group only to lose to eventual silver': {u'gold': u'Yugoslavia national basketball team',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12527504563331604,
#    u"Federal People's Republic of Yugoslavia": 0.8268071413040161,
#    u'Federal Republic of Yugoslavia': 0.675098717212677,
#    u'Football Association of Yugoslavia': 0.3116682171821594,
#    u'Kingdom of Yugoslavia': 0.8052533864974976,
#    u'SFR Yugoslavia': 0.8268071413040161,
#    u'SFRJ': 0.8268071413040161,
#    u'SFRY': 0.8268071413040161,
#    u'Serbia and Montenegro': 0.675098717212677,
#    u'Serbia and Montenegro national football team': 0.17959141731262207,
#    u'Serbia national basketball team': 0.40196090936660767,
#    u'Serbia national football team': 0.20659393072128296,
#    u'Socialist Federal Republic of Yugoslavia': 0.8270432949066162,
#    u'Socialist Republic of Yugoslavia': 0.8268071413040161,
#    u'XXNILXX': 0,
#    u'Yugoslavia': 0.8502351641654968,
#    u'Yugoslavia in the Eurovision Song Contest': 0.34936243295669556,
#    u'Yugoslavia national basketball team': 0.6531493067741394,
#    u'Yugoslavia national football team': 0.552602231502533,
#    u"Yugoslavia women's national basketball team": 0.17181280255317688}},
#  u'of using trigonometric calculations based on the angle between a [plain] and mountain top which yielded more accurate measurements of the': {u'gold': u'Plain',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12324562668800354,
#    u'Great Plains': 0.8135623931884766,
#    u'Phonation': 0.21498394012451172,
#    u'Plain': 0.2005474865436554,
#    u'Plain Township, Franklin County, Ohio': 0.16410711407661438,
#    u'Plain Township, Kosciusko County, Indiana': 0.13400799036026,
#    u'Plain Township, Stark County, Ohio': 0.247013121843338,
#    u'Plain Township, Wood County, Ohio': 0.1604916751384735,
#    u'Plain weave': 0.1649438440799713,
#    u'Plain, Washington': 0.169780433177948,
#    u'Plain, Wisconsin': 0.137698233127594,
#    u'Sermon on the Plain': 0.2504344582557678,
#    u'Tenuis consonant': 0.16066762804985046,
#    u'The Plain (West Point)': 0.20371922850608826,
#    u'Voiceless consonant': 0.15038910508155823,
#    u'Voicelessness': 0.15038910508155823,
#    u'XXNILXX': 0,
#    u'plain': 0.2005474865436554,
#    u'plain weave': 0.1649438440799713,
#    u'tenuis consonant': 0.16066762804985046}},
#  u'of various sorts 93 times , most notably at the [2000 Sydney Olympics] where the Canadians topped Yugoslavia to win their group only': {u'gold': u'2000 Summer Olympics',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.123273104429245,
#    u'2000 Summer Olympics': 0.7278084754943848,
#    u'2000 Sydney Olympics': 0.7045071125030518,
#    u'2008 Summer Olympics': 0.6112685799598694,
#    u'Athletics at the 2000 Summer Olympics': 0.4418855607509613,
#    u'Basketball at the 2000 Summer Olympics': 0.24553295969963074,
#    u"Basketball at the 2000 Summer Olympics \u2013 Men's tournament": 0.1451866626739502,
#    u'Canoeing at the 2000 Summer Olympics': 0.41176196932792664,
#    u'Figure skating at the Olympic Games': 0.21420824527740479,
#    u'Football at the 2000 Summer Olympics': 0.18331274390220642,
#    u"Football at the 2000 Summer Olympics \u2013 Women's tournament": 0.23283421993255615,
#    u'Olympic': 0.7702310085296631,
#    u'Olympic Games': 0.83238685131073,
#    u'Olympics': 0.83238685131073,
#    u'Summer Olympic Games': 0.6568359136581421,
#    u'Sydney Olympics': 0.6752143502235413,
#    u'Tennis at the 2000 Summer Olympics': 0.16815003752708435,
#    u"Tennis at the 2000 Summer Olympics \u2013 Men's singles": 0,
#    u'Winter Olympic Games': 0.7595037817955017,
#    u'XXNILXX': 0}},
#  u'remainder of the constituency contributed 11.6 % of the new [Boothferry] seat .': {u'gold': u'Boothferry (UK Parliament constituency)',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12377843260765076,
#    u'Boothferry': 0.15397530794143677,
#    u'Boothferry (UK Parliament constituency)': 0.14469483494758606,
#    u'Boothferry (district)': 0.26280152797698975,
#    u'XXNILXX': 0}},
#  u'the Kingston upon Hull wards -LRB- which were transferred to [Kingston upon Hull West] -RRB- .': {u'gold': u'Hull West (UK Parliament constituency)',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.1262093186378479,
#    u'Canadian Football League West Division': 0.613990306854248,
#    u'Hull West': 0.17493674159049988,
#    u'Hull West (UK Parliament constituency)': 0.17493674159049988,
#    u'Hull West (UK Parliamentary constituency)': 0.17493674159049988,
#    u'Hull West by-election, 1907': 0,
#    u'Kingston upon Hull West': 0.2325543761253357,
#    u'Kingston upon Hull West (UK Parliament constituency)': 0.2885468006134033,
#    u'Kingston upon Hull West and Hessle (UK Parliament constituency)': 0.15427172183990479,
#    u'Upon Hull West': 0,
#    u'West': 0.22331205010414124,
#    u'West Africa': 0.8041378259658813,
#    u'West Province (Western Australia)': 0,
#    u'Western Conference (NBA)': 0.3998255133628845,
#    u'Western Conference (WNBA)': 0.36463087797164917,
#    u'Western Ukraine': 0.293457567691803,
#    u'Western United States': 0.859100341796875,
#    u'Western world': 0.8389233946800232,
#    u'XXNILXX': 0,
#    u'upon Hull West': 0}},
#  u'to a genetic neuromuscular disorder that affected his feet , [Charcot-Marie-Tooth disease] .': {u'gold': u'Charcot\u2013Marie\u2013Tooth disease',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12331598997116089,
#    u'Charcot-Marie-Tooth': 0.20942029356956482,
#    u'Charcot-Marie-Tooth disease': 0.27790164947509766,
#    u'Charcot\u2013Marie\u2013Tooth disease': 0.2488078474998474,
#    u'Disease': 0.7363116145133972,
#    u'Disease (G.G.F.H. album)': 0,
#    u'Disease (The Ark song)': 0,
#    u'Disease (The Terminals album)': 0,
#    u'Disease (album)': 0,
#    u'Disease (song)': 0.13218563795089722,
#    u'Globalization and disease': 0.16060367226600647,
#    u'Infection': 0.525829017162323,
#    u'Infectious disease': 0.525829017162323,
#    u'Neurological disorder': 0.26127785444259644,
#    u'Occupational disease': 0.1519627869129181,
#    u'Plant pathology': 0.5979064106941223,
#    u'XXNILXX': 0,
#    u'disease': 0.7363116145133972,
#    u'infectious disease': 0.525829017162323,
#    u'plant disease': 0.5979064106941223}},
#  u"trigonometric calculations based on the angle between a plain and [mountain] top which yielded more accurate measurements of the Earth 's": {u'gold': u'mountain',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12368753552436829,
#    u'List of mountains in Serbia': 0.22686436772346497,
#    u'Mountain': 0.5266559720039368,
#    u'Mountain (Leslie West album)': 0.14835602045059204,
#    u'Mountain (Manitoba riding)': 0.1520499885082245,
#    u'Mountain (band)': 0.7314450740814209,
#    u'Mountain (electoral district)': 0.1520499885082245,
#    u'Mountain States': 0.6547905802726746,
#    u'Mountain Time Zone': 0.7171726822853088,
#    u'Mountain bike': 0.37381482124328613,
#    u'Mountain biking': 0.5752289295196533,
#    u'Mountain gun': 0.5196592807769775,
#    u'Mountain railway': 0.6153101921081543,
#    u'Mountain warfare': 0.6342325210571289,
#    u'Mountain, North Dakota': 0.1380363404750824,
#    u'Mountain, Wisconsin': 0.1363511085510254,
#    u'Mountains and hills of Scotland': 0.174870103597641,
#    u'XXNILXX': 0,
#    u'mountain': 0.5266559720039368,
#    u'mountains of Serbia': 0.22053954005241394}},
#  u"ultra-right Tory MP , Alan B ' Stard , in [The New Statesman] . 1950-1955 : The constituency comprised two wards of the": {u'gold': u'The New Statesman',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12674501538276672,
#    u'Holden Caprice': 0.733818769454956,
#    u'List of City of Heroes characters': 0.18809255957603455,
#    u'Nash Statesman': 0.2654871940612793,
#    u'New Statesman': 0.6963205933570862,
#    u'Politician': 0.8488376140594482,
#    u'Public figure': 0.4034397304058075,
#    u'Statesman': 0.8227816820144653,
#    u'Statesman (Amtrak)': 0,
#    u'Statesman (City of Heroes)': 0.18809255957603455,
#    u'Statesman (automobile)': 0.3558245003223419,
#    u'Statesman (dialogue)': 0.7114794254302979,
#    u'Statesman (tug)': 0,
#    u'Statesman Journal': 0.5506941676139832,
#    u'The New Statesman': 0.6761264204978943,
#    u'The New Statesman (Climb)': 0,
#    u'The Statesman': 0.6987789273262024,
#    u'XXNILXX': 0,
#    u'politician': 0.8488376140594482,
#    u'public figure': 0.4034397304058075}},
#  u'upon Hull , Haltemprice -RRB- was a constituency in the [East Riding of Yorkshire] , which was a traditional sub-division of the historic county': {u'gold': u'East Riding of Yorkshire',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12274327874183655,
#    u'Archdeacon of the East Riding': 0.1687539517879486,
#    u'East Riding': 0,
#    u'East Riding Yorkshire': 0.16981273889541626,
#    u'East Riding of Yorkshire': 0.199517160654068,
#    u'East Riding of Yorkshire (UK Parliament constituency)': 0.13744711875915527,
#    u'East Riding of Yorkshire Council': 0.1846238374710083,
#    u'East Riding of Yorkshire by-election, 1852': 0,
#    u'Electoral district (Canada)': 0.16794273257255554,
#    u'Equestrianism': 0.527790367603302,
#    u'Geology of East Riding of Yorkshire': 0,
#    u'Haworth Park': 0,
#    u'History of the East Riding of Yorkshire': 0.16641554236412048,
#    u'Lord Lieutenant of the East Riding of Yorkshire': 0.14516648650169373,
#    u'Riding': 0.17065134644508362,
#    u'Riding (country subdivision)': 0.16019293665885925,
#    u'Riding (division)': 0.16019293665885925,
#    u'Riding horse': 0.527790367603302,
#    u'Riding of': 0,
#    u'XXNILXX': 0}},
#  u'win their group only to lose to eventual silver medalist [France] in the quarterfinals and finish seventh .': {u'gold': u'France national basketball team',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12386181950569153,
#    u'A1 Team France': 0.2341042459011078,
#    u'Cinema of France': 0.19083523750305176,
#    u'First French Empire': 0.29838329553604126,
#    u'France': 0.8323863744735718,
#    u'France national basketball team': 0.21959847211837769,
#    u'France national football team': 0.17166215181350708,
#    u'France national rugby league team': 0.2648565471172333,
#    u'France national rugby union team': 0.269463449716568,
#    u"France women's national football team": 0.17383015155792236,
#    u'French First Republic': 0.3405150771141052,
#    u'French Football Federation': 0.21757081151008606,
#    u'French Rugby Federation': 0.17986485362052917,
#    u'French Third Republic': 0.5229211449623108,
#    u'French poetry': 0.4828716814517975,
#    u'Kingdom of France': 0.29122281074523926,
#    u'LNB Pro A': 0.20691683888435364,
#    u'Second French Empire': 0.39818793535232544,
#    u"Syndicat National de l'\xc9dition Phonographique": 0,
#    u'XXNILXX': 0}},
#  u"with measuring the earth on a global scale , and [surveying] -LRB- '' Ingenieurgeod sie '' -RRB- , which is concerned": {u'gold': u'Geophysical survey',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12384331226348877,
#    u'Aerial survey': 0.4641331434249878,
#    u'Amphibious reconnaissance': 0.6491333246231079,
#    u'Archaeological field survey': 0.6039120554924011,
#    u'Astronomical survey': 0.26998764276504517,
#    u'Cave survey': 0.7000386118888855,
#    u'Geological survey': 0.7491898536682129,
#    u'Geophysical survey': 0.3924422562122345,
#    u'Hydrographic survey': 0.7393962740898132,
#    u'Pacific Railroad Surveys': 0.8383567929267883,
#    u'Position fixing': 0.2200814187526703,
#    u'Public Land Survey System': 0.3570883572101593,
#    u'Quantity surveyor': 0.1782677173614502,
#    u'Statistical survey': 0.33184492588043213,
#    u'Survey methodology': 0.33184492588043213,
#    u'Surveying': 0.6881564855575562,
#    u'Wardriving': 0.21652203798294067,
#    u'XXNILXX': 0,
#    u'hydrographic survey': 0.7393962740898132,
#    u'surveying': 0.6881564855575562}},
#  u'with the measurement and representation of the Earth , its [gravitation] al field and geodynamic phenomena -LRB- polar motion , earth': {u'gold': u'Gravitation',
#   u'training': False,
#   u'vals': {u'-NIL-': 0.12399840354919434,
#    u'General relativity': 0.7078428864479065,
#    u'Gravitation': 0.5674542188644409,
#    u'Gravitation (M. C. Escher)': 0.17841878533363342,
#    u'Gravitation (anime)': 0.20308104157447815,
#    u'Gravitation (book)': 0.22542425990104675,
#    u'Gravitation (film)': 0,
#    u'Gravitation (label)': 0,
#    u'Gravitation (manga)': 0.20373287796974182,
#    u'Gravitation (song)': 0,
#    u'Gravitational coupling constant': 0.1816924810409546,
#    u'Gravitational wave': 0.3300723135471344,
#    u'Gravity': 0.42531856894493103,
#    u'Gravity of Earth': 0.3552674353122711,
#    u"Newton's law of gravitation": 0,
#    u"Newton's law of universal gravitation": 0,
#    u'XXNILXX': 0,
#    u'gravitation': 0.5674542188644409,
#    u'gravitational coupling constant': 0.1816924810409546,
#    u'gravity': 0.42531856894493103}}}

# %%
findWrongItems()  # training set
# Out:
# {u"'' Pachinko Sexy Reaction '' is an ecchi [arcade game] -LRB- more adult than '' Pachinko Sexy Reaction 2 ''": {u'gold': u'Arcade game',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.5234813094139099,
#    u'Arcade game': 0.46396684646606445,
#    u"Bucky O'Hare (arcade game)": 0.19104325771331787,
#    u'Donkey Kong (video game)': 0.5234813094139099,
#    u'Game': 0.241276353597641,
#    u'Game (2011 film)': 0.23126322031021118,
#    u'Game (food)': 0.5055193305015564,
#    u'Game (hunting)': 0.5522598624229431,
#    u'Game (rapper)': 0.33282017707824707,
#    u'Game (retailer)': 0.20123815536499023,
#    u'Ninja Gaiden (arcade)': 0.2089502513408661,
#    u'Pac-Man': 0.18816548585891724,
#    u'Popeye (video game)': 0.8015881776809692,
#    u'Star Wars (1983 video game)': 0.21903544664382935,
#    u'Teenage Mutant Ninja Turtles (arcade game)': 0.12587761878967285,
#    u'The Game (rapper)': 0.5522598624229431,
#    u'Video game': 0.858648419380188,
#    u'XXNILXX': 0,
#    u'arcade game': 0.21701502799987793,
#    u'game': 0.2382102608680725}},
#  u"'' mdash ; for his heroism in April 1970 in [Vietnam] .": {u'gold': u'Vietnam War',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8532803058624268,
#    u'Buddhism in Vietnam': 0.3835776746273041,
#    u'Cinema of Vietnam': 0.2953152060508728,
#    u'French Indochina': 0.2631944417953491,
#    u'North Vietnam': 0.1805238127708435,
#    u'South Vietnam': 0.6346033811569214,
#    u'Vietnam': 0.7860830426216125,
#    u'Vietnam (miniseries)': 0.6045020222663879,
#    u'Vietnam Football Federation': 0.15964266657829285,
#    u'Vietnam War': 0.1279889941215515,
#    u'Vietnam at the 2005 Southeast Asian Games': 0.3569720387458801,
#    u'Vietnam at the 2007 Southeast Asian Games': 0,
#    u'Vietnam at the 2009 Southeast Asian Games': 0,
#    u'Vietnam national football team': 0.4809941053390503,
#    u'Vietnam war': 0.4809941053390503,
#    u"Vietnam women's national football team": 0.7968037128448486,
#    u"Vietnam women's national volleyball team": 0.8606141805648804,
#    u'Vietnamese cuisine': 0.8606141805648804,
#    u'Volleyball Federation of Vietnam': 0,
#    u'XXNILXX': 0}},
#  u', 1921 August 8 , 1984 -RRB- , born in [Philadelphia] , was an American television and motion picture actor .': {u'gold': u'Philadelphia',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1273469626903534,
#    u'2014\u201315 Philadelphia Flyers season': 0,
#    u'Advanta Championships of Philadelphia': 0.27624624967575073,
#    u'Ala\u015fehir': 0.396176278591156,
#    u'Philadelphia': 0.8527278900146484,
#    u'Philadelphia (film)': 0.5168271064758301,
#    u'Philadelphia (magazine)': 0.699574887752533,
#    u'Philadelphia 76ers': 0.8007470369338989,
#    u'Philadelphia County, Pennsylvania': 0.47977566719055176,
#    u'Philadelphia Eagles': 0.8374199867248535,
#    u'Philadelphia Flyers': 0.726953387260437,
#    u'Philadelphia International Airport': 0.4503365755081177,
#    u'Philadelphia Phantoms': 0.3613702952861786,
#    u'Philadelphia Phillies': 0.8560446500778198,
#    u'Philadelphia Union': 0.22351229190826416,
#    u'Philadelphia, Mississippi': 0.6663105487823486,
#    u'Philadelphia, Pennsylvania': 0.8460953235626221,
#    u'Roman Catholic Archdiocese of Philadelphia': 0.39827778935432434,
#    u'U.S. Pro Indoor': 0.30691254138946533,
#    u'XXNILXX': 0}},
#  u', Jr. was born on 23 June 1949 , in [East Chicago , Indiana] , and graduated from Washington High School there in 1968': {u'gold': u'East Chicago, Indiana',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.2374175488948822,
#    u'Central High School (East Chicago, Indiana)': 0.1263209879398346,
#    u'Chicago': 0.2909362316131592,
#    u'Chicago (2002 film)': 0.7734440565109253,
#    u'Chicago (band)': 0.8043686747550964,
#    u'Chicago (musical)': 0.48507189750671387,
#    u'Chicago ,': 0,
#    u'Chicago Blackhawks': 0.24351832270622253,
#    u'Chicago Bulls': 0.5922929048538208,
#    u'Chicago, Illinois': 0.8170945644378662,
#    u'East Chicago': 0.6878410577774048,
#    u'East Chicago (NICTD station)': 0,
#    u'East Chicago (NICTD)': 0,
#    u'East Chicago , Indiana': 0,
#    u'East Chicago High School': 0,
#    u'East Chicago Indiana': 0.3523247241973877,
#    u'East Chicago, Illinois': 0,
#    u'East Chicago, Indiana': 0.6224839687347412,
#    u'East Side, Chicago': 0.4719233512878418,
#    u'XXNILXX': 0}},
#  u', Recruit Training Regiment at the MCRD San Diego , [California] .': {u'gold': u'California',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.3244507312774658,
#    u'2007 California Golden Bears football team': 0.813355028629303,
#    u'2008 California Golden Bears football team': 0.33521369099617004,
#    u'2009 California Golden Bears football team': 0.8462220430374146,
#    u'California': 0.8462106585502625,
#    u'California (wine)': 0.19677019119262695,
#    u'California Golden Bears': 0.45974797010421753,
#    u'California Golden Bears baseball': 0.21703565120697021,
#    u'California Golden Bears football': 0.18193715810775757,
#    u"California Golden Bears men's basketball": 0.6723104119300842,
#    u"California Golden Bears women's basketball": 0.8038606643676758,
#    u'California Trail': 0.6093745231628418,
#    u'California wine': 0.8066380023956299,
#    u'California, Pennsylvania': 0.24240612983703613,
#    u'Miss California Teen USA': 0.17585855722427368,
#    u'Miss California USA': 0.8582454919815063,
#    u'United States congressional delegations from California': 0.1256566047668457,
#    u'University of California': 0.7444538474082947,
#    u'University of California, Berkeley': 0.537047803401947,
#    u'XXNILXX': 0}},
#  u', he was ordered to the Marine Corps Base , [Camp Pendleton] , California , where he joined the 2nd Infantry Training': {u'gold': u'Marine Corps Base Camp Pendleton',
#   u'training': True,
#   u'vals': {u' Marine Corps Base Camp Pendleton': 0,
#    u'-NIL-': 0.8458827137947083,
#    u'Camp Pendleton': 0.15716016292572021,
#    u'Camp Pendleton (Virginia)': 0.8656352758407593,
#    u'Camp Pendleton South, California': 0.4627416431903839,
#    u'Camp Pendleton, California': 0.8656352758407593,
#    u'MCB Camp Pendleton': 0.8656352758407593,
#    u'Marine Corps Base Camp Pendleton': 0.6166864037513733,
#    u'Pendleton': 0.20853564143180847,
#    u'Pendleton County, Kentucky': 0.6098772287368774,
#    u'Pendleton County, West Virginia': 0.3043693006038666,
#    u'Pendleton, Greater Manchester': 0.12709808349609375,
#    u'Pendleton, Indiana': 0.7170218825340271,
#    u'Pendleton, Lancashire': 0.7734440565109253,
#    u'Pendleton, New York': 0.17110681533813477,
#    u'Pendleton, Oregon': 0.4220702648162842,
#    u'Pendleton, South Carolina': 0.29075342416763306,
#    u'Victoria Pendleton': 0.8485544323921204,
#    u'XXNILXX': 0,
#    u'marine Corps Base Camp Pendleton': 0.8427954912185669}},
#  u', in the Republic of Vietnam on April 11 , [1970] .': {u'gold': u'1970',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.33968180418014526,
#    u'1970': 0.8432251214981079,
#    u'1970 FIFA World Cup': 0.871200442314148,
#    u'1970 Formula One season': 0.18798649311065674,
#    u'1970 Grand Prix motorcycle racing season': 0.22446030378341675,
#    u'1970 Indianapolis 500': 0.367695152759552,
#    u'1970 NBA draft': 0.7733454704284668,
#    u'1970 NFL season': 0.12449020147323608,
#    u'1970 NHL Amateur Draft': 0.27762484550476074,
#    u'1970 college football season': 0.3104304075241089,
#    u'1970 in aviation': 0.293809175491333,
#    u'1970 in film': 0.5217568874359131,
#    u'1970 in literature': 0.2524814009666443,
#    u'1970 in music': 0.5941087603569031,
#    u'1970 in spaceflight': 0.6224405169487,
#    u'1970 in sports': 0.8531395196914673,
#    u'Quebec general election, 1970': 0.3915083408355713,
#    u'United Kingdom general election, 1970': 0.2270638644695282,
#    u'United States House of Representatives elections, 1970': 0.15392643213272095,
#    u'XXNILXX': 0}},
#  u'2nd Recruit Training Battalion , Recruit Training Regiment at the [MCRD San Diego] , California .': {u'gold': u'Marine Corps Recruit Depot San Diego',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.30946505069732666,
#    u'Diego': 0.8002078533172607,
#    u'Diego Costa Silva': 0.5281096696853638,
#    u'Diego Eli Moreira': 0,
#    u'Diego Ribas': 0.15776169300079346,
#    u'Diego Ribas da Cunha': 0.8599380254745483,
#    u'Diego Walsh': 0.2691537141799927,
#    u'Diego de Lima Barcelos': 0.156251460313797,
#    u'MCRD San Diego': 0.5064012408256531,
#    u'Marine Corps Recruit Depot San Diego': 0.7390047907829285,
#    u'Primo (wrestler)': 0.18340766429901123,
#    u'San Diego': 0.8352538347244263,
#    u'San Diego Chargers': 0.3833414614200592,
#    u'San Diego County, California': 0.12578389048576355,
#    u'San Diego International Airport': 0.563178539276123,
#    u"San Diego Toreros men's basketball": 0.24800735712051392,
#    u'San Diego, California': 0.5040296316146851,
#    u'Southern California Open': 0.4279462695121765,
#    u'University of San Diego': 0.3683907985687256,
#    u'XXNILXX': 0}},
#  u"Birds '' and a larger role in the original '' [Invasion of the Body Snatchers] '' , having portrayed a physician in the '' book-end": {u'gold': u'Invasion of the Body Snatchers',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1277291178703308,
#    u'2003 invasion of Iraq': 0.8270511627197266,
#    u'Battle of France': 0.49058467149734497,
#    u'Invasion': 0.40690135955810547,
#    u'Invasion (1965 film)': 0.24296745657920837,
#    u'Invasion (1997 film)': 0.18279701471328735,
#    u'Invasion (TV series)': 0.2443462610244751,
#    u'Invasion Body Snatchers': 0,
#    u'Invasion of': 0,
#    u'Invasion of Normandy': 0.6092138290405273,
#    u'Invasion of Poland': 0.7016453146934509,
#    u'Invasion of Poland (1939)': 0.7016453146934509,
#    u'Invasion of the': 0,
#    u'Invasion of the Body': 0,
#    u'Invasion of the Body Snatchers': 0.6974892020225525,
#    u'Invasion of the Body Snatchers (1956 film)': 0.5789269208908081,
#    u'Invasion of the Body Snatchers (1978 film)': 0.1884840726852417,
#    u'Invasion of the Body Snatchers (1978 film) ': 0,
#    u'The Invasion (professional wrestling)': 0.24969694018363953,
#    u'XXNILXX': 0}},
#  u"De La Garza , Jr. -LRB- 1949-1970 -RRB- was a [United States Marine Corps] lance corporal who was posthumous ly presented the nation 's": {u'gold': u'United States Marine Corps',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8618532419204712,
#    u'Aaron Corp': 0.22224679589271545,
#    u'Corp': 0.4641607403755188,
#    u'Corps': 0.810215175151825,
#    u'Corps, Is\xe8re': 0.5057469010353088,
#    u'German Student Corps': 0,
#    u'Marine Air-Ground Task Force': 0.33929383754730225,
#    u'Marine Corps': 0.23942184448242188,
#    u'Marines': 0,
#    u'Republic of Korea Marine Corps': 0.47096219658851624,
#    u'Ronald Corp': 0.6973122954368591,
#    u'Salvation Army corps': 0.5723652839660645,
#    u'States Marine Corps': 0,
#    u'U.S. Marine Corps': 0.8133468627929688,
#    u'USMC': 0.7324410080909729,
#    u'United States Army Corps of Engineers': 0.8618532419204712,
#    u'United States Marine Corps': 0.19501450657844543,
#    u'United States Marine Corps Aviation': 0,
#    u'United States Marines': 0.6291101574897766,
#    u'XXNILXX': 0}},
#  u'De La Garza , Jr. was born on 23 June [1949] , in East Chicago , Indiana , and graduated from': {u'gold': u'1949',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.26159822940826416,
#    u'1949': 0.1805717647075653,
#    u'1949 Grand Prix motorcycle racing season': 0.6646913886070251,
#    u'1949 Indianapolis 500': 0.19487875699996948,
#    u'1949 Masters Tournament': 0.47718876600265503,
#    u'1949 NASCAR Strictly Stock Series': 0.7330647706985474,
#    u'1949 NFL season': 0.12827301025390625,
#    u'1949 VFL season': 0.18324118852615356,
#    u'1949 college football season': 0.4215099513530731,
#    u'1949 in aviation': 0.1843990683555603,
#    u'1949 in baseball': 0.6886087656021118,
#    u'1949 in comics': 0.268039345741272,
#    u'1949 in film': 0.7827542424201965,
#    u'1949 in literature': 0.6018572449684143,
#    u'1949 in music': 0.42775312066078186,
#    u'1949 in poetry': 0.297743022441864,
#    u'1949 in radio': 0.3474978506565094,
#    u'Australian federal election, 1949': 0.2899065613746643,
#    u'Canadian federal election, 1949': 0.242229163646698,
#    u'XXNILXX': 0}},
#  u'De La Garza enlisted in the [United States Marine Corps] on 4 February 1969 , in Chicago , Illinois .': {u'gold': u'United States Marine Corps',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.2250036895275116,
#    u'Aaron Corp': 0.19687119126319885,
#    u'Corp': 0.4591410458087921,
#    u'Corps': 0.8606879711151123,
#    u'Corps, Is\xe8re': 0.5174156427383423,
#    u'German Student Corps': 0.15922939777374268,
#    u'Marine Air-Ground Task Force': 0.16343644261360168,
#    u'Marine Corps': 0.8094301223754883,
#    u'Marines': 0.1619565486907959,
#    u'Republic of Korea Marine Corps': 0.7677937746047974,
#    u'Ronald Corp': 0.6933658719062805,
#    u'Salvation Army corps': 0.5731620788574219,
#    u'States Marine Corps': 0,
#    u'U.S. Marine Corps': 0.23934170603752136,
#    u'USMC': 0.7318530678749084,
#    u'United States Army Corps of Engineers': 0.33390676975250244,
#    u'United States Marine Corps': 0.46290525794029236,
#    u'United States Marine Corps Aviation': 0.12563219666481018,
#    u'United States Marines': 0.2230258285999298,
#    u'XXNILXX': 0}},
#  u'De La Garza observed him pull the pin on a [grenade] .': {u'gold': u'Hand grenade',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.19231221079826355,
#    u'Canton of Grenade': 0,
#    u'F1 grenade (Russia)': 0.7294004559516907,
#    u'Granatwerfer 42': 0.7294004559516907,
#    u'Grenade': 0.27621030807495117,
#    u'Grenade (Bruno Mars song)': 0.593793511390686,
#    u'Grenade (The Chapman Society EP)': 0,
#    u'Grenade (insignia)': 0,
#    u'Grenade (song)': 0.1939748227596283,
#    u'Grenade launcher': 0.44380223751068115,
#    u'Grenade, Haute-Garonne': 0.37530943751335144,
#    u'Hand grenade': 0.23856216669082642,
#    u'Mills bomb': 0.31571707129478455,
#    u'Model 39 grenade': 0.32677221298217773,
#    u'Operation Grenade': 0.7469629049301147,
#    u'Rocket-propelled grenade': 0.4404953718185425,
#    u'Type 97 grenade': 0.44379937648773193,
#    u'XXNILXX': 0,
#    u'grenade': 0.1253100037574768,
#    u'hand grenade': 0.2846744656562805}},
#  u'Directly underneath the burner is the [mantle] , a fabric bag coated with chemicals which incandesce -LRB-': {u'gold': u'Gas mantle',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12475800514221191,
#    u"Earth's mantle": 0.5322423577308655,
#    u'Gas mantle': 0.2824592590332031,
#    u'Lee Mantle': 0.24253106117248535,
#    u'Mantle': 0.4724299907684326,
#    u'Mantle (API)': 0.16093796491622925,
#    u'Mantle (GPU API)': 0.16093796491622925,
#    u'Mantle (climbing)': 0.18195828795433044,
#    u'Mantle (clothing)': 0.28927379846572876,
#    u'Mantle (geology)': 0.6083070039749146,
#    u'Mantle (mollusc)': 0.2885687053203583,
#    u'Mantle (vesture)': 0.2835869789123535,
#    u'Mantling': 0.18733829259872437,
#    u'Mickey Mantle': 0.8235208988189697,
#    u'Robe': 0.48447948694229126,
#    u'XXNILXX': 0,
#    u'mantle': 0.4724299907684326,
#    u'mantle (clothing)': 0.28927379846572876,
#    u'mantle (geology)': 0.6083070039749146,
#    u'mantle (mollusc)': 0.2885687053203583}},
#  u'E , approximately four miles south of Da Nang on [11 April] 1970 , he was mortally wounded by a grenade as': {u'gold': u'April 11',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8578537702560425,
#    u'/April': 0.7345173954963684,
#    u'11 April': 0.1991596519947052,
#    u'April': 0.42072466015815735,
#    u'April (Sun Kil Moon album)': 0.6446948647499084,
#    u'April 11': 0.8485544323921204,
#    u'April 1966': 0.12624415755271912,
#    u'April 1971': 0.4433688819408417,
#    u'April 1972': 0.51030433177948,
#    u'April 1973': 0.4670897424221039,
#    u'April 1975': 0.17485961318016052,
#    u'April 2005': 0.1938493847846985,
#    u'April 2007': 0,
#    u'April 2008': 0,
#    u'April Branning': 0.24242207407951355,
#    u'April Ludgate': 0.5191091895103455,
#    u'CMLL Super Viernes (April 2014)': 0,
#    u'Deaths in April 2012': 0.8545436859130859,
#    u'Deaths in April 2013': 0,
#    u'XXNILXX': 0}},
#  u'Emilio Albert De La Garza , Jr. was born on [23 June] 1949 , in East Chicago , Indiana , and graduated': {u'gold': u'June 23',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.31079474091529846,
#    u'/June': 0.8313080072402954,
#    u'23 June': 0.5394277572631836,
#    u'CMLL Super Viernes (June 2014)': 0,
#    u'Deaths in June 2012': 0,
#    u'Deaths in June 2013': 0.332197904586792,
#    u'Deaths in June 2014': 0.5753724575042725,
#    u'June': 0.8204025626182556,
#    u'June (band)': 0.6598392724990845,
#    u'June (singer)': 0.750841498374939,
#    u'June 1966': 0.7469629049301147,
#    u'June 1971': 0.1925179660320282,
#    u'June 1972': 0.12605834007263184,
#    u'June 1973': 0.23907217383384705,
#    u'June 1975': 0.6172537207603455,
#    u'June 2006': 0.7677937746047974,
#    u'June 23': 0.3541807532310486,
#    u'June Cleaver': 0.156706303358078,
#    u'June Pointer': 0.17181852459907532,
#    u'XXNILXX': 0}},
#  u'First Marine Division , in the Republic of Vietnam on [April 11] , 1970 .': {u'gold': u'April 11',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8615868091583252,
#    u'/April': 0.44652214646339417,
#    u'April': 0.6317931413650513,
#    u'April (Sun Kil Moon album)': 0.8507561683654785,
#    u'April 11': 0.629786491394043,
#    u'April 11 (Eastern Orthodox liturgics)': 0,
#    u'April 1966': 0.1310206949710846,
#    u'April 1971': 0.4729405641555786,
#    u'April 1972': 0.4803025424480438,
#    u'April 1973': 0.6597492694854736,
#    u'April 1975': 0.16330939531326294,
#    u'April 2005': 0.21089309453964233,
#    u'April 2007': 0,
#    u'April 2008': 0,
#    u'April Branning': 0.6751859188079834,
#    u'April Ludgate': 0.5202471017837524,
#    u'CMLL Super Viernes (April 2014)': 0,
#    u'Deaths in April 2012': 0.20027348399162292,
#    u'Deaths in April 2013': 0,
#    u'XXNILXX': 0}},
#  u'Following the restoration of diplomatic relations with [Indonesia] in 1999 , broken after the 1975 Indonesian invasion of': {u'gold': u'Indonesia',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12470141053199768,
#    u'A1 Team Indonesia': 0.2507147789001465,
#    u'Cinema of Indonesia': 0.32583001255989075,
#    u'Dutch East Indies': 0.8563679456710815,
#    u'Elections in Indonesia': 0.42860448360443115,
#    u'Energy in Indonesia': 0.251190185546875,
#    u'Flag of Indonesia': 0.28916388750076294,
#    u'Football Association of Indonesia': 0.44383105635643005,
#    u'Indonesia': 0.8390853404998779,
#    u'Indonesia Open (badminton)': 0.38576552271842957,
#    u'Indonesia at the 2005 Southeast Asian Games': 0.22077009081840515,
#    u'Indonesia at the 2009 Southeast Asian Games': 0,
#    u'Indonesia at the 2011 Southeast Asian Games': 0,
#    u'Indonesia national badminton team': 0.555750846862793,
#    u'Indonesia national basketball team': 0.1960963010787964,
#    u'Indonesia national football team': 0.46425527334213257,
#    u'Indonesian Navy': 0.5347483158111572,
#    u'Indonesian cuisine': 0.37875378131866455,
#    u'Indonesian language': 0.4247758686542511,
#    u'XXNILXX': 0}},
#  u'However , due to [economies of scale] and additional refining necessary this fuel is one of the': {u'gold': u'Economies of scale',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.13103953003883362,
#    u'Eastern Bloc economies': 0.3587327003479004,
#    u'Economic system': 0.17585334181785583,
#    u'Economics': 0.23688754439353943,
#    u'Economies': 0.29321226477622986,
#    u'Economies of': 0,
#    u'Economies of scale': 0.2551878094673157,
#    u'Economies scale': 0,
#    u'Economy': 0.29321226477622986,
#    u'Economy of scale': 0.21730265021324158,
#    u'Economy, Pennsylvania': 0.23039960861206055,
#    u'Old Economy Village': 0.7552540898323059,
#    u'Returns to scale': 0.2089960277080536,
#    u'XXNILXX': 0,
#    u'economies': 0.29321226477622986,
#    u'economies of': 0,
#    u'economies of scale': 0.2551878094673157,
#    u'economies scale': 0,
#    u'economy': 0.29321226477622986,
#    u'economy of scale': 0.21730265021324158}},
#  u'However , kerosene contains more impurities such as [sulfur] and aromatic hydrocarbons than lamp oil .': {u'gold': u'Sulfur',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12440985441207886,
#    u'Allotropes of sulfur': 0.1697969138622284,
#    u'Delirium Tremens (album)': 0.15134984254837036,
#    u'Isotopes of sulfur': 0.22683566808700562,
#    u'Silver sulfide': 0.347339928150177,
#    u'Sulfur': 0.7115551829338074,
#    u'Sulfur (band)': 0.14999526739120483,
#    u'Sulfur (magazine)': 0.34816083312034607,
#    u'Sulfur (pharmacy)': 0.22841131687164307,
#    u'Sulfur (song)': 0.15156978368759155,
#    u'Sulfur cycle': 0.4296887516975403,
#    u'Sulfur dioxide': 0.7326110601425171,
#    u'Sulfur dye': 0,
#    u'Sulfur lamp': 0.211248517036438,
#    u'Sulfur oxide': 0.26422494649887085,
#    u'XXNILXX': 0,
#    u'sulfur': 0.7115551829338074,
#    u'sulfur (pharmacy)': 0.22841131687164307,
#    u'sulfur oxide': 0.26422494649887085,
#    u'sulfuric': 0.6120424270629883}},
#  u'If the [mantle] is visibly damaged , heat may become focused and damage': {u'gold': u'Gas mantle',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12423846125602722,
#    u"Earth's mantle": 0.5322277545928955,
#    u'Gas mantle': 0.28188443183898926,
#    u'Lee Mantle': 0.23477134108543396,
#    u'Mantle': 0.4690466821193695,
#    u'Mantle (API)': 0.16129738092422485,
#    u'Mantle (GPU API)': 0.16129738092422485,
#    u'Mantle (climbing)': 0.17931026220321655,
#    u'Mantle (clothing)': 0.2946067750453949,
#    u'Mantle (geology)': 0.6086638569831848,
#    u'Mantle (mollusc)': 0.287145733833313,
#    u'Mantle (vesture)': 0.2862863838672638,
#    u'Mantling': 0.18834766745567322,
#    u'Mickey Mantle': 0.8257876634597778,
#    u'Robe': 0.49729588627815247,
#    u'XXNILXX': 0,
#    u'mantle': 0.4690466821193695,
#    u'mantle (clothing)': 0.2946067750453949,
#    u'mantle (geology)': 0.6086638569831848,
#    u'mantle (mollusc)': 0.287145733833313}},
#  u'In real life , he was a gourmet [chef] .': {u'gold': u'Chef',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.124188631772995,
#    u'Celebrity chef': 0.6880788803100586,
#    u'Chef': 0.7149749398231506,
#    u'Chef (2014 film)': 0.16435635089874268,
#    u'Chef (South Park character)': 0.5547887682914734,
#    u'Chef (South Park)': 0.5550454258918762,
#    u'Chef (company)': 0.16140452027320862,
#    u'Chef (film)': 0.16435635089874268,
#    u'Chef (programming language)': 0.1518966555595398,
#    u'Chef (software)': 0.1737695336341858,
#    u"Chef's uniform": 0.1938338279724121,
#    u'Cook (profession)': 0.6743309497833252,
#    u'Isaac Hayes': 0.7802637815475464,
#    u'Japanese cuisine': 0.37803763151168823,
#    u'Magician': 0.6222299933433533,
#    u'Michael Smith (chef)': 0.4013018310070038,
#    u'Swedish Chef': 0.45129460096359253,
#    u'XXNILXX': 0,
#    u'celebrity chef': 0.6880788803100586,
#    u'chef': 0.7149749398231506}},
#  u"In the 1956 motion picture '' [Carousel] '' , adapted from the classic Rodgers and Hammerstein stage": {u'gold': u'Carousel (film)',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12558597326278687,
#    u'Carousel': 0.36946818232536316,
#    u'Carousel (1923 film)': 0.1829255223274231,
#    u'Carousel (1956 film)': 0.7600582838058472,
#    u'Carousel (Blink-182 song)': 0,
#    u'Carousel (Leila K album)': 0,
#    u'Carousel (TV channel)': 0.2258429229259491,
#    u'Carousel (Vanessa Carlton song)': 0.17211413383483887,
#    u'Carousel (advert)': 0.18542176485061646,
#    u'Carousel (advertisement)': 0.18542176485061646,
#    u'Carousel (album)': 0,
#    u'Carousel (ballet)': 0.23967373371124268,
#    u'Carousel (film)': 0.7729051113128662,
#    u'Carousel (musical)': 0.7995019555091858,
#    u'Carousel slide projector': 0.23517462611198425,
#    u'Cheshire Cat (Blink-182 album)': 0.15752050280570984,
#    u'Ford Carousel': 0,
#    u'Rabbits on the Run': 0.17211413383483887,
#    u'Westfield Carousel': 0.18972435593605042,
#    u'XXNILXX': 0}},
#  u'In the United States , the [Coleman Company] is perhaps the most famous producer of all four types': {u'gold': u'Coleman Company',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12548041343688965,
#    u'Coleman Company': 0.4556158483028412,
#    u'Company': 0.39077693223953247,
#    u'Company (Heroes)': 0.5103346109390259,
#    u'Company (film)': 0.18910446763038635,
#    u'Company (free improvisation group)': 0.1773710548877716,
#    u'Company (magazine)': 0.21345779299736023,
#    u'Company (military unit)': 0.4283559024333954,
#    u'Company (military)': 0.4283559024333954,
#    u'Company (musical)': 0.6367674469947815,
#    u'Company (novel)': 0.2999570071697235,
#    u'Company (short story)': 0.17665401101112366,
#    u'Dutch East India Company': 0.7415790557861328,
#    u'East India Company': 0.7437811493873596,
#    u'Livery company': 0.33387550711631775,
#    u'Miguel Company': 0.14378544688224792,
#    u'The Company (Heroes)': 0.5103346109390259,
#    u'XXNILXX': 0,
#    u'company (military unit)': 0.4283559024333954,
#    u'company (military)': 0.4283559024333954}},
#  u'Kerosene obtained from [filling station] s is more likely to be contaminated with water than': {u'gold': u'filling station',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1308269500732422,
#    u'Diving air compressor': 0.2148629128932953,
#    u'Filling station': 0.28811976313591003,
#    u'Hydrogen station': 0.19858664274215698,
#    u'Metro station': 0.20758533477783203,
#    u"Nuns' Island gas station": 0,
#    u'Radio broadcasting': 0.2972121238708496,
#    u'Royal Air Force station': 0.2050292193889618,
#    u'Station': 0.19492822885513306,
#    u'Station (Australian agriculture)': 0.37521326541900635,
#    u'Station (album)': 0,
#    u'Station (film)': 0.22967103123664856,
#    u'Station (frontier defensive structure)': 0.26097074151039124,
#    u'Train station': 0.2075604796409607,
#    u'XXNILXX': 0,
#    u'filling station': 0.28811976313591003,
#    u'metro station': 0.20758533477783203,
#    u'radio station': 0.2972121238708496,
#    u'railway station': 0.2075604796409607,
#    u'train station': 0.2075604796409607}},
#  u'La Garza enlisted in the United States Marine Corps on [4 February] 1969 , in Chicago , Illinois .': {u'gold': u'February 4',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.2183823585510254,
#    u'/February': 0.596852719783783,
#    u'4 February': 0.23218536376953125,
#    u'CMLL Super Viernes (February 2014)': 0,
#    u'Deaths in February 2011': 0,
#    u'Deaths in February 2012': 0.2103567123413086,
#    u'Deaths in February 2014': 0.22277215123176575,
#    u'February': 0.2137637436389923,
#    u'February 1966': 0.5530691146850586,
#    u'February 1971': 0.7133402228355408,
#    u'February 1972': 0.8090189695358276,
#    u'February 1973': 0.42384201288223267,
#    u'February 1975': 0.8511626720428467,
#    u'February 2006': 0,
#    u'February 2007': 0.13166695833206177,
#    u'February 2008': 0,
#    u'February 4': 0.40435752272605896,
#    u'February Revolution': 0.21150612831115723,
#    u'United Kingdom general election, February 1974': 0.22277215123176575,
#    u'XXNILXX': 0}},
#  u"Pachinko Sexy Reaction 2 '' -RRB- developed by Sammy in [1998] .": {u'gold': u'1998',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.16855666041374207,
#    u'1998': 0.1751534342765808,
#    u'1998 AFL season': 0.4565468430519104,
#    u'1998 FIFA World Cup': 0.23274847865104675,
#    u'1998 Grand Prix motorcycle racing season': 0.30398863554000854,
#    u'1998 J. League': 0.2207971215248108,
#    u'1998 NCAA Division I-A football season': 0.23546862602233887,
#    u'1998 NFL season': 0.17061036825180054,
#    u'1998 NHL Entry Draft': 0.4372498393058777,
#    u'1998 Winter Olympics': 0.23371785879135132,
#    u'1998 in film': 0.2480865716934204,
#    u'1998 in literature': 0.2862195372581482,
#    u'1998 in music': 0.2633785605430603,
#    u'1998 in sports': 0.12516489624977112,
#    u'1998 in television': 0.3458659052848816,
#    u'1998 in video gaming': 0.1779535412788391,
#    u'Eurovision Song Contest 1998': 0.44481998682022095,
#    u'Ice hockey at the 1998 Winter Olympics': 0.24400508403778076,
#    u'United States House of Representatives elections, 1998': 0.24612915515899658,
#    u'XXNILXX': 0}},
#  u'Platoon of Company E , approximately four miles south of [Da Nang] on 11 April 1970 , he was mortally wounded by': {u'gold': u'Da Nang',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.18234601616859436,
#    u'Burmese honorific': 0.12510576844215393,
#    u'Burmese honorifics': 0.6120715141296387,
#    u'Burmese names': 0.3742052912712097,
#    u'Da Nang': 0.5569232106208801,
#    u'Da Nang Air Base': 0.17926931381225586,
#    u'Da Nang Airport': 0.8332655429840088,
#    u'Da Nang F.C.': 0.3742052912712097,
#    u'Da Nang International Airport': 0.3698538839817047,
#    u'Da Nang Port': 0.2408541440963745,
#    u'Danang': 0.5710258483886719,
#    u'Nang': 0.3742052912712097,
#    u'Nang (Sikhism)': 0,
#    u'Nang County': 0,
#    u'Nitrous oxide': 0.3870665729045868,
#    u'SHB Da Nang F.C.': 0.14955607056617737,
#    u'XXNILXX': 0,
#    u'\u0110\xe0 N\u1eb5ng': 0.39005807042121887,
#    u'\u0110\xe0 N\u1eb5ng International Airport': 0.217239648103714,
#    u'\u0110\xe0 N\u1eb5ng Railway Station': 0}},
#  u'President of the United States in the name of The [Congress] takes pride in presenting the MEDAL OF HONOR posthumously to': {u'gold': u'United States Congress',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8505304455757141,
#    u'Argentine National Congress': 0.8606879711151123,
#    u'Congre': 0.4789581894874573,
#    u'Congres': 0.743079423904419,
#    u'Congress': 0.4871407449245453,
#    u'Congress of Colombia': 0.8629807829856873,
#    u'Congress of Deputies (Spain)': 0.18132621049880981,
#    u'Congress of Guatemala': 0.1319703757762909,
#    u'Congress of Mexico': 0.4663989543914795,
#    u'Congress of the Philippines': 0.8606879711151123,
#    u'Congress of the Republic of Peru': 0.7506657242774963,
#    u'Congress of the Union': 0.713181734085083,
#    u'Congress of the United States': 0.2856290936470032,
#    u'Daniel Congre': 0,
#    u'Daniel Congr\xe9': 0,
#    u'Indian National Congress': 0.4370221495628357,
#    u'U.S. Congress': 0.7071007490158081,
#    u'United States Congress': 0.646605372428894,
#    u'United States House of Representatives': 0.8462106585502625,
#    u'XXNILXX': 0}},
#  u'Pure [paraffin] oil is marketed as the cleanest burning fuel , suitable': {u'gold': u'Paraffin',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1245013177394867,
#    u'Alkane': 0.2964901328086853,
#    u'Higher alkanes': 0.3987767696380615,
#    u'Hydrocarbon': 0.31303519010543823,
#    u'Kerosene': 0.5034293532371521,
#    u'Liquid paraffin (medicinal)': 0.17975804209709167,
#    u'Mineral oil': 0.3176754415035248,
#    u'Paraffin': 0.36894136667251587,
#    u'Paraffin (song)': 0,
#    u'Paraffin wax': 0.6572393774986267,
#    u'Petroleum jelly': 0.3047661781311035,
#    u'Tractor vaporising oil': 0.2266412079334259,
#    u'XXNILXX': 0,
#    u'alkane': 0.2964901328086853,
#    u'kerosene': 0.5034293532371521,
#    u'kerosine': 0.5033283233642578,
#    u'paraffin': 0.36894136667251587,
#    u'paraffin wax': 0.6572393774986267,
#    u'tractor vaporising oil': 0.2266412079334259,
#    u'wood': 0.34548088908195496}},
#  u'The [President of the United States] in the name of The Congress takes pride in presenting': {u'gold': u'President of the United States',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8069642782211304,
#    u'Barack Obama': 0.17818337678909302,
#    u'George W. Bush': 0.8443502187728882,
#    u'President': 0.6053839325904846,
#    u'President United States': 0,
#    u'President of Cyprus': 0.7840303182601929,
#    u'President of Liberia': 0.5375949144363403,
#    u'President of Pakistan': 0.4641491770744324,
#    u'President of Ukraine': 0.8075124025344849,
#    u'President of United States of America': 0,
#    u'President of the': 0,
#    u'President of the Comoros': 0.7934577465057373,
#    u'President of the Philippines': 0.6773180365562439,
#    u'President of the Senate of Romania': 0.58561772108078,
#    u'President of the United': 0,
#    u'President of the United States': 0.7396573424339294,
#    u'President of the United States of America': 0.5394803285598755,
#    u'President of the World Esperanto Association': 0,
#    u'United States presidential election, 2008': 0.44652214646339417,
#    u'XXNILXX': 0}},
#  u'The game is based on the Japan ese amusement of [pachinko] , which Sammy is noted for .': {u'gold': u'pachinko',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.6686258316040039,
#    u'Jumanji (Pachinko)': 0,
#    u'Pachinko': 0.8712302446365356,
#    u'Pachinko (band)': 0,
#    u'XXNILXX': 0,
#    u'pachinko': 0.19940125942230225}},
#  u'The game is based on the [Japan] ese amusement of pachinko , which Sammy is noted for': {u'gold': u'Japan',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.5766983032226562,
#    u'Cinema of Japan': 0.1653958559036255,
#    u'Empire of Japan': 0.6986556053161621,
#    u'Japan': 0.12585657835006714,
#    u'Japan (band)': 0.2870541214942932,
#    u'Japan Football Association': 0.2831326723098755,
#    u'Japan Rugby Football Union': 0.8359766602516174,
#    u'Japan national badminton team': 0.335701584815979,
#    u'Japan national baseball team': 0.6986556053161621,
#    u'Japan national basketball team': 0.21472185850143433,
#    u'Japan national football team': 0.234178364276886,
#    u'Japan national rugby union team': 0.4477900266647339,
#    u'Japan national under-23 football team': 0.5788384675979614,
#    u"Japan women's national football team": 0.8612090349197388,
#    u"Japan women's national volleyball team": 0.2172088325023651,
#    u'J\u014dmon period': 0.2309803068637848,
#    u'Recording Industry Association of Japan': 0.6277099251747131,
#    u'Tokugawa shogunate': 0.6219573616981506,
#    u'XXNILXX': 0,
#    u'Yayoi period': 0.29924100637435913}},
#  u'These products are often sold in [hardware store] s during the heating season .': {u'gold': u'Hardware store',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12510472536087036,
#    u'Chain store': 0.30850982666015625,
#    u'Data storage device': 0.17095762491226196,
#    u'General store': 0.359058678150177,
#    u'Hardware store': 0.236771821975708,
#    u'ITunes Store': 0.24757251143455505,
#    u'Magic store': 0,
#    u'Online shopping': 0.17499962449073792,
#    u'PlayStation Store': 0.23056071996688843,
#    u'Plunkett-Meeks Store': 0,
#    u'Retail': 0.19525066018104553,
#    u'Retailing': 0.19525066018104553,
#    u'Storage (memory)': 0.1592157483100891,
#    u'Store': 0.1895308792591095,
#    u'Windows Store': 0.1622467041015625,
#    u'XXNILXX': 0,
#    u'hardware store': 0.236771821975708,
#    u'iTunes Store': 0.24757251143455505,
#    u'retailer': 0.19525066018104553,
#    u'store': 0.1895308792591095}},
#  u'approximately four miles south of Da Nang on 11 April [1970] , he was mortally wounded by a grenade as he': {u'gold': u'1970',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.3460681438446045,
#    u'1970': 0.6926718354225159,
#    u'1970 FIFA World Cup': 0.30660825967788696,
#    u'1970 Formula One season': 0.5997126698493958,
#    u'1970 Grand Prix motorcycle racing season': 0.22215983271598816,
#    u'1970 Indianapolis 500': 0.3688831329345703,
#    u'1970 NBA draft': 0.553788959980011,
#    u'1970 NFL season': 0.7145150899887085,
#    u'1970 NHL Amateur Draft': 0.2893456220626831,
#    u'1970 college football season': 0.16973960399627686,
#    u'1970 in aviation': 0.8709763884544373,
#    u'1970 in film': 0.5256733894348145,
#    u'1970 in literature': 0.24742001295089722,
#    u'1970 in music': 0.3847833275794983,
#    u'1970 in spaceflight': 0.2885960340499878,
#    u'1970 in sports': 0.49237143993377686,
#    u'Quebec general election, 1970': 0.6143474578857422,
#    u'United Kingdom general election, 1970': 0.22510048747062683,
#    u'United States House of Representatives elections, 1970': 0.1250641644001007,
#    u'XXNILXX': 0}},
#  u'are Portuguese missions in East Timor -LRB- but not in [Singapore] or Kuala Lumpur -RRB- , Macau -LRB- but not Hong': {u'gold': u'Singapore',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1258784532546997,
#    u'2011 Singapore Grand Prix': 0.2359136939048767,
#    u'2012 Singapore Grand Prix': 0.2652735114097595,
#    u'A1 Team Singapore': 0.2003970742225647,
#    u'ATP Singapore': 0,
#    u'Battle of Singapore': 0.8067429065704346,
#    u'Football Association of Singapore': 0.3157797157764435,
#    u'Port of Singapore': 0.26408714056015015,
#    u'Singapore': 0.7909253239631653,
#    u'Singapore (1947 film)': 0.3356531858444214,
#    u'Singapore Changi Airport': 0.40954166650772095,
#    u'Singapore FA': 0.23891711235046387,
#    u'Singapore Lions': 0.23891711235046387,
#    u'Singapore Open (badminton)': 0.317913293838501,
#    u"Singapore Open (men's tennis)": 0.17259716987609863,
#    u'Singapore Rugby Union': 0.18770968914031982,
#    u'Singapore national cricket team': 0.43738800287246704,
#    u'Singapore national football team': 0.30998992919921875,
#    u'Singapore national rugby union team': 0.2877625823020935,
#    u'XXNILXX': 0}},
#  u'around the same time as the Wales Millennium Centre in [Cardiff] .': {u'gold': u'Cardiff',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12480330467224121,
#    u'Cardiff': 0.3474593460559845,
#    u'Cardiff (UK Parliament constituency)': 0.17833438515663147,
#    u'Cardiff Airport': 0.44650712609291077,
#    u'Cardiff Arms Park': 0.34152066707611084,
#    u'Cardiff Blues': 0.27286964654922485,
#    u'Cardiff Central railway station': 0.29066580533981323,
#    u'Cardiff City F.C.': 0.319713294506073,
#    u'Cardiff Council': 0.2444118857383728,
#    u'Cardiff Devils': 0.38496118783950806,
#    u'Cardiff International White Water': 0.26053446531295776,
#    u'Cardiff RFC': 0.36613285541534424,
#    u'Cardiff University': 0.39930129051208496,
#    u'Cardiff, Maryland': 0.17123740911483765,
#    u'Cardiff, New South Wales': 0.17503169178962708,
#    u'Cardiff, Wales': 0.2753385901451111,
#    u'Millennium Stadium': 0.2603607773780823,
#    u'Ninian Park': 0.4614519476890564,
#    u'SWALEC Stadium': 0.3240664303302765,
#    u'XXNILXX': 0}},
#  u'current interests in Europe and its historical linkages to its [former colonies in Africa] , South America and Asia .': {u'gold': u'Portuguese-speaking African countries',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1267620027065277,
#    u'Bird colony': 0.44406720995903015,
#    u'British Empire': 0.7779157161712646,
#    u'Colonies': 0.6779327392578125,
#    u'Colonies in': 0,
#    u'Colony': 0.6779327392578125,
#    u'Colony (In Flames album)': 0.164883553981781,
#    u'Colony (The X-Files)': 0.20906966924667358,
#    u'Colony (biology)': 0.2521982789039612,
#    u'Decolonization of Africa': 0.715769350528717,
#    u'Former colonies': 0,
#    u'Former colonies and territories in Canada': 0.213786780834198,
#    u'Former colonies in Africa': 0,
#    u'French colonial empire': 0.6838143467903137,
#    u'Portuguese Empire': 0.7815757989883423,
#    u'Portuguese-speaking African countries': 0.7211761474609375,
#    u'XXNILXX': 0,
#    u'colonies in': 0,
#    u'colony': 0.6779327392578125,
#    u'former colonies in Africa': 0}},
#  u'enhanced the finest traditions of the Marine Corps and the [United States Naval Service] .': {u'gold': u'United States Navy',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.44846484065055847,
#    u'Community service': 0.6317931413650513,
#    u'Department of the Navy': 0.17695394158363342,
#    u"Her Majesty's Naval Service": 0.813727855682373,
#    u'Irish Naval Service': 0.8516099452972412,
#    u'Naval Service': 0.20864525437355042,
#    u'Naval Service (Ireland)': 0.19210556149482727,
#    u'Naval Service (United Kingdom)': 0,
#    u'Royal Canadian Navy': 0.23958808183670044,
#    u'Service': 0.15538537502288818,
#    u'Service (album)': 0.6621953248977661,
#    u'Service (economics)': 0.5710258483886719,
#    u'Service (record label)': 0.5710258483886719,
#    u'States Naval Service': 0,
#    u'U.S. Department of the Navy': 0.1616370975971222,
#    u'U.S. Navy': 0.813727855682373,
#    u'United States Department of the Navy': 0.44846484065055847,
#    u'United States Naval Service': 0.15066906809806824,
#    u'United States Navy': 0.2505859136581421,
#    u'XXNILXX': 0}},
#  u'enlisted in the United States Marine Corps on 4 February [1969] , in Chicago , Illinois .': {u'gold': u'1969',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.5548466444015503,
#    u'1969': 0.1325417160987854,
#    u'1969 American Football League season': 0.8618532419204712,
#    u'1969 Formula One season': 0.24473053216934204,
#    u'1969 Grand Prix motorcycle racing season': 0.8701677918434143,
#    u'1969 Indianapolis 500': 0.27191030979156494,
#    u'1969 NBA draft': 0.5446345806121826,
#    u'1969 NFL season': 0.7175661325454712,
#    u'1969 NHL Amateur Draft': 0.4672185480594635,
#    u'1969 college football season': 0.3219163715839386,
#    u'1969 in aviation': 0.32901108264923096,
#    u'1969 in baseball': 0.2638494372367859,
#    u'1969 in film': 0.28274935483932495,
#    u'1969 in literature': 0.8639829158782959,
#    u'1969 in music': 0.17933356761932373,
#    u'1969 in spaceflight': 0.1765163540840149,
#    u'Australian federal election, 1969': 0.47177985310554504,
#    u'Eurovision Song Contest 1969': 0.43290895223617554,
#    u'Kenyan general election, 1969': 0,
#    u'XXNILXX': 0}},
#  u'filling station s is more likely to be contaminated with [water] than kerosene obtained in prepackaged containers .': {u'gold': u'Water',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12555772066116333,
#    u'Drinking water': 0.36856991052627563,
#    u'Properties of water': 0.21445190906524658,
#    u'Water': 0.2451716959476471,
#    u'Water (1985 film)': 0.2519015669822693,
#    u'Water (2005 film)': 0.1968749761581421,
#    u'Water (Battlestar Galactica)': 0.2596203088760376,
#    u'Water (Brad Paisley song)': 0,
#    u'Water (The Who song)': 0.18920111656188965,
#    u'Water (Wu Xing)': 0.22887873649597168,
#    u'Water (classical element)': 0.2623245120048523,
#    u'Water (molecule)': 0.2144852578639984,
#    u'Water industry': 0.2459934651851654,
#    u'Water on Mars': 0.5217888951301575,
#    u'Water pollution': 0.4198726713657379,
#    u'Water supply': 0.33489781618118286,
#    u'XXNILXX': 0,
#    u'water': 0.2451716959476471,
#    u'water (classical element)': 0.2623245120048523,
#    u'water (molecule)': 0.2144852578639984}},
#  u"had a brief role in Alfred Hitchcock 's film '' [The Birds] '' and a larger role in the original '' Invasion": {u'gold': u'The Birds (film)',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.1252661645412445,
#    u'Bird': 0.2726845145225525,
#    u'Bird (disambiguation)': 0.2726845145225525,
#    u'Bird (film)': 0.3652856945991516,
#    u'Birds': 0.2726845145225525,
#    u'Birds (Anouk song)': 0.16703617572784424,
#    u'Birds (Bic Runga album)': 0,
#    u'Birds (Kate Nash song)': 0,
#    u'Birds, Illinois': 0.18538600206375122,
#    u'Greg Bird': 0.31237828731536865,
#    u'Larry Bird': 0.5978271961212158,
#    u'Ryan Bird': 0,
#    u'Sue Bird': 0.5925354361534119,
#    u'The Birds': 0.2935909032821655,
#    u'The Birds (Respighi)': 0.23016533255577087,
#    u'The Birds (band)': 0.20402851700782776,
#    u'The Birds (film)': 0.5453930497169495,
#    u'The Birds (play)': 0.5845572352409363,
#    u'The Birds (story)': 0.46750408411026,
#    u'XXNILXX': 0}},
#  u'in Massachusetts and Rhode Island , as well as Congressman [Barney Frank] .': {u'gold': u'Barney Frank',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12805894017219543,
#    u'Barney Frank': 0.7481804490089417,
#    u'Frank': 0.40006348490715027,
#    u'Frank (Amy Winehouse album)': 0.20026779174804688,
#    u'Frank (band)': 0.19081562757492065,
#    u'Frank (comics)': 0.28117936849594116,
#    u'Frank (film)': 0.16330716013908386,
#    u'Frank (given name)': 0.19060587882995605,
#    u'Frank (magazine)': 0.23090749979019165,
#    u'Frank Butcher': 0.6974626779556274,
#    u'Frank Hardy (The Hardy Boys)': 0.38130396604537964,
#    u'Frank James': 0.524050772190094,
#    u'Frank McLaury': 0.5908914804458618,
#    u'Frank Patrick (ice hockey)': 0.7470649480819702,
#    u'Frank Sinatra': 0.8263683319091797,
#    u'Frank de Boer': 0.2322714626789093,
#    u'Frank, Alberta': 0.5931161642074585,
#    u'Franks': 0.5260739922523499,
#    u'Wolfgang Frank': 0.16793102025985718,
#    u'XXNILXX': 0}},
#  u"is an ecchi arcade game -LRB- more adult than '' [Pachinko Sexy Reaction 2] '' -RRB- developed by Sammy in 1998 .": {u'gold': u'Pachinko Sexy Reaction 2',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.2760811448097229,
#    u'Pachinko Sexy': 0,
#    u'Pachinko Sexy Reaction 2': 0,
#    u'Sexual attraction': 0.4014636278152466,
#    u'Sexy': 0.4777037799358368,
#    u'Sexy (Glee)': 0.16599547863006592,
#    u'Sexy (Hitomi song)': 0,
#    u'Sexy (Klymaxx Song)': 0,
#    u'Sexy (Klymaxx song)': 0,
#    u'Sexy (Roxane LeBrasse song)': 0,
#    u'Sexy (film)': 0,
#    u'Sexy (novel)': 0,
#    u'Sexy Reaction': 0,
#    u'Sexy prime': 0.5055193305015564,
#    u'XXNILXX': 0,
#    u'sexual attraction': 0.12425071001052856}},
#  u'kerosene burner has to be heated by means of a [primer] , usually methylated spirit , which is burnt in a': {u'gold': u'Primer',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12602022290229797,
#    u'Blasting cap': 0.26353901624679565,
#    u'Book of hours': 0.23240530490875244,
#    u'Percussion cap': 0.3110377788543701,
#    u'Primer': 0.17411372065544128,
#    u'Primer (Comico)': 0,
#    u'Primer (album)': 0,
#    u'Primer (cosmetics)': 0,
#    u'Primer (film)': 0.1464354395866394,
#    u'Primer (firearm)': 0.18657982349395752,
#    u'Primer (molecular biology)': 0.2001337707042694,
#    u'Primer (paint)': 0.24969664216041565,
#    u'Primer (textbook)': 0.5322562456130981,
#    u'Primer (video)': 0,
#    u'Primer-E Primer': 0,
#    u'XXNILXX': 0,
#    u'percussion cap': 0.3110377788543701,
#    u'primer': 0.17411372065544128,
#    u'primer (molecular biology)': 0.2001337707042694,
#    u'primer (textbook)': 0.5322562456130981}},
#  u"presented the nation 's highest honor '' mdash ; the [Medal of Honor] '' mdash ; for his heroism in April 1970 in": {u'gold': u'Medal of Honor',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.8378962278366089,
#    u'IEEE Medal of Honor': 0.1651298701763153,
#    u'IRI Medal': 0.8546276688575745,
#    u'Laura Ingalls Wilder Medal': 0.7019245028495789,
#    u'Medal': 0.4078066051006317,
#    u'Medal (band)': 0,
#    u'Medal Honor': 0,
#    u'Medal game': 0.783560574054718,
#    u'Medal of': 0,
#    u'Medal of Honor': 0.2642236053943634,
#    u'Medal of Honor (1999 video game)': 0.1267901062965393,
#    u'Medal of Honor (2010 video game)': 0.5643385052680969,
#    u'Medal of Honor (comics)': 0.5566357970237732,
#    u'Medal of Honor (series)': 0.17019641399383545,
#    u'Medal of Honor (video game)': 0.783560574054718,
#    u'Medals of Honor (Japan)': 0.7528677582740784,
#    u'Military awards and decorations': 0.38089096546173096,
#    u'Olympic medal': 0.2241080403327942,
#    u'University Medal': 0.2642236053943634,
#    u'XXNILXX': 0}},
#  u'relations with Indonesia in 1999 , broken after the 1975 [Indonesian invasion of East Timor] , there is now an embassy in Jakarta .': {u'gold': u'Indonesian invasion of East Timor',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12622278928756714,
#    u'2003 invasion of Iraq': 0.828751802444458,
#    u'Allied invasion of Italy': 0.5992847681045532,
#    u'Allied invasion of Sicily': 0.720485508441925,
#    u'Indonesia invasion of East Timor': 0.6924430131912231,
#    u'Indonesian invasion': 0,
#    u'Indonesian invasion East Timor': 0,
#    u'Indonesian invasion of East Timor': 0.7801302671432495,
#    u'Invasion': 0.39097094535827637,
#    u'Invasion (1997 film)': 0.1699766218662262,
#    u'Invasion (TV series)': 0.24017754197120667,
#    u'Invasion of': 0,
#    u'Invasion of East': 0,
#    u'Invasion of Normandy': 0.5966574549674988,
#    u'Invasion of Poland': 0.7049409747123718,
#    u'Korean War': 0.8569663763046265,
#    u'The Invasion (professional wrestling)': 0.2495931088924408,
#    u'XXNILXX': 0,
#    u'invasion': 0.39097094535827637,
#    u'invasion of East': 0}},
#  u'series of cookbook s and hosted a television series on [microwave] cooking .': {u'gold': u'Microwave oven',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12688717246055603,
#    u'British Telecom microwave network': 0.19852587580680847,
#    u'Cavalier Computer': 0,
#    u'EM spectrum': 0.33123892545700073,
#    u'Electromagnetic spectrum': 0.33123892545700073,
#    u'Microwave': 0.6397882103919983,
#    u'Microwave (game)': 0,
#    u'Microwave chemistry': 0.19846948981285095,
#    u'Microwave oven': 0.3139879107475281,
#    u'Microwave radio relay': 0.72641921043396,
#    u'Microwave radiometer': 0.22766709327697754,
#    u'Microwave spectroscopy': 0.5067650079727173,
#    u'Microwave transmission': 0.7370589971542358,
#    u'Microwaves': 0.5454196929931641,
#    u'Rotational spectroscopy': 0.5067650079727173,
#    u'Waldorf Microwave': 0,
#    u'XXNILXX': 0,
#    u'microwave': 0.6397882103919983,
#    u'microwave oven': 0.3139879107475281,
#    u'microwave transmission': 0.7370589971542358}},
#  u"than '' Pachinko Sexy Reaction 2 '' -RRB- developed by [Sammy] in 1998 .": {u'gold': u'Sammy',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.20696347951889038,
#    u'Darren Sammy': 0.18505465984344482,
#    u'Hendra Samuel Simorangkir': 0,
#    u'List of Prison Break minor characters': 0.29359740018844604,
#    u'Sammy': 0.12473005056381226,
#    u'Sammy (Cracker)': 0,
#    u'Sammy (Prison Break character)': 0.18479633331298828,
#    u'Sammy (TV series)': 0,
#    u'Sammy (band)': 0,
#    u'Sammy (comics)': 0.5485057830810547,
#    u'Sammy (song)': 0,
#    u'Sammy Ameobi': 0.7731402516365051,
#    u'Sammy Babitzin': 0.44127607345581055,
#    u'Sammy Corporation': 0.5246254205703735,
#    u'Sammy Gravano': 0.1537521481513977,
#    u'Sammy Hagar': 0.5451704859733582,
#    u'Sammy Ofer': 0.12527057528495789,
#    u'Sammy Sosa': 0.153801828622818,
#    u'Sega Sammy Holdings': 0.5451704859733582,
#    u'XXNILXX': 0}},
#  u"was a United States Marine Corps lance corporal who was [posthumous] ly presented the nation 's highest honor '' mdash ;": {u'gold': u'Posthumous recognition',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.7524242401123047,
#    u'List of prizes, medals and awards': 0.17449861764907837,
#    u'List of works published posthumously': 0.12584072351455688,
#    u'Posthumou': 0,
#    u'Posthumous': 0.7524242401123047,
#    u'Posthumous (EP)': 0,
#    u'Posthumous award': 0.6052759885787964,
#    u'Posthumous birth': 0.4814663529396057,
#    u'Posthumous name': 0.7524242401123047,
#    u'Posthumous publication': 0.17449861764907837,
#    u'Posthumous recognition': 0.17337554693222046,
#    u'Posthumous work': 0.4809941053390503,
#    u"Shakespeare's reputation": 0.16561809182167053,
#    u'XXNILXX': 0,
#    u'posthumou': 0,
#    u'posthumous': 0.4680342972278595,
#    u'posthumous award': 0.18077784776687622,
#    u'posthumous birth': 0.5348818898200989,
#    u'posthumous recognition': 0.7968037128448486,
#    u'posthumous work': 0.37603434920310974}},
#  u'with a diverse programme mix of comedy , opera , [dance] , music and drama .': {u'gold': u'Dance',
#   u'training': True,
#   u'vals': {u'-NIL-': 0.12544238567352295,
#    u'Dance': 0.581364631652832,
#    u'Dance (Gary Numan album)': 0.2370603084564209,
#    u'Dance (Nina Girado song)': 0.14920517802238464,
#    u'Dance (music)': 0.3124655485153198,
#    u'Dance Music': 0.37508103251457214,
#    u'Dance music': 0.37508103251457214,
#    u'Dance radio': 0.48922836780548096,
#    u'Dance-pop': 0.22514915466308594,
#    u'Electronic dance music': 0.27697813510894775,
#    u'Hot Dance Club Play': 0.5715277194976807,
#    u'Hot Dance Club Songs': 0.5866890549659729,
#    u'Indian classical dance': 0.6403675079345703,
#    u'Irish dance': 0.3889230191707611,
#    u'XXNILXX': 0,
#    u'dance': 0.581364631652832,
#    u'dance (music)': 0.3124655485153198,
#    u'dance music': 0.37508103251457214,
#    u'dance-pop': 0.22514915466308594,
#    u'electronic dance music': 0.27697813510894775}}}

# %%
queries.values()[0]
# Out:
# {u', 1921 August 8 , 1984 -RRB- , born in [Philadelphia] , was an American television and motion picture actor .': {u'gold': u'Philadelphia',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'2014\u201315 Philadelphia Flyers season': 0,
#    u'Advanta Championships of Philadelphia': 0.1833834946155548,
#    u'Ala\u015fehir': 0.23164361715316772,
#    u'Philadelphia': 0.8694509267807007,
#    u'Philadelphia (film)': 0.40520280599594116,
#    u'Philadelphia (magazine)': 0.5469392538070679,
#    u'Philadelphia 76ers': 0.6569768786430359,
#    u'Philadelphia County, Pennsylvania': 0.36047476530075073,
#    u'Philadelphia Eagles': 0.8495123386383057,
#    u'Philadelphia Flyers': 0.5137590169906616,
#    u'Philadelphia International Airport': 0.3388158679008484,
#    u'Philadelphia Phantoms': 0.16947954893112183,
#    u'Philadelphia Phillies': 0.8689995408058167,
#    u'Philadelphia Union': 0.138202965259552,
#    u'Philadelphia, Mississippi': 0.6829430460929871,
#    u'Philadelphia, Pennsylvania': 0.8625656366348267,
#    u'Roman Catholic Archdiocese of Philadelphia': 0.15483418107032776,
#    u'U.S. Pro Indoor': 0.16976237297058105,
#    u'XXNILXX': 0}},
#  u"-RRB- and as Roger '' Cutes '' Buell on '' [The Mothers-in-Law] '' .": {u'gold': u'The Mothers-in-Law',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Mothers-in-Law': 0.6849562525749207,
#    u'The Mothers-in-Law': 0.8580461740493774,
#    u'XXNILXX': 0}},
#  u"Bascombe '' -RRB- about [Gordon MacRae] -LRB- '' Billy Bigelow '' -RRB- in the famous ''": {u'gold': u'Gordon MacRae',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Calum MacRae': 0,
#    u'Gordon MacRae': 0.8358817100524902,
#    u'Jade MacRae': 0.20423036813735962,
#    u'MacRae': 0.3621269464492798,
#    u'MacRae (surname)': 0,
#    u'William MacRae': 0,
#    u'XXNILXX': 0}},
#  u"Birds '' and a larger role in the original '' [Invasion of the Body Snatchers] '' , having portrayed a physician in the '' book-end": {u'gold': u'Invasion of the Body Snatchers',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'2003 invasion of Iraq': 0.8634963631629944,
#    u'Battle of France': 0.7265636920928955,
#    u'Invasion': 0.35082578659057617,
#    u'Invasion (1965 film)': 0.1741202175617218,
#    u'Invasion (1997 film)': 0.13784247636795044,
#    u'Invasion (TV series)': 0.2047957181930542,
#    u'Invasion Body Snatchers': 0,
#    u'Invasion of': 0,
#    u'Invasion of Normandy': 0.763329267501831,
#    u'Invasion of Poland': 0.8036489486694336,
#    u'Invasion of Poland (1939)': 0.8036489486694336,
#    u'Invasion of the': 0,
#    u'Invasion of the Body': 0,
#    u'Invasion of the Body Snatchers': 0.8355892300605774,
#    u'Invasion of the Body Snatchers (1956 film)': 0.7242826223373413,
#    u'Invasion of the Body Snatchers (1978 film)': 0.1407342255115509,
#    u'Invasion of the Body Snatchers (1978 film) ': 0,
#    u'The Invasion (professional wrestling)': 0.15881997346878052,
#    u'XXNILXX': 0}},
#  u"Cooley on '' The Dick Van Dyke Show '' , [Fred Rutherford] on '' Leave It to Beaver '' -LRB- Mr.": {u'gold': u'Fred Rutherford',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Alexander Cameron Rutherford': 0.17940548062324524,
#    u'Ernest Rutherford': 0.6761009097099304,
#    u'Fred Rutherford': 0.8313846588134766,
#    u'Jock Rutherford': 0.12979808449745178,
#    u'John Rutherford (rugby union)': 0.13828682899475098,
#    u'Johnny Rutherford': 0.35508978366851807,
#    u'Rutherford': 0.45398950576782227,
#    u'Rutherford (NJT station)': 0.2751075029373169,
#    u'Rutherford AVA': 0.23069077730178833,
#    u'Rutherford County, North Carolina': 0.1649327576160431,
#    u'Rutherford County, Tennessee': 0.17546626925468445,
#    u'Rutherford GO Station': 0.1411416232585907,
#    u'Rutherford, California': 0.6509907245635986,
#    u'Rutherford, Edmonton': 0.1375981867313385,
#    u'Rutherford, New Jersey': 0.3477044105529785,
#    u'Rutherford, New South Wales': 0.1403418481349945,
#    u'Rutherford, Pennsylvania': 0,
#    u'Rutherford, Tennessee': 0.1296670138835907,
#    u'XXNILXX': 0}},
#  u"Deacon also appeared on '' [The Addams Family] '' in April 1965 , and puts Cousin Itt through": {u'gold': u'The Addams Family',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Addams Family': 0.6512760519981384,
#    u'Addams Family (pinball)': 0.19200322031974792,
#    u"Children's film": 0,
#    u'Family': 0.1509825587272644,
#    u'Family (1976 TV series)': 0.6526721715927124,
#    u'Family (band)': 0.7843923568725586,
#    u'Family (biology)': 0.29368144273757935,
#    u'Family Channel': 0.1483367383480072,
#    u'The Addams Family': 0.8275148868560791,
#    u'The Addams Family (1964 TV series)': 0.6910790205001831,
#    u'The Addams Family (1973 animated series)': 0.15177464485168457,
#    u'The Addams Family (1992 animated series)': 0.14551550149917603,
#    u'The Addams Family (film)': 0.30883538722991943,
#    u'The Addams Family (musical)': 0.578612208366394,
#    u'The Addams Family (pinball)': 0.19200322031974792,
#    u'The Addams Family (video game)': 0.2732948064804077,
#    u'The Addams Family Theme': 0.21253803372383118,
#    u'XXNILXX': 0,
#    u'family (biology)': 0.29368144273757935}},
#  u"Game '' , and played '' Horace Vandergelder '' opposite [Phyllis Diller] 's '' Dolly Gallagher Levi '' in a touring production": {u'gold': u'Phyllis Diller',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Diller': 0.8061450719833374,
#    u'Diller Glacier': 0,
#    u'Diller, Nebraska': 0.1603698432445526,
#    u'LeGrande A. Diller': 0,
#    u'Phyllis Diller': 0.8678340911865234,
#    u'XXNILXX': 0}},
#  u"He had a brief role in [Alfred Hitchcock] 's film '' The Birds '' and a larger role": {u'gold': u'Alfred Hitchcock',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Alfred Hitchcock': 0.8059481978416443,
#    u'Alfred Hitchcock (book)': 0,
#    u'Alfred Hitchcock (police officer)': 0,
#    u'Cameron Hitchcock': 0,
#    u'E. Hitchcock': 0.1677514910697937,
#    u'Edward Hitchcock': 0.1677514910697937,
#    u'Hitchcock': 0.6482489109039307,
#    u'Hitchcock (automobile)': 0,
#    u'Hitchcock (film)': 0.13832923769950867,
#    u'Hitchcock County, Nebraska': 0.12869134545326233,
#    u'Hitchcock, Oklahoma': 0,
#    u'Hitchcock, South Dakota': 0.1275428831577301,
#    u'Hitchcock, Texas': 0.13749775290489197,
#    u'Ken Hitchcock': 0.2563866972923279,
#    u'Sterling Hitchcock': 0.3485456109046936,
#    u'The Birds (film)': 0.2332702875137329,
#    u'Tom Hitchcock': 0,
#    u'Tommy Hitchcock (racing driver)': 0,
#    u'XXNILXX': 0}},
#  u"His best-known roles are Mel Cooley on '' [The Dick Van Dyke Show] '' , Fred Rutherford on '' Leave It to Beaver": {u'gold': u'The Dick Van Dyke Show',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Agricultural show': 0.25644636154174805,
#    u'Days of Our Lives': 0.4640484154224396,
#    u'Days of our Lives': 0.4640484154224396,
#    u'Dick Van Dyke Show': 0.7615524530410767,
#    u'Dyke Show': 0,
#    u'Eric Show': 0.26746517419815063,
#    u'General Hospital': 0.6943050026893616,
#    u'Show': 0.1607435643672943,
#    u'Show (The Cure album)': 0.20506733655929565,
#    u'Show (The Jesus Lizard album)': 0,
#    u'Show (film)': 0.12918934226036072,
#    u'Show (magazine)': 0.2136220633983612,
#    u'Showbiz (producer)': 0.5612326860427856,
#    u'Showbiz and A.G.': 0.5612326860427856,
#    u'The Dick Van Dyke Show': 0.8454205989837646,
#    u'The Dick Van Dyke Show ': 0,
#    u'The Van Dyke Show': 0.13048982620239258,
#    u'Van Dyke Show': 0.13048982620239258,
#    u'XXNILXX': 0}},
#  u'In real life , he was a gourmet [chef] .': {u'gold': u'Chef',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Celebrity chef': 0.5118269324302673,
#    u'Chef': 0.8155021667480469,
#    u'Chef (2014 film)': 0.15886905789375305,
#    u'Chef (South Park character)': 0.7191298007965088,
#    u'Chef (South Park)': 0.7242103219032288,
#    u'Chef (company)': 0.1392345130443573,
#    u'Chef (film)': 0.15886905789375305,
#    u'Chef (programming language)': 0.13418543338775635,
#    u'Chef (software)': 0.14388558268547058,
#    u"Chef's uniform": 0.14098191261291504,
#    u'Cook (profession)': 0.6391148567199707,
#    u'Isaac Hayes': 0.8334829807281494,
#    u'Japanese cuisine': 0.23640602827072144,
#    u'Magician': 0.7457906603813171,
#    u'Michael Smith (chef)': 0.2249334454536438,
#    u'Swedish Chef': 0.3320505917072296,
#    u'XXNILXX': 0,
#    u'celebrity chef': 0.5118269324302673,
#    u'chef': 0.8155021667480469}},
#  u"In the 1956 motion picture '' [Carousel] '' , adapted from the classic Rodgers and Hammerstein stage": {u'gold': u'Carousel (film)',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Carousel': 0.4345928430557251,
#    u'Carousel (1923 film)': 0.13549858331680298,
#    u'Carousel (1956 film)': 0.7902743816375732,
#    u'Carousel (Blink-182 song)': 0,
#    u'Carousel (Leila K album)': 0,
#    u'Carousel (TV channel)': 0.19608667492866516,
#    u'Carousel (Vanessa Carlton song)': 0.14123067259788513,
#    u'Carousel (advert)': 0.1389126181602478,
#    u'Carousel (advertisement)': 0.1389126181602478,
#    u'Carousel (album)': 0,
#    u'Carousel (ballet)': 0.17563962936401367,
#    u'Carousel (film)': 0.8144166469573975,
#    u'Carousel (musical)': 0.8219839930534363,
#    u'Carousel slide projector': 0.2567857503890991,
#    u'Cheshire Cat (Blink-182 album)': 0.1329030692577362,
#    u'Ford Carousel': 0,
#    u'Rabbits on the Run': 0.14123067259788513,
#    u'Westfield Carousel': 0.1453789472579956,
#    u'XXNILXX': 0}},
#  u"Invasion of the Body Snatchers '' , having portrayed a [physician] in the '' book-end '' sequences added to the beginning": {u'gold': u'Physician',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Doctor of Medicine': 0.32091981172561646,
#    u'General practitioner': 0.16384541988372803,
#    u'Internal medicine': 0.18447831273078918,
#    u'Islamic medicine': 0.7613822221755981,
#    u'John Snow (physician)': 0.4499253034591675,
#    u'Medicine': 0.30891525745391846,
#    u'Medicine in medieval Islam': 0.7613822221755981,
#    u'Medicine in the medieval Islamic world': 0.7643983960151672,
#    u'Physician': 0.8457880616188049,
#    u'Physician (horse)': 0,
#    u'Physics': 0.4012599289417267,
#    u'Physiology': 0.17842751741409302,
#    u"Ship's doctor": 0,
#    u'Traditional Chinese medicine': 0.4005093574523926,
#    u'XXNILXX': 0,
#    u'medical doctor': 0.8165948390960693,
#    u'medicine': 0.30891525745391846,
#    u'physician': 0.8457880616188049,
#    u'physiology': 0.17842751741409302}},
#  u"Levi '' in a touring production of the musical '' [Hello , Dolly !] '' .": {u'gold': u'Hello, Dolly! (musical)',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Hello': 0.2524941563606262,
#    u'Hello (2008 film)': 0.14543381333351135,
#    u'Hello (Ice Cube song)': 0.14809343218803406,
#    u'Hello (Lionel Richie song)': 0.17202827334403992,
#    u'Hello (Martin Solveig song)': 0.13950401544570923,
#    u'Hello (band)': 0.25759410858154297,
#    u'Hello (magazine)': 0.2524941563606262,
#    u'Hello ,': 0,
#    u'Hello , Dolly': 0,
#    u'Hello , Dolly !': 0,
#    u'Hello Dolly': 0,
#    u'Hello Dolly (film)': 0.32076534628868103,
#    u'Hello Dolly (movie)': 0.31379780173301697,
#    u'Hello Dolly (song)': 0.749738335609436,
#    u'Hello, Dolly!': 0,
#    u'Hello, Dolly! (film)': 0.32076534628868103,
#    u'Hello, Dolly! (musical)': 0.8361502885818481,
#    u'Hello, Dolly! (song)': 0.749738335609436,
#    u'XXNILXX': 0}},
#  u'Richard Deacon -LRB- May 14 , 1921 August 8 , [1984] -RRB- , born in Philadelphia , was an American television': {u'gold': u'1984',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'1984': 0.8732270002365112,
#    u'1984 Grand Prix motorcycle racing season': 0.14833614230155945,
#    u'1984 NBA draft': 0.19109615683555603,
#    u'1984 NCAA Division I-A football season': 0.1529652178287506,
#    u'1984 NFL season': 0.338204026222229,
#    u'1984 NHL Entry Draft': 0.2681371569633484,
#    u'1984 Summer Olympics': 0.7921844124794006,
#    u'1984 Winter Olympics': 0.33983808755874634,
#    u'1984 in film': 0.18055951595306396,
#    u'1984 in literature': 0.16943144798278809,
#    u'1984 in music': 0.14097216725349426,
#    u'1984 in television': 0.3184438645839691,
#    u'1984 in video gaming': 0.13033482432365417,
#    u'Australian federal election, 1984': 0.27974992990493774,
#    u'Nineteen Eighty-Four': 0.2814434766769409,
#    u'UEFA Euro 1984': 0.17520898580551147,
#    u'United States House of Representatives elections, 1984': 0.13865318894386292,
#    u'United States presidential election, 1984': 0.3543718457221985,
#    u'XXNILXX': 0}},
#  u'Richard Deacon -LRB- May 14 , 1921 [August 8] , 1984 -RRB- , born in Philadelphia , was an': {u'gold': u'August 8',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'/August': 0.7666029930114746,
#    u'August': 0.7666029930114746,
#    u'August (1996 film)': 0.14161014556884766,
#    u'August (2008 film)': 0.15747785568237305,
#    u'August (Eric Clapton album)': 0.14086180925369263,
#    u'August (Fringe)': 0.19575414061546326,
#    u'August (company)': 0.13817396759986877,
#    u'August 1966': 0.35340338945388794,
#    u'August 1971': 0.3560347557067871,
#    u'August 1972': 0.21684500575065613,
#    u'August 1973': 0.5290806889533997,
#    u'August 1975': 0.37325188517570496,
#    u'August 2007': 0.14272406697273254,
#    u'August 8': 0.8739560842514038,
#    u'August 8 (Eastern Orthodox liturgics)': 0.1350807249546051,
#    u'August, California': 0,
#    u'CMLL Super Viernes (August 2014)': 0,
#    u'Papal conclave, August 1978': 0.22462087869644165,
#    u'XXNILXX': 0}},
#  u'Richard Deacon -LRB- May 14 , [1921] August 8 , 1984 -RRB- , born in Philadelphia ,': {u'gold': u'1921',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'144th New York State Legislature': 0.4187002182006836,
#    u'1921': 0.8751060366630554,
#    u'1921 APFA season': 0.3549869954586029,
#    u'1921 Green Bay Packers season': 0,
#    u'1921 Indianapolis 500': 0.12742182612419128,
#    u'1921 NFL season': 0.3549869954586029,
#    u'1921 VFL season': 0.13476350903511047,
#    u'1921 World Series': 0.3055974245071411,
#    u'1921 college football season': 0.14451253414154053,
#    u'1921 in Canada': 0.8163086771965027,
#    u'1921 in aviation': 0.21419915556907654,
#    u'1921 in film': 0.14145764708518982,
#    u'1921 in literature': 0.21152561902999878,
#    u'1921 in poetry': 0.28146040439605713,
#    u'1921 in the United States': 0.31008702516555786,
#    u'Canadian federal election, 1921': 0.13816624879837036,
#    u'Irish elections, 1921': 0.43322721123695374,
#    u'Norwegian parliamentary election, 1921': 0.1600862741470337,
#    u'XXNILXX': 0}},
#  u'Richard Deacon -LRB- [May 14] , 1921 August 8 , 1984 -RRB- , born in': {u'gold': u'May 14',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'/May': 0.5427804589271545,
#    u'Ben May': 0.13512301445007324,
#    u'Brian May': 0.8314448595046997,
#    u'CMLL Super Viernes (May 2014)': 0,
#    u'Darrell May': 0.23553675413131714,
#    u'David May (footballer)': 0.13097712397575378,
#    u'Jonny May': 0.12785762548446655,
#    u'Kathy May': 0,
#    u'List of Pok\xe9mon anime characters': 0.5493520498275757,
#    u'May': 0.5427804589271545,
#    u'May (Pok\xe9mon)': 0.5493520498275757,
#    u'May (film)': 0.17514082789421082,
#    u'May 14': 0.8704898357391357,
#    u'May 14 (Eastern Orthodox liturgics)': 0.13519388437271118,
#    u'May, Oklahoma': 0.13114610314369202,
#    u'May, Texas': 0.160264790058136,
#    u'Sean May': 0.25917142629623413,
#    u'Stevie May': 0.1393178105354309,
#    u'XXNILXX': 0}},
#  u'The bald and usually bespectacled [character actor] often portrayed imperious authority figures .': {u'gold': u'Character actor',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Academy Award for Best Actor': 0.22181960940361023,
#    u'Acting': 0.8180662989616394,
#    u'Actor': 0.8578702211380005,
#    u'Actor (UML)': 0.12766671180725098,
#    u'Actor (album)': 0.13349813222885132,
#    u'Actor (mythology)': 0.20541122555732727,
#    u'Character actor': 0.8554877042770386,
#    u'Film actor': 0.8578702211380005,
#    u'Golden Globe Award for Best Actor \u2013 Miniseries or Television Film': 0.1507590115070343,
#    u'Golden Globe Award for Best Actor \u2013 Motion Picture Drama': 0.1502266526222229,
#    u'Golden Globe Award for Best Actor \u2013 Motion Picture Musical or Comedy': 0.16740944981575012,
#    u'Pornographic film actor': 0.8226467370986938,
#    u'XXNILXX': 0,
#    u'acting': 0.8180662989616394,
#    u'actor': 0.8578702211380005,
#    u'character actor': 0.8554877042770386,
#    u'film actor': 0.8578702211380005,
#    u'pornographic actor': 0.8226467370986938,
#    u'television actor': 0.8578702211380005}},
#  u"had a brief role in Alfred Hitchcock 's film '' [The Birds] '' and a larger role in the original '' Invasion": {u'gold': u'The Birds (film)',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Bird': 0.1816122829914093,
#    u'Bird (disambiguation)': 0.1816122829914093,
#    u'Bird (film)': 0.29251518845558167,
#    u'Birds': 0.1816122829914093,
#    u'Birds (Anouk song)': 0.13856616616249084,
#    u'Birds (Bic Runga album)': 0,
#    u'Birds (Kate Nash song)': 0,
#    u'Birds, Illinois': 0.15836971998214722,
#    u'Greg Bird': 0.15104812383651733,
#    u'Larry Bird': 0.2666056156158447,
#    u'Ryan Bird': 0,
#    u'Sue Bird': 0.2586645483970642,
#    u'The Birds': 0.20998689532279968,
#    u'The Birds (Respighi)': 0.15400081872940063,
#    u'The Birds (band)': 0.1558663249015808,
#    u'The Birds (film)': 0.41960960626602173,
#    u'The Birds (play)': 0.673349916934967,
#    u'The Birds (story)': 0.2259884774684906,
#    u'XXNILXX': 0}},
#  u"he had a bit role as the policeman who admonishes [Shirley Jones] -LRB- '' Julie '' -RRB- and John Dehner -LRB- ''": {u'gold': u'Shirley Jones',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Asjha Jones': 0.219852477312088,
#    u'Jermaine Jones': 0.13125723600387573,
#    u'Jone': 0.2872491776943207,
#    u'Jone (band)': 0,
#    u'Jone (opera)': 0.2226155400276184,
#    u'Jone Pedro': 0,
#    u'Jone da Silva Pinto': 0,
#    u'Jones': 0.2214503288269043,
#    u'Jones County, Texas': 0.13008788228034973,
#    u'Kenwyne Jones': 0.1318802535533905,
#    u'Nathan Jones (Australian rules footballer)': 0.13409024477005005,
#    u'Shirley Jones': 0.8650473356246948,
#    u'Shirley Jones (R&amp;B singer)': 0,
#    u'Shirley Jones (horse)': 0,
#    u'Shirley Jones (politician)': 0,
#    u'Stacey Jones': 0.24721050262451172,
#    u'The Jones Girls': 0.3661825656890869,
#    u'Todd Jones': 0.5317643284797668,
#    u'XXNILXX': 0}},
#  u"revealed to have been gay , and his interview with [Boze Hadleigh] was published in Hadleigh 's '' Hollywood Gays '' ,": {u'gold': u'Boze Hadleigh',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Boze Hadleigh': 0.8465708494186401,
#    u'Hadleigh': 0.2281753420829773,
#    u'Hadleigh (TV series)': 0.14818400144577026,
#    u'Hadleigh (disambiguation)': 0.2281753420829773,
#    u'Hadleigh Airfield': 0,
#    u'Hadleigh Castle': 0.15374872088432312,
#    u'Hadleigh railway station': 0,
#    u'Hadleigh, Essex': 0.15144968032836914,
#    u'Hadleigh, Suffolk': 0.1425303816795349,
#    u'RAF Hadleigh': 0,
#    u'XXNILXX': 0}},
#  u'series of cookbook s and hosted a television series on [microwave] cooking .': {u'gold': u'Microwave oven',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'British Telecom microwave network': 0.1505255401134491,
#    u'Cavalier Computer': 0,
#    u'EM spectrum': 0.22473996877670288,
#    u'Electromagnetic spectrum': 0.22473996877670288,
#    u'Microwave': 0.7118898630142212,
#    u'Microwave (game)': 0,
#    u'Microwave chemistry': 0.1592121124267578,
#    u'Microwave oven': 0.22886145114898682,
#    u'Microwave radio relay': 0.6431255340576172,
#    u'Microwave radiometer': 0.15820392966270447,
#    u'Microwave spectroscopy': 0.3840326964855194,
#    u'Microwave transmission': 0.6912140250205994,
#    u'Microwaves': 0.4359413683414459,
#    u'Rotational spectroscopy': 0.3840326964855194,
#    u'Waldorf Microwave': 0,
#    u'XXNILXX': 0,
#    u'microwave': 0.7118898630142212,
#    u'microwave oven': 0.22886145114898682,
#    u'microwave transmission': 0.6912140250205994}},
#  u'the 1970s and 1980s , he wrote a series of [cookbook] s and hosted a television series on microwave cooking .': {u'gold': u'cookbook',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Cookbook': 0.795617401599884,
#    u"Nanny Ogg's Cookbook": 0.15979412198066711,
#    u'XXNILXX': 0,
#    u'cookbook': 0.795617401599884}},
#  u"who admonishes Shirley Jones -LRB- '' Julie '' -RRB- and [John Dehner] -LRB- '' Mr.": {u'gold': u'John Dehner',
#   u'training': True,
#   u'vals': {u'-NIL-': 0,
#    u'Dehner': 0.38972634077072144,
#    u'John Dehner': 0.7745968103408813,
#    u'XXNILXX': 0}}}

# %%
surface_counts['arcade game']
# Out:
# {u'arcade_game': 1636,
#  u'bionic_commando__lrb_arcade_rrb_': 1,
#  u'bucky_ohare__lrb_arcade_game_rrb_': 2,
#  u'cadillacs_and_dinosaurs__lrb_video_game_rrb_': 1,
#  u'donkey_kong__lrb_video_game_rrb_': 2,
#  u'double_dragon': 1,
#  u'indiana_jones_and_the_temple_of_doom__lrb_1985_video_game_rrb_': 1,
#  u'juno_first': 1,
#  u'jurassic_park_iii__lrb_arcade_game_rrb_': 1,
#  u'list_of_arcade_video_games': 2,
#  u'pacman': 2,
#  u'street_fighter_the_movie__lrb_arcade_game_rrb_': 1,
#  u'teenage_mutant_ninja_turtles__lrb_arcade_game_rrb_': 4,
#  u'tempest__lrb_video_game_rrb_': 1,
#  u'video_game_arcade_cabinet': 1}

# %%
len(queries_exp.documentvecs.reverse_word_location)
# Out:
# 443223

# %%
queries_exp.documentvecs.reverse_word_location[0]

# %%
exp_results
# Out:
# [(0, 0.13412095478504968),
#  (1, 0.08384761093081565),
#  (2, 0.075165537455837886),
#  (3, 0.074463398532355854),
#  (4, 0.074139625877423787),
#  ('testing run', 0.077500098314125229),
#  ('training state', (28229, 0.39268128520315987)),
#  ('testing state', (28313, 0.7650902412319429))]

# %%
[(p, np.isnan(p.get_value(borrow=True)).sum()) for p in queries_exp.all_params]
# Out:
# [(target_simple1.W, 91500),
#  (target_simple1.b, 300),
#  (surface_cxt_conv1.W, 450000),
#  (surface_cxt_conv1.b, 300),
#  (surface_conv1.W, 450000),
#  (surface_conv1.b, 300),
#  (surface_dens1.W, 150000),
#  (surface_dens1.b, 250),
#  (source_dens1.W, 75000),
#  (source_dens1.b, 300),
#  (source_dens12.W, 75000),
#  (source_dens12.b, 250),
#  (source_dens2.W, 75000),
#  (source_dens2.b, 300)]

# %%
queries_exp.failed_match
# Out:
# [u'pachinko sexy reaction 2',
#  u'16th-century',
#  u'santiago ram n y cajal ,',
#  u'abul-faraj ibn al-jawzi',
#  u'abul-faraj ibn al-jawzi',
#  u'abu muhammad ibn hazm',
#  u"hmcs '' cayuga ''",
#  u"hmcs '' athabaskan ''",
#  u"seychellois creole -lrb- '' kreol",
#  u'33 bce',
#  u'dactylic hexameters',
#  u"'' zembla ''",
#  u'rebecca ray',
#  u'weekending',
#  u'weekending',
#  u'edward wiley']

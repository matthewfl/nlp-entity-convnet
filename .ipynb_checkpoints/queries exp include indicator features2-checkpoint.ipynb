# %% [markdown]
# Working on adding a lot of features just to see if it can get the score up regardless of how complicated or where the data is coming from
#
# Features that I will be adding
#
# * Taget given surface counts
# * words from the target and source document
#   * possible back prop into these vectors, idea is to replace tf-idf with some nn and back prop here
# * using a linear layer near the output to combine the features
#
# * adding the indicator features from the berkeley entity system
#   * I guess that these will be on the final linear layer
#
# * the tesor product type stuff did not really work, going to try and maybe increase the dim of the convs somehow

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from theano import *
from lasagne.layers import InputLayer, get_output
import lasagne
import lasagne.layers
import theano.tensor as T
import theano
import numpy as np
from helpers import SimpleMaxingLayer, SimpleAverageLayer
from wordvecs import WordVectors, EmbeddingLayer, WordTokenizer
import json
import re
import random

theano.config.floatX = 'float32'
#theano.config.linker = 'cvm_nogc'
theano.config.openmp = True
theano.config.openmp_elemwise_minsize = 20000
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
with open('/data/matthew/external-wiki-wplinks4.json') as f:
    externalWikiJ = json.load(f)
    queries = externalWikiJ['queries']
    featuresNames = externalWikiJ['featIndex']

# %%
def evalNumPossible(qus):
    total = 0
    possible = 0
    for qu in qus.values():
        for q in qu.values():
            total += 1
            if q['gold'] in q['vals']:
                possible += 1
    return float(possible) / total

evalNumPossible(queries)
# Out:
# 0.9345417925478349

# %%
len(featuresNames)
# Out:
# 9972

# %%
len(queries)
# Out:
# 463

# %%
sum([any([g['gold'] for g in v.values()]) for v in queries.values()])
# Out:
# 463

# %%
sum(sum(not g['training'] for g in v.values()) for v in queries.values())
# Out:
# 485

# %%
sum(sum(g['training'] for g in v.values()) for v in queries.values())
# Out:
# 4480

# %%
len(featuresNames)
# Out:
# 9972

# %%
max(max(max(max(a[1]) for a in g['vals'].values()) for g in v.values()) for v in queries.values())
# Out:
# 9970

# %%
# for q,v in queries.items():
#     if not v.values()[0]['training']:
#         del queries[q]

# %%
# # load the samples from the provided testing set

# with open('/data/matthew/external-wiki-testing.json') as f:
#     queries.update(**json.load(f)['queries'])

# %%
for q,v in queries.items():
    for v2 in v.values():
        v2['gold'] = v2['gold'].replace('_', ' ')

# %%
wordvectors = WordVectors(
    fname="/data/matthew/enwiki-20141208-pages-articles-multistream-links7-output1.bin",
    redir_fname='/data/matthew/enwiki-20141208-pages-articles-multistream-redirect7.json',
    negvectors=False,
    sentence_length=200,
)
wordvectors.add_unknown_words = False

# %%
# with open('/data/matthew/enwiki-20141208-pages-articles-multistream-redirects5.json') as f:
#     page_redirects = json.load(f)
page_redirects = wordvectors.redirects

# %%
len(wordvectors.vectors)
# Out:
# 4056055

# %%
with open('/data/matthew/enwiki-20141208-pages-articles-multistream-surface-counts7.json') as f:
    surface_counts = json.load(f)

# %%
# try and make the surfaces items match what we are looking for
surface_counts_re = re.compile('([\.,!\?])')
for sk in surface_counts.keys():
    nsk = sk.replace('(', '-lrb-').replace(')', '-rrb-')
    nsk = surface_counts_re.sub(' \\1', nsk)
    if nsk != sk:
        surface_counts[nsk] = surface_counts[sk]

# %%
from wikireader import WikiRegexes, WikipediaReader

# %%
def PreProcessedQueries(wikipedia_dump_fname, vectors=wordvectors, queries=queries, redirects=page_redirects, surface=surface_counts):
    
    get_words = re.compile('[^a-zA-Z0-9 ]')
    get_link = re.compile('.*?\[(.*?)\].*?')
    
    wordvec = WordTokenizer(vectors, sentence_length=200)
    documentvec = WordTokenizer(vectors, sentence_length=1)
    
    queried_pages = set()
    for docs, q in queries.iteritems():
        wordvec.tokenize(docs)
        for sur, v in q.iteritems():
            wrds_sur = get_words.sub(' ', sur)
            wordvec.tokenize(wrds_sur)
            link_sur = get_link.match(sur).group(1)
            wordvec.tokenize(link_sur)
            for link in v['vals'].keys():
                wrds = get_words.sub(' ', link)
                wordvec.tokenize(wrds)
                tt = WikiRegexes.convertToTitle(link)
                documentvec.get_location(tt)
                queried_pages.add(tt)

    added_pages = set()
    for title in queried_pages:
        if title in redirects:
            #wordvec.tokenize(self.redirects[title])
            documentvec.get_location(redirects[title])
            added_pages.add(redirects[title])
    queried_pages |= added_pages
    
    for w in queried_pages:
        wordvec.tokenize(get_words.sub(' ', w))

    page_content = {}

    class GetWikipediaWords(WikipediaReader, WikiRegexes):

        def readPage(ss, title, content, namespace):
            if namespace != 0:
                return
            tt = ss.convertToTitle(title)
            if tt in queried_pages:
                cnt = ss._wikiToText(content)
                page_content[tt] = wordvec.tokenize(cnt)

    GetWikipediaWords(wikipedia_dump_fname).read()
    
    rr = redirects
    rq = queried_pages
    rc = page_content
    rs = surface

    class PreProcessedQueriesCls(object):
        
        wordvecs = wordvec
        documentvecs = documentvec
        queries = queries
        redirects = rr
        queried_pages = rq
        page_content = rc
        surface_counts = rs
        
        
    return PreProcessedQueriesCls

# %%
# %time basePreProcessedQueries = PreProcessedQueries('/data/matthew/enwiki-20141208-pages-articles-multistream.xml')
# Out:
# CPU times: user 5min 59s, sys: 14.4 s, total: 6min 13s
# Wall time: 6min 21s

# %%
len(wordvectors.vectors)
# Out:
# 4056055

# %%
len(basePreProcessedQueries.wordvecs.reverse_word_location)
# Out:
# 146883

# %%
for qu in queries.values():
    for en in qu.values():
        en['boosted'] = 1.0

# %%
def cleanUpMultipleLinks():
    for qu in queries.values():
        for en in qu.values():
            gold_page = en['gold']
            gold_title = WikiRegexes.convertToTitle(gold_page)
            gold_title = page_redirects.get(gold_title, gold_title)
            pages = set()
            for p in en['vals'].keys():
                wiki_title = WikiRegexes.convertToTitle(p)
                wiki_title = page_redirects.get(wiki_title, wiki_title)
                if wiki_title == gold_title and p != en['gold']:
                    del en['vals'][p]
                elif wiki_title not in pages:
                    pages.add(wiki_title)
                else:
                    del en['vals'][p]
cleanUpMultipleLinks()

# %%
sum(len(q) for q in queries)
# Out:
# 314614

# %%
# def removeSingleLinkTargets():
#     "items that the surface link set only has a single item are trival, so remove"
#     get_link = re.compile('.*?\[(.*?)\].*?')
#     for quk, qu in queries.items():
#         for sur in qu.keys():
#             surlink = get_link.match(sur).group(1)
#             surmatch = surlink.lower()
#             surcounts = surface_counts.get(surmatch)
#             if surcounts and len(surcounts) == 1:
#                 # this is trival since there is only one item
#                 del qu[sur]
#         if not qu:
#             # we removed all the links on this page, remove it otherwise the program crashes
#             del queries[quk]
# removeSingleLinkTargets()

# %%
queries.values()[0].values()[0]['vals'].values()[0]
# Out:
# [0,
#  [0,
#   1,
#   5,
#   6,
#   7,
#   11,
#   19,
#   20,
#   21,
#   23,
#   24,
#   27,
#   28,
#   31,
#   32,
#   35,
#   36,
#   39,
#   41,
#   43,
#   45,
#   47,
#   49,
#   51,
#   53,
#   55,
#   175,
#   883]]

# %%
class EntityVectorLinkExp(basePreProcessedQueries):

    batch_size = 250 #20000
    num_training_items = 500000 #200000
    dim_compared_vec = 100  # 100

    def __init__(self):
        self.sentence_length = self.wordvecs.sentence_length
        self.sentence_length_short = 10
        self.document_length = 100
        
        self.num_words_to_use_conv = 5
        self.enable_boosting = False
        self.num_negative_target_samples = 1
        #self.enable_match_surface = False
        #self.enable_link_counts = True
        self.enable_train_wordvecs = False
        self.enable_cap_boosting = True
        
        self.num_indicator_features = len(featuresNames)
        
        self.main_nl = lasagne.nonlinearities.softmax# leaky_rectify

        self._setup()

    def _setup(self):
        self.x_document_input = T.imatrix('x_doc')  # words from the source document

        self.x_document_id = T.ivector('x_doc_id')  # index of which source doucment this is from
        self.x_surface_text_input = T.imatrix('x_surface_link')  # text of the surface link
        self.x_surface_context_input = T.imatrix('x_surface_cxt')  #  words surrounding the surface link

        self.x_target_input = T.ivector('x_target')  # id of the target vector
        self.x_target_words = T.imatrix('x_target_words')  # words from the target title link
        self.x_matches_surface = T.ivector('x_match_surface')  # indicator if the target title matches the surface
        self.x_matches_counts = T.imatrix('x_matches_counts')  # info about the link counts
        self.x_target_document_words = T.imatrix('x_target_document_words')  # words from the body of target document
        self.x_link_id = T.ivector('x_link_id')  # indx of what link to compare to in the matrix

        self.x_indicator_features = T.matrix('x_indicator_features', dtype='int8')
        
        #self.y_score = T.vector('y')
        self.y_answer = T.ivector('y_ans')  # (Not used) contains the location of the gold answer so we can compute the loss
        self.y_grouping = T.imatrix('y_grouping')  # matrix containing [start_idx, end_idx, gold_idx]
        self.y_boosted = T.vector('y_boosted')  # only used if boosting enabled, vector of how much to boost items

        self.embedding_W = theano.shared(self.wordvecs.get_numpy_matrix().astype(theano.config.floatX),name='embedding_W')
        self.embedding_W_docs = theano.shared(self.documentvecs.get_numpy_matrix().astype(theano.config.floatX),name='embedding_W_docs')
        
        def convSoftMax(t):
            shape = t.shape  # (document_sample, num_filters, output_rows, output_cols)
            new_shape = (shape[0] * shape[2] * shape[3], shape[1])
            return T.nnet.softmax(t.reshape(new_shape)).reshape(shape)
        
#             return lasagne.nonlinearities.leaky_rectify(t)
        
        
        self.document_l = lasagne.layers.InputLayer(
            (None,self.document_length),
            input_var=self.x_document_input
        )

        self.document_embedding_l = EmbeddingLayer(
            self.document_l,
            W=self.embedding_W,
            add_word_params=self.enable_train_wordvecs,
        )
        
        self.document_simple_conv1_l = lasagne.layers.Conv2DLayer(
            self.document_embedding_l,
            num_filters=self.dim_compared_vec,
            filter_size=(2, self.wordvecs.vector_size),
            name='document_simple_conv',
            nonlinearity=simpleConvNonLin,#lasagne.nonlinearities.leaky_rectify,
        )
        
        self.document_simple_sum_l = lasagne.layers.Pool2DLayer(
            #lasagne.layers.reshape(self.document_embedding_l, ([0],[3],[2],1)),
            self.document_simple_conv1_l,
            name='document_simple_pool',
            pool_size=(self.document_length - 2, 1),
            mode='sum',
        )
        
        self.document_conv1_l = lasagne.layers.Conv2DLayer(
            self.document_embedding_l,
            num_filters=30,  # was 75, 100, 500
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            name='document_conv1',
            nonlinearity=self.main_nl,# lasagne.nonlinearities.softmax,  # was leaky_rectify
        )

        self.document_max_l = lasagne.layers.Pool2DLayer(
            self.document_conv1_l,
            name='document_pool1',
            pool_size=(self.document_length - self.num_words_to_use_conv, 1),
            mode='max',  # was sum
        )

        document_output_length = 25 # was 100, 200
        
        self.document_dens1 = lasagne.layers.DenseLayer(
            self.document_max_l,
            num_units=document_output_length,
            name='doucment_dens1',
            nonlinearity=lasagne.nonlinearities.leaky_rectify,
        )

#         self.document_drop1 = lasagne.layers.DropoutLayer(
#             self.document_dens1,
#             p=.25,
#         )

#         self.document_dens2 = lasagne.layers.DenseLayer(
#             self.document_drop1,
#             num_units=225,
#             name='document_dens2',
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.document_drop2 = lasagne.layers.DropoutLayer(
#             self.document_dens2,
#             p=.25,
#         )

#         self.document_dens3 = lasagne.layers.DenseLayer(
#             self.document_drop2,
#             num_units=document_output_length,
#             name='document_dens3',
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

        self.document_output = lasagne.layers.get_output(
            lasagne.layers.reshape(self.document_simple_sum_l, ([0],-1)))
    
    
        ##########################################
        ## surface text

        self.surface_context_l = lasagne.layers.InputLayer(
            (None, self.sentence_length),
            input_var=self.x_surface_context_input,
        )

        self.surface_context_embedding_l = EmbeddingLayer(
            self.surface_context_l,
            W=self.embedding_W,
            add_word_params=self.enable_train_wordvecs,
        )

        self.surface_context_conv1_l = lasagne.layers.Conv2DLayer(
            self.surface_context_embedding_l,
            num_filters=self.dim_compared_vec,  # was 300
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            name='surface_cxt_conv1',
            nonlinearity=simpleConvNonLin,# self.main_nl,
        )

#         self.surface_context_avg1_l = SimpleAverageLayer(
#             [self.surface_context_conv1_l, self.surface_context_l],
#             #name='surface_context_avg'
#         )

        self.surface_context_pool1_l = lasagne.layers.Pool2DLayer(
            self.surface_context_conv1_l,
            name='surface_cxt_pool1',
            pool_size=(self.sentence_length - self.num_words_to_use_conv, 1),
            mode='max', #sum',
        )
    
        self.surface_output = lasagne.layers.get_output(
            lasagne.layers.reshape(self.surface_context_pool1_l, ([0], -1))
        )

        self.surface_input_l = lasagne.layers.InputLayer(
            (None, self.sentence_length_short),
            input_var=self.x_surface_text_input
        )

        self.surface_embedding_l = EmbeddingLayer(
            self.surface_input_l,
            W=self.embedding_W,
            add_word_params=self.enable_train_wordvecs,
        )

        self.surface_conv1_l = lasagne.layers.Conv2DLayer(
            self.surface_embedding_l,
            num_filters=self.dim_compared_vec,  # was 300
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            name='surface_conv1',
            nonlinearity=simpleConvNonLin, #self.main_nl,
        )

#         self.surface_avg1_l = SimpleAverageLayer(
#             [self.surface_conv1_l, self.surface_input_l],
#             #name='surface_avg'
#         )

        self.surface_pool1_l = lasagne.layers.Pool2DLayer(
            self.surface_conv1_l,
            name='surface_pool1',
            pool_size=(self.sentence_length_short - self.num_words_to_use_conv, 1),
            mode='sum',
        )
    
        self.surface_words_output = lasagne.layers.get_output(
            lasagne.layers.reshape(self.surface_pool1_l, ([0], -1))
        )

#         self.surface_merged_l = lasagne.layers.ConcatLayer(
#             [self.surface_context_pool1_l, self.surface_pool1_l]
#         )

#         self.surface_dens1 = lasagne.layers.DenseLayer(
#             self.surface_merged_l,
#             name='surface_dens1',
#             num_units=200,  # was 250
#             nonlinearity=self.main_nl,# lasagne.nonlinearities.tanh,
#         )

# #         self.surface_drop1 = lasagne.layers.DropoutLayer(
# #             self.surface_dens1,
# #             p=.25,
# #         )

# #         self.surface_dens2 = lasagne.layers.DenseLayer(
# #             self.surface_drop1,
# #             name='surface_dens2',
# #             num_units=200,
# #             nonlinearity=lasagne.nonlinearities.tanh,
# #         )

#         ##################################################
#         ## merge the documents with the surface info

#         self.document_aligned_l = InputLayer(
#             (None, document_output_length),
#             input_var=self.document_output[self.x_document_id,:]
#         )

#         self.source_l = lasagne.layers.ConcatLayer(
#             [self.document_aligned_l, self.surface_dens1]
#         )

#         self.source_dens1 = lasagne.layers.DenseLayer(
#             self.source_l,
#             num_units=300,
#             name='source_dens1',
#             nonlinearity=self.main_nl,# lasagne.nonlinearities.tanh,
#         )

#         self.source_drop1 = lasagne.layers.DropoutLayer(
#             self.source_dens1,
#             p=.25,
#         )

#         self.source_dens12 = lasagne.layers.DenseLayer(
#             self.source_drop1,
#             num_units=250,
#             name='source_dens12',
#             nonlinearity=self.main_nl,# lasagne.nonlinearities.tanh,
#         )

#         self.source_drop12 = lasagne.layers.DropoutLayer(
#             self.source_dens12,
#             p=.25,
#         )

#         compared_vector_size = 150 #self.wordvecs.vector_size #+ 2 # extra space for if it matches the surface text

#         self.source_dens2 = lasagne.layers.DenseLayer(
#             self.source_drop12,
#             num_units=compared_vector_size,  # this is the same size as the learned wikipedia vectors
#             name='source_dens2',
#             nonlinearity=lasagne.nonlinearities.linear,
#         )

#         self.source_out = lasagne.layers.get_output(self.source_dens2)
        
        
        ###################################################
        ## dealing with the target side

        matched_surface_reshaped = self.x_matches_surface.reshape(
            (self.x_matches_surface.shape[0], 1, 1, 1)).astype(theano.config.floatX)

        self.target_input_l = lasagne.layers.InputLayer(
            (None,),
            input_var=self.x_target_input
        )
        
        #################################
        ## target indicators features

        self.target_matched_surface_input_l = lasagne.layers.InputLayer(
            (None,1,1,1),
            input_var=matched_surface_reshaped,
        )
        
        self.target_matched_counts_input_l = lasagne.layers.InputLayer(
            (None,5),
            input_var=self.x_matches_counts.astype(theano.config.floatX),
        )

        # embedding of the target documents
        self.target_embedding_l = EmbeddingLayer(
            lasagne.layers.reshape(self.target_input_l, ([0], 1)),
            W=self.embedding_W_docs,
            add_word_params=False,
        )
        
        self.target_embedding_dens_l = lasagne.layers.DenseLayer(
            lasagne.layers.reshape(self.target_embedding_l, ([0], -1)),
            name='target_embedding_dens',
            num_units=self.dim_compared_vec,
            nonlinearity=lasagne.nonlinearities.leaky_rectify,  # should be compariable to the simpleConvNonLin
        )
        
        self.target_embedding_out = lasagne.layers.get_output(
            lasagne.layers.reshape(self.target_embedding_dens_l, ([0],-1)),
        )

#         self.target_combined_feats_l = lasagne.layers.ConcatLayer(
#             [self.target_embedding_l, self.target_matched_surface_input_l,
#             lasagne.layers.reshape(self.target_matched_counts_input_l, ([0],1,1,[1]))],
#             axis=3
#         )

        # words from the title of the target
        self.target_words_input_l = lasagne.layers.InputLayer(
            (None,self.sentence_length_short),
            input_var=self.x_target_words,
        )

        self.target_words_embedding_l = EmbeddingLayer(
            self.target_words_input_l,
            W=self.embedding_W,
            add_word_params=self.enable_train_wordvecs,
        )

        self.target_words_conv1_l = lasagne.layers.Conv2DLayer(
            self.target_words_embedding_l,
            name='target_wrds_conv1',
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            num_filters=self.dim_compared_vec,  # was 75, 150, 350
            nonlinearity=simpleConvNonLin,# self.main_nl,# lasagne.nonlinearities.leaky_rectify,
        )

        self.target_words_pool1_l = lasagne.layers.Pool2DLayer(
            self.target_words_conv1_l,
            name='target_wrds_pool1',
            pool_size=(self.sentence_length_short - self.num_words_to_use_conv, 1),
            mode='sum',  # was sum
        )
        
        self.target_title_out = lasagne.layers.get_output(
            lasagne.layers.reshape(self.target_words_pool1_l, ([0],-1))
        )
        
        
        # words from the body of the target
        self.target_body_words_input_l = lasagne.layers.InputLayer(
            (None,self.sentence_length),
            input_var=self.x_target_document_words,
        )
        
        self.target_body_words_embedding_l = EmbeddingLayer(
            self.target_body_words_input_l,
            W=self.embedding_W,
            add_word_params=self.enable_train_wordvecs,
        )
        
        self.target_body_simple_conv1_l = lasagne.layers.Conv2DLayer(
            self.target_body_words_embedding_l,
            name='target_body_simple_conv',
            filter_size=(2, self.wordvecs.vector_size),
            num_filters=self.dim_compared_vec,
            nonlinearity=simpleConvNonLin,# self.main_nl,# lasagne.nonlinearities.leaky_rectify,
        )
        
        self.target_body_simple_sum_l = lasagne.layers.Pool2DLayer(
            #lasagne.layers.reshape(self.target_body_words_embedding_l, ([0],[3],[2],1)),
            self.target_body_simple_conv1_l,
            name='target_body_simple_sum',
            pool_size=(self.sentence_length - 2, 1),
            mode='sum',
        )
        
        self.target_body_words_conv1_l = lasagne.layers.Conv2DLayer(
            self.target_body_words_embedding_l,
            name='target_body_wrds_conv1',
            filter_size=(self.num_words_to_use_conv, self.wordvecs.vector_size),
            num_filters=150,
            nonlinearity=lasagne.nonlinearities.leaky_rectify,
        )
        
        self.target_body_words_pool1_l = lasagne.layers.Pool2DLayer(
            self.target_body_words_conv1_l,
            name='target_body_wrds_pool1',
            pool_size=(self.sentence_length - self.num_words_to_use_conv, 1),
            mode='max',
        )
    
        self.target_merge_l = lasagne.layers.ConcatLayer(
            [lasagne.layers.reshape(self.target_words_pool1_l, ([0], [1])),
             lasagne.layers.reshape(self.target_body_words_pool1_l, ([0], [1])),
            # lasagne.layers.reshape(self.target_embedding_l, ([0], [3]))
            ]
        )

#         self.target_dens1 = lasagne.layers.DenseLayer(
#             self.target_merge_l,
#             name='target_wrds_dens1',
#             num_units=400,
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.target_drop1 = lasagne.layers.DropoutLayer(
#             self.target_dens1,
#             p=.25,
#         )

#         self.target_dens2 = lasagne.layers.DenseLayer(
#             self.target_drop1,
#             name='target_wrds_dens1',
#             num_units=compared_vector_size,
#             nonlinearity=lasagne.nonlinearities.linear,
#         )

#         self.target_simple = lasagne.layers.DenseLayer(
#             self.target_embedding_l, #self.target_combined_feats_l,
#             name='target_simple1',
#             num_units=compared_vector_size,
#             nonlinearity=lasagne.nonlinearities.linear,
#         )
    
#         self.target_simple2 = lasagne.layers.DenseLayer(
#             self.target_merge_l,
#             name='target_simple2',
#             num_units=compared_vector_size,
#             nonlinearity=lasagne.nonlinearities.linear,
#         )

#         self.target_dens1 = lasagne.layers.DenseLayer(
#             self.target_conv1_l,
#             name='target_dens1',
#             num_units=300,
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )

#         self.target_drop1 = lasagne.layers.DropoutLayer(
#             self.target_dens1,
#             p=.25,
#         )

#         self.target_dens2 = lasagne.layers.DenseLayer(
#             self.target_drop1,
#             name='target_dens2',
#             num_units=300,
#             nonlinearity=lasagne.nonlinearities.tanh,
#         )



        #self.target_out = lasagne.layers.get_output(self.target_embedding_l)


#         self.target_out = T.concatenate(
#             [self.embedding_W[self.x_target_input],
#              matched_surface_reshaped,
#             1-matched_surface_reshaped],
#              axis=1)


        #self.target_out = self.embedding_W[self.x_target_input]
        #self.target_out = lasagne.layers.get_output(self.target_dens2)

        self.target_out = lasagne.layers.get_output(
            lasagne.layers.reshape(self.target_body_simple_sum_l, ([0],-1)))

        #########################################################
        ## compute the cosine distance between the two layers
       
        # source body
        self.source_aligned_l = self.document_output[self.x_document_id,:][self.x_link_id,:] #self.source_out[self.x_link_id, :]
        # source context
        self.source_context_aligned_l = self.surface_output[self.x_link_id,:]
        # source surface words
        self.source_surface_words_aligned_l = self.surface_words_output[self.x_link_id,:]
        
        # this uses scan internally, which means that it comes back into python code to run the loop.....fml
        self.dotted_vectors =  T.batched_dot(self.target_out, self.source_aligned_l)
        # diag also does not support a C version.........
        #self.dotted_vectors = T.dot(self.target_out, self.source_aligned_l.T).diagonal()

        def augNorm(v):
            return T.maximum(T.basic.pow(T.basic.pow(T.basic.abs_(v), 2).sum(axis=1) + .001, .5), .001)

        self.res_l = self.dotted_vectors / (augNorm(self.target_out) * augNorm(self.source_aligned_l) + .001)
        
        self.res_cap = T.clip((T.tanh(self.res_l) + 1) / 2, .001, .999)
        
        def cosinsim(a, b):
            dotted = T.batched_dot(a, b)
            return dotted / (augNorm(a) * augNorm(b) + .001)
        
        
        
        
        
        ##############################################
        ## tensor product stuff
        
        def tensorP(a,b):
            res, _ = theano.scan(
                fn=lambda x_vec, y_vec, x_norm, y_norm: T.concatenate(
                    [x_vec, y_vec, 
                     T.outer(x_vec / x_norm, y_vec / y_norm).flatten()]
                ),
                outputs_info=None,
                sequences=[a,b, augNorm(a), augNorm(b)],
                non_sequences=None
            )
            return res
        
        
        ##################################################
        ## f-life, changing it to dens layers b/c why not
        
#         self.final_merged_l = lasagne.layers.concat(
#             [
#                 self.target_merge_l,  # the conv layer + embedding without any transforms
#                 # results from the layers with the source   
#                 lasagne.layers.InputLayer(
#                     (None,compared_vector_size),
#                     input_var=self.source_aligned_l,
#                 )
#             ]
#         )
        
#         self.final_dens1 = lasagne.layers.DenseLayer(
#             self.final_merged_l,
#             num_units=400,
#             nonlinearity=lasagne.nonlinearities.tanh,
#             name='final_dens1',
#         )
        
#         self.final_drop1 = lasagne.layers.DropoutLayer(
#             self.final_dens1,
#             p=.25,
#         )
        
#         self.final_dens2 = lasagne.layers.DenseLayer(
#             self.final_drop1,
#             num_units=300,
#             nonlinearity=lasagne.nonlinearities.tanh,
#             name='final_dens2',
#         )
        
#         self.final_drop2 = lasagne.layers.DropoutLayer(
#             self.final_dens2,
#             p=.25,
#         )
        
#         self.final_dens3 = lasagne.layers.DenseLayer(
#             self.final_drop2,
#             num_units=1,
#             nonlinearity=lasagne.nonlinearities.tanh,
#             name='final_dens3',
#         )
        
#         self.final_output = lasagne.layers.get_output(self.final_dens3)
        
    
    
        ######################################################
        ## indicator feature input
    
        self.indicator_feat_l = lasagne.layers.InputLayer(
            (None, self.num_indicator_features),
            input_var=self.x_indicator_features.astype(theano.config.floatX),
        )
        
        #############################
        ## Linear features combined
        #############################
        
        def comparedVLayers(a,b):
            dv = cosinsim(a,b)
            return lasagne.layers.InputLayer(
                (None,1),
                input_var=dv.reshape((dv.shape[0], 1))
            )
        
        def comparedVLayers2(a,b):
            dv = theano.gradient.disconnected_grad(tensorP(a,b))  # just see how well this performs without learning this
            return lasagne.layers.InputLayer(
                (None,self.dim_compared_vec ** 2 + self.dim_compared_vec*2 ),
                input_var=dv
            )
#             dp1 = lasagne.layers.DropoutLayer(
#                 il,
#                 p=.1,
#             )
#             de1 = lasagne.layers.DenseLayer(
#                 dp1,
#                 num_units=50,
#                 nonlinearity=lasagne.nonlinearities.leaky_rectify,
#                 name='compD1',
#             )
#             dp2 = lasagne.layers.DropoutLayer(
#                 de1,
#                 p=.1,
#             )
#             return lasagne.layers.DenseLayer(
#                 dp2,
#                 num_units=1,
#                 nonlinearity=lasagne.nonlinearities.tanh,
#                 name='linD2',
#             )
            
        
        self.linear_features_combined = lasagne.layers.concat(
            [
#                 lasagne.layers.InputLayer(
#                     (None, 1), 
#                     input_var=self.res_l.reshape((self.res_l.shape[0], 1)),  # changed from res_l
#                 ),
                
                
               comparedVLayers(self.target_out, self.source_aligned_l),
               comparedVLayers(self.target_out, self.source_context_aligned_l),
               comparedVLayers(self.target_out, self.source_surface_words_aligned_l),
                
                comparedVLayers(self.target_title_out, self.source_aligned_l),
                comparedVLayers(self.target_title_out, self.source_context_aligned_l),
                comparedVLayers(self.target_title_out, self.source_surface_words_aligned_l),
                
                comparedVLayers(self.target_embedding_out, self.source_aligned_l),
                comparedVLayers(self.target_embedding_out, self.source_context_aligned_l),
                
                
                
#                comparedVLayers2(self.target_out, self.source_aligned_l),
#                comparedVLayers2(self.target_out, self.source_context_aligned_l),
#                comparedVLayers2(self.target_out, self.source_surface_words_aligned_l),
            lasagne.layers.reshape(self.target_matched_surface_input_l, ([0],1)),
            self.target_matched_counts_input_l,
             self.indicator_feat_l
            ],
            axis=1
        )
        
        self.linear_features_dens_l = lasagne.layers.DenseLayer(
            self.linear_features_combined,
            nonlinearity=lasagne.nonlinearities.linear,  # use tanh so that too large of values don't cause the softmax issues
            num_units=1,
            name='linear_final_l',
            W=lasagne.init.Normal(mean=0.0),
        )
        
        self.linear_features_dens_l.W.get_value(borrow=True)[0:6] += 1.0  # set the word vecs positive
#         lin_feat_W = self.linear_features_dens_l.W.get_value(borrow=True)
#         lin_feat_add_one = np.eye(self.dim_compared_vec).reshape(self.dim_compared_vec**2, 1)
#         lin_feat_W[self.dim_compared_vec*2                           :self.dim_compared_vec*2+  self.dim_compared_vec**2] += lin_feat_add_one
#         lin_feat_W[self.dim_compared_vec*4+  self.dim_compared_vec**2:self.dim_compared_vec*4+2*self.dim_compared_vec**2] += lin_feat_add_one
#         lin_feat_W[self.dim_compared_vec*6+2*self.dim_compared_vec**2:self.dim_compared_vec*6+3*self.dim_compared_vec**2] += lin_feat_add_one
        
        self.linear_output = lasagne.layers.get_output(
            lasagne.layers.reshape(self.linear_features_dens_l, ([0],))
        )
        
        # rescaled the output so we don't crash the softmax layer with a value that is too large
        # just a hack
        self.linear_output_rescaled = 10 * self.linear_output / theano.gradient.disconnected_grad(abs(self.linear_output).max())
        
        ########################################
        ## true output values
        ########################################
        
        self.true_output = self.linear_output_rescaled
        
        
        
#         self.res_l = self.dotted_vectors / ((self.target_out.norm(1, axis=1) + .001) *
#                                             (self.source_aligned_l.norm(1, axis=1) + .001))


        #self.golds = self.res_cap[self.y_answer]

#         def maxOverRange(indx):
#             #return T.max(self.res_cap[T.arange(indx[0],indx[1])]) - self.res_cap[indx[2]]
#             #return -( self.res_l[indx[2]] - T.log(T.exp(self.res_l[T.arange(indx[0],indx[1])]).sum()) )
#             return -( self.res_l[indx[2]] - self.res_l[indx[0]])

#         # build a tensor to make a matrix with one set on each dimention
#         self.grouped, grouped_update = theano.scan(maxOverRange, sequences=self.y_grouping)

        def setSubSelector(indx, outputs):
            return T.set_subtensor(outputs[T.arange(indx[0], indx[1]), indx[3]], 1)

        num_target_samples = self.linear_output.shape[0]

        select_seq = T.concatenate([
            self.y_grouping,
            T.arange(self.y_grouping.shape[0]).reshape((self.y_grouping.shape[0], 1))
        ], axis=1)

        self.selecting_matrix, _ = theano.scan(
            setSubSelector,
            outputs_info=T.zeros((num_target_samples, self.y_grouping.shape[0])), #num_target_samples)),
            #n_steps=self.y_grouping.shape[0]
            sequences=select_seq,
        )

#         self.groupped_elems = T.dot(self.selecting_matrix[-1], 
#                                     T.diag(T.exp(self.true_output)))
#         self.groupped_res = T.log(self.groupped_elems.sum(axis=0)[T.arange(self.y_grouping.shape[0])])
        self.groupped_elems = T.dot(self.selecting_matrix[-1].T, 
                                   T.exp(self.true_output))
        self.groupped_res = T.log(self.groupped_elems)
        
        self.loss_vec = self.groupped_res - self.true_output[self.y_grouping[:,2]]
        
        if self.enable_boosting:
            self.loss_scalar = T.dot(self.y_boosted, self.loss_vec)
        else:
            self.loss_scalar = self.loss_vec.sum()

        self.all_params = (
            #lasagne.layers.get_all_params(self.target_dens2) +
            # TODO: add params for the target stuff,
            #lasagne.layers.get_all_params(self.final_dens3) +
            #lasagne.layers.get_all_params(self.target_simple2) +
            #lasagne.layers.get_all_params(self.source_dens2) +
            lasagne.layers.get_all_params(self.target_embedding_dens_l) +
            lasagne.layers.get_all_params(self.document_simple_sum_l) +
            lasagne.layers.get_all_params(self.surface_context_pool1_l) +
            lasagne.layers.get_all_params(self.surface_pool1_l) +
            lasagne.layers.get_all_params(self.target_body_simple_sum_l) +
            lasagne.layers.get_all_params(self.target_words_pool1_l) + 
            lasagne.layers.get_all_params(self.linear_features_dens_l)
            #lasagne.layers.get_all_params(self.document_dens2)
        )
        
        self.regularization = (self.linear_features_dens_l.W ** 2).sum() / 400

        # weight the positive samples more since there are fewer of them,
        # freaking hack
        #self.loss_vec = -(10 * self.y_score * T.log(self.res_cap) + (1.0 - self.y_score) * T.log(1.0 - self.res_cap))

        #self.loss_vec = T.nnet.binary_crossentropy(self.res_cap, self.y_score)

        #self.loss_vec = T.exp(T.max(self.res_cap - self.res_cap[self.y_answer] + .1, 0)) - 1  # TODO: maybe have some squared term here or something?

        # this one works reasonably well
        #self.loss_vec = - T.log((T.clip(self.res_cap[self.y_answer] - self.res_cap, -1.0, 0.4) + 1.0) / 1.5)

        #self.loss_vec = self.grouped

        #self.loss_vec = - T.log((T.clip(self.res_l[self.y_answer] - self.res_l, -40.0, 10.0) + 40.0) / 51.0)
        #self.loss_vec = T.max(self.res_l[self.y_answer] - self.res_l + .1, 0)

        self.updates = lasagne.updates.adadelta(
            self.loss_scalar / self.loss_vec.shape[0] + self.regularization, 
            self.all_params)

        self.func_inputs = [
            self.x_document_input,
            self.x_surface_text_input, self.x_surface_context_input, self.x_document_id,
            self.x_target_input, self.x_matches_surface, self.x_matches_counts, self.x_link_id, 
            self.x_target_words, self.x_target_document_words, self.x_indicator_features,
            self.y_answer, self.y_grouping, self.y_boosted
        ]
        
        self.func_outputs = [
            self.true_output,
            self.loss_vec.sum(),
            self.loss_scalar,
            self.loss_vec,
            #self.res_l,
        ]

        ################################################################3
        ## TODO: need to return the actual output layer instead of the res_cap, since that is something else now
        
        self.train_func = theano.function(
            self.func_inputs,
            self.func_outputs,
            updates=self.updates,
            on_unused_input='ignore',
        )

        self.test_func = theano.function(
            self.func_inputs,
            self.func_outputs,
            on_unused_input='ignore',
        )

    def reset_accums(self):
        self.current_documents = []
        self.current_surface_context = []
        self.current_surface_link = []
        self.current_link_id = []
        self.current_target_input = []
        self.current_target_words = []
        self.current_target_body_words = []
        self.current_target_matches_surface = []
        self.current_target_id = []
        self.current_target_goal = []
        self.current_feat_indicators = []
        self.current_learning_groups = []
        self.learning_targets = []
        self.current_surface_target_counts = []
        self.current_boosted_groups = []
        
        self.failed_match = []
            
    def compute_batch(self, isTraining=True, useTrainingFunc=True):
        if isTraining and useTrainingFunc:
            func = self.train_func
        else:
            func = self.test_func
        self.reset_accums()
        self.total_links = 0
        self.total_loss = 0.0
        self.total_boosted_loss = 0.0

        get_words = re.compile('[^a-zA-Z0-9 ]')
        get_link = re.compile('.*?\[(.*?)\].*?')

        for doc, queries in self.queries.iteritems():
            # skip the testing documents while training and vice versa
            if queries.values()[0]['training'] != isTraining:
                continue
            docid = len(self.current_documents)
            self.current_documents.append(self.wordvecs.tokenize(doc, length=self.document_length))
            for surtxt, targets in queries.iteritems():
                self.current_link_id.append(docid)
                surid = len(self.current_surface_link)
                self.current_surface_context.append(self.wordvecs.tokenize(get_words.sub(' ' , surtxt)))
                surlink = get_link.match(surtxt).group(1)
                self.current_surface_link.append(self.wordvecs.tokenize(surlink, length=self.sentence_length_short))
                surmatch = surlink.lower()
                surcounts = self.surface_counts.get(surmatch)
                if not surcounts:
                    self.failed_match.append(surmatch)
                    surcounts = {}
                target_body_words_input = []  # words from the target document
                target_words_input = []  # the words from the target title
                target_matches_surface = []
                target_inputs = []  # the target vector
                target_learings = []
                target_match_counts = []
                target_gold_loc = -1
                target_group_start = len(self.current_target_input)
                target_feat_indicators = []
                
                for target in set(targets['vals'].keys() +
                                 random.sample(self.documentvecs.reverse_word_location, self.num_negative_target_samples)
                                  ) - {None,}:
                    
                    
                    isGold = target == targets['gold']
                    cnt_wrds = self.page_content.get(WikiRegexes.convertToTitle(target))
                    wiki_title = WikiRegexes.convertToTitle(target)
                    cnt = self.documentvecs.get_location(wiki_title)
                    if wiki_title == 'nil':
                        cnt = 0  # this is the stop symbol location
                    if cnt is None:
                        # were not able to find this wikipedia document
                        # so just ignore tihs result since trying to train on it will cause
                        # issues
                        continue
                    if isGold:
                        target_gold_loc = len(target_inputs)
                    target_body_words_input.append(cnt_wrds or [0]*self.sentence_length)
                    target_words_input.append(self.wordvecs.tokenize(get_words.sub(' ', target), length=self.sentence_length_short))
                    target_inputs.append(cnt)  
                    # page_content already tokenized
                    target_matches_surface.append(int(surmatch == target.lower()))
                    target_learings.append((targets, target))
                    target_match_counts.append(surcounts.get(wiki_title, 0))
                    indicators = np.zeros((self.num_indicator_features,), dtype='int8')
                    indicators_place = targets['vals'].get(target)
                    if indicators_place:
                        indicators[indicators_place[1]] = 1
                    target_feat_indicators.append(indicators)
                    #if wiki_title not in surcounts:
                    #    print surcounts, wiki_title
                if target_gold_loc is not None or not isTraining:  # if we can't get the gold item
                    # contain the index of the gold item for these items, so it can be less then it
                    gold_loc = (len(self.current_target_goal) + target_gold_loc)
                    sorted_match_counts = [-4,-3,-2,-1] + sorted(set(target_match_counts))
                    #print sorted_match_counts
                    target_match_counts_indicators = [
                        [
                            int(s == sorted_match_counts[-1]),
                            int(s == sorted_match_counts[-2]),
                            int(s == sorted_match_counts[-3]),
                            int(0 < s <= sorted_match_counts[-4]),
                            int(s == 0),
                        ]
                        for s in target_match_counts
                    ]
                    self.current_target_goal += [gold_loc] * len(target_inputs)
                    self.current_target_input += target_inputs
                    self.current_target_id += [surid] * len(target_inputs)
                    self.current_target_words += target_words_input
                    self.current_target_matches_surface += target_matches_surface
                    self.current_surface_target_counts += target_match_counts_indicators
                    self.current_target_body_words += target_body_words_input
                    self.current_feat_indicators += target_feat_indicators
                    target_group_end = len(self.current_target_input)
                    self.current_learning_groups.append(
                        [target_group_start, target_group_end,
                         gold_loc])
                    self.current_boosted_groups.append(targets['boosted'])

                #self.current_target_goal.append(isGold)
                self.learning_targets += target_learings
            if len(self.current_target_id) > self.batch_size:
                self.run_batch(func)
                if self.total_links > self.num_training_items:
                    return self.total_loss / self.total_links, self.total_boosted_loss / self.total_links

        if len(self.current_target_id) > 0:
            self.run_batch(func)

        return self.total_loss / self.total_links, self.total_boosted_loss / self.total_links

    def run_batch(self, func):
        res_vec, loss_sum, loss_boosted, loss_vec, = func(
            self.current_documents,
            self.current_surface_link, self.current_surface_context, self.current_link_id,
            self.current_target_input, self.current_target_matches_surface, self.current_surface_target_counts, self.current_target_id, 
            self.current_target_words, self.current_target_body_words, self.current_feat_indicators,
            self.current_target_goal, self.current_learning_groups, self.current_boosted_groups,
        )
        self.check_params()
        self.total_links += len(self.current_target_id)
        self.total_loss += loss_sum
        self.total_boosted_loss += loss_boosted
        learned_groups = []  # right...dict not hashable....
        for i in xrange(len(res_vec)):
            # save the results from this pass
            l = self.learning_targets[i]
            if l[1] in l[0]['vals']:
                l[0]['vals'][ l[1] ][0] = float(res_vec[i]), 0#float(nn_outs[i])
            if l[0] not in learned_groups:
                learned_groups.append(l[0])
        for group in learned_groups:
            if group['gold']:
                correct = max(group['vals']) == group['vals'].get(group['gold'])
                group['boosted'] *= .4 if correct else 2.0
                if self.enable_cap_boosting:
                    if group['boosted'] > 10:
                        group['boosted'] = 10.0
                    elif group['boosted'] < 0.1:
                        group['boosted'] = 0.1
        self.reset_accums()

    def check_params(self):
        if any([np.isnan(v.get_value(borrow=True)).any() for v in self.all_params]):
            raise RuntimeError('nan in some of the parameters')



queries_exp = EntityVectorLinkExp()

# %%
queries_exp.linear_features_dens_l.W.get_value(borrow=True).shape
# Out:
# (9986, 1)

# %%
queries_exp.all_params
# Out:
# [target_embedding_dens.W,
#  target_embedding_dens.b,
#  document_simple_conv.W,
#  document_simple_conv.b,
#  surface_cxt_conv1.W,
#  surface_cxt_conv1.b,
#  surface_conv1.W,
#  surface_conv1.b,
#  target_body_simple_conv.W,
#  target_body_simple_conv.b,
#  target_wrds_conv1.W,
#  target_wrds_conv1.b,
#  linear_final_l.W,
#  linear_final_l.b]

# %%
def evalCurrentState(trainingData=True, numSamples=50000):
    all_measured = 0
    all_correct = 0
    all_trained = 0
    for qu in queries.values():
        for en in qu.values():
            if en['training'] != trainingData:
                continue
            if en['gold']:
                if all_trained > numSamples:
                    break
                all_measured += 1
                all_trained += len(en['vals'].values())
                m = max(en['vals'].values())
                if en['vals'].get(en['gold']) == m and m != 0:
                    all_correct += 1
           
    r = all_measured, float(all_correct) / all_measured
    print r
    return r

# %%
def evalCurrentStateRank(trainingData=True, numSamples=50000):
    all_measured = 0
    all_correct_place = 0
    p_counts = dict((k,0) for k in range(0,10))
    all_trained = 0
    for qu in queries.values():
        for en in qu.values():
            if en['training'] != trainingData:
                continue
            if en['gold']:
                if all_trained > numSamples:
                    break
                svals = sorted(en['vals'].values(), key=lambda x: 0 if not isinstance(x, tuple) else -x[0])
                gv = en['vals'][en['gold']]
                if gv == 0:
                    continue
                all_measured += 1
                for i in xrange(len(svals)):
                    if svals[i] == gv:
                        if i < 10:
                            p_counts[i] += 1
                        all_correct_place += i + 1
                        break

    r = all_measured, float(all_correct_place) / all_measured, p_counts
    print r
    return r

# %%
def evalCurrentStateF1(trainingData=True, numSamples=50000):
    correct = 0
    precDenom = 0
    recDenom = 0
    all_trained = 0
    all_measured = 0
    for qu in queries.values():
        if qu.values()[0]['training'] != trainingData:
            continue
        allGold = set()
        allChoosen = set()
        if all_trained > numSamples:
            break
        for en in qu.values():
            if en['gold']:  # we can eval this item
                all_measured += 1
                allGold.add(en['gold'])
                svals = sorted(en['vals'].values())
                picked = None
                for k,v in en['vals'].iteritems():
                    all_trained += 1
                    if v == svals[-1]:
                        picked = k
                allChoosen.add(picked)
                #if svals[0] == svals[1] and en['gold'] != picked:
                #    raise NotImplementedError()
#                 if en['gold'] == picked:
#                     correct += 1
#             if len(svals) > 5 and en['gold'] != picked:
#                 raise NotImplementedError()
        precDenom += len(allChoosen)
        recDenom += len(allGold)
        correct += len(allGold & allChoosen)
    correct = float(correct)
    prec = correct / precDenom
    rec = correct / recDenom
    f1 = 2 * prec * rec / (prec + rec)
    r = all_measured, 'Prec = {}/{} = {}, Rec = {}/{} = {}, F1 = {}'.format(
        correct, precDenom, prec, 
        correct, recDenom, rec, 
        f1)
    print r
    return r

# %%
#sorted(queries.values()[0].values()[0]['vals'].values(), key=lambda x: 0 if not isinstance(x, tuple) else -x[0])

# %%
# import random
# def augmentTrainingData():
#     for quk in queries.keys():
#         qu = queries[quk]
#         for enk in qu.keys():
#             en = qu[enk]
#             if not en['gold']:
#                 del qu[enk]
#         if not qu:
#             del queries[quk]
#     for qu in queries.values():
#         training = random.random() > .15
#         for en in qu.values():
#             en['training'] = training
# augmentTrainingData()

# %%
def findWrongItems(trainingData=True, numSamples=50):
    ret = {}
    for qu in queries.values():
        for ek, en in qu.items():
            if en['training'] != trainingData:
                continue
            for e in en:
                if en['gold']:
                    if len(ret) > numSamples:
                        return ret
                    m = max(en['vals'].values())
                    g = en['vals'].get(en['gold'], 0)
                    if g != m and g != 0:
                        ret[ek] = en
    return ret

# %%
queries_exp.check_params()

# %%
queries_exp.num_training_items = 250000# 250000

# %%
queries_exp.num_training_items = 50000
# %time print queries_exp.compute_batch()
# Out:
# (0.19255790085869953, 0.19255790085869953)
# CPU times: user 10min 33s, sys: 8.21 s, total: 10min 41s
# Wall time: 1min 21s

# %%
def gg_test():
    self = queries_exp
    gg_f = theano.function(
            self.func_inputs,
            T.grad(self.loss_vec.sum(), [self.linear_features_dens_l.W]),
            updates=self.updates,
            on_unused_input='ignore',
    )
    return gg_f( self.current_documents,
            self.current_surface_link, self.current_surface_context, self.current_link_id,
            self.current_target_input, self.current_target_matches_surface, self.current_surface_target_counts, self.current_target_id, 
            self.current_target_words, self.current_target_body_words, self.current_feat_indicators,
            self.current_target_goal, self.current_learning_groups, self.current_boosted_groups,
        )

gg_res = gg_test()
gg_res
# Out:
# [array([[-0.01040162],
#         [-0.10106535],
#         [-0.12414555],
#         ...,
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32)]

# %%
findWrongItems()
# Out:
# {u' [Citronella oil] can be burned in wick lamps outdoors .': {'boosted': 2.0,
#   u'gold': u'Citronella oil',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.266223430633545, 0.2794010043144226), [87, 124]],
#    u'Citronella oil': [(2.752781629562378, 0.7169269323348999),
#     [88, 90, 93, 95, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Cooking oil': [(2.6866421699523926, 0.6919172406196594),
#     [88,
#      95,
#      104,
#      105,
#      109,
#      111,
#      112,
#      115,
#      116,
#      118,
#      141,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      230,
#      484]],
#    u'Fuel oil': [(2.609722852706909, 0.616443932056427),
#     [88,
#      95,
#      104,
#      106,
#      108,
#      109,
#      111,
#      112,
#      114,
#      115,
#      141,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      235,
#      236]],
#    u'List of Dynasty episodes': [(2.1522104740142822, 0.16753116250038147),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      186,
#      187,
#      188,
#      191]],
#    u'Motor oil': [(2.491284132003784, 0.5002313852310181),
#     [88,
#      95,
#      104,
#      105,
#      109,
#      111,
#      112,
#      115,
#      116,
#      118,
#      141,
#      162,
#      163,
#      166,
#      167,
#      173,
#      183,
#      184,
#      188,
#      189,
#      417]],
#    u'Oil': [(2.6410484313964844, 0.6471805572509766),
#     [88, 90, 93, 95, 104, 106, 109, 111, 112, 115, 116, 118, 139, 140, 141]],
#    u'Oil (The Young Ones)': [0,
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      239]],
#    u'Oil (band)': [(2.2916817665100098, 0.3043808043003082),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Oil Bowl': [(2.2472572326660156, 0.2607913613319397),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      141,
#      183,
#      184,
#      185,
#      186,
#      443]],
#    u'Oil paint': [(2.7285144329071045, 0.7330025434494019),
#     [88,
#      95,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      233,
#      237]],
#    u'Oil pipeline': [(1.3192945718765259, -0.6497284770011902), [88]],
#    u'XXNILXX': [0, [88]],
#    u'oil painting': [(2.6654839515686035, 0.6711568236351013), [88]],
#    u'petroleum': [(2.8083465099334717, 0.811333954334259), [88]]}},
#  u"'' mdash ; for his heroism in April 1970 in [Vietnam] .": {'boosted': 2.0,
#   u'gold': u'Vietnam War',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.4687010049819946, 0.4710793197154999), [87, 124]],
#    u'Buddhism in Vietnam': [(1.7477147579193115, 0.7366976141929626),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 138]],
#    u'Cinema of Vietnam': [(1.6599591970443726, 0.6501026153564453),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 746]],
#    u'French Indochina': [(1.718503713607788, 0.7078729271888733),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 176]],
#    u'North Vietnam': [(1.7563247680664062, 0.7451937794685364),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 136]],
#    u'South Vietnam': [(1.7594413757324219, 0.7482692003250122),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 129]],
#    u'Vietnam': [(2.784212827682495, 0.7595714926719666),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Vietnam (miniseries)': [(1.6559503078460693, 0.6461467146873474),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      137]],
#    u'Vietnam Football Federation': [(1.7202253341674805, 0.7095717787742615),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 128]],
#    u'Vietnam War': [(1.7571868896484375, 0.7490766048431396),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Vietnam at the 2005 Southeast Asian Games': [(1.5903890132904053,
#      0.5814523696899414),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Vietnam at the 2007 Southeast Asian Games': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 134]],
#    u'Vietnam at the 2009 Southeast Asian Games': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 133]],
#    u'Vietnam national football team': [(1.6296390295028687,
#      0.6104037165641785),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u"Vietnam women's national football team": [(1.622668743133545,
#      0.6133052110671997),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u"Vietnam women's national volleyball team": [(1.5461061000823975,
#      0.5377550721168518),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 127]],
#    u'Vietnamese cuisine': [(1.676189661026001, 0.6661185026168823),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Volleyball Federation of Vietnam': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 175]],
#    u'XXNILXX': [0, [88]]}},
#  u', 280 lb -LRB- 2.13 m , 125 kg -RRB- [center] played four seasons in the NBA before being forced to': {'boosted': 2.0,
#   u'gold': u'Center (basketball)',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.5075254440307617, 0.5076805949211121), [87, 124]],
#    u'Basketball positions': [(1.5200436115264893, 0.5078043341636658),
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      141,
#      162,
#      165,
#      166,
#      169,
#      183,
#      186,
#      187,
#      188,
#      191,
#      560]],
#    u'Center': [(2.4940690994262695, 0.48253417015075684), [88]],
#    u'Center (algebra)': [(1.3925879001617432, 0.37521877884864807),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      233]],
#    u'Center (basketball)': [(1.515317440032959, 0.5155872106552124),
#     [88,
#      90,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Center, Colorado': [(1.4579709768295288, 0.446390837430954),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      185,
#      186,
#      236]],
#    u'Center, Texas': [(1.4514594078063965, 0.4399484097957611),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      182,
#      183,
#      184,
#      185,
#      186]],
#    u'Centre (geometry)': [(1.3898295164108276, 0.3789728879928589),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      165,
#      166,
#      169,
#      171,
#      183,
#      186,
#      188,
#      191,
#      193,
#      268,
#      451,
#      452,
#      33357]],
#    u'XXNILXX': [0, [88]],
#    u'center (American football)': [(0.1988288313150406, -0.7871208190917969),
#     [88]],
#    u'center (group theory)': [(1.3829374313354492, 0.37750959396362305), [88]],
#    u'center (ice hockey)': [(0.1988288313150406, -0.7871208190917969), [88]]}},
#  u', Jr. was born on 23 June 1949 , in [East Chicago , Indiana] , and graduated from Washington High School there in 1968': {'boosted': 2.0,
#   u'gold': u'East Chicago, Indiana',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4667727947235107, 0.4710793197154999), [87, 124]],
#    u'Central High School (East Chicago, Indiana)': [(2.7645857334136963,
#      0.7649539113044739),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      126,
#      128]],
#    u'Chicago (2002 film)': [(2.528486490249634, 0.5319769978523254),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      130]],
#    u'Chicago (band)': [(2.623445749282837, 0.6256804466247559),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Chicago (musical)': [(2.564356565475464, 0.567372739315033),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      128]],
#    u'Chicago ,': [0, [88]],
#    u'Chicago Blackhawks': [(2.5467565059661865, 0.5500053763389587),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Chicago Bulls': [(2.4836573600769043, 0.48774072527885437),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'East Chicago (NICTD station)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      122]],
#    u'East Chicago , Indiana': [0, [88]],
#    u'East Chicago High School': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'East Chicago, Illinois': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'East Chicago, Indiana': [(1.742113471031189, 0.7337114810943604),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'East Side, Chicago': [(2.758713722229004, 0.7591597437858582),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'XXNILXX': [0, [88]]}},
#  u', he was ordered to the Marine Corps Base , [Camp Pendleton] , California , where he joined the 2nd Infantry Training': {'boosted': 2.0,
#   u'gold': u'Marine Corps Base Camp Pendleton',
#   u'training': True,
#   u'vals': {u' Marine Corps Base Camp Pendleton': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'-NIL-': [(1.4687010049819946, 0.4710793197154999), [87, 124]],
#    u'Camp Pendleton (Virginia)': [(1.7788701057434082, 0.7704731225967407),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Camp Pendleton South, California': [(1.7628710269927979,
#      0.7418738603591919),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Marine Corps Base Camp Pendleton': [(1.7797523736953735,
#      0.7708526849746704),
#     [88,
#      89,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      4214]],
#    u'Pendleton': [(1.8343615531921387, 0.8319043517112732), [88]],
#    u'Pendleton County, Kentucky': [(1.7978849411010742, 0.795910120010376),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Pendleton County, West Virginia': [(1.7929999828338623,
#      0.7910897135734558),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Pendleton, Greater Manchester': [(1.7595263719558716, 0.7580587863922119),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Pendleton, Indiana': [(1.7420828342437744, 0.7408459782600403),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Pendleton, Lancashire': [(1.7727375030517578, 0.7710951566696167),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'Pendleton, New York': [(1.7874634265899658, 0.7856263518333435),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Pendleton, Oregon': [(1.7972831726074219, 0.7953163385391235),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Pendleton, South Carolina': [(1.8270559310913086, 0.8246954083442688),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Victoria Pendleton': [(1.635603904724121, 0.6357750296592712),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 131]],
#    u'XXNILXX': [0, [88]]}},
#  u"-RRB- and as Roger '' Cutes '' Buell on '' [The Mothers-in-Law] '' .": {'boosted': 2.0,
#   u'gold': u'The Mothers-in-Law',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Mothers-in-Law': [(2.0047168731689453, 0.0), [88]],
#    u'The Mothers-in-Law': [(2.9251646995544434, 0.922147274017334),
#     [88, 90, 93, 95, 106, 108, 109, 114, 115, 121, 142, 143]],
#    u'XXNILXX': [0, [88]]}},
#  u'-RRB- is a Canadian former professional basketball player in the [NBA] .': {'boosted': 2.0,
#   u'gold': u'National Basketball Association',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.5075254440307617, 0.5076805949211121), [87, 124]],
#    u'2008&amp;ndash;09 NBA season': [0,
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'2008\u201309 NBA season': [(1.485654592514038, 0.4737805128097534),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'2009\u201310 NBA season': [(1.484905481338501, 0.47303929924964905),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'2010\u201311 NBA season': [(1.5557830333709717, 0.5431643128395081),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'2012\u201313 NBA season': [(1.5055673122406006, 0.49348184466362),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 136]],
#    u'NBA (song)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      128]],
#    u'NBA All-Star Game': [(1.5156357288360596, 0.5034432411193848),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 135]],
#    u'NBA Most Valuable Player Award': [(1.5699800252914429,
#      0.5572105646133423),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 138]],
#    u'NBA on ABC': [(1.5125925540924072, 0.5004324913024902),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 176]],
#    u'NBA on CBS': [(1.6673305034637451, 0.6535273790359497),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 134]],
#    u'NBA on ESPN': [(1.5200289487838745, 0.5013066530227661),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'NBA on NBC': [(1.5219128131866455, 0.5096537470817566),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 137]],
#    u'National Basketball Association': [(1.5686452388763428, 0.56834876537323),
#     [88, 89, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'National Board of Accreditation': [(1.529589056968689,
#      0.5226041674613953),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 115, 116, 118, 121, 123]],
#    u'National Boxing Association': [(0.1988288313150406, -0.7871208190917969),
#     [88]],
#    u'Neue Bach-Ausgabe': [(1.5221885442733765, 0.5099265575408936),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 130]],
#    u'XXNILXX': [0, [88]]}},
#  u'2nd Recruit Training Battalion , Recruit Training Regiment at the [MCRD San Diego] , California .': {'boosted': 2.0,
#   u'gold': u'Marine Corps Recruit Depot San Diego',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4667727947235107, 0.4710793197154999), [87, 124]],
#    u'Diego': [(2.660470724105835, 0.6622158885002136),
#     [88, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Diego Costa Silva': [(2.4430880546569824, 0.44770774245262146),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Diego Eli Moreira': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Diego Ribas': [(1.1924352645874023, -0.7864062190055847), [88]],
#    u'Diego Walsh': [(2.4911835193634033, 0.49516716599464417),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Diego de Lima Barcelos': [(2.6176865100860596, 0.6199973225593567),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Marine Corps Recruit Depot San Diego': [(1.7676079273223877,
#      0.7588688731193542),
#     [88,
#      89,
#      92,
#      94,
#      96,
#      98,
#      99,
#      100,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      2779]],
#    u'Primo (wrestler)': [(2.4637181758880615, 0.46806520223617554),
#     [88,
#      92,
#      98,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      126,
#      133]],
#    u'San Diego': [(2.798135995864868, 0.7980605959892273),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'San Diego Chargers': [(2.488844156265259, 0.49285876750946045),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'San Diego County, California': [(2.8436129093170166, 0.842936098575592),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'San Diego International Airport': [(2.7459185123443604,
#      0.7465335130691528),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u"San Diego Toreros men's basketball": [(2.416851043701172,
#      0.4218178391456604),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 115, 116, 117, 118, 121, 132]],
#    u'Southern California Open': [(2.540726661682129, 0.5440552830696106),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'University of San Diego': [(2.7728641033172607, 0.7731228470802307),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 127]],
#    u'XXNILXX': [0, [88]]}},
#  u"Bascombe '' -RRB- about [Gordon MacRae] -LRB- '' Billy Bigelow '' -RRB- in the famous ''": {'boosted': 2.0,
#   u'gold': u'Gordon MacRae',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Calum MacRae': [0,
#     [88, 89, 92, 94, 96, 99, 104, 106, 109, 114, 115, 116, 121, 125, 143]],
#    u'Gordon MacRae': [(2.923532485961914, 0.9205251932144165),
#     [88, 89, 91, 94, 106, 108, 109, 111, 115, 118, 121, 142]],
#    u'Jade MacRae': [(2.9286601543426514, 0.9181638360023499),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 123, 125]],
#    u'MacRae': [(2.908473491668701, 0.8981034159660339), [88]],
#    u'MacRae (surname)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      128]],
#    u'William MacRae': [0,
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 122, 125]],
#    u'XXNILXX': [0, [88]]}},
#  u"Birds '' and a larger role in the original '' [Invasion of the Body Snatchers] '' , having portrayed a physician in the '' book-end": {'boosted': 2.0,
#   u'gold': u'Invasion of the Body Snatchers',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9520444869995117, 0.9295127987861633), [87, 124]],
#    u'2003 invasion of Iraq': [(2.921672821044922, 0.8993310332298279),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Battle of France': [(2.918896198272705, 0.8965718746185303),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Invasion': [(2.926300525665283, 0.9039297103881836),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Invasion (1965 film)': [(2.955690622329712, 0.9331361055374146),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      130]],
#    u'Invasion (1997 film)': [(2.9535012245178223, 0.9309603571891785),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      128]],
#    u'Invasion (TV series)': [(2.9519400596618652, 0.9294089078903198),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Invasion Body Snatchers': [0, [88]],
#    u'Invasion of': [0, [88]],
#    u'Invasion of Normandy': [(2.932813882827759, 0.9104023575782776),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Invasion of Poland': [(2.9237680435180664, 0.9014131426811218),
#     [88,
#      92,
#      94,
#      96,
#      97,
#      100,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123,
#      307]],
#    u'Invasion of the': [0, [88]],
#    u'Invasion of the Body': [0, [88]],
#    u'Invasion of the Body Snatchers': [(2.9333624839782715,
#      0.9302937388420105),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Invasion of the Body Snatchers (1978 film)': [(1.9396817684173584,
#      0.9279922246932983),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Invasion of the Body Snatchers (1978 film) ': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'The Invasion (professional wrestling)': [(2.9400014877319336,
#      0.9175451397895813),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123,
#      126]],
#    u'XXNILXX': [0, [88]]}},
#  u"Cooley on '' The Dick Van Dyke Show '' , [Fred Rutherford] on '' Leave It to Beaver '' -LRB- Mr.": {'boosted': 2.0,
#   u'gold': u'Fred Rutherford',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Alexander Cameron Rutherford': [(2.9075231552124023, 0.8971589803695679),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 135]],
#    u'Ernest Rutherford': [(2.9257211685180664, 0.9152432084083557),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 130]],
#    u'Fred Rutherford': [(2.924851417541504, 0.921835720539093),
#     [88, 89, 91, 94, 106, 108, 109, 114, 115, 121, 142, 143]],
#    u'Jock Rutherford': [(2.917264461517334, 0.9068392515182495),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 125, 138]],
#    u'John Rutherford (rugby union)': [(2.9361844062805176, 0.9256411194801331),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      126,
#      131]],
#    u'Johnny Rutherford': [(2.9301247596740723, 0.9196192026138306),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 125, 133]],
#    u'Rutherford': [(2.9260952472686768, 0.9156149625778198), [88]],
#    u'Rutherford (NJT station)': [(2.9284205436706543, 0.9179255366325378),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      134]],
#    u'Rutherford AVA': [(2.927462100982666, 0.9169731140136719),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 137]],
#    u'Rutherford County, North Carolina': [(2.8997414112091064,
#      0.8894258737564087),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Rutherford County, Tennessee': [(2.918435573577881, 0.908003032207489),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Rutherford GO Station': [(2.926701784133911, 0.9162177443504333),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 136]],
#    u'Rutherford, California': [(2.9416019916534424, 0.9310246109962463),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Rutherford, Edmonton': [(2.911714553833008, 0.9013242721557617),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Rutherford, New Jersey': [(2.888692617416382, 0.8784463405609131),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Rutherford, New South Wales': [(2.9436216354370117, 0.9330316185951233),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 127]],
#    u'Rutherford, Pennsylvania': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 176]],
#    u'Rutherford, Tennessee': [(2.9202706813812256, 0.9098268747329712),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'XXNILXX': [0, [88]]}},
#  u"De La Garza , Jr. -LRB- 1949-1970 -RRB- was a [United States Marine Corps] lance corporal who was posthumous ly presented the nation 's": {'boosted': 2.0,
#   u'gold': u'United States Marine Corps',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4797561168670654, 0.4710793197154999), [87, 124]],
#    u'Aaron Corp': [(2.52744197845459, 0.518134593963623),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      145,
#      146,
#      151,
#      153,
#      154,
#      155,
#      178,
#      179,
#      199,
#      201,
#      202,
#      203]],
#    u'Corp': [(2.7912189960479736, 0.7784233093261719), [88]],
#    u'Corps': [(2.5993266105651855, 0.5890686511993408),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Corps, Is\xe8re': [(2.8108103275299072, 0.7977557182312012),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'German Student Corps': [(2.7016139030456543, 0.6900030970573425),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 122, 125]],
#    u'Marine Air-Ground Task Force': [(1.7489893436431885, 0.7409874796867371),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Marine Corps': [(1.2054187059402466, -0.7864062190055847), [88]],
#    u'Republic of Korea Marine Corps': [(2.738224744796753, 0.7261298298835754),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 123, 125]],
#    u'Ronald Corp': [(2.6494545936584473, 0.6385337114334106),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      144,
#      145,
#      146,
#      153,
#      154,
#      155,
#      177,
#      178,
#      179,
#      201,
#      202,
#      203]],
#    u'Salvation Army corps': [(2.7377209663391113, 0.7256328463554382),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'States Marine Corps': [0, [88]],
#    u'United States Army Corps of Engineers': [(2.8312933444976807,
#      0.8179677128791809),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'United States Marine Corps': [(2.789654493331909, 0.7649412155151367),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      132]],
#    u'United States Marine Corps Aviation': [(1.7735729217529297,
#      0.7652459144592285),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'XXNILXX': [0, [88]]}},
#  u'De La Garza enlisted in the [United States Marine Corps] on 4 February 1969 , in Chicago , Illinois .': {'boosted': 2.0,
#   u'gold': u'United States Marine Corps',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4797561168670654, 0.4710793197154999), [87, 124]],
#    u'Aaron Corp': [(2.52744197845459, 0.518134593963623),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      145,
#      146,
#      151,
#      153,
#      154,
#      155,
#      178,
#      179,
#      199,
#      201,
#      202,
#      203]],
#    u'Corp': [(2.7912189960479736, 0.7784233093261719), [88]],
#    u'Corps': [(2.5993266105651855, 0.5890686511993408),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Corps, Is\xe8re': [(2.8108103275299072, 0.7977557182312012),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'German Student Corps': [(2.7016139030456543, 0.6900030970573425),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 122, 125]],
#    u'Marine Air-Ground Task Force': [(1.7489893436431885, 0.7409874796867371),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Marine Corps': [(1.2054187059402466, -0.7864062190055847), [88]],
#    u'Republic of Korea Marine Corps': [(2.738224744796753, 0.7261298298835754),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 123, 125]],
#    u'Ronald Corp': [(2.6494545936584473, 0.6385337114334106),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      144,
#      145,
#      146,
#      153,
#      154,
#      155,
#      177,
#      178,
#      179,
#      201,
#      202,
#      203]],
#    u'Salvation Army corps': [(2.7377209663391113, 0.7256328463554382),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'States Marine Corps': [0, [88]],
#    u'United States Army Corps of Engineers': [(2.8312933444976807,
#      0.8179677128791809),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'United States Marine Corps': [(2.789654493331909, 0.7649412155151367),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      132]],
#    u'United States Marine Corps Aviation': [(1.7735729217529297,
#      0.7652459144592285),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'XXNILXX': [0, [88]]}},
#  u'De La Garza observed him pull the pin on a [grenade] .': {'boosted': 2.0,
#   u'gold': u'Hand grenade',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.4687010049819946, 0.4710793197154999), [87, 124]],
#    u'Canton of Grenade': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      182,
#      183,
#      184,
#      188,
#      189]],
#    u'F1 grenade (Russia)': [(1.5945056676864624, 0.5855146050453186),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      163,
#      165,
#      166,
#      171,
#      232,
#      451]],
#    u'Granatwerfer 42': [(1.5591695308685303, 0.5506458282470703),
#     [88, 95, 104, 106, 109, 111, 115, 116, 118, 121, 162, 165, 166, 169, 233]],
#    u'Grenade (The Chapman Society EP)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      239]],
#    u'Grenade (insignia)': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      163,
#      164,
#      165,
#      170,
#      171,
#      172]],
#    u'Grenade (song)': [(1.454520344734192, 0.4504125416278839),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Grenade launcher': [(1.5687042474746704, 0.5600544214248657),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      173,
#      183,
#      184,
#      185,
#      186,
#      236]],
#    u'Grenade, Haute-Garonne': [(1.8034782409667969, 0.7917236685752869),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      185,
#      186,
#      195]],
#    u'Hand grenade': [(1.6601808071136475, 0.6528623700141907),
#     [88,
#      90,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      192]],
#    u'Mills bomb': [(1.5898782014846802, 0.5809483528137207),
#     [88, 95, 104, 106, 109, 111, 112, 116, 118, 119, 161, 162, 165, 166, 169]],
#    u'Model 39 grenade': [(1.4936047792434692, 0.4859480857849121),
#     [88, 95, 104, 106, 109, 111, 115, 116, 118, 121, 162, 163, 166, 167, 235]],
#    u'Operation Grenade': [(1.644477367401123, 0.625045895576477),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      183,
#      184,
#      187,
#      188,
#      189]],
#    u'Rocket-propelled grenade': [(1.5508501529693604, 0.5424364805221558),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 163, 166, 167, 258]],
#    u'Type 97 grenade': [(1.5918984413146973, 0.5829419493675232),
#     [88, 95, 104, 106, 109, 111, 112, 116, 118, 119, 162, 163, 166, 167, 268]],
#    u'XXNILXX': [0, [88]]}},
#  u'Directly underneath the burner is the [mantle] , a fabric bag coated with chemicals which incandesce -LRB-': {'boosted': 2.0,
#   u'gold': u'Gas mantle',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.2720496654510498, 0.2794010043144226), [87, 124]],
#    u'Gas mantle': [(1.5645081996917725, 0.5569858551025391),
#     [88, 95, 104, 106, 111, 112, 115, 116, 117, 118, 162, 163, 166, 167, 233]],
#    u'Lee Mantle': [(1.7542436122894287, 0.7525312900543213),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      141,
#      183,
#      184,
#      188,
#      189,
#      239]],
#    u'Mantle': [(2.609745979309082, 0.5823410749435425), [88]],
#    u'Mantle (API)': [(1.4619240760803223, 0.45632997155189514),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Mantle (climbing)': [(0.3251208961009979, -0.6497284770011902), [88]],
#    u'Mantle (geology)': [(1.6908550262451172, 0.6751967072486877),
#     [88,
#      90,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      195]],
#    u'Mantle (mollusc)': [(1.638568639755249, 0.6322823166847229),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      162,
#      163,
#      164,
#      165,
#      170,
#      171,
#      172,
#      183,
#      184,
#      185,
#      186,
#      187,
#      193,
#      194]],
#    u'Mantle (vesture)': [(1.7575234174728394, 0.7463730573654175),
#     [88,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      161,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Mantling': [(1.6350605487823486, 0.6262121200561523),
#     [88,
#      95,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      141,
#      162,
#      165,
#      166,
#      169,
#      183,
#      186,
#      188,
#      191,
#      237,
#      261]],
#    u'Mickey Mantle': [(1.2680095434188843, 0.2660605013370514),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      141,
#      183,
#      184,
#      188,
#      189]],
#    u'Robe': [(1.6800346374511719, 0.6797171235084534),
#     [88,
#      95,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      141,
#      162,
#      165,
#      166,
#      169,
#      183,
#      186,
#      188,
#      191,
#      240,
#      268]],
#    u'XXNILXX': [0, [88]],
#    u'mantle (clothing)': [(1.640315294265747, 0.6209641695022583), [88]]}},
#  u'E , approximately four miles south of Da Nang on [11 April] 1970 , he was mortally wounded by a grenade as': {'boosted': 2.0,
#   u'gold': u'April 11',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4667727947235107, 0.4710793197154999), [87, 124]],
#    u'/April': [(2.506849527359009, 0.5106261372566223),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'April (Sun Kil Moon album)': [(2.4526376724243164, 0.4571310877799988),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      130]],
#    u'April 11': [(1.670026183128357, 0.6625775098800659),
#     [88, 89, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'April 1966': [(2.707362174987793, 0.7084872722625732),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'April 1971': [(2.6390693187713623, 0.641097366809845),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'April 1972': [(2.571559429168701, 0.5744803547859192),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 134]],
#    u'April 1973': [(2.7135603427886963, 0.7146034240722656),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'April 1975': [(2.676837921142578, 0.6783665418624878),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'April 2005': [(2.7728004455566406, 0.7730600833892822),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 138]],
#    u'April 2007': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 176]],
#    u'April 2008': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 135]],
#    u'April Branning': [(2.575688123703003, 0.5785544514656067),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 136]],
#    u'April Ludgate': [(2.62011456489563, 0.6223932504653931),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 123]],
#    u'CMLL Super Viernes (April 2014)': [0,
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      126]],
#    u'Deaths in April 2012': [(2.5677895545959473, 0.5707602500915527),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'Deaths in April 2013': [0,
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 137]],
#    u'XXNILXX': [0, [88]]}},
#  u'Emilio Albert De La Garza , Jr. was born on [23 June] 1949 , in East Chicago , Indiana , and graduated': {'boosted': 2.0,
#   u'gold': u'June 23',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4667727947235107, 0.4710793197154999), [87, 124]],
#    u'/June': [(2.541503429412842, 0.5448217988014221),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 123, 125]],
#    u'CMLL Super Viernes (June 2014)': [0,
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      126]],
#    u'Deaths in June 2012': [0,
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 136]],
#    u'Deaths in June 2013': [(2.5671324729919434, 0.5701117515563965),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 137]],
#    u'Deaths in June 2014': [(2.5671324729919434, 0.5701117515563965),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 135]],
#    u'June (band)': [(2.5130884647369385, 0.5167825222015381),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      128]],
#    u'June (singer)': [(2.5198090076446533, 0.5234141945838928),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      130]],
#    u'June 1966': [(2.6589531898498535, 0.6607183814048767),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'June 1971': [(2.620535373687744, 0.6228084564208984),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'June 1972': [(2.7365078926086426, 0.7372474670410156),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'June 1973': [(2.628235340118408, 0.6304066777229309),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'June 1975': [(2.708287477493286, 0.7094001173973083),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 134]],
#    u'June 2006': [(2.459376335144043, 0.4637807607650757),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 127]],
#    u'June 23': [(1.6863796710968018, 0.6787146925926208),
#     [88, 89, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'June Cleaver': [(2.5074541568756104, 0.511222779750824),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 175]],
#    u'June Pointer': [(2.46334171295166, 0.46769362688064575),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 138]],
#    u'XXNILXX': [0, [88]]}},
#  u'First Marine Division , in the Republic of Vietnam on [April 11] , 1970 .': {'boosted': 2.0,
#   u'gold': u'April 11',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.4667727947235107, 0.4710793197154999), [87, 124]],
#    u'/April': [(2.506849527359009, 0.5106261372566223),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'April (Sun Kil Moon album)': [(2.4526376724243164, 0.4571310877799988),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      130]],
#    u'April 11': [(2.6859188079833984, 0.6625775098800659),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'April 11 (Eastern Orthodox liturgics)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      122]],
#    u'April 1966': [(2.707362174987793, 0.7084872722625732),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 132]],
#    u'April 1971': [(2.6390693187713623, 0.641097366809845),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 127]],
#    u'April 1972': [(2.571559429168701, 0.5744803547859192),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 134]],
#    u'April 1973': [(2.7135603427886963, 0.7146034240722656),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 131]],
#    u'April 1975': [(2.676837921142578, 0.6783665418624878),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'April 2005': [(2.7728004455566406, 0.7730600833892822),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 138]],
#    u'April 2007': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 176]],
#    u'April 2008': [0,
#     [88, 92, 94, 96, 97, 100, 106, 108, 109, 114, 115, 121, 135, 142, 143]],
#    u'April Branning': [(2.575688123703003, 0.5785544514656067),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 136]],
#    u'April Ludgate': [(2.62011456489563, 0.6223932504653931),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 123]],
#    u'CMLL Super Viernes (April 2014)': [0,
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      126]],
#    u'Deaths in April 2012': [(2.5677895545959473, 0.5707602500915527),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'Deaths in April 2013': [0,
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 137]],
#    u'XXNILXX': [0, [88]]}},
#  u"Game '' , and played '' Horace Vandergelder '' opposite [Phyllis Diller] 's '' Dolly Gallagher Levi '' in a touring production": {'boosted': 2.0,
#   u'gold': u'Phyllis Diller',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Diller': [(2.8673770427703857, 0.85726398229599), [88]],
#    u'Diller Glacier': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 123]],
#    u'Diller, Nebraska': [(2.928952217102051, 0.9184539914131165),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'LeGrande A. Diller': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'Phyllis Diller': [(2.9318673610687256, 0.92880779504776),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      125]],
#    u'XXNILXX': [0, [88]]}},
#  u"He had a brief role in [Alfred Hitchcock] 's film '' The Birds '' and a larger role": {'boosted': 2.0,
#   u'gold': u'Alfred Hitchcock',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Alfred Hitchcock': [(2.9229586124420166, 0.9199548959732056),
#     [88, 89, 91, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125]],
#    u'Alfred Hitchcock (book)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Alfred Hitchcock (police officer)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      128]],
#    u'Cameron Hitchcock': [0,
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 129]],
#    u'Edward Hitchcock': [(2.9201347827911377, 0.9096916913986206),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 127]],
#    u'Hitchcock (automobile)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      137]],
#    u'Hitchcock (film)': [(2.927245616912842, 0.9167580604553223),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Hitchcock County, Nebraska': [(2.9200000762939453, 0.9095578789710999),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Hitchcock, Oklahoma': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'Hitchcock, South Dakota': [(2.92465877532959, 0.9141873717308044),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'Hitchcock, Texas': [(2.9405229091644287, 0.9299523234367371),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Ken Hitchcock': [(2.9319729804992676, 0.9214558005332947),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 134]],
#    u'Sterling Hitchcock': [(2.9104971885681152, 0.9001144766807556),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 130]],
#    u'The Birds (film)': [(2.9240217208862305, 0.9135542511940002),
#     [88,
#      92,
#      98,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      126]],
#    u'Tom Hitchcock': [0,
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 125, 128]],
#    u'Tommy Hitchcock (racing driver)': [0,
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      126,
#      307]],
#    u'XXNILXX': [0, [88]]}},
#  u"His best-known roles are Mel Cooley on '' [The Dick Van Dyke Show] '' , Fred Rutherford on '' Leave It to Beaver": {'boosted': 2.0,
#   u'gold': u'The Dick Van Dyke Show',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Agricultural show': [(2.9197311401367188, 0.909290611743927),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 132]],
#    u'Days of our Lives': [(2.9243335723876953, 0.9138643145561218), [88]],
#    u'Dyke Show': [0, [88]],
#    u'Eric Show': [(2.9104528427124023, 0.9000704288482666),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 130]],
#    u'General Hospital': [(2.9259531497955322, 0.9154736995697021),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Show': [(2.9304616451263428, 0.9199540615081787), [88]],
#    u'Show (The Cure album)': [(2.9349782466888428, 0.9244424104690552),
#     [88,
#      89,
# ...
#    u'Indonesian invasion of East Timor': [(2.595146894454956,
#      0.5827360153198242),
#     [88,
#      90,
#      93,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      166,
#      183,
#      184,
#      186,
#      188,
#      258,
#      484]],
#    u'Invasion (1997 film)': [(2.6938679218292236, 0.690682590007782),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      187,
#      193,
#      194]],
#    u'Invasion (TV series)': [(2.6517765522003174, 0.6490380764007568),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Invasion of': [0, [88]],
#    u'Invasion of East': [0, [88]],
#    u'Invasion of Normandy': [(2.581127643585205, 0.5791393518447876),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      232]],
#    u'Invasion of Poland': [(2.574089288711548, 0.5721757411956787),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      195,
#      230,
#      1063]],
#    u'Korean War': [(2.5676767826080322, 0.5658313035964966),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 233]],
#    u'The Invasion (professional wrestling)': [(2.5820703506469727,
#      0.5800721049308777),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      186,
#      188,
#      193,
#      195,
#      452]],
#    u'XXNILXX': [0, [88]],
#    u'invasion': [(2.631884813308716, 0.6293575763702393), [88]]}},
#  u"revealed to have been gay , and his interview with [Boze Hadleigh] was published in Hadleigh 's '' Hollywood Gays '' ,": {'boosted': 2.0,
#   u'gold': u'Boze Hadleigh',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Boze Hadleigh': [(2.9200944900512695, 0.9171087145805359),
#     [88, 89, 91, 94, 104, 106, 109, 111, 112, 116, 118, 119]],
#    u'Hadleigh': [(2.9173693656921387, 0.9069435000419617), [88]],
#    u'Hadleigh (TV series)': [(2.9260270595550537, 0.915547251701355),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Hadleigh Airfield': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Hadleigh Castle': [(2.930598258972168, 0.9200899004936218),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Hadleigh railway station': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 128]],
#    u'Hadleigh, Essex': [(2.935105085372925, 0.9245684742927551),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Hadleigh, Suffolk': [(2.9306840896606445, 0.9201750159263611),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'RAF Hadleigh': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 132]],
#    u'XXNILXX': [0, [88]]}},
#  u'series of cookbook s and hosted a television series on [microwave] cooking .': {'boosted': 2.0,
#   u'gold': u'Microwave oven',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.934232234954834, 0.9295127987861633), [87, 124]],
#    u'British Telecom microwave network': [(1.9370325803756714,
#      0.9199815988540649),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      141,
#      183,
#      184,
#      186,
#      188,
#      195]],
#    u'Cavalier Computer': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      183,
#      186,
#      188,
#      191,
#      237]],
#    u'Electromagnetic spectrum': [(1.890190601348877, 0.8734326958656311),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      186,
#      187,
#      188,
#      191]],
#    u'Microwave (game)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Microwave chemistry': [(1.92560875415802, 0.9021181464195251),
#     [88, 95, 104, 106, 109, 111, 112, 116, 118, 119, 162, 163, 164, 165, 233]],
#    u'Microwave oven': [(1.9119797945022583, 0.9164859056472778),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      170,
#      183,
#      184,
#      185,
#      186,
#      192]],
#    u'Microwave radiometer': [(1.89009690284729, 0.8856534361839294),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      183,
#      184,
#      185,
#      186,
#      236]],
#    u'Microwave spectroscopy': [(0.9988687038421631, 0.0), [88]],
#    u'Microwave transmission': [(1.8950371742248535, 0.8836268782615662),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 161, 162, 163, 164, 165]],
#    u'Microwaves': [(0.9988687038421631, 0.0), [88]],
#    u'Waldorf Microwave': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      188,
#      189,
#      239]],
#    u'XXNILXX': [0, [88]]}},
#  u'the 1970s and 1980s , he wrote a series of [cookbook] s and hosted a television series on microwave cooking .': {'boosted': 2.0,
#   u'gold': u'cookbook',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u"Nanny Ogg's Cookbook": [(2.8708205223083496, 0.8606858849525452),
#     [88, 95, 106, 108, 109, 114, 115, 121, 142, 143, 162, 163, 166, 167, 170]],
#    u'XXNILXX': [0, [88]],
#    u'cookbook': [(2.9299116134643555, 0.9268643856048584), [88]]}},
#  u'to a genetic neuromuscular disorder that affected his feet , [Charcot-Marie-Tooth disease] .': {'boosted': 2.0,
#   u'gold': u'Charcot\u2013Marie\u2013Tooth disease',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.508902072906494, 0.5076805949211121), [87, 124]],
#    u'Charcot\u2013Marie\u2013Tooth disease': [(1.4867750406265259,
#      0.48734790086746216),
#     [88, 90, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169]],
#    u'Disease (The Ark song)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      187,
#      193,
#      194]],
#    u'Disease (The Terminals album)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      239]],
#    u'Disease (album)': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      195]],
#    u'Disease (song)': [(2.5287413597106934, 0.527309238910675),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Globalization and disease': [(2.560920000076294, 0.5591463446617126),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      188,
#      189,
#      236]],
#    u'Infection': [(2.503202438354492, 0.5020415782928467),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      161,
#      162,
#      165,
#      166,
#      169,
#      183,
#      186,
#      188,
#      191,
#      237]],
#    u'Neurological disorder': [(2.48014497756958, 0.47922900319099426),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 232]],
#    u'Occupational disease': [(2.494020462036133, 0.49295705556869507),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      182,
#      183,
#      184,
#      188,
#      189]],
#    u'Plant pathology': [(2.5089001655578613, 0.5076788663864136),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 170]],
#    u'XXNILXX': [0, [88]],
#    u'disease': [(2.491644859313965, 0.4906066358089447), [88]]}},
#  u"was a United States Marine Corps lance corporal who was [posthumous] ly presented the nation 's highest honor '' mdash ;": {'boosted': 2.0,
#   u'gold': u'Posthumous recognition',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.4687010049819946, 0.4710793197154999), [87, 124]],
#    u'Posthumous': [(2.650947093963623, 0.6280680894851685), [88]],
#    u'Posthumous (EP)': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Posthumous name': [(1.6814022064208984, 0.6614823341369629),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 163, 164, 165, 232]],
#    u'Posthumous recognition': [(0.19436362385749817, -0.7864062190055847),
#     [88]],
#    u'Posthumous work': [(0.19436362385749817, -0.7864062190055847), [88]],
#    u"Shakespeare's reputation": [(1.6471290588378906, 0.6471478939056396),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      186,
#      188,
#      191,
#      195]],
#    u'XXNILXX': [0, [88]],
#    u'posthumou': [0, [88]],
#    u'posthumous birth': [(1.7106231451034546, 0.7031285762786865), [88]]}},
#  u'where there are consulates in comparatively small cities such as [New Bedford] and Providence whose links to Portugal are based on receiving': {'boosted': 2.0,
#   u'gold': u'New Bedford, Massachusetts',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.574843406677246, 0.57428377866745), [87, 124]],
#    u'Bedford': [(1.5041650533676147, 0.5043558478355408),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Bedford (UK Parliament constituency)': [(1.4993884563446045,
#      0.4996299743652344),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Bedford Blues': [(1.5839511156082153, 0.5832947492599487),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'Bedford County, Pennsylvania': [(1.5472304821014404, 0.5469639897346497),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Bedford Vehicles': [(1.5741610527038574, 0.5736086368560791),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'Bedford, Massachusetts': [(1.5503003597259521, 0.550001323223114),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Bedford, Nova Scotia': [(1.618334174156189, 0.6173127293586731),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Bedford, Pennsylvania': [(1.5846891403198242, 0.5840250253677368),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Borough of Bedford': [(1.4636385440826416, 0.46425962448120117),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 123, 125]],
#    u'National Register of Historic Places listings in New Bedford, Massachusetts': [(1.5415340662002563,
#      0.5413280725479126),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'New Bedford Bay Sox': [(1.5806726217269897, 0.5613064169883728),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'New Bedford High School': [(1.5798779726028442, 0.5605202317237854),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'New Bedford Regional Airport': [(1.5782170295715332, 0.5588769316673279),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 127]],
#    u'New Bedford, Illinois': [(1.5168166160583496, 0.5099672675132751),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'New Bedford, Massachusetts': [(1.572725772857666, 0.5723859667778015),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'New Bedford, Ohio': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 128]],
#    u'New Bedford, Pennsylvania': [(1.5379092693328857, 0.5377417802810669),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 130]],
#    u'XXNILXX': [0, [88]]}},
#  u"who admonishes Shirley Jones -LRB- '' Julie '' -RRB- and [John Dehner] -LRB- '' Mr.": {'boosted': 2.0,
#   u'gold': u'John Dehner',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.9400806427001953, 0.9295127987861633), [87, 124]],
#    u'Dehner': [(2.0047168731689453, 0.0), [88]],
#    u'John Dehner': [(2.9255549907684326, 0.9225350618362427),
#     [88, 89, 91, 94, 106, 108, 109, 114, 115, 121, 142, 143]],
#    u'XXNILXX': [0, [88]]}},
#  u'win their group only to lose to eventual silver medalist [France] in the quarterfinals and finish seventh .': {'boosted': 2.0,
#   u'gold': u'France national basketball team',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.5075254440307617, 0.5076805949211121), [87, 124]],
#    u'A1 Team France': [(1.5161402225494385, 0.5039423704147339),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 176]],
#    u'Cinema of France': [(1.6377010345458984, 0.6242125630378723),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 136]],
#    u'First French Empire': [(1.5262821912765503, 0.5139767527580261),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 138]],
#    u'France': [(2.5067715644836426, 0.4952991008758545),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'France national basketball team': [(1.541994571685791,
#      0.5295222997665405),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 317]],
#    u'France national football team': [(1.5279901027679443, 0.5210221409797668),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'France national rugby league team': [(1.5103340148925781,
#      0.4981977939605713),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 132]],
#    u'France national rugby union team': [(1.555011510848999,
#      0.5359178185462952),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 128]],
#    u"France women's national football team": [(1.5502833127975464,
#      0.5377230048179626),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 134]],
#    u'French First Republic': [(1.5492222309112549, 0.5366731882095337),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 135]],
#    u'French Football Federation': [(1.5550146102905273, 0.542404055595398),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 123]],
#    u'French Rugby Federation': [(1.586944818496704, 0.5739952921867371),
#     [88, 92, 94, 98, 99, 100, 106, 108, 109, 114, 115, 121, 129, 142, 143]],
#    u'French Third Republic': [(1.523660659790039, 0.5113831162452698),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'French poetry': [(1.4795821905136108, 0.46777257323265076),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Kingdom of France': [(1.5147833824157715, 0.5026000738143921),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 131]],
#    u'LNB Pro A': [(1.4351469278335571, 0.42380908131599426),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 523]],
#    u'Second French Empire': [(1.5111026763916016, 0.4989584684371948),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 746]],
#    u"Syndicat National de l'\xc9dition Phonographique": [0,
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 133]],
#    u'XXNILXX': [0, [88]]}}}

# %%
len(queries_exp.current_surface_target_counts)

# %%
evalCurrentState(False, 500000)

# %%
evalCurrentState(True, 500000)

# %%
exp_results = []

true_num_samples = 500000 #queries_exp.num_training_items

for i in xrange(10):
    queries_exp.num_training_items = true_num_samples
    res = (i, queries_exp.compute_batch())
    print res
    exp_results.append(res)
    #if i % 2 == 1:
    exp_results.append(('training state', evalCurrentState(True, queries_exp.num_training_items)))
    queries_exp.num_training_items = 50000  # don't need that many samples to see how well it performs
    exp_results.append(('testing run', queries_exp.compute_batch(False)))
    exp_results.append(('testing state', evalCurrentState(False, queries_exp.num_training_items)))
# Out:
# (0, (0.084552645653629604, 0.084552645653629604))
# (4480, 0.7551339285714286)
# (485, 0.7195876288659794)
# (1, (0.054401656721812373, 0.054401656721812373))
# (4480, 0.8122767857142857)
# (485, 0.7257731958762886)
# (2, (0.045442575675018748, 0.045442575675018748))
# (4480, 0.8258928571428571)
# (485, 0.734020618556701)
# (3, (0.038935665023289302, 0.038935665023289302))
# (4480, 0.8357142857142857)
# (485, 0.7360824742268042)
# (4, (0.034458860742299618, 0.034458860742299618))
# (4480, 0.8439732142857143)
# (485, 0.7360824742268042)
# (5, (0.031939252412700798, 0.031939252412700798))
# (4480, 0.8504464285714286)
# (485, 0.7422680412371134)
# (6, (0.028427405341246131, 0.028427405341246131))
# (4480, 0.8546875)
# (485, 0.7360824742268042)
# (7, (0.025638149749117742, 0.025638149749117742))
# (4480, 0.8618303571428572)
# (485, 0.7402061855670103)
# (8, (0.023210681474392716, 0.023210681474392716))
# (4480, 0.8654017857142857)
# (485, 0.7381443298969073)
# (9, (0.02094186570814819, 0.02094186570814819))
# (4480, 0.86875)
# (485, 0.7360824742268042)

# %%
evalCurrentStateF1(False, 50000)
# Out:
# (485, 'Prec = 298.0/396 = 0.752525252525, Rec = 298.0/394 = 0.756345177665, F1 = 0.754430379747')
# (485,
#  'Prec = 298.0/396 = 0.752525252525, Rec = 298.0/394 = 0.756345177665, F1 = 0.754430379747')

# %%
exp_results
# Out:
# [(0, (0.077007342273082868, 0.077007342273082868)),
#  ('training state', (14507, 0.7443992555318122)),
#  ('testing run', (0.05550440773557494, 0.05550440773557494)),
#  ('testing state', (2786, 0.7681263460157932)),
#  (1, (0.049090448561995001, 0.049090448561995001)),
#  ('training state', (14507, 0.8500034466119805)),
#  ('testing run', (0.049654608572627622, 0.049654608572627622)),
#  ('testing state', (2786, 0.7835606604450825)),
#  (2, (0.040758830454690531, 0.040758830454690531)),
#  ('training state', (14507, 0.8808850899565727)),
#  ('testing run', (0.048032516460673351, 0.048032516460673351)),
#  ('testing state', (2786, 0.7889447236180904)),
#  (3, (0.035743609206569792, 0.035743609206569792)),
#  ('training state', (14507, 0.8991521334528159)),
#  ('testing run', (0.046497399569593895, 0.046497399569593895)),
#  ('testing state', (2786, 0.791816223977028)),
#  (4, (0.032063148292749734, 0.032063148292749734)),
#  ('training state', (14507, 0.9154201420004136)),
#  ('testing run', (0.045787234784460805, 0.045787234784460805)),
#  ('testing state', (2786, 0.7939698492462312)),
#  (5, (0.02873328122129672, 0.02873328122129672)),
#  ('training state', (14507, 0.925415316743641)),
#  ('testing run', (0.045069633703215754, 0.045069633703215754)),
#  ('testing state', (2786, 0.8018664752333095)),
#  (6, (0.025974297559462761, 0.025974297559462761)),
#  ('training state', (14507, 0.9367891362790377)),
#  ('testing run', (0.044887604688609535, 0.044887604688609535)),
#  ('testing state', (2786, 0.8025843503230438)),
#  (7, (0.023840884886437642, 0.023840884886437642)),
#  ('training state', (14507, 0.942027986489281)),
#  ('testing run', (0.044172348134515149, 0.044172348134515149)),
#  ('testing state', (2786, 0.8000717875089735)),
#  (8, (0.021776811462738722, 0.021776811462738722)),
#  ('training state', (14507, 0.9487833459709106)),
#  ('testing run', (0.04426101122096255, 0.04426101122096255)),
#  ('testing state', (2786, 0.8025843503230438)),
#  (9, (0.020118322562738197, 0.020118322562738197)),
#  ('training state', (14507, 0.953884331701937)),
#  ('testing run', (0.044236213112934152, 0.044236213112934152)),
#  ('testing state', (2786, 0.8047379755922469))]

# %%
evalCurrentStateF1(False, 50000)
# Out:
# (2786, 'Prec = 1227.0/1530 = 0.801960784314, Rec = 1227.0/1491 = 0.822937625755, F1 = 0.812313803376')
# (2786,
#  'Prec = 1227.0/1530 = 0.801960784314, Rec = 1227.0/1491 = 0.822937625755, F1 = 0.812313803376')

# %%
exp_results
# Out:
# [(0, (0.078138949114696474, 0.078138949114696474)),
#  ('training state', (14507, 0.7339215551113256)),
#  ('testing run', (0.056753362598735077, 0.056753362598735077)),
#  ('testing state', (2786, 0.7638190954773869)),
#  (1, (0.049944703551281958, 0.049944703551281958)),
#  ('training state', (14507, 0.8417315778589647)),
#  ('testing run', (0.050976422710410488, 0.050976422710410488)),
#  ('testing state', (2786, 0.7774587221823402)),
#  (2, (0.041119292557657429, 0.041119292557657429)),
#  ('training state', (14507, 0.8742675949541601)),
#  ('testing run', (0.049062282774639851, 0.049062282774639851)),
#  ('testing state', (2786, 0.7792534099066762)),
#  (3, (0.03576254595473783, 0.03576254595473783)),
#  ('training state', (14507, 0.8966705728269111)),
#  ('testing run', (0.047454943072275213, 0.047454943072275213)),
#  ('testing state', (2786, 0.7885857860732233)),
#  (4, (0.031338119074726424, 0.031338119074726424)),
#  ('training state', (14507, 0.9122492589784242)),
#  ('testing run', (0.046184339742121723, 0.046184339742121723)),
#  ('testing state', (2786, 0.7896625987078248)),
#  (5, (0.028104384990730997, 0.028104384990730997)),
#  ('training state', (14507, 0.9233473495553871)),
#  ('testing run', (0.046050086922599084, 0.046050086922599084)),
#  ('testing state', (2786, 0.7885857860732233)),
#  (6, (0.02579276150988247, 0.02579276150988247)),
#  ('training state', (14507, 0.9346522368511753)),
#  ('testing run', (0.045680695583375917, 0.045680695583375917)),
#  ('testing state', (2786, 0.7896625987078248)),
#  (7, (0.023616245472598614, 0.023616245472598614)),
#  ('training state', (14507, 0.943061970083408)),
#  ('testing run', (0.045266211870660295, 0.045266211870660295)),
#  ('testing state', (2786, 0.7946877243359656)),
#  (8, (0.02158084047148992, 0.02158084047148992)),
#  ('training state', (14507, 0.9485765492520852)),
#  ('testing run', (0.044525325341483339, 0.044525325341483339)),
#  ('testing state', (2786, 0.793610911701364)),
#  (9, (0.020222975064656947, 0.020222975064656947)),
#  ('training state', (14507, 0.9527814158682015)),
#  ('testing run', (0.045160752745598075, 0.045160752745598075)),
#  ('testing state', (2786, 0.7914572864321608)),
#  (0, (0.019072413376496816, 0.019072413376496816)),
#  ('training state', (14507, 0.9550561797752809)),
#  ('testing run', (0.045163917408950607, 0.045163917408950607)),
#  ('testing state', (2786, 0.7910983488872936)),
#  (1, (0.018180216729019327, 0.018180216729019327)),
#  ('training state', (14507, 0.9578134693596195)),
#  ('testing run', (0.044648165141055206, 0.044648165141055206)),
#  ('testing state', (2786, 0.790021536252692)),
#  (2, (0.017693714220713769, 0.017693714220713769)),
#  ('training state', (14507, 0.9601571655063073)),
#  ('testing run', (0.044811209881437782, 0.044811209881437782)),
#  ('testing state', (2786, 0.7910983488872936)),
#  (3, (0.016747104612587899, 0.016747104612587899)),
#  ('training state', (14507, 0.9624319294133866)),
#  ('testing run', (0.045032622815018596, 0.045032622815018596)),
#  ('testing state', (2786, 0.7878679109834889)),
#  (4, (0.016167908183106067, 0.016167908183106067)),
#  ('training state', (14507, 0.9643620321224237)),
#  ('testing run', (0.045164379375868938, 0.045164379375868938)),
#  ('testing state', (2786, 0.7875089734386217)),
#  (5, (0.015539363526430792, 0.015539363526430792)),
#  ('training state', (14507, 0.9655338801957676)),
#  ('testing run', (0.045338165386183973, 0.045338165386183973)),
#  ('testing state', (2786, 0.7885857860732233)),
#  (6, (0.015017191761627812, 0.015017191761627812)),
#  ('training state', (14507, 0.9669814572275454)),
#  ('testing run', (0.044913037223452981, 0.044913037223452981)),
#  ('testing state', (2786, 0.7875089734386217)),
#  (7, (0.014477694250698522, 0.014477694250698522)),
#  ('training state', (14507, 0.9682222375404977)),
#  ('testing run', (0.045154876934516093, 0.045154876934516093)),
#  ('testing state', (2786, 0.7857142857142857)),
#  (8, (0.014006139615131318, 0.014006139615131318)),
#  ('training state', (14507, 0.9701523402495347)),
#  ('testing run', (0.045283588357373318, 0.045283588357373318)),
#  ('testing state', (2786, 0.7832017229002154)),
#  (9, (0.013641773630350842, 0.013641773630350842)),
#  ('training state', (14507, 0.9712552560832701)),
#  ('testing run', (0.045092679718583335, 0.045092679718583335)),
#  ('testing state', (2786, 0.7885857860732233))]

# %%
exp_results  # softmax with sum
# Out:
# [(0, (0.056138775254378749, 0.056138775254378749)),
#  ('training state', (16751, 0.8275326846158438)),
#  ('testing run', (0.041264208608243182, 0.041264208608243182)),
#  ('testing state', (3257, 0.8222290451335585)),
#  (1, (0.032694965263001904, 0.032694965263001904)),
#  ('training state', (16751, 0.8921855411617217)),
#  ('testing run', (0.036458856948669523, 0.036458856948669523)),
#  ('testing state', (3257, 0.8317470064476512)),
#  (2, (0.026061488875205145, 0.026061488875205145)),
#  ('training state', (16751, 0.9128410244164528)),
#  ('testing run', (0.034066918085718802, 0.034066918085718802)),
#  ('testing state', (3257, 0.8394227817009517)),
#  (3, (0.022176126083093824, 0.022176126083093824)),
#  ('training state', (16751, 0.923288161900782)),
#  ('testing run', (0.032215075407071095, 0.032215075407071095)),
#  ('testing state', (3257, 0.8394227817009517)),
#  (4, (0.019028079153091241, 0.019028079153091241)),
#  ('training state', (16751, 0.9338546952420751)),
#  ('testing run', (0.031710045067207149, 0.031710045067207149)),
#  ('testing state', (3257, 0.8452563708934603)),
#  (5, (0.0166650842451634, 0.0166650842451634)),
#  ('training state', (16751, 0.9428093845143574)),
#  ('testing run', (0.030275234635146722, 0.030275234635146722)),
#  ('testing state', (3257, 0.8458704329137243)),
#  (6, (0.014874705678229863, 0.014874705678229863)),
#  ('training state', (16751, 0.9483612918631723)),
#  ('testing run', (0.029983090529854092, 0.029983090529854092)),
#  ('testing state', (3257, 0.842493091802272)),
#  (7, (0.01350522439454083, 0.01350522439454083)),
#  ('training state', (16751, 0.9512267924303026)),
#  ('testing run', (0.030187902033537523, 0.030187902033537523)),
#  ('testing state', (3257, 0.8492477740251766)),
#  (8, (0.012334567229042978, 0.012334567229042978)),
#  ('training state', (16751, 0.9545101784968062)),
#  ('testing run', (0.030026178257516595, 0.030026178257516595)),
#  ('testing state', (3257, 0.8501688670555726)),
#  (9, (0.011126156570005491, 0.011126156570005491)),
#  ('training state', (16751, 0.9583308459196466)),
#  ('testing run', (0.02995118396154706, 0.02995118396154706)),
#  ('testing state', (3257, 0.8510899600859687))]

# %%
exp_results
# Out:
# [(0, (0.045419816074390475, 0.045419816074390475)),
#  ('training state', (16751, 0.8604859411378425)),
#  ('testing run', (0.033767858709709934, 0.033767858709709934)),
#  ('testing state', (3257, 0.8477126189745164)),
#  (1, (0.024159178331701999, 0.024159178331701999)),
#  ('training state', (16751, 0.9201838696197242)),
#  ('testing run', (0.029704254039343091, 0.029704254039343091)),
#  ('testing state', (3257, 0.8563094872582131)),
#  (2, (0.018057037956445549, 0.018057037956445549)),
#  ('training state', (16751, 0.9386305295206256)),
#  ('testing run', (0.027614201312658491, 0.027614201312658491)),
#  ('testing state', (3257, 0.8566165182683451)),
#  (3, (0.014547730161543412, 0.014547730161543412)),
#  ('training state', (16751, 0.9493761566473643)),
#  ('testing run', (0.026470875968818721, 0.026470875968818721)),
#  ('testing state', (3257, 0.8563094872582131)),
#  (4, (0.012402786729561526, 0.012402786729561526)),
#  ('training state', (16751, 0.9570771894215271)),
#  ('testing run', (0.02702622656700672, 0.02702622656700672)),
#  ('testing state', (3257, 0.8575376112987412)),
#  (5, (0.010669449655487283, 0.010669449655487283)),
#  ('training state', (16751, 0.9610172527013313)),
#  ('testing run', (0.026088953338701208, 0.026088953338701208)),
#  ('testing state', (3257, 0.8563094872582131)),
#  (6, (0.00925610204474509, 0.00925610204474509)),
#  ('training state', (16751, 0.962688794698824)),
#  ('testing run', (0.025499047632517664, 0.025499047632517664)),
#  ('testing state', (3257, 0.8584587043291373)),
#  (7, (0.0086170968051623598, 0.0086170968051623598)),
#  ('training state', (16751, 0.965196107695063)),
#  ('testing run', (0.026590514774027019, 0.026590514774027019)),
#  ('testing state', (3257, 0.8569235492784771)),
#  (8, (0.0077804314971884432, 0.0077804314971884432)),
#  ('training state', (16751, 0.9673452331204108)),
#  ('testing run', (0.026533269176835836, 0.026533269176835836)),
#  ('testing state', (3257, 0.8599938593797973)),
#  (9, (0.0070150313940936628, 0.0070150313940936628)),
#  ('training state', (16751, 0.9685391916900483)),
#  ('testing run', (0.026192095118841487, 0.026192095118841487)),
#  ('testing state', (3257, 0.8578446423088733))]

# %%
exp_results
# Out:
# [(0, (0.064189446505648742, 0.064189446505648742)),
#  ('training state', (16751, 0.7997731478717689)),
#  ('testing run', (0.046786291718423398, 0.046786291718423398)),
#  ('testing state', (3257, 0.7835431378569235)),
#  (1, (0.034940440456979402, 0.034940440456979402)),
#  ('training state', (16751, 0.8700973076234255)),
#  ('testing run', (0.038705401029782198, 0.038705401029782198)),
#  ('testing state', (3257, 0.7942892232115444)),
#  (2, (0.028999492954004349, 0.028999492954004349)),
#  ('training state', (16751, 0.8899767178078921)),
#  ('testing run', (0.036473699762248089, 0.036473699762248089)),
#  ('testing state', (3257, 0.8068774946269573)),
#  (3, (0.026587150493473509, 0.026587150493473509)),
#  ('training state', (16751, 0.899588084293475)),
#  ('testing run', (0.035577757867320307, 0.035577757867320307)),
#  ('testing state', (3257, 0.8139392078599939)),
#  (4, (0.024141828166381499, 0.024141828166381499)),
#  ('training state', (16751, 0.9053190854277356)),
#  ('testing run', (0.036197332528041401, 0.036197332528041401)),
#  ('testing state', (3257, 0.8136321768498619)),
#  (5, (0.022808142567021458, 0.022808142567021458)),
#  ('training state', (16751, 0.9100949197062862)),
#  ('testing run', (0.034714288429163027, 0.034714288429163027)),
#  ('testing state', (3257, 0.8243782622044826)),
#  (6, (0.021728968167185621, 0.021728968167185621)),
#  ('training state', (16751, 0.9161244104829562)),
#  ('testing run', (0.034657329636058588, 0.034657329636058588)),
#  ('testing state', (3257, 0.8237642001842186)),
#  (7, (0.020544069067644079, 0.020544069067644079)),
#  ('training state', (16751, 0.9195868903349054)),
#  ('testing run', (0.034843573708465136, 0.034843573708465136)),
#  ('testing state', (3257, 0.829597789376727)),
#  (8, (0.019424857832944675, 0.019424857832944675)),
#  ('training state', (16751, 0.9234075577577459)),
#  ('testing run', (0.034616934825395837, 0.034616934825395837)),
#  ('testing state', (3257, 0.8277556033159349)),
#  (9, (0.01904428211993878, 0.01904428211993878)),
#  ('training state', (16751, 0.9246612142558653)),
#  ('testing run', (0.035673006444737532, 0.035673006444737532)),
#  ('testing state', (3257, 0.8259134172551428))]

# %%
exp_results
# Out:
# [(0, (0.040649041546011011, 0.040649041546011011)),
#  ('training state', (16751, 0.8726643185481464)),
#  ('testing run', (0.029816368260841913, 0.029816368260841913)),
#  ('testing state', (3257, 0.8541602701872889)),
#  (1, (0.019999649017465558, 0.019999649017465558)),
#  ('training state', (16751, 0.9320637573876186)),
#  ('testing run', (0.025060822855288361, 0.025060822855288361)),
#  ('testing state', (3257, 0.8652133865520417)),
#  (2, (0.014082454662991323, 0.014082454662991323)),
#  ('training state', (16751, 0.9490776670049549)),
#  ('testing run', (0.023715640716943546, 0.023715640716943546)),
#  ('testing state', (3257, 0.8655204175621738)),
#  (3, (0.010434311972288748, 0.010434311972288748)),
#  ('training state', (16751, 0.9579726583487553)),
#  ('testing run', (0.022557722516562687, 0.022557722516562687)),
#  ('testing state', (3257, 0.8618360454405894)),
#  (4, (0.0077628766400616618, 0.0077628766400616618)),
#  ('training state', (16751, 0.9640618470539072)),
#  ('testing run', (0.02326933684437231, 0.02326933684437231)),
#  ('testing state', (3257, 0.8618360454405894)),
#  (5, (0.0057502205511872186, 0.0057502205511872186)),
#  ('training state', (16751, 0.9681213061906752)),
#  ('testing run', (0.023536921738982499, 0.023536921738982499)),
#  ('testing state', (3257, 0.8615290144304575)),
#  (6, (0.0041946526475814989, 0.0041946526475814989)),
#  ('training state', (16751, 0.9705092233299505)),
#  ('testing run', (0.023658735553125688, 0.023658735553125688)),
#  ('testing state', (3257, 0.8652133865520417)),
#  (7, (0.0024024432286194456, 0.0024024432286194456)),
#  ('training state', (16751, 0.9718822756850337)),
#  ('testing run', (0.022629264024184501, 0.022629264024184501)),
#  ('testing state', (3257, 0.8633712004912496)),
#  (8, (0.0012604201247880837, 0.0012604201247880837)),
#  ('training state', (16751, 0.9734941197540445)),
#  ('testing run', (0.023282996382134252, 0.023282996382134252)),
#  ('testing state', (3257, 0.8615290144304575)),
#  (9, (0.0005413959569609486, 0.0005413959569609486)),
#  ('training state', (16751, 0.9742104948958271)),
#  ('testing run', (0.022229960825013138, 0.022229960825013138)),
#  ('testing state', (3257, 0.8624501074608536))]

# %%
evalCurrentStateF1(False,50000)
# Out:
# (3264, 'Prec = 1724.0/2046 = 0.842619745846, Rec = 1724.0/2015 = 0.855583126551, F1 = 0.849051957646')
# (3264,
#  'Prec = 1724.0/2046 = 0.842619745846, Rec = 1724.0/2015 = 0.855583126551, F1 = 0.849051957646')

# %%
exp_results # fix indicators, with neural stuff
# Out:
# [(0, (0.040737683761148918, 0.040737683761148918)),
#  ('training state', (16751, 0.8703957972658348)),
#  ('testing run', (0.03043622349096143, 0.03043622349096143)),
#  ('testing state', (3257, 0.8523180841264968)),
#  (1, (0.020092518089640764, 0.020092518089640764)),
#  ('training state', (16751, 0.9301534236761985)),
#  ('testing run', (0.025570338057137203, 0.025570338057137203)),
#  ('testing state', (3257, 0.8630641694811176)),
#  (2, (0.014424285078212177, 0.014424285078212177)),
#  ('training state', (16751, 0.9479434063637991)),
#  ('testing run', (0.02385036148350576, 0.02385036148350576)),
#  ('testing state', (3257, 0.8652133865520417)),
#  (3, (0.010878184881017971, 0.010878184881017971)),
#  ('training state', (16751, 0.9573756790639365)),
#  ('testing run', (0.023522055788912338, 0.023522055788912338)),
#  ('testing state', (3257, 0.8652133865520417)),
#  (4, (0.0078855968551349888, 0.0078855968551349888)),
#  ('training state', (16751, 0.9638230553399797)),
#  ('testing run', (0.023398395655811696, 0.023398395655811696)),
#  ('testing state', (3257, 0.8636782315013817)),
#  (5, (0.0060327848223781224, 0.0060327848223781224)),
#  ('training state', (16751, 0.9666288579786282)),
#  ('testing run', (0.022295818032174633, 0.022295818032174633)),
#  ('testing state', (3257, 0.8661344795824378)),
#  (6, (0.0040191331735678106, 0.0040191331735678106)),
#  ('training state', (16751, 0.9701510357590591)),
#  ('testing run', (0.023270757825656987, 0.023270757825656987)),
#  ('testing state', (3257, 0.867669634633098)),
#  (7, (0.0027172430318706661, 0.0027172430318706661)),
#  ('training state', (16751, 0.971703181899588)),
#  ('testing run', (0.023944983422190234, 0.023944983422190234)),
#  ('testing state', (3257, 0.8655204175621738)),
#  (8, (0.0015658363004497633, 0.0015658363004497633)),
#  ('training state', (16751, 0.9735538176825265)),
#  ('testing run', (0.023076504511215994, 0.023076504511215994)),
#  ('testing state', (3257, 0.8652133865520417)),
#  (9, (0.00025918538454784424, 0.00025918538454784424)),
#  ('training state', (16751, 0.9743895886812728)),
#  ('testing run', (0.023383247054022352, 0.023383247054022352)),
#  ('testing state', (3257, 0.8612219834203254))]

# %%
evalCurrentStateF1(False, 50000)
# Out:
# (3188, 'Prec = 1385.0/1896 = 0.730485232068, Rec = 1385.0/2060 = 0.672330097087, F1 = 0.700202224469')
# (3188,
#  'Prec = 1385.0/1896 = 0.730485232068, Rec = 1385.0/2060 = 0.672330097087, F1 = 0.700202224469')

# %%
evalCurrentStateF1(False, 50000)
# Out:
# (3247, 'Prec = 1366.0/1821 = 0.750137287205, Rec = 1366.0/2037 = 0.6705940108, F1 = 0.708138932089')
# (3247,
#  'Prec = 1366.0/1821 = 0.750137287205, Rec = 1366.0/2037 = 0.6705940108, F1 = 0.708138932089')

# %%
findWrongItems(False)
# Out:
# {u' [Antonella Bellutti] ( Italy ) 3:32.174 caught and eliminated Rasa Mazeikyte (': {'boosted': 10.0,
#   u'gold': u'Antonella Bellutti',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.121854066848755, 0), [15, 50]],
#    u'Antonella Bellutti': [0,
#     [35, 48, 49, 77, 78, 79, 81, 83, 87, 88, 93, 96, 111, 112, 113, 114]],
#    u'Stefano Bellutti': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 83, 93, 96]]}},
#  u" [Baltimore] 's Eddie Murray cracked his 20th homer of the season": {'boosted': 10.0,
#   u'gold': u'Baltimore Orioles',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.557110071182251, 0), [15, 50]],
#    u'2011 Baltimore Ravens season': [(-1.8019276857376099, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 84, 93, 127]],
#    u'2012 Baltimore Ravens season': [(-2.2568023204803467, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 84, 93, 108]],
#    u'Baltimore': [(6.689257621765137, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Baltimore (Parliament of Ireland constituency)': [(-1.577612280845642, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 81, 84, 85, 87, 93, 104, 105, 120]],
#    u'Baltimore Clippers': [(-0.996390700340271, 0),
#     [26, 27, 32, 33, 35, 48, 79, 81, 84, 87, 93, 104, 109, 111, 113]],
#    u'Baltimore County, Maryland': [(0.6235138773918152, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Baltimore Orioles': [(5.1962995529174805, 0),
#     [23, 29, 30, 32, 35, 48, 49, 79, 81, 84, 88, 89, 93, 104, 112]],
#    u'Baltimore Ravens': [(2.515341281890869, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 91, 93, 104]],
#    u'Baltimore SC': [(-0.5101154446601868, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 79, 81, 84, 87, 92, 93, 104]],
#    u'Baltimore Skipjacks': [(-0.639750599861145, 0),
#     [23, 26, 27, 29, 32, 35, 48, 79, 81, 84, 87, 88, 93, 104, 107]],
#    u'Baltimore Symphony Orchestra': [(0.12518857419490814, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 110]],
#    u'Baltimore, County Cork': [(0.2813742458820343, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Baltimore, Ohio': [(1.163924217224121, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 104, 106]],
#    u'Baltimore\u2013Washington International Airport': [(0.29444876313209534,
#      0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Grand Prix of Baltimore': [(-0.4906919598579407, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 83, 93, 96, 125]],
#    u'Pennsylvania Station (Baltimore)': [(-0.1609904170036316, 0),
#     [23, 26, 27, 29, 30, 35, 48, 81, 83, 84, 85, 86, 88, 93, 114, 140]],
#    u'Roman Catholic Archdiocese of Baltimore': [(-0.6854955554008484, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 83, 93, 96, 97]],
#    u'University of Baltimore': [(-0.9796101450920105, 0),
#     [23, 24, 26, 29, 30, 35, 49, 79, 81, 83, 88, 93, 94, 96, 114]],
#    u'Washington Wizards': [(0.04524420574307442, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 82, 83, 84, 98]]}},
#  u" [Cleveland] 's lead over the White Sox in the American League": {'boosted': 10.0,
#   u'gold': u'Cleveland Indians',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.298819661140442, 0), [15, 50]],
#    u'Cleveland': [(6.35442590713501, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Cleveland (UK Parliament constituency)': [(-1.2064136266708374, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 109, 120]],
#    u'Cleveland Barons (1937\u201373)': [(-0.9266882538795471, 0),
#     [23, 26, 27, 29, 32, 35, 48, 81, 84, 85, 86, 87, 88, 93, 104, 140]],
#    u'Cleveland Brown': [(3.079864740371704, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 84, 88, 92, 93, 104]],
#    u'Cleveland Browns': [(1.5237244367599487, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 93, 95, 104]],
#    u'Cleveland Cavaliers': [(0.43311619758605957, 0),
#     [23, 26, 29, 30, 32, 35, 48, 49, 79, 80, 81, 84, 88, 93, 104]],
#    u'Cleveland County, North Carolina': [(0.29136303067207336, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 104, 108]],
#    u'Cleveland County, Oklahoma': [(1.313774585723877, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 94, 104]],
#    u'Cleveland Hopkins International Airport': [(0.5260871648788452, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Cleveland Indians': [(4.874871253967285, 0),
#     [23, 24, 29, 30, 32, 33, 35, 49, 79, 81, 84, 93, 97, 104, 112]],
#    u'Cleveland Rockers': [(1.5163733959197998, 0),
#     [26, 27, 32, 33, 35, 48, 79, 81, 84, 87, 91, 93, 104, 111, 113]],
#    u'Cleveland, England': [(0.7875206470489502, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 89, 93, 104]],
#    u'Cleveland, Georgia': [(0.5524976253509521, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 104, 110]],
#    u'Cleveland, Mississippi': [(1.9362794160842896, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 84, 88, 93, 104, 125]],
#    u'Cleveland, Queensland': [(0.954537570476532, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 104, 105]],
#    u'Cleveland, Tennessee': [(1.9561835527420044, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Cleveland, Texas': [(2.5026748180389404, 0),
#     [23, 26, 29, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 114, 127]],
#    u'Grand Prix of Cleveland': [(0.428587943315506, 0),
#     [23, 26, 27, 29, 32, 35, 48, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'Grover Cleveland': [(2.539088487625122, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]]}},
#  u' [Holland] was moved to a more secure centre earlier this year': {'boosted': 10.0,
#   u'gold': u'Netherlands',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.206307888031006, 0), [15, 50]],
#    u'Count of Holland': [(-0.9491336345672607, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 109]],
#    u'County of Holland': [(1.3256503343582153, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Derek Holland': [(-0.8551508784294128, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Dutch Republic': [(0.21649211645126343, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 110]],
#    u'Greg Holland': [(-1.4289326667785645, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 91, 93, 96]],
#    u'Holland': [(5.500089645385742, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Holland (album)': [(-2.531157970428467, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 106, 120]],
#    u'Holland (band)': [(-1.215790867805481, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 120, 127]],
#    u'Holland, Manitoba': [(-1.2096229791641235, 0),
#     [35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 111, 112, 113, 114, 140]],
#    u'Holland, Massachusetts': [(-2.0672428607940674, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 92, 93, 104]],
#    u'Holland, Michigan': [(-0.8006198406219482, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Holland, New York': [(-0.5857555866241455, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 125]],
#    u'Holland, Ohio': [(-2.4546291828155518, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 108]],
#    u'Kingdom of Holland': [(0.6258983612060547, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 94, 96]],
#    u'Matt Holland': [(-0.5054949522018433, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 105]],
#    u'Netherlands': [(3.4683477878570557, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 98]],
#    u'Netherlands national football team': [(0.441444993019104, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 97]],
#    u'Parts of Holland': [(-0.8411498665809631, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'William Jacob Holland': [(-1.2404695749282837, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 95, 96]]}},
#  u' [Kansas City] has scored only one run in two games .': {'boosted': 10.0,
#   u'gold': u'Kansas City Royals',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.8986194133758545, 0), [15, 50]],
#    u'Cities of Japan': [(-2.3672502040863037, 0),
#     [26, 27, 32, 33, 35, 48, 79, 80, 81, 82, 83, 84, 87, 111, 113]],
#    u'Cities of the Philippines': [(-2.7748260498046875, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 98]],
#    u'City': [(-1.6375741958618164, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'City (TV network)': [(-2.1463186740875244, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 81, 84, 85, 88, 93, 97, 104, 120]],
#    u'City of London': [(-2.1486246585845947, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'County-level city': [(-2.221801996231079, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'Kansas City (Leiber and Stoller song)': [(-1.6610220670700073, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 81, 84, 85, 93, 98, 104, 120]],
#    u'Kansas City (film)': [(-2.086556911468506, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 81, 84, 85, 87, 93, 94, 104, 120]],
#    u'Kansas City Chiefs': [(-1.202200174331665, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 89, 93, 104]],
#    u'Kansas City International Airport': [(-1.65277898311615, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 93, 95, 104]],
#    u'Kansas City Royals': [(1.5232778787612915, 0),
#     [23, 29, 30, 35, 48, 49, 79, 81, 84, 88, 93, 104, 105, 112, 114]],
#    u'Kansas City metropolitan area': [(0.6856222152709961, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 91, 93, 104]],
#    u'Kansas City, Kansas': [(0.3287409245967865, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 80, 81, 84, 88, 93, 104]],
#    u'Kansas City, Missouri': [(4.792930603027344, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 84, 93, 104]],
#    u'List of cities in Kentucky': [(-3.0071890354156494, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 90]],
#    u'Local government in California': [(-1.6330596208572388, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 82, 83, 84, 88, 95]],
#    u'Prefecture-level city': [(-1.8718554973602295, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 83, 89, 93, 96]],
#    u'Sacramento Kings': [(-1.4317375421524048, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 97]],
#    u'Sporting Kansas City': [(-0.3416440188884735, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 90, 93, 96]]}},
#  u' [Lucy Tyler-Sharman] ( Australia ) 3:35.087 beat Svetlana Samokhvalova ( Russia )': {'boosted': 10.0,
#   u'gold': u'Lucy Tyler-Sharman',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.0042479038238525, 0), [15, 50]],
#    u'Lucy Tyler-Sharman': [0,
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]]}},
#  u' [Roberto Chiappa] ( Italy ) beat Frederic Magne ( France ) 2-0': {'boosted': 10.0,
#   u'gold': u'Roberto Chiappa',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.089356899261475, 0), [15, 50]],
#    u'Chiappa': [(-3.7207045555114746, 0),
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]],
#    u'Chiappa (La Spezia)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 89, 93, 104, 120]],
#    u'Chiappa (San Bartolomeo Al Mare)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 90, 93, 104, 120]],
#    u'Chiappa Firearms': [(-3.336179733276367, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'Roberto Chiappa': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 80, 81, 83, 87, 88, 93, 96]]}},
#  u' [Roger Pavlik] ( 15-7 ) gave up three runs and seven hits': {'boosted': 10.0,
#   u'gold': u'Roger Pavlik',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.1024601459503174, 0), [15, 50]],
#    u'Pavlik': [(-1.718929648399353, 0),
#     [23, 29, 35, 48, 49, 77, 78, 79, 87, 88, 112, 114]],
#    u'Roger Pavlik': [0,
#     [26, 32, 35, 48, 49, 77, 78, 79, 80, 81, 83, 87, 88, 93, 96, 111, 113]],
#    u'Rudolf Pavlik': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Whitney Pavlik': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]]}},
#  u' [Slovakia] - Lubomir Moravcik ( 13th ) , Peter Dubovsky (': {'boosted': 10.0,
#   u'gold': u'Slovakia national football team',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.018104076385498, 0), [15, 50]],
#    u'Acceleration Team Slovakia': [0,
#     [17, 18, 21, 23, 26, 29, 32, 35, 39, 44, 48, 49, 87, 88, 330]],
#    u'Elections in Slovakia': [(-0.6430994868278503, 0),
#     [17, 18, 21, 23, 26, 29, 32, 35, 39, 48, 49, 58, 87, 88, 330]],
#    u'ISU Junior Grand Prix in Slovakia': [0,
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 41, 330]],
#    u'Slovak Extraliga (basketball)': [(-2.7178897857666016, 0),
#     [17, 20, 23, 26, 29, 32, 35, 39, 45, 48, 49, 59, 60, 87, 88, 193]],
#    u'Slovak Football Association': [(2.0267751216888428, 0),
#     [17, 20, 21, 35, 37, 39, 45, 48, 49, 87, 88, 111, 112, 113, 114]],
#    u'Slovak Republic (1939\u201345)': [(-0.9740526676177979, 0),
#     [17, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 40, 45, 59, 60]],
#    u'Slovak wine': [(-2.2488925457000732, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 45, 61]],
#    u'Slovakia': [(9.290631294250488, 0),
#     [16, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 328]],
#    u'Slovakia Davis Cup team': [(1.4836171865463257, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 46]],
#    u'Slovakia Fed Cup team': [(1.0497876405715942, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 42]],
#    u'Slovakia at the Hopman Cup': [0,
#     [17, 18, 19, 20, 21, 23, 26, 29, 32, 35, 48, 49, 57, 87, 88]],
#    u"Slovakia men's national ice hockey team": [(3.063718318939209, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 38]],
#    u"Slovakia men's national junior ice hockey team": [0,
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 192]],
#    u'Slovakia national football team': [(3.6939566135406494, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36]],
#    u'Slovakia national handball team': [(-1.2593672275543213, 0),
#     [17, 18, 19, 20, 21, 23, 26, 29, 32, 35, 48, 49, 87, 88, 207]],
#    u'Slovakia national under-21 football team': [(3.520451307296753, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 55]],
#    u"Slovakia women's national basketball team": [(0.16105994582176208, 0),
#     [17, 18, 19, 20, 21, 23, 26, 29, 32, 35, 47, 48, 49, 87, 88]],
#    u"Slovakia women's national football team": [(0.4425387978553772, 0),
#     [17, 18, 19, 20, 21, 23, 26, 29, 32, 35, 43, 48, 49, 87, 88]],
#    u"Slovakia women's national ice hockey team": [(3.6089649200439453, 0),
#     [17, 18, 19, 20, 21, 23, 26, 29, 30, 32, 33, 35, 48, 49, 56]]}},
#  u' [Slovakia] beat the Faroe Islands 2-1 ( halftime 1-0 ) in': {'boosted': 10.0,
#   u'gold': u'Slovakia national football team',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.2777867317199707, 0), [15, 50]],
#    u'Acceleration Team Slovakia': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 94, 96]],
#    u'Elections in Slovakia': [(-0.4259978234767914, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'ISU Junior Grand Prix in Slovakia': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 98]],
#    u'Slovak Extraliga (basketball)': [(-1.9956974983215332, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 82, 83, 84, 85, 86, 87, 88, 127]],
#    u'Slovak Football Association': [(2.9687509536743164, 0),
#     [35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 91, 111, 112, 113, 114]],
#    u'Slovak Republic (1939\u201345)': [(-0.6893526315689087, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 82, 83, 84, 85, 86, 90]],
#    u'Slovak wine': [(-1.7689698934555054, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 109]],
#    u'Slovakia': [(8.368792533874512, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Slovakia Davis Cup team': [(0.7077274322509766, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'Slovakia Fed Cup team': [(0.6982406377792358, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Slovakia at the Hopman Cup': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 108]],
#    u"Slovakia men's national ice hockey team": [(2.4748902320861816, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u"Slovakia men's national junior ice hockey team": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 140]],
#    u'Slovakia national football team': [(5.563255310058594, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Slovakia national handball team': [(-0.9802206754684448, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 110]],
#    u'Slovakia national under-21 football team': [(4.47639274597168, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u"Slovakia women's national basketball team": [(0.3324988782405853, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 105]],
#    u"Slovakia women's national football team": [(1.2391600608825684, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 97, 104]],
#    u"Slovakia women's national ice hockey team": [(3.1225976943969727, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 125]]}},
#  u' [U. Chandana] not out 14': {'boosted': 10.0,
#   u'gold': u'U. Chandana',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.829237461090088, 0), [15, 50]],
#    u'Chandana (film)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Chandana Banerjee': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 80, 81, 84, 87, 88, 93, 104]],
#    u'U. Chandana': [0, [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]],
#    u'Upul Chandana': [(3.1390392780303955, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88, 93, 96]]}},
#  u'" A member of the public recognised [Holland] in a newsagent shop as he was reading the headlines': {'boosted': 10.0,
#   u'gold': u'Netherlands',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.3233532905578613, 0), [15, 50]],
#    u'Count of Holland': [(-0.21018122136592865, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 109]],
#    u'County of Holland': [(1.5503243207931519, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Derek Holland': [(-0.22088676691055298, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Dutch Republic': [(0.5227980017662048, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 110]],
#    u'Greg Holland': [(-0.5579485297203064, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 91, 93, 96]],
#    u'Holland': [(5.211437225341797, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Holland (album)': [(-1.5231298208236694, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 106, 120]],
#    u'Holland (band)': [(-0.48865222930908203, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 120, 127]],
#    u'Holland, Manitoba': [(-0.8434966206550598, 0),
#     [35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 111, 112, 113, 114, 140]],
#    u'Holland, Massachusetts': [(-1.2342909574508667, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 92, 93, 104]],
#    u'Holland, Michigan': [(-0.30947935581207275, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Holland, New York': [(0.05927826091647148, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 125]],
#    u'Holland, Ohio': [(-1.4159865379333496, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 108]],
#    u'Kingdom of Holland': [(1.2425036430358887, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 94, 96]],
#    u'Matt Holland': [(0.5135203003883362, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 105]],
#    u'Netherlands': [(3.2097909450531006, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 98]],
#    u'Netherlands national football team': [(1.5333212614059448, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 97]],
#    u'Parts of Holland': [(-0.027091462165117264, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'William Jacob Holland': [(-0.21707718074321747, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 95, 96]]}},
#  u'" Aziz said in a statement carried by the official [Iraqi News Agency] ( INA ) .': {'boosted': 10.0,
#   u'gold': u'National Iraqi News Agency',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.233046293258667, 0), [15, 50]],
#    u'Agency (philosophy)': [(-2.870323896408081, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 81, 84, 85, 93, 95, 104, 120]],
#    u'Agency (sociology)': [(-2.351651668548584, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 81, 84, 85, 93, 98, 104, 120]],
#    u'Agency Township, Buchanan County, Missouri': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 105]],
#    u'Agency Township, Roberts County, South Dakota': [(-3.1215767860412598, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 92, 93, 104]],
#    u'Agency Township, Wapello County, Iowa': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 94, 104]],
#    u'Agency, Iowa': [(-2.320838212966919, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 84, 93, 104]],
#    u'Agency, Mississippi': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 107]],
#    u'Agency, Missouri': [(-3.0579159259796143, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Agency, Montana': [(-2.732407569885254, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 125]],
#    u'Central Intelligence Agency': [(1.1332765817642212, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 106]],
#    u'Federally Administered Tribal Areas': [(-0.8056729435920715, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 97]],
#    u'Government agency': [(-2.0041983127593994, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 83, 93, 96]],
#    u'Independent agencies of the United States government': [(-2.3830134868621826,
#      0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 82, 83, 84]],
#    u'Iraqi News Agency': [0, [23, 24, 26, 27, 29, 30, 32, 33, 35, 78, 79, 80]],
#    u'Law of agency': [(-2.3177409172058105, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'Ministry (government department)': [(-0.7650834918022156, 0),
#     [35, 48, 49, 81, 82, 83, 84, 85, 86, 87, 88, 108, 111, 112, 113, 114]],
#    u'National Iraqi News Agency': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 83, 87, 88, 93, 96]],
#    u'News agency': [(-0.3976786136627197, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'The Agency (film)': [(-2.805053949356079, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 83, 84, 85, 86, 87, 88, 89, 93]]}},
#  u'" Since [Mauritania] has been eliminated on all fronts and the next commitments': {'boosted': 10.0,
#   u'gold': u'Mauritania national football team',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.6156961917877197, 0), [15, 50]],
#    u'2011\u201313 Mauritanian protests': [(-0.7580209970474243, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 109]],
#    u'Demographics of Mauritania': [(-1.9997186660766602, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 107]],
#    u'Elections in Mauritania': [(-1.0252701044082642, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 89, 93, 96]],
#    u'Flag of Mauritania': [(-0.5165853500366211, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 98]],
#    u'Football Federation of the Islamic Republic of Mauritania': [(-0.2525140345096588,
#      0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 80, 81, 83, 87, 88, 93, 96]],
#    u'Football in Mauritania': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 127]],
#    u'LGBT rights in Mauritania': [(-0.88311368227005, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 95, 96]],
#    u'Mauretania': [(-0.07492239773273468, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 108]],
#    u'Mauritania': [(4.1231560707092285, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Mauritania Rugby Federation': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 105]],
#    u'Mauritania national football team': [(3.647484540939331, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'Mauritania national rugby union team': [(0.36294224858283997, 0),
#     [35, 48, 49, 79, 81, 84, 87, 88, 92, 93, 104, 111, 112, 113, 114]],
#    u'Military of Mauritania': [(-1.4455984830856323, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Music of Mauritania': [(-1.7645092010498047, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 97]],
#    u'Outline of Mauritania': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Politics of Mauritania': [(-0.33146965503692627, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 110]],
#    u'Religion in Mauritania': [(-1.2337117195129395, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 125]],
#    u'Slavery in Mauritania': [(-1.2203587293624878, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 106]],
#    u'Women in Mauritania': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 140]]}},
#  u"'s costliest footballer Alan Shearer was named as the new [England] captain on Friday .": {'boosted': 10.0,
#   u'gold': u'England national football team',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.076251029968262, 0), [15, 50]],
#    u'England': [(4.563355922698975, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'England cricket team': [(4.272439479827881, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'England national football team': [(2.3791892528533936, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u"England national men's squash team": [(-1.0801444053649902, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 107]],
#    u'England national rugby league team': [(-0.5341746807098389, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 90, 93, 104]],
#    u'England national rugby union team': [(-0.05981528386473656, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'England national rugby union team (sevens)': [(-2.093034505844116, 0),
#     [23, 26, 35, 48, 49, 81, 84, 85, 86, 87, 88, 93, 104, 108, 113, 114]],
#    u'England national under-21 football team': [(-0.1948358714580536, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 110]],
#    u"England national women's squash team": [(-1.6706392765045166, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 109]],
#    u"England women's cricket team": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 94, 104]],
#    u"England women's national football team": [(-0.8159161806106567, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 105]],
#    u'Football in England': [(-0.6702372431755066, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 125]],
#    u'Great Britain national speedway team': [(-0.7080438733100891, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 92]],
#    u'Kingdom of England': [(-0.8600367307662964, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Peerage of England': [(-2.1588082313537598, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 140]],
#    u'Rugby Football League': [(-1.5519073009490967, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 127]],
#    u'Rugby Football Union': [(-0.6990465521812439, 0),
#     [29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 95, 111, 112]],
#    u'The Football Association': [(0.15399082005023956, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 98]],
#    u'United Kingdom': [(0.19943691790103912, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 106]]}},
#  u'( J. Benjamin 4-17 , M. Bicknell 4-38 ) , [Surrey] 468 ( C. Lewis 94 , M. Butcher 70 ,': {'boosted': 10.0,
#   u'gold': u'Surrey County Cricket Club',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.5061475038528442, 0), [15, 50]],
#    u'High Sheriff of Surrey': [(0.9749215841293335, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 110]],
#    u'Surrey': [(8.013906478881836, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Surrey (European Parliament constituency)': [(-0.28524667024612427, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 120, 140]],
#    u'Surrey (UK Parliament constituency)': [(0.16280454397201538, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 90, 93, 104, 120]],
#    u'Surrey (carriage)': [(1.514810562133789, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 120, 127]],
#    u'Surrey (electoral district)': [(-0.9037488102912903, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 105, 120]],
#    u'Surrey CCC Women': [(2.1684913635253906, 0),
#     [35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 107, 111, 112, 113, 114]],
#    u'Surrey County Council': [(0.26335611939430237, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 94, 104]],
#    u'Surrey County Cricket Club': [(6.963846206665039, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Surrey County Cricket Club in 2005': [(1.3212000131607056, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Surrey County Football Association': [(-0.5624378323554993, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 108]],
#    u'Surrey County, Jamaica': [(1.6421654224395752, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 106]],
#    u'Surrey Eagles': [(1.1941711902618408, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 97, 104]],
#    u'Surrey Police': [(0.23186446726322174, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 109]],
#    u'Surrey Rugby Football Union': [(0.183423712849617, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 98, 104]],
#    u'Surrey county cricket teams': [(1.7943353652954102, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 89, 93, 104]],
#    u'Surrey, British Columbia': [(1.1336385011672974, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'Surrey, North Dakota': [(-0.3819686770439148, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 125]],
#    u'University of Surrey': [(2.0984251499176025, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 92, 93, 96]]}},
#  u'( world record ) beat Russia ( Anton Chantyr , [Edouard Gritsoun] , Nikolai Kouznetsov ) 4:06.534 .': {'boosted': 10.0,
#   u'gold': u'Eduard Gritsun',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.8540990352630615, 0), [15, 50]],
#    u'Eduard Gritsun': [0,
#     [35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88, 111, 112, 113, 114]]}},
#  u', G. Hamilton 61 ; P. Such 8-118 ) , [Essex] 372 and 100-5 .': {'boosted': 10.0,
#   u'gold': u'Essex County Cricket Club',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.3686074018478394, 0), [15, 50]],
#    u'Essex': [(8.65333366394043, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Essex (UK Parliament constituency)': [(-0.12585322558879852, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 98, 104, 120]],
#    u'Essex (electoral district)': [(-0.4885063171386719, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 94, 104, 120]],
#    u'Essex (whaleship)': [(1.0474367141723633, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 120, 127]],
#    u"Essex 73's": [(1.8736846446990967, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 110]],
#    u'Essex County Cricket Club': [(6.825782299041748, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 80, 81, 84, 87, 88, 93, 104]],
#    u'Essex County, Massachusetts': [(0.7433350682258606, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 89, 93, 104]],
#    u'Essex County, New Jersey': [(3.288722515106201, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Essex County, New York': [(4.783871173858643, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 91, 93, 104]],
#    u'Essex County, Ontario': [(1.4324915409088135, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Essex County, Vermont': [(2.1098544597625732, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 108]],
#    u'Essex County, Virginia': [(2.302211046218872, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 107]],
#    u'Essex county cricket teams': [(1.169851303100586, 0),
#     [35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 109, 111, 112, 113, 114]],
#    u'Essex, Connecticut': [(2.0551064014434814, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'Essex, Maryland': [(0.36963921785354614, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 125]],
#    u'Essex, Massachusetts': [(1.229407787322998, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'Essex, Ontario': [(1.039783239364624, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Essex, Vermont': [(1.2295756340026855, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 140]],
#    u'Kingdom of Essex': [(3.414059638977051, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 106]]}},
#  u'1. [Antonella Bellutti] ( Italy ) 3:31.526 ( world record )': {'boosted': 10.0,
#   u'gold': u'Antonella Bellutti',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.211717128753662, 0), [15, 50]],
#    u'Antonella Bellutti': [0,
#     [35, 48, 49, 77, 78, 79, 81, 83, 87, 88, 93, 96, 111, 112, 113, 114]],
#    u'Stefano Bellutti': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 83, 93, 96]]}},
#  u'11. [Wendy Everson] ( Britain ) 37.624': {'boosted': 10.0,
#   u'gold': u'Wendy Everson',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.025552749633789, 0), [15, 50]],
#    u'Arthur and Ernest Everson': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Ben Everson': [(-2.0888521671295166, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 90, 93, 96]],
#    u'Cory Everson': [(-1.6678811311721802, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Cromwell Everson': [(-2.1536526679992676, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 95, 96]],
#    u'Everson Pereira da Silva': [(-1.4793052673339844, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 80, 81, 84, 93, 104]],
#    u'Everson aircraft': [(-1.457371711730957, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 97, 104]],
#    u'Everson v. Board of Education': [(-2.184267282485962, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Everson, Pennsylvania': [(-2.8412365913391113, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'Everson, Washington': [(-1.328813076019287, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 84, 93, 104]],
#    u'Joel Everson': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 105]],
#    u'Wendy Everson': [0,
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]]}},
#  u'2. Michael Green ( Jamaica ) , [Osmond Ezinwa] ( Nigeria ) , Oeji Aliu': {'boosted': 10.0,
#   u'gold': u'Osmond Ezinwa',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.3839941024780273, 0), [15, 50]],
#    u'Osmond Ezinwa': [0,
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]]}},
#  u'2. [Annett Neumann] ( Germany ) 35.202': {'boosted': 10.0,
#   u'gold': u'Annett Neumann',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.520499229431152, 0), [15, 50]],
#    u'Annett Neumann': [0,
#     [35, 48, 49, 77, 78, 79, 81, 83, 87, 88, 93, 96, 111, 112, 113, 114, 169]],
#    u'Bernhard Neumann': [(-5.049476623535156, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 93, 96, 108]],
#    u'Carlheinz Neumann': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 110]],
#    u'Franz Ernst Neumann': [(-5.2396650314331055, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 125]],
#    u'Georg Neumann': [(-4.994288921356201, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'Herbert Neumann': [(-4.1616644859313965, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 98]],
#    u'Jer\xf3nimo Morales Neumann': [(-4.907209396362305, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Johnny Neumann': [(-4.564180850982666, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 140]],
#    u'Karl Eugen Neumann': [(-5.525448322296143, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 107]],
#    u'Liselotte Neumann': [(-2.2601864337921143, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Neumann': [(-5.292339324951172, 0),
#     [23, 24, 26, 27, 29, 32, 35, 77, 78, 79, 87, 88]],
#    u'Neumann Knights inline hockey': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'Neumann University': [(-3.8818840980529785, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 80, 81, 84, 93, 104]],
#    u'Neumann boundary condition': [(-4.646583557128906, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 95, 104]],
#    u'Oscar Neumann': [(-5.420718669891357, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 89, 93, 96]],
#    u'Philipp Neumann': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Sebastian Neumann': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 106]],
#    u'Steve Neumann': [(-5.427554130554199, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 105]],
#    u'Tom\xe1\u0161 Neumann': [(-5.1884260177612305, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 109]]}},
#  u'3. [Lucy Tyler-Sharman] ( Australia ) 3:31.830': {'boosted': 10.0,
#   u'gold': u'Lucy Tyler-Sharman',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.6424174308776855, 0), [15, 50]],
#    u'Lucy Tyler-Sharman': [0,
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]]}},
#  u'3. [Paul Koech] ( Kenya ) 13:06.45': {'boosted': 10.0,
#   u'gold': u'Paul Koech',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.556062698364258, 0), [15, 50]],
#    u'Koech': [(-3.077808380126953, 0),
#     [26, 32, 35, 48, 49, 77, 78, 79, 87, 88, 111, 113]],
#    u'Paul Kipsiele Koech': [(-0.9194576740264893, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 79, 80, 81, 83, 87, 93, 96]],
#    u'Paul Koech': [0, [23, 29, 35, 48, 49, 77, 78, 79, 87, 88, 112, 114]],
#    u'Paul Koech (long jumper)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 84, 85, 93, 104, 120]]}},
#  u'4. [Tatyana Motkova] ( Russia ) 1.97': {'boosted': 10.0,
#   u'gold': u'Tatyana Babashkina',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-3.6456899642944336, 0), [15, 50]],
#    u'Tatyana Babashkina': [0,
#     [35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88, 111, 112, 113, 114]]}},
#  u'5. [Stephanie Storp] ( Germany ) 18.41': {'boosted': 10.0,
#   u'gold': u'Stephanie Storp',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.130849838256836, 0), [15, 50]],
#    u'Stephanie Storp': [0,
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]]}},
#  u'6,739-yard [Brown Deer Park Golf Course] after the first round': {'boosted': 10.0,
#   u'gold': u'Brown Deer Park Golf Course',
#   u'training': False,
#   u'vals': {u'-NIL-': [(0.873538076877594, 0), [15, 50]],
#    u'Brackenridge Park Golf Course': [(5.180909633636475, 0),
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 42, 330]],
#    u'Brown Deer Park Golf Course': [0,
#     [16, 21, 35, 48, 49, 87, 88, 111, 112, 113, 114, 328]],
#    u'Course (ballet)': [0,
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 41, 59, 329]],
#    u'Course (education)': [(0.8396069407463074, 0),
#     [16, 17, 18, 19, 20, 23, 26, 29, 30, 32, 33, 35, 48, 49, 59, 329]],
#    u'Course (film)': [0,
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 43, 59, 329]],
#    u'Course (navigation)': [(2.6528100967407227, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 40, 59, 329]],
#    u'Course (orienteering)': [(2.724827766418457, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 47, 59, 329]],
#    u'Course (sail)': [(1.8079190254211426, 0),
#     [17, 18, 19, 20, 23, 26, 29, 32, 35, 38, 48, 49, 59, 87, 88, 329]],
#    u'Course River': [0,
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 42]],
#    u'Course catalog': [(3.0951151847839355, 0),
#     [17, 18, 19, 20, 21, 23, 26, 29, 32, 35, 44, 48, 49, 87, 88]],
#    u'Cynthia course': [0,
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 37, 39, 330]],
#    u'Golf': [(4.056267261505127, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 37, 39, 45]],
#    u'Golf Course Railway Station': [0,
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36]],
#    u'Golf course': [(4.941495418548584, 0),
#     [16, 17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36, 39, 328, 330]],
#    u'Major (academic)': [(0.8986021876335144, 0),
#     [17, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 45, 55, 59, 60]],
#    u'Mozingo Lake Golf Course': [0,
#     [17, 18, 21, 23, 26, 29, 32, 35, 38, 39, 48, 49, 87, 88, 330]],
#    u'The Meadows at Grand Valley State University': [0,
#     [17, 20, 21, 23, 26, 29, 32, 35, 39, 41, 45, 48, 49, 87, 88]],
#    u'University of Idaho Golf Course': [(4.434384346008301, 0),
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 40, 330]],
#    u'University of Maryland Golf Course': [0,
#     [17, 18, 21, 23, 26, 29, 32, 35, 39, 43, 48, 49, 87, 88, 330]]}},
#  u'6. [Phylis Smith] ( Britain ) 52.05': {'boosted': 10.0,
#   u'gold': u'Phylis Smith',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.283384799957275, 0), [15, 50]],
#    u'Alan Smith (footballer, born 1962)': [(-3.319368362426758, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 94]],
#    u'Alan Smith (footballer, born 1980)': [(-4.529921531677246, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 98]],
#    u'Andrew Smith (zoologist)': [(-4.200868606567383, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 81, 83, 84, 85, 86, 93]],
#    u'Cameron Smith': [(-3.7259063720703125, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 109]],
#    u'Devin Smith': [(-3.7003440856933594, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 79, 81, 83, 87, 93, 96, 106]],
#    u'Jack Smith (footballer, born 1915)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 105]],
#    u'Joe Smith (pitcher)': [(-4.1977949142456055, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 90, 93]],
#    u'Katie Smith': [(-3.5380985736846924, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 83, 89, 93, 96]],
#    u'Kevin Smith (footballer)': [(-4.312005043029785, 0),
#     [23, 24, 26, 27, 29, 32, 33, 35, 81, 83, 84, 85, 86, 87, 93, 140]],
#    u'Lee Smith (baseball)': [(-3.0324180126190186, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 83, 84, 85, 86, 93]],
#    u'Matt Smith (footballer, born 1989)': [(-4.932835102081299, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 108]],
#    u'Phylis Smith': [0,
#     [35,
#      48,
#      49,
#      77,
#      78,
#      79,
#      81,
#      83,
#      87,
#      88,
#      93,
#      96,
#      111,
#      112,
#      113,
#      114,
#      5387]],
#    u'Smith (TV series)': [(-4.260919094085693, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 81, 84, 85, 87, 93, 104, 120, 125]],
#    u'Smith (surname)': [(-3.557931900024414, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 92, 93, 104, 120]],
#    u'Smith County, Texas': [(-4.024178504943848, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'Stan Smith': [(-2.738780975341797, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 83, 93, 95, 96]],
#    u'Tommy Smith (footballer, born 1945)': [(-4.1672210693359375, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 110]],
#    u'Tommy Smith (footballer, born 1980)': [(-4.370713233947754, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 97]],
#    u'Tommy Smith (footballer, born 1990)': [(-4.71826171875, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 107]]}},
#  u"Adams and Platt are both injured and will miss [England] 's opening World Cup qualifier against Moldova on Sunday .": {'boosted': 10.0,
#   u'gold': u'England national football team',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.6136996746063232, 0), [15, 50]],
#    u'England': [(4.529932022094727, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'England cricket team': [(5.730348587036133, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'England national football team': [(4.834583282470703, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u"England national men's squash team": [(-0.7185946106910706, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 107]],
#    u'England national rugby league team': [(-0.47528940439224243, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 90, 93, 104]],
#    u'England national rugby union team': [(0.28450605273246765, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'England national rugby union team (sevens)': [(-1.2858084440231323, 0),
#     [23, 26, 35, 48, 49, 81, 84, 85, 86, 87, 88, 93, 104, 108, 113, 114]],
#    u'England national under-21 football team': [(1.5396803617477417, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 110]],
#    u"England national women's squash team": [(-1.0620366334915161, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 109]],
#    u"England women's cricket team": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 94, 104]],
#    u"England women's national football team": [(1.3453445434570312, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 105]],
#    u'Football in England': [(0.9760322570800781, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 125]],
#    u'Great Britain national speedway team': [(0.031216435134410858, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 92]],
#    u'Kingdom of England': [(-0.40495064854621887, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Peerage of England': [(-1.236426830291748, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 140]],
#    u'Rugby Football League': [(-1.0834087133407593, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 127]],
#    u'Rugby Football Union': [(0.3033991754055023, 0),
#     [29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 95, 111, 112]],
#    u'The Football Association': [(1.0166734457015991, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 98]],
#    u'United Kingdom': [(0.33219239115715027, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 106]]}},
#  u"An explosion leveled [Rochester] 's one-story Lilac Falls Motel , killing two people ,": {'boosted': 10.0,
#   u'gold': u'Rochester, New Hampshire',
#   u'training': False,
#   u'vals': {u'-NIL-': [(0.39762306213378906, 0), [15, 50]],
#    u'Bishop of Rochester': [(0.6841678619384766, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 125]],
#    u'Diocese of Rochester': [(0.7059639692306519, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 106]],
#    u'Rochester (UK Parliament constituency)': [(-0.20993080735206604, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 89, 93, 104, 120]],
#    u'Rochester Americans': [(1.2653542757034302, 0),
# ...
#    u'M\xf3\xf0i and Magne': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'Olivier Magne': [(-0.7582358121871948, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 83, 87, 88, 93, 96]]}},
#  u"Texas 's lead over Seattle in the [West] increased to six .": {'boosted': 10.0,
#   u'gold': u'American League West',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.317497730255127, 0), [15, 50]],
#    u'AFC West': [(-0.5190384984016418, 0),
#     [17, 18, 21, 23, 26, 27, 29, 30, 32, 33, 35, 39, 46, 48, 330]],
#    u'American League West': [(2.6577565670013428, 0),
#     [17, 18, 21, 23, 29, 35, 39, 48, 49, 55, 87, 88, 112, 114, 330]],
#    u'Canadian Football League West Division': [(-1.7319247722625732, 0),
#     [17, 18, 20, 21, 23, 26, 27, 29, 30, 32, 33, 35, 38, 39, 48]],
#    u'Enoch West': [(-0.4043530821800232, 0),
#     [17, 18, 21, 23, 26, 29, 32, 35, 39, 48, 49, 87, 88, 207, 330]],
#    u'Longitude': [(1.4162631034851074, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 45, 61]],
#    u'NFC West': [(-0.18398496508598328, 0),
#     [17, 18, 21, 23, 26, 27, 29, 30, 32, 33, 35, 39, 48, 56, 330]],
#    u'Scottish Junior Football Association, West Region': [(-1.5214446783065796,
#      0),
#     [17, 18, 20, 21, 23, 26, 27, 29, 32, 33, 35, 39, 48, 87, 192]],
#    u'West': [(1.1870168447494507, 0),
#     [21, 23, 26, 27, 29, 32, 33, 35, 36, 48, 87, 328]],
#    u'West (cigarette)': [(0.5365171432495117, 0),
#     [17, 18, 19, 20, 26, 27, 32, 33, 35, 44, 48, 59, 87, 111, 113, 329]],
#    u'West Africa': [(0.9932103157043457, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 42]],
#    u'West Division (NHL)': [(-1.4080411195755005, 0),
#     [17, 18, 19, 20, 23, 26, 29, 32, 33, 35, 48, 49, 59, 60, 87, 193]],
#    u'West Germany': [(-0.12859351933002472, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 58]],
#    u'West Province (Western Australia)': [0,
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 43, 59, 60]],
#    u'West Tennessee': [(-0.38198167085647583, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 29, 30, 32, 35, 49, 57, 88]],
#    u'Western Conference (NBA)': [(-1.9880062341690063, 0),
#     [17, 18, 19, 20, 23, 26, 29, 32, 35, 47, 48, 49, 59, 60, 87, 88]],
#    u'Western Conference (WNBA)': [(-1.4324426651000977, 0),
#     [17, 18, 19, 20, 23, 26, 27, 29, 32, 33, 35, 40, 48, 59, 60, 87]],
#    u'Western Ukraine': [(-0.6253144145011902, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 41]],
#    u'Western United States': [(2.232445240020752, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 29, 30, 32, 33, 35, 37, 49]],
#    u'Western world': [(3.7806835174560547, 0),
#     [16, 17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35]]}},
#  u"Texas 's lead over [Seattle] in the West increased to six .": {'boosted': 10.0,
#   u'gold': u'Seattle Mariners',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.9868072271347046, 0), [15, 50]],
#    u'1977\u201378 Seattle SuperSonics season': [(-2.2217884063720703, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 84, 87, 88, 93, 108]],
#    u'2004\u201305 Seattle SuperSonics season': [(-1.8898587226867676, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 84, 87, 88, 93, 109]],
#    u'2007\u201308 Seattle SuperSonics season': [(-1.5973525047302246, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 83, 84, 88, 93, 110]],
#    u'2013 Seattle Seahawks season': [(-1.597913146018982, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 84, 93, 107]],
#    u'King Street Station (Seattle)': [(0.03341655060648918, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 106]],
#    u'Roman Catholic Archdiocese of Seattle': [(-0.46068501472473145, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 140]],
#    u'Seattle': [(7.56705904006958, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Seattle Mariners': [(4.285905361175537, 0),
#     [23, 29, 30, 35, 48, 49, 79, 81, 84, 88, 93, 98, 104, 112, 114]],
#    u'Seattle Redhawks': [(0.0790085718035698, 0),
#     [26, 27, 32, 35, 48, 79, 81, 84, 87, 88, 93, 104, 105, 111, 113]],
#    u"Seattle Redhawks men's basketball": [(-1.6825164556503296, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 97, 104]],
#    u'Seattle Reign FC': [(-1.2128087282180786, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 84, 88, 93, 104, 127]],
#    u'Seattle Seahawks': [(-0.009528916329145432, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 89, 93, 104]],
#    u'Seattle Sounders FC': [(-1.0746538639068604, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Seattle Storm': [(-0.8664328455924988, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 80, 81, 84, 88, 93, 104]],
#    u'Seattle SuperSonics': [(0.07912574708461761, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 91, 93, 104]],
#    u'Seattle Thunderbirds': [(-0.09766120463609695, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 104, 125]],
#    u'Seattle University': [(0.36241021752357483, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 95, 104]],
#    u'Seattle metropolitan area': [(-0.28883621096611023, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 94, 104]],
#    u'Seattle\u2013Tacoma International Airport': [(-0.07604245096445084, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]]}},
#  u"The loss was [Boston] 's seventh in its last 29 games .": {'boosted': 10.0,
#   u'gold': u'Boston Red Sox',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.3912296295166016, 0), [15, 50]],
#    u'2010\u201311 Boston Celtics season': [(-1.853859543800354, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 127]],
#    u'2012\u201313 Boston Celtics season': [(-1.8288954496383667, 0),
#     [23, 26, 29, 30, 32, 35, 48, 49, 79, 81, 83, 84, 88, 93, 110]],
#    u'2014\u201315 Boston Bruins season': [0,
#     [23, 26, 29, 30, 32, 35, 48, 49, 79, 81, 83, 84, 88, 93, 108]],
#    u'Borough of Boston': [(-0.7959731817245483, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 83, 93, 96, 106]],
#    u'Boston': [(7.130127906799316, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Boston (UK Parliament constituency)': [(-1.7125394344329834, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 97, 104, 120]],
#    u'Boston (band)': [(0.19300219416618347, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Boston (horse)': [(-1.0002598762512207, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 81, 84, 85, 87, 93, 104, 109, 120]],
#    u'Boston (magazine)': [(-0.5053176283836365, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 81, 84, 85, 87, 92, 93, 104, 120]],
#    u'Boston Bruins': [(-0.09465480595827103, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 90, 93, 104]],
#    u'Boston Celtics': [(-0.38568809628486633, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 80, 81, 84, 93, 104]],
#    u'Boston Red Sox': [(4.388044834136963, 0),
#     [23, 24, 29, 30, 32, 33, 35, 49, 79, 81, 84, 93, 95, 104, 112]],
#    u'Boston Soccer Club': [(-1.6532167196273804, 0),
#     [26, 27, 32, 33, 35, 48, 79, 81, 84, 87, 93, 104, 107, 111, 113]],
#    u'Boston, Lincolnshire': [(-0.3860913813114166, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Logan International Airport': [(-0.9556512236595154, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 82, 83, 84, 98]],
#    u'Northeast Division GAA Board': [(-0.8513852953910828, 0),
#     [23, 26, 27, 29, 32, 33, 35, 48, 79, 81, 82, 83, 84, 87, 125]],
#    u'Roman Catholic Archdiocese of Boston': [(-0.7531603574752808, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 83, 88, 93, 96, 105]],
#    u'TD Garden': [(-0.7916728258132935, 0),
#     [23, 24, 26, 29, 30, 32, 35, 49, 79, 81, 82, 83, 84, 88, 140]],
#    u'U.S. Pro Tennis Championships': [(-0.2015567570924759, 0),
#     [23, 26, 29, 35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 94, 114]]}},
#  u'Trentino ) 4:00.958 ( world record ) beat Russia ( [Anton Chantyr] , Edouard Gritsoun , Nikolai Kouznetsov ) 4:06.534 .': {'boosted': 10.0,
#   u'gold': u'Anton Shantyr',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-4.034604549407959, 0), [15, 50]],
#    u'Anton Shantyr': [0,
#     [35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88, 111, 112, 113, 114]]}},
#  u'about his team winning seven of the 10 meetings from [Cleveland] this season .': {'boosted': 10.0,
#   u'gold': u'Cleveland Indians',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-2.397718906402588, 0), [15, 50]],
#    u'Cleveland': [(5.950582027435303, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Cleveland (UK Parliament constituency)': [(-2.060392379760742, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 109, 120]],
#    u'Cleveland Barons (1937\u201373)': [(-1.6468262672424316, 0),
#     [23, 26, 27, 29, 32, 35, 48, 81, 84, 85, 86, 87, 88, 93, 104, 140]],
#    u'Cleveland Brown': [(1.8697675466537476, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 84, 88, 92, 93, 104]],
#    u'Cleveland Browns': [(0.9701719880104065, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 93, 95, 104]],
#    u'Cleveland Cavaliers': [(-0.448691189289093, 0),
#     [23, 26, 29, 30, 32, 35, 48, 49, 79, 80, 81, 84, 88, 93, 104]],
#    u'Cleveland County, North Carolina': [(-0.6164687275886536, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 104, 108]],
#    u'Cleveland County, Oklahoma': [(0.3754391670227051, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 94, 104]],
#    u'Cleveland Hopkins International Airport': [(-0.10469327867031097, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Cleveland Indians': [(3.7442893981933594, 0),
#     [23, 24, 29, 30, 32, 33, 35, 49, 79, 81, 84, 93, 97, 104, 112]],
#    u'Cleveland Rockers': [(0.24404726922512054, 0),
#     [26, 27, 32, 33, 35, 48, 79, 81, 84, 87, 91, 93, 104, 111, 113]],
#    u'Cleveland, England': [(-0.14673733711242676, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 89, 93, 104]],
#    u'Cleveland, Georgia': [(-0.1104433462023735, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 104, 110]],
#    u'Cleveland, Mississippi': [(0.4718457758426666, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 84, 88, 93, 104, 125]],
#    u'Cleveland, Queensland': [(-0.1977098435163498, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 104, 105]],
#    u'Cleveland, Tennessee': [(0.8180873394012451, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Cleveland, Texas': [(1.0829312801361084, 0),
#     [23, 26, 29, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 114, 127]],
#    u'Grand Prix of Cleveland': [(-0.721664309501648, 0),
#     [23, 26, 27, 29, 32, 35, 48, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'Grover Cleveland': [(1.6004712581634521, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]]}},
#  u'ancestors for five generations , " Chen Chun-yeh told the [High Court] after sentencing on Friday , the Hong Kong Standard said': {'boosted': 10.0,
#   u'gold': u'High Court (Hong Kong)',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.3902572393417358, 0), [15, 50]],
#    u'Court': [(-1.2277073860168457, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Court (District Electoral Area)': [(-1.4162708520889282, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 89, 93, 104, 120]],
#    u'Court (royal)': [(-0.40738147497177124, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Court Street (Boston)': [(-1.1630672216415405, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 93, 104, 105]],
#    u'Court, Switzerland': [(-0.004412358161062002, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'High Court': [(1.5299885272979736, 0),
#     [35, 48, 49, 78, 79, 80, 87, 88, 111, 112, 113, 114]],
#    u'High Court (Hong Kong)': [(1.5764288902282715, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 98, 104, 120]],
#    u'High Court (Ireland)': [(0.0958152487874031, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 81, 84, 85, 89, 93, 104, 120]],
#    u'High Court of Australia': [(1.5390105247497559, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'High Court of Fiji': [(-0.15773022174835205, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 94, 104]],
#    u'High Court of Justice': [(0.7170904278755188, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 84, 93, 104]],
#    u'High Court of New Zealand': [(0.3400423228740692, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 95, 104]],
#    u'High Court of Singapore': [(0.6356516480445862, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'High Court of South Africa': [(0.9253714084625244, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 105]],
#    u'List of High Courts of India': [(-0.356954962015152, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 97]],
#    u'Margaret Court': [(-0.2091957926750183, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 83, 93, 96]],
#    u'Richard Court': [(-0.13612927496433258, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 98]],
#    u'Supreme Court of the United States': [(2.066972255706787, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 95]],
#    u'Yoann Court': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 97]]}},
#  u'hit his 38th homer and Edgar Martinez his 23rd for [Seattle] .': {'boosted': 10.0,
#   u'gold': u'Seattle Mariners',
#   u'training': False,
#   u'vals': {u'-NIL-': [(-1.0187000036239624, 0), [15, 50]],
#    u'1977\u201378 Seattle SuperSonics season': [(-1.433949589729309, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 84, 87, 88, 93, 108]],
#    u'2004\u201305 Seattle SuperSonics season': [(-1.3720338344573975, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 84, 87, 88, 93, 109]],
#    u'2007\u201308 Seattle SuperSonics season': [(-1.0799790620803833, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 83, 84, 88, 93, 110]],
#    u'2013 Seattle Seahawks season': [(-1.2756990194320679, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 84, 93, 107]],
#    u'King Street Station (Seattle)': [(0.9924982786178589, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 106]],
#    u'Roman Catholic Archdiocese of Seattle': [(0.3078156113624573, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 140]],
#    u'Seattle': [(8.658553123474121, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Seattle Mariners': [(4.621544361114502, 0),
#     [23, 29, 30, 35, 48, 49, 79, 81, 84, 88, 93, 98, 104, 112, 114]],
#    u'Seattle Redhawks': [(0.7044280171394348, 0),
#     [26, 27, 32, 35, 48, 79, 81, 84, 87, 88, 93, 104, 105, 111, 113]],
#    u"Seattle Redhawks men's basketball": [(-1.1175343990325928, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 97, 104]],
#    u'Seattle Reign FC': [(-0.4361554682254791, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 81, 84, 88, 93, 104, 127]],
#    u'Seattle Seahawks': [(0.6772258877754211, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 89, 93, 104]],
#    u'Seattle Sounders FC': [(-0.2970111668109894, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Seattle Storm': [(-0.3914627730846405, 0),
#     [23, 26, 27, 29, 30, 32, 35, 48, 79, 80, 81, 84, 88, 93, 104]],
#    u'Seattle SuperSonics': [(0.6040666699409485, 0),
#     [23, 24, 26, 29, 30, 32, 33, 35, 49, 79, 81, 84, 91, 93, 104]],
#    u'Seattle Thunderbirds': [(0.3134886622428894, 0),
#     [23, 26, 27, 29, 30, 32, 33, 35, 48, 79, 81, 84, 93, 104, 125]],
#    u'Seattle University': [(1.047912359237671, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 95, 104]],
#    u'Seattle metropolitan area': [(0.5622565150260925, 0),
#     [23, 24, 26, 27, 29, 30, 32, 35, 79, 81, 84, 88, 93, 94, 104]],
#    u'Seattle\u2013Tacoma International Airport': [(0.628532350063324, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]]}}}

# %%
findWrongItems(True)
# Out:
# {u' [Andrea Collinelli] ( Italy ) 4:17.551 beat Michael Sandstod': {'boosted': 10.0,
#   u'gold': u'Andrea Collinelli',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.728690147399902, 0), [15, 50]],
#    u'Andrea Collinelli': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79, 81, 83, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u' [Angel Miranda] retired one batter and Bob Wickman retired the next four': {'boosted': 10.0,
#   u'gold': u'\xc1ngel Miranda',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.398836612701416, 0), [15, 50]],
#    u'Clifford Miranda': [(-3.7557566165924072, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 94, 96]],
#    u'Electoral district of Miranda': [(-4.386631488800049, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 98]],
#    u'Herminio Miranda': [(-4.012001991271973, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 93, 96, 106]],
#    u'Miranda': [(-3.7171192169189453, 0), [35]],
#    u'Miranda (1948 film)': [(-4.854853630065918, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 105, 120]],
#    u'Miranda (Doctor Who)': [(-4.84076452255249, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 104, 120, 125]],
#    u'Miranda (TV series)': [(-5.05791711807251, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Miranda (The Tempest)': [(-3.5981292724609375, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 97, 104, 120]],
#    u'Miranda (footballer)': [(-3.3722140789031982, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 84, 85, 93, 104, 120]],
#    u'Miranda (moon)': [(-4.533685207366943, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 89, 93, 104, 120]],
#    u'Miranda (programming language)': [(-4.06301212310791, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 95, 104, 120]],
#    u'Miranda Camera Company': [(-4.084786891937256, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 92, 93, 104]],
#    u'Miranda, California': [(-4.22957181930542, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Miranda, New South Wales': [(-4.348026275634766, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Miranda, Venezuela': [(-2.9156835079193115, 0), [35]],
#    u'XXNILXX': [0, [35]],
#    u'\xc1ngel Miranda': [0,
#     [23,
#      26,
#      29,
#      32,
#      35,
#      48,
#      49,
#      77,
#      79,
#      81,
#      82,
#      83,
#      84,
#      87,
#      88,
#      93,
#      96,
#      393]]}},
#  u' [Malta] , with a population of 365,000 , has 195,000 registered': {'boosted': 10.0,
#   u'gold': u'Malta',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.159780502319336, 0), [15, 50]],
#    u'History of Malta under the Order of Saint John': [(-3.3283607959747314,
#      0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 98]],
#    u'Malta': [0, [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Malta Colony': [(-4.2526326179504395, 0), [35]],
#    u'Malta Football Association': [(-1.497997760772705, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 91, 93, 104]],
#    u'Malta International Airport': [(-1.7126061916351318, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Malta Island': [(-3.661635160446167, 0), [35]],
#    u'Malta national football team': [(-0.942730724811554, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Malta national rugby league team': [(-3.1578168869018555, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'Malta national under-21 football team': [(-2.3708317279815674, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 94, 104]],
#    u"Malta women's national football team": [(-2.8711912631988525, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Malta, Montana': [(-3.041916847229004, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Malta, New York': [(-3.468670129776001, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'Malta, Ohio': [(-3.566573143005371, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 140]],
#    u'Roman Catholic Archdiocese of Malta': [(-3.4912805557250977, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 105]],
#    u'Siege of Malta (World War II)': [(-2.9010229110717773, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 125]],
#    u'State of Malta': [(-1.8205713033676147, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'XXNILXX': [0, [35]]}},
#  u' [Rangers] 3 3 0 0 7 2 9': {'boosted': 10.0,
#   u'gold': u'Rangers F.C.',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-7.100012302398682, 0), [15, 50]],
#    u'2009 Texas Rangers season': [(-7.533167839050293, 0),
#     [17, 18, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 42]],
#    u'2010 Texas Rangers season': [(-6.611178874969482, 0),
#     [17, 18, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 43]],
#    u'2011 Texas Rangers season': [(-6.164677143096924, 0),
#     [17, 18, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 41]],
#    u'2012 Texas Rangers season': [(-6.520824432373047, 0),
#     [17, 18, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 47]],
#    u'Ford Ranger': [(-7.111491680145264, 0),
#     [23,
#      26,
#      35,
#      48,
#      49,
#      87,
#      88,
#      113,
#      114,
#      209,
#      210,
#      213,
#      216,
#      227,
#      233,
#      234,
#      237,
#      240,
#      251,
#      353,
#      356]],
#    u'Hong Kong Rangers FC': [(-6.25248384475708, 0),
#     [17, 18, 20, 21, 29, 32, 35, 38, 39, 48, 49, 87, 88, 111, 112]],
#    u'New York Rangers': [(-6.465797424316406, 0),
#     [17,
#      18,
#      21,
#      23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      39,
#      40,
#      209,
#      210,
#      212,
#      213,
#      216,
#      233,
#      234,
#      236,
#      237,
#      240,
#      330,
#      1840,
#      1841]],
#    u'Nile Ranger': [(-7.795760631561279, 0),
#     [17,
#      20,
#      21,
#      23,
#      26,
#      29,
#      30,
#      32,
#      33,
#      35,
#      39,
#      45,
#      48,
#      49,
#      209,
#      210,
#      213,
#      216,
#      217,
#      233,
#      234,
#      237,
#      240,
#      241,
#      353,
#      356,
#      423]],
#    u'Park ranger': [(-6.939032077789307, 0),
#     [17,
#      20,
#      21,
#      23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      39,
#      45,
#      209,
#      210,
#      213,
#      216,
#      221,
#      233,
#      234,
#      237,
#      240,
#      245,
#      353,
#      356,
#      1314]],
#    u'Ranger': [(-6.557285308837891, 0), [35]],
#    u'Ranger (Dungeons &amp; Dragons)': [0,
#     [17,
#      20,
#      23,
#      26,
#      29,
#      30,
#      32,
#      33,
#      35,
#      39,
#      45,
#      48,
#      49,
#      59,
#      60,
#      209,
#      210,
#      211,
#      212,
#      222,
#      229,
#      233,
#      234,
#      235,
#      236,
#      246,
#      253,
#      807,
#      808,
#      1674]],
#    u'Ranger School': [(-7.165370941162109, 0),
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      209,
#      210,
#      211,
#      212,
#      213,
#      225,
#      233,
#      234,
#      235,
#      236,
#      237,
#      249]],
#    u'Ranger program': [(-6.647560119628906, 0),
#     [17,
#      20,
#      21,
#      23,
#      26,
#      29,
#      32,
#      35,
#      39,
#      45,
#      48,
#      49,
#      87,
#      88,
#      209,
#      210,
#      211,
#      212,
#      213,
#      220,
#      233,
#      234,
#      235,
#      236,
#      237,
#      244,
#      1839]],
#    u'Ranger, Texas': [(-6.928257942199707, 0),
#     [23,
#      26,
#      29,
#      30,
#      32,
#      33,
#      35,
#      48,
#      49,
#      209,
#      210,
#      211,
#      212,
#      213,
#      214,
#      233,
#      234,
#      235,
#      236,
#      237,
#      238]],
#    u'Rangers F.C.': [0,
#     [16, 17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35]],
#    u'Rangers de Talca': [(-5.484805107116699, 0),
#     [17, 18, 19, 20, 21, 23, 26, 29, 32, 35, 37, 48, 49, 87, 88]],
#    u'Texas Rangers (baseball)': [(-5.000252723693848, 0),
#     [17, 18, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36, 39, 59, 60]],
#    u'United States Army Rangers': [(-6.314001560211182, 0),
#     [17,
#      18,
#      21,
#      23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      39,
#      46,
#      208,
#      209,
#      210,
#      212,
#      213,
#      216,
#      232,
#      233,
#      234,
#      236,
#      237,
#      240,
#      330]],
#    u'XXNILXX': [0, [35]]}},
#  u' [Sutjeska] 3 Sloboda 2': {'boosted': 10.0,
#   u'gold': u'FK Sutjeska Nik\u0161i\u0107',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.057812452316284, 0), [15, 50]],
#    u'Battle of the Sutjeska': [(-1.9819568395614624, 0), [35]],
#    u'FK Sutjeska Fo\u010da': [(5.6499762535095215, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 83, 84, 93]],
#    u'FK Sutjeska Nik\u0161i\u0107': [(5.2076826095581055, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 83, 84, 93]],
#    u'KK Sutjeska': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 106]],
#    u'KK Sutjeska Nik\u0161i\u0107': [(-0.31699898838996887, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 89, 93]],
#    u'Nik\u0161i\u0107': [(-1.7419679164886475, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 108]],
#    u'OK Sutjeska': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 92, 93, 96]],
#    u'RK Sutjeska': [(0.901587188243866, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 91, 93, 96]],
#    u'Sutjeska': [(-0.7346472144126892, 0), [35]],
#    u'Sutjeska (Zemun)': [(0.10501062124967575, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 97, 104, 120]],
#    u'Sutjeska (film)': [(-2.1799428462982178, 0), [35]],
#    u'Sutjeska (river)': [(-1.6930967569351196, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 90, 93, 104, 120]],
#    u'Sutjeska (village)': [(-1.5212738513946533, 0), [35]],
#    u'Sutjeska National Park': [(-0.4176532030105591, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'XXNILXX': [0, [35]]}},
#  u', members of a mostly Kurdish militia which fights the [PKK] , hit the mine in the province of Diyarbakir .': {'boosted': 10.0,
#   u'gold': u"Kurdistan Workers' Party",
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.466752052307129, 0), [15, 50]],
#    u'Kota Kinabalu Polytechnic': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 82, 83, 84]],
#    u"Kurdistan Workers' Party": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Politeknik Kota Kinabalu': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 91]],
#    u'XXNILXX': [0, [35]]}},
#  u'1. [Shayne King] ( New Zealand ) KTM': {'boosted': 10.0,
#   u'gold': u'Shayne King',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.261210560798645, 0), [15, 50]],
#    u'Billie Jean King': [(-0.41850581765174866, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Electoral district of King': [(-1.5130547285079956, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 140]],
#    u'George King (botanist)': [(-1.0871504545211792, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 89, 93]],
#    u'King': [(-0.3725115954875946, 0), [35]],
#    u'King County, Texas': [(-0.9895920753479004, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 127]],
#    u'King County, Washington': [(-0.8428316712379456, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'King Records (Japan)': [(-0.33435744047164917, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 92, 93, 104]],
#    u'King Records (United States)': [(-0.6760721802711487, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 91, 93, 104]],
#    u'King of the Romanians': [(-0.7083045840263367, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'King, Ontario': [(-0.9600748419761658, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Marlon King': [(-0.663556694984436, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Martyn King': [(-1.2149075269699097, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 95, 96]],
#    u'Monarch': [(-0.842298686504364, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Shayne King': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'William Lyon Mackenzie King': [(-0.28479477763175964, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'1. [Shayne King] 323 points': {'boosted': 10.0,
#   u'gold': u'Shayne King',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.1586642265319824, 0), [15, 50]],
#    u'Billie Jean King': [(-1.381221890449524, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Electoral district of King': [(-2.48582124710083, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 140]],
#    u'George King (botanist)': [(-3.1524078845977783, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 89, 93]],
#    u'King': [(-2.0289509296417236, 0), [35]],
#    u'King County, Texas': [(-2.854840040206909, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 127]],
#    u'King County, Washington': [(-2.5360922813415527, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'King Records (Japan)': [(-2.402442455291748, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 92, 93, 104]],
#    u'King Records (United States)': [(-2.3116602897644043, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 91, 93, 104]],
#    u'King of the Romanians': [(-1.2138917446136475, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'King, Ontario': [(-3.1796200275421143, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Marlon King': [(-1.9374141693115234, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Martyn King': [(-2.1191229820251465, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 95, 96]],
#    u'Monarch': [(-2.0507354736328125, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Shayne King': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'William Lyon Mackenzie King': [(-1.6893805265426636, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'11. [Jose Escuredo] ( Spain ) 1:05.731': {'boosted': 10.0,
#   u'gold': u'Jos\xe9 Antonio Escuredo',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.533403158187866, 0), [15, 50]],
#    u'Escuredo': [(-2.820537805557251, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Jos\xe9 Antonio Escuredo': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88]],
#    u'XXNILXX': [0, [35]]}},
#  u'2. Scott McGrory - [Stephen Pate] ( Australia ) 25': {'boosted': 10.0,
#   u'gold': u'Stephen Pate',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.438467502593994, 0), [15, 50]],
#    u'David Pate': [(-1.7232991456985474, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 80, 81, 83, 93, 96]],
#    u'Janez Pate': [0,
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 90, 93, 96]],
#    u'Jerry Pate': [(-1.9845952987670898, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Michael Pate': [(-3.4992823600769043, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 105]],
#    u'Pate Mustaj\xe4rvi': [(-3.371035099029541, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Pate sultanate': [(-3.0001168251037598, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 92, 93, 104]],
#    u'Pate, Alabama': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Pate, Cambodia': [0,
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 84, 87, 88, 91, 93, 104]],
#    u'Paul Pate': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'P\xe2t\xe9': [(-2.229935884475708, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 109]],
#    u'Randolph M. Pate': [(-3.125656843185425, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Rulers of Pate': [(-3.366208553314209, 0), [35]],
#    u'Stephen Pate': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Stephen Pate (rugby)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 84, 85, 93, 104, 120]],
#    u'Steve Pate': [(0.2981438934803009, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 91, 93, 96, 98]],
#    u'Tom Pate Memorial Award': [(-3.5342519283294678, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 84, 87, 88, 93, 95]],
#    u'XXNILXX': [0, [35]]}},
#  u'2. [Peter Johansson] ( Sweden ) Husqvarna': {'boosted': 10.0,
#   u'gold': u'Peter Johansson (motorcyclist)',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.4707868099212646, 0), [15, 50]],
#    u'Andreas Johansson (footballer, born 1978)': [(-3.4118738174438477, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 91, 93]],
#    u'Georg Johansson (ice hockey)': [0,
#     [23, 26, 29, 32, 35, 48, 49, 81, 83, 84, 85, 86, 87, 88, 93, 94]],
#    u'Johansson': [(-2.7280492782592773, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Jonatan Johansson (footballer)': [(-2.66951847076416, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 83, 84, 85, 86, 93]],
#    u'Nils-Eric Johansson': [(-2.2982070446014404, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Peter Johansson': [0, [35]],
#    u'Peter Johansson (artist)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 90, 93, 104, 120]],
#    u'Peter Johansson (athlete)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 95, 104, 120]],
#    u'Peter Johansson (figure skater)': [(-0.8462916612625122, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 81, 84, 85, 93, 104, 120]],
#    u'Peter Johansson (footballer)': [0,
#     [23, 24, 26, 27, 29, 32, 35, 81, 84, 85, 87, 88, 93, 104, 105, 120]],
#    u'Peter Johansson (ice hockey)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Peter Johansson (motorcyclist)': [0,
#     [35, 48, 49, 80, 81, 84, 85, 87, 88, 93, 104, 111, 112, 113, 114, 120]],
#    u'Peter Johansson (musician)': [0,
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 89, 93, 104, 120]],
#    u'Peter Johansson (trombon)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 98, 104, 120]],
#    u'Stefan Johansson': [(-0.08204448968172073, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Thomas Johansson': [(-0.724071204662323, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 98]],
#    u'Torsten Johansson': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 90, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'2. [Shayne King] 28': {'boosted': 10.0,
#   u'gold': u'Shayne King',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.0528244972229004, 0), [15, 50]],
#    u'Billie Jean King': [(-1.3834706544876099, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Electoral district of King': [(-2.2554802894592285, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 140]],
#    u'George King (botanist)': [(-3.093318462371826, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 89, 93]],
#    u'King': [(-2.0822694301605225, 0), [35]],
#    u'King County, Texas': [(-2.7844207286834717, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 127]],
#    u'King County, Washington': [(-2.464937210083008, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'King Records (Japan)': [(-2.4102985858917236, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 92, 93, 104]],
#    u'King Records (United States)': [(-2.290618658065796, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 91, 93, 104]],
#    u'King of the Romanians': [(-1.0643965005874634, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'King, Ontario': [(-3.093538761138916, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Marlon King': [(-1.983643651008606, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Martyn King': [(-2.028132438659668, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 95, 96]],
#    u'Monarch': [(-1.894043207168579, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Shayne King': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'William Lyon Mackenzie King': [(-1.6299128532409668, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'2. [Soren Lausberg] ( Germany ) 1:02.795': {'boosted': 10.0,
#   u'gold': u'S\xf6ren Lausberg',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.528048992156982, 0), [15, 50]],
#    u'Lausberg': [(-3.4129157066345215, 0), [35]],
#    u'S\xf6ren Lausberg': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88]],
#    u'XXNILXX': [0, [35]]}},
#  u'3. [Frederic Magne] ( France )': {'boosted': 10.0,
#   u'gold': u'Fr\xe9d\xe9ric Magn\xe9',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.8060470819473267, 0), [15, 50]],
#    u'Antonin Magne': [(1.5679889917373657, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 89, 93, 96]],
#    u'Fr\xe9d\xe9ric Magn\xe9': [0,
#     [35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88, 111, 112, 113, 114]],
#    u'Magne': [(-1.3584535121917725, 0), [35]],
#    u'Magne Furuholmen': [(-0.8096165060997009, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'M\xf3\xf0i and Magne': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'Olivier Magne': [(-0.5772350430488586, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 83, 87, 88, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'3/4 - Marlene Thomsen / [Lisbet Stuer-Lauridsen] ( Denmark ) beat': {'boosted': 10.0,
#   u'gold': u'Lisbeth Stuer-Lauridsen',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.6573052406311035, 0), [15, 50]],
#    u'Lisbeth Stuer-Lauridsen': [0,
#     [16, 17, 20, 21, 35, 39, 45, 48, 49, 87, 88, 111, 112, 113, 114]],
#    u'Stuer-Lauridsen': [(-4.173647403717041, 0), [35]],
#    u'Thomas Stuer-Lauridsen': [(-3.526332378387451, 0),
#     [16, 17, 18, 21, 23, 26, 29, 32, 35, 39, 48, 49, 87, 88, 330]],
#    u'XXNILXX': [0, [35]]}},
#  u'4. [Jacky Martens] ( Belgium ) Husqvarna': {'boosted': 10.0,
#   u'gold': u'Jacky Martens',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.1971042156219482, 0), [15, 50]],
#    u'American marten': [(-2.888488531112671, 0),
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      209,
#      210,
#      213,
#      216,
#      220,
#      233,
#      234,
#      237,
#      240,
#      244,
#      353,
#      356]],
#    u'Eduard von Martens': [(-3.401092529296875, 0),
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 38, 39, 330]],
#    u'Greg Marten': [0,
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      209,
#      210,
#      213,
#      216,
#      219,
#      233,
#      234,
#      237,
#      240,
#      243,
#      353,
#      356]],
#    u'Jacky Martens': [0, [16, 21, 23, 26, 29, 32, 35, 48, 49, 87, 88, 328]],
#    u'Lieke Martens': [(-2.109259605407715, 0),
#     [17, 18, 21, 23, 26, 29, 32, 35, 37, 39, 48, 49, 87, 88, 330]],
#    u'Luis Marten': [0,
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      209,
#      210,
#      213,
#      216,
#      227,
#      233,
#      234,
#      237,
#      240,
#      251,
#      353,
#      356]],
#    u'Maarten Martens': [(-2.5845205783843994, 0),
#     [17, 18, 21, 23, 26, 29, 30, 32, 33, 35, 36, 39, 48, 49, 330]],
#    u'Marten': [(-3.1078641414642334, 0),
#     [16,
#      17,
#      20,
#      21,
#      23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      39,
#      45,
#      208,
#      213,
#      232,
#      237,
#      582,
#      585]],
#    u'Marten, Bulgaria': [0,
#     [23,
#      26,
#      29,
#      32,
#      35,
#      48,
#      49,
#      87,
#      88,
#      209,
#      210,
#      211,
#      212,
#      213,
#      214,
#      233,
#      234,
#      235,
#      236,
#      237,
#      238]],
#    u'Marten, Germany': [0,
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      209,
#      210,
#      211,
#      212,
#      213,
#      229,
#      233,
#      234,
#      235,
#      236,
#      237,
#      253]],
#    u'Marten, Wiltshire': [(-3.2411909103393555, 0), [35]],
#    u'Martens (disambiguation)': [0, [35]],
#    u'Maurice Martens': [0,
#     [17, 18, 21, 23, 26, 29, 32, 35, 39, 41, 48, 49, 87, 88, 330]],
#    u'Rick Martens': [0,
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 43, 330]],
#    u'Ulrich Marten': [0,
#     [23,
#      26,
#      29,
#      32,
#      35,
#      48,
#      49,
#      87,
#      88,
#      209,
#      210,
#      213,
#      216,
#      221,
#      233,
#      234,
#      237,
#      240,
#      245,
#      353,
#      356]],
#    u'Wilfried Martens': [(-0.8090171813964844, 0),
#     [17, 18, 21, 23, 26, 29, 30, 32, 33, 35, 39, 40, 48, 49, 330]],
#    u'XXNILXX': [0, [35]]}},
#  u'4. [Kurt Betschart] - Bruno Risi ( Switzerland ) 22': {'boosted': 10.0,
#   u'gold': u'Kurt Betschart',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.8460323810577393, 0), [15, 50]],
#    u'Betschart': [(-2.9257609844207764, 0), [35]],
#    u'Kurt Betschart': [0,
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]],
#    u'Sandra Betschart': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 83, 87, 88, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'4. [Pavel Buran] ( Czech Republic )': {'boosted': 10.0,
#   u'gold': u'Pavel Buran',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.4644919633865356, 0), [15, 50]],
#    u'Borandukht': [(-0.5870003700256348, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 98]],
#    u'Buraan': [(-0.8962516188621521, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 97]],
#    u'Buran': [(-1.376457691192627, 0), [35]],
#    u'Buran (icebreaker)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 109, 120]],
#    u'Buran (snowmobile)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 108, 120]],
#    u'Buran (station)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 94, 104, 120]],
#    u'Buran (video game)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 95, 104, 120]],
#    u'Buran program': [(-1.8791450262069702, 0), [35]],
#    u'Buran, Albania': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 107]],
#    u'Buran, Ardabil': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Buran, Mazandaran': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Chaiyawat Buran': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Pavel Buran': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'RSS-40 Buran': [(-1.1341817378997803, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 91, 93, 96]],
#    u'Shuttle Buran': [(-1.7196978330612183, 0), [35]],
#    u'XXNILXX': [0, [35]]}},
#  u'5. [Lietti] 8': {'boosted': 10.0,
#   u'gold': u'Marco Lietti',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.523893356323242, 0), [15, 50]],
#    u'Marco Lietti': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 83, 87, 88, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'5. [Marco Lietti] ( Italy ) MG-Technogym 1 second behind': {'boosted': 10.0,
#   u'gold': u'Marco Lietti',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.9185047149658203, 0), [15, 50]],
#    u'Marco Lietti': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 81, 83, 87, 88, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'6. [Endrio Leoni] ( Italy ) Aki': {'boosted': 10.0,
#   u'gold': u'Endrio Leoni',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.4411537647247314, 0), [15, 50]],
#    u'Berg, Upper Bavaria': [(-1.810566782951355, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 106]],
#    u'Endrio Leoni': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Frank Leoni': [(-1.4376440048217773, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Giacomo Leoni': [(-2.4343721866607666, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Giorgio Leoni': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 93, 96, 125]],
#    u'Johnny Leoni': [0,
#     [23, 24, 26, 27, 29, 32, 35, 79, 80, 81, 83, 87, 88, 93, 96]],
#    u'Lamberto Leoni': [(-0.6793598532676697, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 108]],
#    u'Leone Leoni': [(-1.3166759014129639, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 94, 96]],
#    u'Leoni': [(-2.2579588890075684, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Leoni (Bavaria)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 95, 104, 120]],
#    u'Leoni (songwriter)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 97, 104, 120]],
#    u'Leoni AG': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 98, 104]],
#    u'Leoni Township, Michigan': [(-2.5604000091552734, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 91, 93, 104]],
#    u'Ottavio Leoni': [(-2.377441167831421, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 92, 93, 96]],
#    u'Ra\xfal Leoni': [(-1.2009474039077759, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 105]],
#    u'XXNILXX': [0, [35]]}},
#  u'At [Colchester] : Gloucestershire 280 and 27-4 .': {'boosted': 10.0,
#   u'gold': u'Castle Park Cricket Ground',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.050601005554199, 0), [15, 50]],
#    u'Camulodunum': [(0.6567842364311218, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 125]],
#    u'Castle Park Cricket Ground': [(3.699625253677368, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 107]],
#    u'Colchester': [(4.010336875915527, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Colchester (UK Parliament constituency)': [(-1.3339924812316895, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 84, 85, 93, 104, 120]],
#    u'Colchester (borough)': [(-1.4511851072311401, 0), [35]],
#    u'Colchester (electoral district)': [(-1.7674766778945923, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 97, 104, 120]],
#    u'Colchester (provincial electoral district)': [(-1.9258655309677124, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 93, 94, 104, 120]],
#    u'Colchester County, Nova Scotia': [(-1.3718860149383545, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Colchester United F.C.': [(1.1863998174667358, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Colchester railway station': [(-1.9349552392959595, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Colchester, Connecticut': [(-1.0865017175674438, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Colchester, Illinois': [(-1.2597060203552246, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Colchester, New York': [(-0.8342663645744324, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Colchester, Ontario': [(-1.6550856828689575, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 109]],
#    u'Colchester, Vermont': [(-0.6421334743499756, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Colchester, Virginia': [(-0.7258394956588745, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'XXNILXX': [0, [35]]}},
#  u"Chinese officials would soon open dialogue with Hong Kong 's [Democratic Party] and the newly-established democracy lobby , Frontier , in order": {'boosted': 10.0,
#   u'gold': u'Democratic Party (Hong Kong)',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.5091066360473633, 0), [15, 50]],
#    u'Communist Party of China': [(1.9006673097610474, 0),
#     [17, 18, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 41]],
#    u'Communist Party of the Soviet Union': [(-0.8403733968734741, 0),
#     [17, 18, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 40]],
#    u'Democratic Party': [(1.2869911193847656, 0),
#     [21, 23, 26, 29, 32, 35, 42, 48, 49, 87, 88, 328]],
#    u'Democratic Party (Hong Kong)': [(5.252384185791016, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 38, 59, 329]],
#    u'Democratic Party (Italy)': [(1.5559842586517334, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36, 59, 329]],
#    u'Democratic Party (Luxembourg)': [(2.7124717235565186, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 40, 59, 329]],
#    u'Democratic Party (Mongolia)': [(1.3819056749343872, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 43, 59, 329]],
#    u'Democratic Party (Serbia)': [(2.9327502250671387, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 37, 59, 329]],
#    u'Democratic Party (United States)': [(5.281839370727539, 0),
#     [16, 17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 59, 329]],
#    u'Democratic Party of Albania': [(3.00547194480896, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 41]],
#    u'Party': [0, [16, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 328]],
#    u'Party (1984 film)': [(-1.1008316278457642, 0),
#     [17, 18, 19, 20, 23, 26, 29, 30, 32, 33, 35, 42, 48, 49, 59, 329]],
#    u'Party (Beyonc\xe9 song)': [(-1.0822076797485352, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 30, 32, 33, 35, 37, 59, 329]],
#    u'Party (Iggy Pop album)': [(-0.7130774259567261, 0),
#     [17, 18, 19, 20, 23, 24, 26, 27, 29, 32, 35, 47, 59, 87, 88, 329]],
#    u'Party game': [(-1.8821645975112915, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36]],
#    u'Political party': [(-1.6801344156265259, 0),
#     [17, 18, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 38, 39, 330]],
#    u'XXNILXX': [0, [35]]}},
#  u'Five people arrested in Romania after drugs container found in [Malta] .': {'boosted': 10.0,
#   u'gold': u'Malta',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.837714195251465, 0), [15, 50]],
#    u'History of Malta under the Order of Saint John': [(-4.165435791015625, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 98]],
#    u'Malta': [0, [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Malta Colony': [(-4.947746276855469, 0), [35]],
#    u'Malta Football Association': [(-1.4827748537063599, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 91, 93, 104]],
#    u'Malta International Airport': [(-2.9881787300109863, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Malta Island': [(-4.228304862976074, 0), [35]],
#    u'Malta national football team': [(-0.8583107590675354, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Malta national rugby league team': [(-3.701321601867676, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'Malta national under-21 football team': [(-2.5435025691986084, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 94, 104]],
#    u"Malta women's national football team": [(-2.8015780448913574, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Malta, Montana': [(-4.168032169342041, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Malta, New York': [(-4.4021220207214355, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'Malta, Ohio': [(-4.443803787231445, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 140]],
#    u'Roman Catholic Archdiocese of Malta': [(-3.890597343444824, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 105]],
#    u'Siege of Malta (World War II)': [(-4.156297206878662, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 125]],
#    u'State of Malta': [(-2.765298366546631, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'XXNILXX': [0, [35]]}},
#  u'He reiterates promise that a future [Labour] government will remove VAT .': {'boosted': 10.0,
#   u'gold': u'Labour Party (Malta)',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.8354802131652832, 0), [15, 50]],
#    u'Australian Labor Party': [(5.594447612762451, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 97]],
#    u'Israeli Labor Party': [(5.398248672485352, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 94]],
#    u'Labour': [(4.110196113586426, 0), [35]],
#    u'Labour (constituency)': [(0.7052831053733826, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 105, 120]],
#    u'Labour Party (Ireland)': [(2.146064519882202, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 93, 95, 104]],
#    u'Labour Party (Malta)': [(5.987509727478027, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 93, 104, 106]],
#    u'Labour candidates and parties in Canada': [(-0.625224232673645, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Labour party (UK)': [(1.7644768953323364, 0), [35]],
#    u'New Zealand Labour Party': [(6.4429931640625, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 83, 84, 93]],
#    u'Norwegian Labour Party': [(1.0952324867248535, 0), [35]],
#    u'Scottish Labour Party': [(3.3302173614501953, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 89, 93]],
#    u'Welsh Labour': [(3.3048129081726074, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 98]],
#    u'XXNILXX': [0, [35]]}},
#  u"Kankkunen was runner-up in his Toyota as Finland 's [Jarmo Kytolehto] produced a remarkable drive to finish third in his Ford": {'boosted': 10.0,
#   u'gold': u'Jarmo Kyt\xf6lehto',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.474720001220703, 0), [15, 50]],
#    u'Jarmo Kyt\xf6lehto': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 79, 81, 82, 83, 84, 87, 88]],
#    u'Kytolehto': [0, [35]],
#    u'XXNILXX': [0, [35]]}},
#  u"More than 20,000 people have died in the [PKK] 's 12-year-old fight for independence or autonomy in southeastern Turkey": {'boosted': 10.0,
#   u'gold': u"Kurdistan Workers' Party",
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.400518894195557, 0), [15, 50]],
#    u'Kota Kinabalu Polytechnic': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 82, 83, 84]],
#    u"Kurdistan Workers' Party": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Politeknik Kota Kinabalu': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 91]],
#    u'XXNILXX': [0, [35]]}},
#  u'PRESS DIGEST - [Malta] - Aug 26 .': {'boosted': 10.0,
#   u'gold': u'Malta',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.600730895996094, 0), [15, 50]],
#    u'History of Malta under the Order of Saint John': [(-4.863370418548584, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 98]],
#    u'Malta': [0, [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Malta Colony': [(-5.564645290374756, 0), [35]],
#    u'Malta Football Association': [(-2.3471148014068604, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 91, 93, 104]],
#    u'Malta International Airport': [(-3.5764379501342773, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Malta Island': [(-4.737173557281494, 0), [35]],
#    u'Malta national football team': [(-1.1582057476043701, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Malta national rugby league team': [(-4.342153072357178, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 92, 93, 104]],
#    u'Malta national under-21 football team': [(-3.3392934799194336, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 94, 104]],
#    u"Malta women's national football team": [(-3.8167524337768555, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Malta, Montana': [(-5.107688903808594, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Malta, New York': [(-5.318558692932129, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'Malta, Ohio': [(-5.149276256561279, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 140]],
#    u'Roman Catholic Archdiocese of Malta': [(-4.576584815979004, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 105]],
#    u'Siege of Malta (World War II)': [(-5.035080909729004, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 125]],
#    u'State of Malta': [(-3.3647310733795166, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 83, 87, 88, 93, 96, 107]],
#    u'XXNILXX': [0, [35]]}},
#  u"Santos suffered more from their loss as Narciso 's replacement [Jean] gave away a penalty from which Sao Paulo scored the": {'boosted': 10.0,
#   u'gold': u'Jean Carlo Witte',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-7.5003461837768555, 0), [15, 50]],
#    u'Earl Jean': [(-4.897425174713135, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 106]],
#    u'Jean': [(-4.033042907714844, 0), [35]],
#    u'Jean (female given name)': [(-5.9698381423950195, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 104, 120, 125]],
#    u'Jean (footballer)': [0,
#     [23, 26, 29, 32, 35, 48, 49, 80, 81, 84, 85, 87, 88, 93, 104, 120]],
#    u'Jean (male given name)': [(-5.69688081741333, 0),
#     [23, 24, 26, 27, 29, 32, 35, 81, 84, 85, 87, 88, 92, 93, 104, 120]],
#    u'Jean (song)': [(-5.279266834259033, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 89, 93, 104, 120]],
#    u'Jean Carlo Witte': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 98, 104]],
#    u'Jean Carlos da Silva Ferreira': [0,
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 84, 87, 88, 93, 94, 104]],
#    u'Jean Grey': [(-5.357974529266357, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 107]],
#    u'Jean Narde': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 91, 93, 104]],
#    u'Jean Sagal': [(-4.645436763763428, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Jean Slater': [(-6.073642730712891, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'Jean of Luxembourg': [(-5.533387660980225, 0), [35]],
#    u'Jean, Nevada': [(-3.7339255809783936, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 90, 93, 104]],
#    u'Micha\xeblle Jean': [(-5.7748308181762695, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 95, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u"Santos suffered more from their loss as [Narciso] 's replacement Jean gave away a penalty from which Sao": {'boosted': 10.0,
#   u'gold': u'Narciso dos Santos',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-6.131748676300049, 0), [15, 50]],
#    u"Amor d'un'ombra e gelosia d'un'aura": [0,
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 89]],
#    u'Marcio Jose Narciso': [0, [35]],
#    u'Narciso': [(-2.4286234378814697, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Narciso Gener Gonzales': [(-4.386768817901611, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 95, 104]],
#    u'Narciso Macamo': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Narciso Malatesta': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 97, 104]],
#    u'Narciso dos Santos': [0,
#     [35, 48, 49, 79, 80, 81, 84, 87, 88, 93, 104, 111, 112, 113, 114]],
#    u'Narcissus (mythology)': [(-3.539241313934326, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 82, 83, 84, 85, 86, 90]],
#    u'XXNILXX': [0, [35]]}},
#  u"Sao Paulo midfielder Andre and Santos defender [Narciso] were both substituted during their teams ' game , taken": {'boosted': 10.0,
#   u'gold': u'Narciso dos Santos',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.405219554901123, 0), [15, 50]],
#    u"Amor d'un'ombra e gelosia d'un'aura": [0,
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 89]],
#    u'Marcio Jose Narciso': [0, [35]],
#    u'Narciso': [(-0.7938612103462219, 0),
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Narciso Gener Gonzales': [(-2.728081464767456, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 95, 104]],
#    u'Narciso Macamo': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Narciso Malatesta': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 97, 104]],
#    u'Narciso dos Santos': [0,
#     [35, 48, 49, 79, 80, 81, 84, 87, 88, 93, 104, 111, 112, 113, 114]],
#    u'Narcissus (mythology)': [(-1.9782633781433105, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 82, 83, 84, 85, 86, 90]],
#    u'XXNILXX': [0, [35]]}},
#  u"Slough 's chairman Sir [Nigel Mobbs] added to the bullish mood in the sector , saying": {'boosted': 10.0,
#   u'gold': u'Nigel Mobbs',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.229085445404053, 0), [15, 50]],
#    u'Edgar Mobbs': [(-4.516368389129639, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 80, 81, 83, 93, 96]],
#    u'Mobbs': [(-4.311776638031006, 0),
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]],
#    u'Nigel Mobbs': [0, [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 87, 88]],
#    u'Rosemary Mobbs': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'West Coast hip hop': [(-5.36798095703125, 0),
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      289,
#      291,
#      293,
#      295,
#      299,
#      304,
#      305,
#      307,
#      309,
#      311,
#      315,
#      320]],
#    u'William Mobbs': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u"Swede Kenneth Eriksson kept [Subaru] in the hunt for the manufacturers ' title with fifth": {'boosted': 10.0,
#   u'gold': u'Subaru World Rally Team',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.4141693115234375, 0), [15, 50]],
#    u'Fuji Heavy Industries': [(3.892676830291748, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 92]],
#    u'Pleiades': [(2.1848063468933105, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 95]],
#    u'Subaru': [(6.407581329345703, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Subaru (.hack)': [(0.032357778400182724, 0), [35]],
#    u'Subaru (Byakko Seishi)': [(-1.4124150276184082, 0), [35]],
#    u'Subaru (literary magazine)': [0,
#     [23, 24, 26, 27, 29, 32, 35, 81, 84, 85, 87, 88, 93, 104, 107, 120]],
#    u'Subaru (manga)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 90, 93, 104, 120]],
#    u'Subaru EA engine': [(2.3271281719207764, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 105]],
#    u'Subaru Impreza': [(2.7652130126953125, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 106]],
#    u'Subaru Rally Team USA': [(3.1504921913146973, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 115]],
#    u'Subaru Rex': [(1.3794879913330078, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 140]],
#    u'Subaru Sumeragi': [(1.8792004585266113, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'Subaru Telescope': [(0.8046597242355347, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'Subaru World Rally Team': [(6.103927135467529, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 84, 93, 104]],
#    u'Subaru of America': [(1.0603320598602295, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'XXNILXX': [0, [35]]}},
#  u"The [Salang] highway , Afghanistan 's main route to Central Asia ,": {'boosted': 10.0,
#   u'gold': u'Salang, Afghanistan',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.7619433403015137, 0), [15, 50]],
#    u'Kotal-e Salang': [(-3.371236801147461, 0), [35]],
#    u'Phuket Province': [(-0.5650265216827393, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 94]],
#    u'Salang': [(-1.024336338043213, 0), [35]],
#    u'Salang (ethnic group)': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 95, 104, 120]],
#    u'Salang District': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 89, 93, 104]],
#    u'Salang Mountains': [0,
# ...
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 108]],
#    u'Kurdish people': [(5.531167507171631, 0), [35]],
#    u'Kurdistan': [(6.014509677886963, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 91]],
#    u'Kurds in Iraq': [(1.0504329204559326, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 95]],
#    u'Kurds in Syria': [(0.30340859293937683, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 92]],
#    u'Kurds in Turkey': [(1.2834408283233643, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 90]],
#    u'Turkish Kurdistan': [(3.1847686767578125, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 94]],
#    u'XXNILXX': [0, [35]]}},
#  u'Willem II Tilburg 0 Fortuna Sittard 1 ( [Hamming] 65th ) .': {'boosted': 10.0,
#   u'gold': u'Ronald Hamming',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.2960050106048584, 0), [15, 50]],
#    u'Hamming': [(-1.6138267517089844, 0), [35]],
#    u'Hamming code': [(-0.985710859298706, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Hamming metric': [(-2.298537492752075, 0), [35]],
#    u'Richard Hamming': [(-0.48046499490737915, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 83, 93, 96]],
#    u'Ronald Hamming': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 91, 93, 96]],
#    u'XXNILXX': [0, [35]]}},
#  u'Zimbabwe in the first day-night limited overs match of the [Singer World Series] tournament on Monday .': {'boosted': 10.0,
#   u'gold': u'Singer World Series',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.9008100032806396, 0), [15, 50]],
#    u'2004 World Series': [(-4.588296890258789, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'2008 World Series': [(-4.661515235900879, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'2009 World Series': [(-4.322668075561523, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 98]],
#    u'2010 World Series': [(-5.380568504333496, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'ATP International Series': [(-4.623720645904541, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 82, 83, 84]],
#    u'Remi Sery': [0,
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      291,
#      293,
#      294,
#      295,
#      296,
#      302,
#      307,
#      309,
#      310,
#      311,
#      312,
#      318]],
#    u'Series': [(-4.959782600402832, 0), [35]],
#    u'Series (mathematics)': [(-4.297664165496826, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Series (stratigraphy)': [(-4.429239273071289, 0),
#     [23, 26, 29, 32, 35, 48, 49, 80, 81, 84, 85, 87, 88, 93, 104, 120]],
#    u'Sery': [(-4.441689968109131, 0),
#     [23, 26, 29, 32, 35, 48, 49, 87, 88, 289, 290, 291, 305, 306, 307]],
#    u'Sery, Ardennes': [0,
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      291,
#      292,
#      293,
#      294,
#      298,
#      299,
#      307,
#      308,
#      309,
#      310,
#      314,
#      315]],
#    u'Sery, Yonne': [0,
#     [23,
#      26,
#      29,
#      32,
#      35,
#      48,
#      49,
#      87,
#      88,
#      291,
#      293,
#      294,
#      298,
#      299,
#      303,
#      307,
#      309,
#      310,
#      314,
#      315,
#      319]],
#    u'Singer World Series': [0, [35]],
#    u'S\xe9ry-l\xe8s-M\xe9zi\xe8res': [(-4.52337646484375, 0),
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      291,
#      293,
#      295,
#      297,
#      299,
#      304,
#      307,
#      309,
#      311,
#      313,
#      315,
#      320]],
#    u'Television series': [(-4.305160999298096, 0), [35]],
#    u'World Series': [(-4.09101676940918, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79, 81, 83, 93, 96, 105]],
#    u'XXNILXX': [0, [35]]}},
#  u'a taxi carrying the guards , members of a mostly [Kurdish] militia which fights the PKK , hit the mine in': {'boosted': 10.0,
#   u'gold': u'Kurdish nationalism',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.2658298015594482, 0), [15, 50]],
#    u'Iraqi Kurdistan': [(4.2437567710876465, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 41, 45]],
#    u'Kurdish': [(2.885643243789673, 0), [35]],
#    u'Kurdish People': [(3.209657907485962, 0), [35]],
#    u'Kurdish alphabets': [(0.1953156590461731, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 43]],
#    u'Kurdish cuisine': [(-0.32961082458496094, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 58]],
#    u'Kurdish language': [(-0.13201984763145447, 0), [35]],
#    u'Kurdish music': [(-0.6832786202430725, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 38]],
#    u'Kurdish nationalism': [(4.007040023803711, 0),
#     [17, 18, 19, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 57]],
#    u'Kurdistan': [(5.483940601348877, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 37, 39, 45]],
#    u'Kurds in Iraq': [(1.6374096870422363, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 42, 45]],
#    u'Kurds in Syria': [(0.8648004531860352, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 45, 46]],
#    u'Kurds in Turkey': [(1.751178503036499, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 40, 45]],
#    u'Turkish Kurdistan': [(3.1838672161102295, 0),
#     [17, 20, 21, 23, 24, 26, 27, 29, 30, 32, 33, 35, 39, 44, 45]],
#    u'XXNILXX': [0, [35]]}},
#  u'entering the 11th , the Orioles rallied against Oakland reliever [Mark Acre] ( 0-2 ) with a walk and a triple by': {'boosted': 10.0,
#   u'gold': u'Mark Acre',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.307567119598389, 0), [15, 50]],
#    u'Acre': [(-1.834635615348816, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 78, 79, 80]],
#    u'Acre (Israel)': [(-3.0129733085632324, 0), [35]],
#    u'Acre Railway Station': [0,
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 84, 87, 88, 93, 104, 106]],
#    u'Acre River': [(-2.7028207778930664, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 108]],
#    u'Acre State': [(-2.5866425037384033, 0), [35]],
#    u'Acre Subdistrict, Mandatory Palestine': [(-3.446038007736206, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Acre, Lancashire': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 94, 104]],
#    u'Campeonato Acreano': [(-3.101593494415283, 0), [35]],
#    u'Federa\xe7\xe3o de Futebol do Estado do Acre': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Mark Acre': [0,
#     [23, 26, 29, 32, 35, 48, 49, 77, 78, 79, 81, 83, 87, 88, 93, 96, 1757]],
#    u'Republic of Acre': [(-3.2265238761901855, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 105]],
#    u'Siege of Acre (1291)': [(-3.0612502098083496, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 97]],
#    u'Siege of Acre (1799)': [(-4.098819732666016, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 83, 84, 85, 86, 93, 98]],
#    u'XXNILXX': [0, [35]]}},
#  u'in Van province , five in Sirnak and four in [Hakkari] .': {'boosted': 10.0,
#   u'gold': u'Hakk\xe2ri Province',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.282444715499878, 0), [15, 50]],
#    u'Dioceses of the Church of the East, 1552\u20131913': [(-1.2855095863342285,
#      0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 89]],
#    u'Hakkari': [(3.269378662109375, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 77, 78, 79]],
#    u'Hakkari Vilayet': [(-0.3572647273540497, 0), [35]],
#    u'Hakkari Y\xfcksekova Airport': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 98, 104]],
#    u'Hakk\xe2ri': [(5.691366195678711, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 82, 83, 84, 90]],
#    u'Hakk\xe2ri Province': [(4.772834300994873, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 80, 81, 82, 83, 84, 87, 88]],
#    u'XXNILXX': [0, [35]]}},
#  u'of his new businesslike approach , Medvedev hired Australian coach [Bob Brett] at the start of this year and the partnership is': {'boosted': 10.0,
#   u'gold': u'Bob Brett',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.35764741897583, 0), [15, 50]],
#    u'Bob Brett': [0, [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]],
#    u'Brett': [(-2.891724109649658, 0),
#     [23, 24, 26, 27, 29, 32, 35, 77, 78, 79, 87, 88]],
#    u'Brett Bodine': [(-2.1970109939575195, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 94, 104]],
#    u'Brett Craig': [(-4.322943687438965, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 108]],
#    u'Brett DiBiase': [(-3.2499005794525146, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 89, 93, 104]],
#    u'Brett Hull': [(-3.923112392425537, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 97, 104]],
#    u'Brett Lee': [(-2.15523099899292, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 104, 110]],
#    u'Brett Morris': [(-3.1765658855438232, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 84, 87, 88, 93, 104, 105]],
#    u'Brett Stark': [(-4.63600492477417, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 98, 104]],
#    u'Brett Stewart (rugby league)': [(-3.889364004135132, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 86, 93, 104, 107]],
#    u'Brett Sutter': [(-3.6351163387298584, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 84, 93, 104, 106]],
#    u'Dean Brett': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 83, 87, 88, 90, 93, 96]],
#    u'George Brett': [(-2.3737828731536865, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 91, 93, 96]],
#    u'Ken Brett': [(-3.4875645637512207, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 95, 96]],
#    u'Neco Brett': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 109]],
#    u'Robert Brett': [(-3.11603045463562, 0),
#     [23, 26, 29, 30, 32, 33, 35, 48, 49, 79, 81, 83, 93, 96, 125]],
#    u'Stephen Brett': [(-3.9681031703948975, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 80, 81, 83, 87, 88, 93, 96]],
#    u'The Dance Party': [(-3.8533828258514404, 0),
#     [23, 26, 29, 32, 35, 48, 49, 79, 81, 82, 83, 84, 87, 88, 92]],
#    u'XXNILXX': [0, [35]]}},
#  u'this Sunday for talks with President Hosni Mubarak , the [Foreign Ministry] said on Wednesday .': {'boosted': 10.0,
#   u'gold': u'Ministry of Foreign Affairs (Israel)',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.856715202331543, 0), [15, 50]],
#    u'Anglican ministry': [(-0.9951893091201782, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 93, 96, 97]],
#    u'Christian ministry': [(-1.2303063869476318, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 90, 93, 96]],
#    u'Foreign Ministry of Austria-Hungary': [(2.8118534088134766, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 95, 104]],
#    u'Foreign minister': [(3.587125301361084, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84, 589]],
#    u'Ministry': [(-1.0590379238128662, 0), [35]],
#    u'Ministry (band)': [(-1.9090662002563477, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 81, 84, 85, 93, 104, 120]],
#    u'Ministry (collective executive)': [(-0.25254958868026733, 0),
#     [23, 26, 29, 32, 35, 48, 49, 81, 84, 85, 87, 88, 91, 93, 104, 120]],
#    u'Ministry (government department)': [(0.09723121672868729, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 84, 85, 93, 104, 120]],
#    u'Ministry (magazine)': [(-1.1115047931671143, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 89, 93, 104, 120]],
#    u'Ministry of Foreign Affairs (Iran)': [(3.774416446685791, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 82, 83, 84, 85, 86, 90]],
#    u'Ministry of Foreign Affairs (Israel)': [(4.68988037109375, 0),
#     [23,
#      24,
#      26,
#      27,
#      29,
#      30,
#      32,
#      33,
#      35,
#      81,
#      82,
#      83,
#      84,
#      85,
#      86,
#      93,
#      98,
#      104,
#      850]],
#    u'Ministry of Foreign Affairs (Japan)': [(2.8660380840301514, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 80, 81, 82, 83, 84, 85, 86]],
#    u'Ministry of Foreign Affairs (Russia)': [(2.698031425476074, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 82, 83, 84, 85, 86, 89]],
#    u'Ministry of Foreign Affairs (Turkey)': [(5.058971881866455, 0),
#     [23, 24, 26, 27, 29, 32, 35, 81, 82, 83, 84, 85, 86, 87, 88, 105]],
#    u"Ministry of Foreign Affairs of the People's Republic of China": [(4.997111797332764,
#      0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 91]],
#    u'Ministry of Jesus': [(-0.21866019070148468, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 93, 98, 104]],
#    u'XXNILXX': [0, [35]]}},
#  u'two state-paid village guards were killed in the fighting with [Kurdistan Workers Party] ( PKK ) guerrillas , the agency quoted the emergency': {'boosted': 10.0,
#   u'gold': u"Kurdistan Workers' Party",
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.4325461387634277, 0), [15, 50]],
#    u'Communist Party of China': [(0.11801640689373016, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 93, 98]],
#    u'Communist Party of the Soviet Union': [(-1.3604758977890015, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 84, 90, 93]],
#    u"Kurdistan Workers' Party": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84, 784]],
#    u'Party': [0, [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 78, 79]],
#    u'Party (1984 film)': [(-1.8370637893676758, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 93, 95, 104, 120]],
#    u'Party (Beyonc\xe9 song)': [(-2.0314834117889404, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 84, 85, 91, 93, 104, 120]],
#    u'Party video game': [(-1.843066930770874, 0), [35]],
#    u'Political party': [(-2.006129026412964, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 83, 89, 93, 96]],
#    u'Workers Party': [0, [35]],
#    u'Workers Party (US)': [(-1.2438666820526123, 0), [35]],
#    u'Workers Party of America': [(-1.7605279684066772, 0),
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 89, 93, 104]],
#    u'Workers Party of Finland': [(-0.8550427556037903, 0),
#     [23, 24, 26, 27, 29, 32, 35, 79, 81, 84, 87, 88, 93, 98, 104]],
#    u"Workers' Party (Brazil)": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 81, 82, 83, 84, 85, 86, 91]],
#    u'XXNILXX': [0, [35]]}},
#  u'two village guards , died when a mine planted by [PKK] rebels exploded on a road in the southeast , Anatolian': {'boosted': 10.0,
#   u'gold': u"Kurdistan Workers' Party",
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.136460781097412, 0), [15, 50]],
#    u'Kota Kinabalu Polytechnic': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 82, 83, 84]],
#    u"Kurdistan Workers' Party": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Politeknik Kota Kinabalu': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 91]],
#    u'XXNILXX': [0, [35]]}},
#  u'were killed in the fighting with Kurdistan Workers Party ( [PKK] ) guerrillas , the agency quoted the emergency rule governor': {'boosted': 10.0,
#   u'gold': u"Kurdistan Workers' Party",
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.253833293914795, 0), [15, 50]],
#    u'Kota Kinabalu Polytechnic': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 80, 81, 82, 83, 84]],
#    u"Kurdistan Workers' Party": [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 77, 79, 81, 82, 83, 84]],
#    u'Politeknik Kota Kinabalu': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 82, 83, 84, 91]],
#    u'XXNILXX': [0, [35]]}},
#  u'with dogs trained to find bodies searched one house at [Ransart] and one at Mont-sur-Marchienne -- both suburbs of the southern': {'boosted': 10.0,
#   u'gold': u'Ransart, Belgium',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-0.7557085752487183, 0), [15, 50]],
#    u'Ransart': [(1.480666995048523, 0),
#     [35, 48, 49, 77, 78, 79, 87, 88, 111, 112, 113, 114]],
#    u'Ransart, Belgium': [0,
#     [23, 26, 29, 32, 35, 48, 49, 79, 80, 81, 84, 87, 88, 93, 104]],
#    u'Ransart, Pas-de-Calais': [0,
#     [23, 24, 26, 27, 29, 30, 32, 33, 35, 79, 81, 84, 91, 93, 104]],
#    u'XXNILXX': [0, [35]]}}}

# %%
queries_exp.linear_features_dens_l.W.get_value(borrow=True)
# Out:
# array([[ 1.92961287],
#        [ 2.47265267],
#        [ 2.17662072],
#        [ 2.20051455],
#        [ 2.91088605],
#        [ 2.93594003],
#        [ 1.12081432],
#        [ 0.92143965],
#        [-0.07416955],
#        [-0.2855275 ],
#        [-0.67375642],
#        [-1.69501054]], dtype=float32)

# %%
evalCurrentStateF1(False,50000)
# Out:
# (3264, 'Prec = 1725.0/2045 = 0.843520782396, Rec = 1725.0/2015 = 0.856079404467, F1 = 0.849753694581')
# (3264,
#  'Prec = 1725.0/2045 = 0.843520782396, Rec = 1725.0/2015 = 0.856079404467, F1 = 0.849753694581')

# %%
queries_exp.updates.keys()[-6].get_value(borrow=True).min()
# Out:
# 0.0

# %%
findWrongItems()
# Out:
# {u' [Citronella oil] can be burned in wick lamps outdoors .': {'boosted': 10.0,
#   u'gold': u'Citronella oil',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.6257750988006592, 0), [87, 124]],
#    u'Citronella oil': [(4.7099714279174805, 0),
#     [88, 90, 93, 95, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Cooking oil': [(5.390409469604492, 0),
#     [88,
#      95,
#      104,
#      105,
#      109,
#      111,
#      112,
#      115,
#      116,
#      118,
#      141,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      230,
#      484]],
#    u'Fuel oil': [(5.317875385284424, 0),
#     [88,
#      95,
#      104,
#      106,
#      108,
#      109,
#      111,
#      112,
#      114,
#      115,
#      141,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      235,
#      236]],
#    u'List of Dynasty episodes': [(1.3453088998794556, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      186,
#      187,
#      188,
#      191]],
#    u'Motor oil': [(3.6169919967651367, 0),
#     [88,
#      95,
#      104,
#      105,
#      109,
#      111,
#      112,
#      115,
#      116,
#      118,
#      141,
#      162,
#      163,
#      166,
#      167,
#      173,
#      183,
#      184,
#      188,
#      189,
#      417]],
#    u'Oil': [(6.055103778839111, 0),
#     [88, 90, 93, 95, 104, 106, 109, 111, 112, 115, 116, 118, 139, 140, 141]],
#    u'Oil (The Young Ones)': [0,
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      239]],
#    u'Oil (band)': [(3.0466558933258057, 0),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Oil Bowl': [(1.2331550121307373, 0),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      141,
#      183,
#      184,
#      185,
#      186,
#      443]],
#    u'Oil paint': [(4.345753192901611, 0),
#     [88,
#      95,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      233,
#      237]],
#    u'Oil pipeline': [(2.3566641807556152, 0), [88]],
#    u'XXNILXX': [0, [88]],
#    u'oil painting': [(5.14805793762207, 0), [88]],
#    u'petroleum': [(6.556687831878662, 0), [88]]}},
#  u' [Gasoline] - burning lamps have also been produced ; these do': {'boosted': 10.0,
#   u'gold': u'Gasoline',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.312314510345459, 0), [87, 124]],
#    u'Alpine': [(2.271693468093872, 0),
#     [88, 95, 104, 106, 111, 116, 117, 118, 119, 121, 162, 165, 166, 169, 259]],
#    u'Avgas': [(2.7723517417907715, 0),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 258]],
#    u'Dame Darcy': [(1.3167775869369507, 0),
#     [88, 95, 104, 106, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 235]],
#    u'Gasoline': [(3.418592929840088, 0),
#     [88, 90, 93, 95, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Gasoline (1913 song)': [0,
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      268]],
#    u'Gasoline (Band)': [(1.0938613414764404, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      260]],
#    u'Gasoline (Moist song)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      261]],
#    u'Gasoline (Seether song)': [(1.0365172624588013, 0),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      161,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172]],
#    u'Gasoline (The Hard Lessons album)': [0,
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      173]],
#    u'Gasoline (Theory of a Deadman album)': [(-0.7135027050971985, 0),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      162,
#      163,
#      164,
#      165,
#      170,
#      171,
#      172]],
#    u'Gasoline (brand)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      234]],
#    u'Gasoline (film)': [(0.09870044887065887, 0),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      232]],
#    u'Oil refinery': [(3.7781496047973633, 0),
#     [88, 95, 104, 106, 109, 111, 112, 115, 116, 118, 162, 165, 166, 169, 230]],
#    u'XXNILXX': [0, [88]]}},
#  u"'' Pachinko Sexy Reaction '' is an ecchi [arcade game] -LRB- more adult than '' Pachinko Sexy Reaction 2 ''": {'boosted': 10.0,
#   u'gold': u'Arcade game',
#   u'training': True,
#   u'vals': {u'-NIL-': [(0.18251167237758636, 0), [87, 124]],
#    u'Arcade game': [(4.003387451171875, 0),
#     [88,
#      90,
#      93,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      140,
#      141,
#      162,
#      163,
#      166,
#      167,
#      261]],
#    u"Bucky O'Hare (arcade game)": [(4.422698020935059, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      161,
#      162,
#      163,
#      165,
#      166,
#      171,
#      451]],
#    u'Donkey Kong (video game)': [(3.7976551055908203, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      165,
#      166,
#      169,
#      171,
#      232,
#      451]],
#    u'Game': [(2.579775333404541, 0),
#     [88, 90, 93, 95, 104, 105, 111, 112, 116, 117, 118, 119, 140, 141, 192]],
#    u'Game (2011 film)': [(3.1452672481536865, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      187,
#      193,
#      194]],
#    u'Game (food)': [(3.4962944984436035, 0), [88]],
#    u'Game (retailer)': [(3.5807342529296875, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      195]],
#    u'Ninja Gaiden (arcade)': [(2.8601977825164795, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      183,
#      186,
#      188,
#      191,
#      192,
#      193,
#      452]],
#    u'Pac-Man': [(4.615911483764648, 0),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 233]],
#    u'Popeye (video game)': [(3.5881576538085938, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      183,
#      186,
#      187,
#      188,
#      191,
#      193,
#      452]],
#    u'Star Wars (1983 video game)': [(4.334691047668457, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      183,
#      186,
#      188,
#      191,
#      193,
#      195,
#      452]],
#    u'Teenage Mutant Ninja Turtles (arcade game)': [(3.227137804031372, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      162,
#      163,
#      165,
#      166,
#      170,
#      171,
#      451]],
#    u'The Game (rapper)': [(4.467388153076172, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      183,
#      184,
#      186,
#      188,
#      193,
#      452]],
#    u'Video game': [(3.4725425243377686, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      161,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      236]],
#    u'XXNILXX': [0, [88]]}},
#  u"'' mdash ; for his heroism in April 1970 in [Vietnam] .": {'boosted': 10.0,
#   u'gold': u'Vietnam War',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.5118019580841064, 0), [87, 124]],
#    u'Buddhism in Vietnam': [(2.51902174949646, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 138]],
#    u'Cinema of Vietnam': [(1.8191494941711426, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 746]],
#    u'French Indochina': [(2.7077205181121826, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 176]],
#    u'North Vietnam': [(2.6792328357696533, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 136]],
#    u'South Vietnam': [(3.3220670223236084, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 129]],
#    u'Vietnam': [(4.871014595031738, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Vietnam (miniseries)': [(3.0233194828033447, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      137]],
#    u'Vietnam Football Federation': [(1.2599977254867554, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 128]],
#    u'Vietnam War': [(3.6275744438171387, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Vietnam at the 2005 Southeast Asian Games': [(-2.2864508628845215, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Vietnam at the 2007 Southeast Asian Games': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 134]],
#    u'Vietnam at the 2009 Southeast Asian Games': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 133]],
#    u'Vietnam national football team': [(1.0628420114517212, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u"Vietnam women's national football team": [(0.0927262231707573, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u"Vietnam women's national volleyball team": [(-2.3476405143737793, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 127]],
#    u'Vietnamese cuisine': [(2.765035390853882, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Volleyball Federation of Vietnam': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 175]],
#    u'XXNILXX': [0, [88]]}},
#  u', 280 lb -LRB- 2.13 m , 125 kg -RRB- [center] played four seasons in the NBA before being forced to': {'boosted': 10.0,
#   u'gold': u'Center (basketball)',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.5030763149261475, 0), [87, 124]],
#    u'Basketball positions': [(0.10320660471916199, 0),
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      141,
#      162,
#      165,
#      166,
#      169,
#      183,
#      186,
#      187,
#      188,
#      191,
#      560]],
#    u'Center': [(-0.2020118236541748, 0), [88]],
#    u'Center (algebra)': [(0.8039794564247131, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      233]],
#    u'Center (basketball)': [(0.7067458629608154, 0),
#     [88,
#      90,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      139,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Center, Colorado': [(0.15797312557697296, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      185,
#      186,
#      236]],
#    u'Center, Texas': [(0.746673583984375, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      182,
#      183,
#      184,
#      185,
#      186]],
#    u'Centre (geometry)': [(1.5056661367416382, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      165,
#      166,
#      169,
#      171,
#      183,
#      186,
#      188,
#      191,
#      193,
#      268,
#      451,
#      452,
#      33357]],
#    u'XXNILXX': [0, [88]],
#    u'center (American football)': [(0.5094395875930786, 0), [88]],
#    u'center (group theory)': [(0.90824294090271, 0), [88]],
#    u'center (ice hockey)': [(0.5094395875930786, 0), [88]]}},
#  u', Jr. was born on 23 June 1949 , in [East Chicago , Indiana] , and graduated from Washington High School there in 1968': {'boosted': 10.0,
#   u'gold': u'East Chicago, Indiana',
#   u'training': True,
#   u'vals': {u'-NIL-': [(1.3155068159103394, 0), [87, 124]],
#    u'Central High School (East Chicago, Indiana)': [(5.251633167266846, 0),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      126,
#      128]],
#    u'Chicago (2002 film)': [(6.4141154289245605, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      130]],
#    u'Chicago (band)': [(7.904870510101318, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Chicago (musical)': [(6.7248215675354, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      128]],
#    u'Chicago ,': [0, [88]],
#    u'Chicago Blackhawks': [(6.118632793426514, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Chicago Bulls': [(5.193690776824951, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'East Chicago (NICTD station)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      122]],
#    u'East Chicago , Indiana': [0, [88]],
#    u'East Chicago High School': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'East Chicago, Illinois': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'East Chicago, Indiana': [(4.82355260848999, 0),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'East Side, Chicago': [(6.5086774826049805, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'XXNILXX': [0, [88]]}},
#  u', he was ordered to the Marine Corps Base , [Camp Pendleton] , California , where he joined the 2nd Infantry Training': {'boosted': 10.0,
#   u'gold': u'Marine Corps Base Camp Pendleton',
#   u'training': True,
#   u'vals': {u' Marine Corps Base Camp Pendleton': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'-NIL-': [(-1.3897826671600342, 0), [87, 124]],
#    u'Camp Pendleton (Virginia)': [(0.8585620522499084, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Camp Pendleton South, California': [(2.8985064029693604, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Marine Corps Base Camp Pendleton': [(3.300462007522583, 0),
#     [88,
#      89,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      4214]],
#    u'Pendleton': [(1.9281330108642578, 0), [88]],
#    u'Pendleton County, Kentucky': [(2.831258773803711, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Pendleton County, West Virginia': [(2.011674404144287, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Pendleton, Greater Manchester': [(4.343199729919434, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Pendleton, Indiana': [(1.25344979763031, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Pendleton, Lancashire': [(3.1832780838012695, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'Pendleton, New York': [(2.969630479812622, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Pendleton, Oregon': [(2.4372692108154297, 0),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Pendleton, South Carolina': [(2.1013734340667725, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Victoria Pendleton': [(2.0562002658843994, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 131]],
#    u'XXNILXX': [0, [88]]}},
#  u'-RRB- is a Canadian former professional basketball player in the [NBA] .': {'boosted': 10.0,
#   u'gold': u'National Basketball Association',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.818966865539551, 0), [87, 124]],
#    u'2008&amp;ndash;09 NBA season': [0,
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'2008\u201309 NBA season': [(-2.5816359519958496, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'2009\u201310 NBA season': [(-1.576541781425476, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'2010\u201311 NBA season': [(-1.7049708366394043, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'2012\u201313 NBA season': [(-2.9864401817321777, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 136]],
#    u'NBA (song)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      128]],
#    u'NBA All-Star Game': [(-2.1307544708251953, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 135]],
#    u'NBA Most Valuable Player Award': [(-1.0310606956481934, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 138]],
#    u'NBA on ABC': [(-1.5245938301086426, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 176]],
#    u'NBA on CBS': [(-0.7985875606536865, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 134]],
#    u'NBA on ESPN': [(-1.5709031820297241, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'NBA on NBC': [(-1.2693657875061035, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 137]],
#    u'National Basketball Association': [(-0.9045060276985168, 0),
#     [88, 89, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'National Board of Accreditation': [(-1.127589225769043, 0),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 115, 116, 118, 121, 123]],
#    u'National Boxing Association': [(-0.8064612746238708, 0), [88]],
#    u'Neue Bach-Ausgabe': [(-0.8117968440055847, 0),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 130]],
#    u'XXNILXX': [0, [88]]}},
#  u'23 October 2004 , around the same time as the [Wales Millennium Centre] in Cardiff .': {'boosted': 10.0,
#   u'gold': u'Wales Millennium Centre',
#   u'training': True,
#   u'vals': {u'-NIL-': [(0.15957167744636536, 0), [87, 124]],
#    u'Center': [(3.2426235675811768, 0), [88]],
#    u'Centre (rugby union)': [(4.141976356506348, 0), [88]],
#    u'Centre (r\xe9gion fran\xe7aise)': [(4.141976356506348, 0), [88]],
#    u'Centre Colonels football': [(3.520268678665161, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'Centre County, Pennsylvania': [(6.614555835723877, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Centre Party (Norway)': [(5.6329498291015625, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      126,
#      127]],
#    u'Centrism': [(5.492557525634766, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Millennium Center': [(3.3637454509735107, 0),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 115, 116, 118, 121, 128]],
#    u'Millennium Centre': [0, [88]],
#    u'Millennium Centre (Chicago)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      122]],
#    u'The Millennium Centre': [(4.783287048339844, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 123, 125]],
#    u'Wales Millennium Centre': [(6.503794193267822, 0),
#     [88, 89, 91, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125]],
#    u'XXNILXX': [0, [88]],
#    u'centre (ice hockey)': [(4.213149547576904, 0), [88]]}},
#  u'2nd Recruit Training Battalion , Recruit Training Regiment at the [MCRD San Diego] , California .': {'boosted': 10.0,
#   u'gold': u'Marine Corps Recruit Depot San Diego',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.6877548694610596, 0), [87, 124]],
#    u'Diego': [(1.5825270414352417, 0),
#     [88, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Diego Costa Silva': [(-1.907974362373352, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Diego Eli Moreira': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Diego Ribas': [(0.6262863278388977, 0), [88]],
#    u'Diego Walsh': [(-0.7221149206161499, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Diego de Lima Barcelos': [(-2.776667356491089, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Marine Corps Recruit Depot San Diego': [(1.4564697742462158, 0),
#     [88,
#      89,
#      92,
#      94,
#      96,
#      98,
#      99,
#      100,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      2779]],
#    u'Primo (wrestler)': [(-0.003676890628412366, 0),
#     [88,
#      92,
#      98,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      126,
#      133]],
#    u'San Diego': [(3.573091745376587, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'San Diego Chargers': [(1.926202654838562, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'San Diego County, California': [(4.35641622543335, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'San Diego International Airport': [(1.4313255548477173, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u"San Diego Toreros men's basketball": [(-1.6709493398666382, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 115, 116, 117, 118, 121, 132]],
#    u'Southern California Open': [(-0.6427585482597351, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'University of San Diego': [(0.5958017706871033, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 127]],
#    u'XXNILXX': [0, [88]]}},
#  u"Birds '' and a larger role in the original '' [Invasion of the Body Snatchers] '' , having portrayed a physician in the '' book-end": {'boosted': 10.0,
#   u'gold': u'Invasion of the Body Snatchers',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.8424322605133057, 0), [87, 124]],
#    u'2003 invasion of Iraq': [(0.9901338219642639, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Battle of France': [(0.22791902720928192, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Invasion': [(0.12190009653568268, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Invasion (1965 film)': [(0.2625645101070404, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      130]],
#    u'Invasion (1997 film)': [(-0.11058913916349411, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      128]],
#    u'Invasion (TV series)': [(-0.336948961019516, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Invasion Body Snatchers': [0, [88]],
#    u'Invasion of': [0, [88]],
#    u'Invasion of Normandy': [(0.6949439644813538, 0),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Invasion of Poland': [(-1.0922781229019165, 0),
#     [88,
#      92,
#      94,
#      96,
#      97,
#      100,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123,
#      307]],
#    u'Invasion of the': [0, [88]],
#    u'Invasion of the Body': [0, [88]],
#    u'Invasion of the Body Snatchers': [(0.3720969259738922, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Invasion of the Body Snatchers (1978 film)': [(1.8609814643859863, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Invasion of the Body Snatchers (1978 film) ': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'The Invasion (professional wrestling)': [(-0.17201918363571167, 0),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123,
#      126]],
#    u'XXNILXX': [0, [88]]}},
#  u"Cooley on '' The Dick Van Dyke Show '' , [Fred Rutherford] on '' Leave It to Beaver '' -LRB- Mr.": {'boosted': 10.0,
#   u'gold': u'Fred Rutherford',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.326326370239258, 0), [87, 124]],
#    u'Alexander Cameron Rutherford': [(-0.16299106180667877, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 135]],
#    u'Ernest Rutherford': [(0.2294500321149826, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 130]],
#    u'Fred Rutherford': [(0.10173959285020828, 0),
#     [88, 89, 91, 94, 106, 108, 109, 114, 115, 121, 142, 143]],
#    u'Jock Rutherford': [(-1.378340482711792, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 125, 138]],
#    u'John Rutherford (rugby union)': [(-0.8672531843185425, 0),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      126,
#      131]],
#    u'Johnny Rutherford': [(-0.9923760890960693, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 125, 133]],
#    u'Rutherford': [(-0.8429898023605347, 0), [88]],
#    u'Rutherford (NJT station)': [(-0.9662341475486755, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      134]],
#    u'Rutherford AVA': [(-0.11958836764097214, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 137]],
#    u'Rutherford County, North Carolina': [(-0.8655601739883423, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Rutherford County, Tennessee': [(1.5111911296844482, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Rutherford GO Station': [(-0.4132553040981293, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 136]],
#    u'Rutherford, California': [(-0.1636534035205841, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Rutherford, Edmonton': [(0.04032639041543007, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Rutherford, New Jersey': [(1.641579031944275, 0),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Rutherford, New South Wales': [(-0.6411170959472656, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 127]],
#    u'Rutherford, Pennsylvania': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 176]],
#    u'Rutherford, Tennessee': [(-1.8503284454345703, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 129]],
#    u'XXNILXX': [0, [88]]}},
#  u"De La Garza , Jr. -LRB- 1949-1970 -RRB- was a [United States Marine Corps] lance corporal who was posthumous ly presented the nation 's": {'boosted': 10.0,
#   u'gold': u'United States Marine Corps',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-1.8898876905441284, 0), [87, 124]],
#    u'Aaron Corp': [(0.9719257950782776, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      145,
#      146,
#      151,
#      153,
#      154,
#      155,
#      178,
#      179,
#      199,
#      201,
#      202,
#      203]],
#    u'Corp': [(1.6609596014022827, 0), [88]],
#    u'Corps': [(1.319993495941162, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Corps, Is\xe8re': [(1.4641199111938477, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'German Student Corps': [(0.7019719481468201, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 122, 125]],
#    u'Marine Air-Ground Task Force': [(1.9339238405227661, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Marine Corps': [(1.424249529838562, 0), [88]],
#    u'Republic of Korea Marine Corps': [(1.555350422859192, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 123, 125]],
#    u'Ronald Corp': [(3.800687551498413, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      144,
#      145,
#      146,
#      153,
#      154,
#      155,
#      177,
#      178,
#      179,
#      201,
#      202,
#      203]],
#    u'Salvation Army corps': [(2.7931325435638428, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'States Marine Corps': [0, [88]],
#    u'United States Army Corps of Engineers': [(1.2024885416030884, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'United States Marine Corps': [(3.291888952255249, 0),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      132]],
#    u'United States Marine Corps Aviation': [(1.4589190483093262, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'XXNILXX': [0, [88]]}},
#  u'De La Garza enlisted in the [United States Marine Corps] on 4 February 1969 , in Chicago , Illinois .': {'boosted': 10.0,
#   u'gold': u'United States Marine Corps',
#   u'training': True,
#   u'vals': {u'-NIL-': [(2.198584794998169, 0), [87, 124]],
#    u'Aaron Corp': [(5.060372829437256, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      145,
#      146,
#      151,
#      153,
#      154,
#      155,
#      178,
#      179,
#      199,
#      201,
#      202,
#      203]],
#    u'Corp': [(5.749435901641846, 0), [88]],
#    u'Corps': [(5.408442497253418, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Corps, Is\xe8re': [(5.552612781524658, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'German Student Corps': [(4.7904205322265625, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 122, 125]],
#    u'Marine Air-Ground Task Force': [(6.022375583648682, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Marine Corps': [(5.512787342071533, 0), [88]],
#    u'Republic of Korea Marine Corps': [(5.643816947937012, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 123, 125]],
#    u'Ronald Corp': [(7.889147758483887, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      144,
#      145,
#      146,
#      153,
#      154,
#      155,
#      177,
#      178,
#      179,
#      201,
#      202,
#      203]],
#    u'Salvation Army corps': [(6.881598949432373, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'States Marine Corps': [0, [88]],
#    u'United States Army Corps of Engineers': [(5.290960311889648, 0),
#     [88, 92, 94, 96, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'United States Marine Corps': [(7.380362510681152, 0),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      132]],
#    u'United States Marine Corps Aviation': [(5.5473551750183105, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'XXNILXX': [0, [88]]}},
#  u"Deacon also appeared on '' [The Addams Family] '' in April 1965 , and puts Cousin Itt through": {'boosted': 10.0,
#   u'gold': u'The Addams Family',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.268979072570801, 0), [87, 124]],
#    u"Children's film": [0,
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Family': [(0.9298980236053467, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Family (1976 TV series)': [(-0.8332417011260986, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      128]],
#    u'Family (band)': [(0.4444371461868286, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Family (biology)': [(0.14918215572834015, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Family Channel': [(-0.0502920038998127, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'The Addams Family': [(0.44833269715309143, 0),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      1198,
#      1199,
#      1200,
#      1201,
#      1202,
#      1203]],
#    u'The Addams Family (1964 TV series)': [(-0.5391231775283813, 0),
#     [88,
#      92,
#      96,
#      97,
#      99,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      126,
#      1199,
#      1200,
#      1201,
#      1205,
#      2643,
#      2644,
#      2647]],
#    u'The Addams Family (1973 animated series)': [(-0.35033559799194336, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      127]],
#    u'The Addams Family (1992 animated series)': [(-0.30139684677124023, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      130]],
#    u'The Addams Family (film)': [(-1.7415075302124023, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'The Addams Family (musical)': [(-0.3972809314727783, 0),
#     [88,
#      92,
#      96,
#      97,
#      99,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      126,
#      128,
#      130,
#      1199,
#      1200,
#      1201,
#      2643,
#      2644,
#      2647,
#      2649]],
#    u'The Addams Family (pinball)': [(-1.7254189252853394, 0),
#     [88,
#      92,
#      96,
#      97,
#      99,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123,
#      126,
#      129,
#      1199,
#      1200,
#      1201,
#      1204,
#      2643,
#      2644,
#      2647]],
#    u'The Addams Family (video game)': [(-0.8242673873901367, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      132]],
#    u'The Addams Family Theme': [(-1.3928543329238892, 0),
#     [88,
#      92,
#      94,
#      96,
#      99,
#      100,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      128,
#      1199,
#      1200,
#      1201,
#      1203,
#      2643,
#      2648]],
#    u'XXNILXX': [0, [88]]}},
#  u"He had a brief role in [Alfred Hitchcock] 's film '' The Birds '' and a larger role": {'boosted': 10.0,
#   u'gold': u'Alfred Hitchcock',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.229469299316406, 0), [87, 124]],
#    u'Alfred Hitchcock': [(2.0606114864349365, 0),
#     [88, 89, 91, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125]],
#    u'Alfred Hitchcock (book)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Alfred Hitchcock (police officer)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      128]],
#    u'Cameron Hitchcock': [0,
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 129]],
#    u'Edward Hitchcock': [(2.635376214981079, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 127]],
#    u'Hitchcock (automobile)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      137]],
#    u'Hitchcock (film)': [(1.6098723411560059, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122]],
#    u'Hitchcock County, Nebraska': [(-0.6116956472396851, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Hitchcock, Oklahoma': [0,
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'Hitchcock, South Dakota': [(-1.7343361377716064, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 131]],
#    u'Hitchcock, Texas': [(0.673846960067749, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 123]],
#    u'Ken Hitchcock': [(0.8505747318267822, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 134]],
#    u'Sterling Hitchcock': [(-0.1382129043340683, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 130]],
#    u'The Birds (film)': [(0.18362075090408325, 0),
#     [88,
#      92,
#      98,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      126]],
#    u'Tom Hitchcock': [0,
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 112, 116, 118, 119, 125, 128]],
#    u'Tommy Hitchcock (racing driver)': [0,
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      126,
#      307]],
#    u'XXNILXX': [0, [88]]}},
#  u"His best-known roles are Mel Cooley on '' [The Dick Van Dyke Show] '' , Fred Rutherford on '' Leave It to Beaver": {'boosted': 10.0,
#   u'gold': u'The Dick Van Dyke Show',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-7.2116804122924805, 0), [87, 124]],
#    u'Agricultural show': [(-1.7564785480499268, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 132]],
#    u'Days of our Lives': [(-2.087970018386841, 0), [88]],
#    u'Dyke Show': [0, [88]],
#    u'Eric Show': [(-3.6547110080718994, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 130]],
#    u'General Hospital': [(-2.2906363010406494, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 128]],
#    u'Show': [(-4.503483772277832, 0), [88]],
#    u'Show (The Cure album)': [(-4.021007061004639, 0),
#     [88,
#      89,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119]],
#    u'Show (The Jesus Lizard album)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      131]],
#    u'Show (film)': [(-4.106915473937988, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Show (magazine)': [(-3.5030996799468994, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      129]],
#    u'Showbiz and A.G.': [(-3.192594289779663, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'The Dick Van Dyke Show': [(-2.8378870487213135, 0),
#     [88,
#      89,
#      91,
#      92,
#      94,
#      96,
#      99,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      125,
#      1198,
#      1199,
#      1200,
#      1201,
#      1202,
#      1203]],
#    u'The Dick Van Dyke Show ': [0,
#     [88,
#      92,
#      94,
#      96,
#      99,
#      100,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      122,
#      1199,
#      1200,
#      1201,
#      1203,
#      1205,
#      2643]],
#    u'The Van Dyke Show': [(-2.763287305831909, 0),
#     [88, 89, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125]],
#    u'XXNILXX': [0, [88]]}},
#  u'However , due to [economies of scale] and additional refining necessary this fuel is one of the': {'boosted': 10.0,
#   u'gold': u'Economies of scale',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-0.15967833995819092, 0), [87, 124]],
#    u'Eastern Bloc economies': [(5.793628215789795, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      188,
#      189,
#      192]],
#    u'Economic system': [(5.628394603729248, 0),
#     [88,
#      95,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      161,
#      162,
#      165,
#      166,
#      169,
#      675,
#      676,
#      677,
#      678,
#      679,
#      680,
#      700,
#      701,
#      702,
#      703,
#      704,
#      705,
#      782,
#      784,
#      787,
#      791,
#      792,
#      797,
#      799,
#      802,
#      806,
#      807,
#      9721,
#      9722]],
#    u'Economics': [(6.374747276306152, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      165,
#      166,
#      169,
#      170,
#      675,
#      677,
#      678,
#      679,
#      680,
#      681,
#      700,
#      702,
#      703,
#      704,
#      705,
#      706,
#      782,
#      784,
#      787,
#      791,
#      792,
#      797,
#      799,
#      802,
#      806,
#      807,
#      985,
#      991]],
#    u'Economies': [(3.8227829933166504, 0), [88]],
#    u'Economies of': [0, [88]],
#    u'Economies of scale': [(4.859684944152832, 0),
#     [88, 90, 93, 95, 104, 106, 111, 115, 116, 117, 118, 121, 139, 140, 141]],
#    u'Economies scale': [0, [88]],
#    u'Economy, Pennsylvania': [(4.5966267585754395, 0),
#     [88,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      782,
#      784,
#      785,
#      786,
#      787,
#      790,
#      797,
#      799,
#      800,
#      801,
#      802,
#      805]],
#    u'Old Economy Village': [(6.7413249015808105, 0),
#     [88,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      782,
#      783,
#      784,
#      785,
#      787,
#      792,
#      797,
#      798,
#      799,
#      800,
#      802,
#      807]],
#    u'Returns to scale': [(3.407579183578491, 0),
#     [88,
#      95,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      141,
#      162,
#      165,
#      166,
#      169,
#      170,
#      183,
#      186,
#      188,
#      191,
#      192]],
#    u'XXNILXX': [0, [88]]}},
#  u'However , kerosene contains more impurities such as [sulfur] and aromatic hydrocarbons than lamp oil .': {'boosted': 10.0,
#   u'gold': u'Sulfur',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-0.8323686718940735, 0), [87, 124]],
#    u'Allotropes of sulfur': [(5.369579792022705, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      114,
#      115,
#      116,
#      141,
#      183,
#      184,
#      188,
#      189,
#      236]],
#    u'Delirium Tremens (album)': [(1.4092110395431519, 0),
#     [88,
#      104,
#      105,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      183,
#      186,
#      188,
#      191,
#      193,
#      237,
#      452]],
#    u'Isotopes of sulfur': [(4.815606594085693, 0),
#     [88, 95, 104, 106, 111, 112, 116, 117, 118, 119, 162, 163, 166, 167, 233]],
#    u'Silver sulfide': [(5.536893844604492, 0),
#     [88, 95, 104, 105, 109, 111, 112, 115, 116, 118, 162, 165, 166, 169, 235]],
#    u'Sulfur': [(6.516486167907715, 0),
#     [88, 90, 93, 95, 104, 105, 109, 111, 112, 116, 118, 119, 139, 140, 141]],
#    u'Sulfur (band)': [(3.383331537246704, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      187,
#      193,
#      194]],
#    u'Sulfur (magazine)': [(3.412242889404297, 0),
#     [88,
#      104,
#      106,
#      111,
#      116,
#      117,
#      118,
#      119,
#      121,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      195]],
#    u'Sulfur (pharmacy)': [(6.5553789138793945, 0),
#     [88,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      163,
#      164,
#      165,
#      171,
#      172,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      232]],
#    u'Sulfur (song)': [(1.764135479927063, 0),
#     [88,
#      104,
#      106,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Sulfur cycle': [(5.816303730010986, 0),
#     [88, 95, 104, 106, 109, 111, 112, 115, 116, 118, 162, 163, 164, 165, 170]],
#    u'Sulfur dioxide': [(5.458128929138184, 0),
#     [88, 95, 104, 105, 109, 111, 112, 116, 118, 119, 161, 162, 163, 164, 165]],
#    u'Sulfur dye': [0,
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      238,
#      268]],
#    u'Sulfur lamp': [(5.807406425476074, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      115,
#      116,
#      118,
#      141,
#      183,
#      184,
#      185,
#      186,
#      239]],
#    u'Sulfur oxide': [(3.9505369663238525, 0),
#     [88, 95, 106, 108, 109, 115, 118, 121, 142, 143, 162, 163, 164, 165, 173]],
#    u'XXNILXX': [0, [88]]}},
#  u'In his first two seasons with the [Philadelphia 76ers] , MacCulloch played reserve center , averaging 9.4 minutes ,': {'boosted': 10.0,
#   u'gold': u'Philadelphia 76ers',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.204031229019165, 0), [87, 124]],
#    u'1966\u201367 Philadelphia 76ers season': [(-0.746065616607666, 0),
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      162,
#      163,
#      165,
#      166,
#      235,
#      262]],
#    u'1969\u201370 Philadelphia 76ers season': [(-1.2131232023239136, 0),
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      161,
#      162,
#      163,
#      165,
#      166,
#      264]],
#    u'1972\u201373 Philadelphia 76ers season': [(-0.4596063196659088, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      162,
#      163,
#      165,
#      166,
#      232,
#      234]],
#    u'1976\u201377 Philadelphia 76ers season': [(-0.7759865522384644, 0),
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      162,
#      163,
#      165,
#      166,
#      232,
#      258]],
#    u'1977\u201378 Philadelphia 76ers season': [(-0.830223023891449, 0),
#     [88,
#      95,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
# ...
#    u'Hadleigh railway station': [0,
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 128]],
#    u'Hadleigh, Essex': [(-0.3783988058567047, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'Hadleigh, Suffolk': [(-0.41631630063056946, 0),
#     [88, 89, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'RAF Hadleigh': [0,
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 132]],
#    u'XXNILXX': [0, [88]]}},
#  u'series of cookbook s and hosted a television series on [microwave] cooking .': {'boosted': 10.0,
#   u'gold': u'Microwave oven',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.9732320308685303, 0), [87, 124]],
#    u'British Telecom microwave network': [(3.9383795261383057, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      141,
#      183,
#      184,
#      186,
#      188,
#      195]],
#    u'Cavalier Computer': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      183,
#      186,
#      188,
#      191,
#      237]],
#    u'Electromagnetic spectrum': [(3.327270030975342, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      186,
#      187,
#      188,
#      191]],
#    u'Microwave (game)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Microwave chemistry': [(3.194445848464966, 0),
#     [88, 95, 104, 106, 109, 111, 112, 116, 118, 119, 162, 163, 164, 165, 233]],
#    u'Microwave oven': [(2.547520399093628, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      170,
#      183,
#      184,
#      185,
#      186,
#      192]],
#    u'Microwave radiometer': [(2.391702651977539, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      183,
#      184,
#      185,
#      186,
#      236]],
#    u'Microwave spectroscopy': [(1.2147529125213623, 0), [88]],
#    u'Microwave transmission': [(2.013044834136963, 0),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 161, 162, 163, 164, 165]],
#    u'Microwaves': [(1.2147529125213623, 0), [88]],
#    u'Waldorf Microwave': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      188,
#      189,
#      239]],
#    u'XXNILXX': [0, [88]]}},
#  u"than '' Pachinko Sexy Reaction 2 '' -RRB- developed by [Sammy] in 1998 .": {'boosted': 10.0,
#   u'gold': u'Sammy',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.3991823196411133, 0), [87, 124]],
#    u'Darren Sammy': [(1.8903955221176147, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 128]],
#    u'Hendra Samuel Simorangkir': [0,
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 133]],
#    u'Sammy': [(1.6241182088851929, 0), [88]],
#    u'Sammy (Cracker)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      137]],
#    u'Sammy (Prison Break character)': [(0.9145762324333191, 0), [88]],
#    u'Sammy (TV series)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      127]],
#    u'Sammy (band)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      130]],
#    u'Sammy (comics)': [(1.7530087232589722, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Sammy (song)': [0,
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      135]],
#    u'Sammy Ameobi': [(0.0024429939221590757, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 129]],
#    u'Sammy Babitzin': [(0.43110722303390503, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121, 523]],
#    u'Sammy Corporation': [(1.3062026500701904, 0),
#     [88, 89, 92, 94, 96, 97, 100, 104, 106, 109, 111, 115, 116, 118, 121]],
#    u'Sammy Gravano': [(4.21199369430542, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 138]],
#    u'Sammy Hagar': [(2.37143874168396, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 176]],
#    u'Sammy Ofer': [(2.236496925354004, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 132]],
#    u'Sammy Sosa': [(2.4630515575408936, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 317]],
#    u'Sega Sammy Holdings': [(0.43753260374069214, 0),
#     [88, 92, 94, 96, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 122]],
#    u'XXNILXX': [0, [88]]}},
#  u"the find 's importance was equated to that of the [Mary Rose] .": {'boosted': 10.0,
#   u'gold': u'Mary Rose',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-5.29193639755249, 0), [87, 124]],
#    u'Andy Rose': [(-2.766636371612549, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 127]],
#    u'Danny Rose (footballer, born 1990)': [(-1.2390438318252563, 0),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      126,
#      129]],
#    u'Danny Rose (footballer, born 1993)': [0,
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      126,
#      138]],
#    u'Derrick Rose': [(-1.8419101238250732, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 137]],
#    u'HMS Mary Rose (1654)': [(-0.8042610287666321, 0),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      123,
#      126]],
#    u'Joseph Nelson Rose': [(-0.588029146194458, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 114, 115, 116, 121, 122, 125, 143]],
#    u'Joshua Rose': [(-3.9816641807556152, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 131]],
#    u'Justin Rose': [(-0.9679920673370361, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 175]],
#    u'Mary Rose': [(0.34655219316482544, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Mary Rose (play)': [(0.7711126804351807, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      106,
#      108,
#      109,
#      111,
#      115,
#      118,
#      121,
#      122,
#      142]],
#    u'Mervyn Rose': [(-2.3994383811950684, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 128]],
#    u'Michael Rose (footballer)': [(-3.1963775157928467, 0),
#     [88,
#      92,
#      96,
#      99,
#      100,
#      101,
#      104,
#      106,
#      109,
#      111,
#      112,
#      116,
#      118,
#      119,
#      126,
#      134]],
#    u'Pete Rose': [(-0.5363896489143372, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 136]],
#    u'Rose': [(-1.0916714668273926, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'Rose (Doctor Who)': [(0.32968175411224365, 0),
#     [88,
#      92,
#      96,
#      97,
#      100,
#      101,
#      102,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      123]],
#    u'Rose Bowl Game': [(-0.5164616107940674, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 132]],
#    u'Rose Tyler': [(-0.5708871483802795, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'Rose, New York': [(-1.359619379043579, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 523]],
#    u'XXNILXX': [0, [88]]}},
#  u'to a genetic neuromuscular disorder that affected his feet , [Charcot-Marie-Tooth disease] .': {'boosted': 10.0,
#   u'gold': u'Charcot\u2013Marie\u2013Tooth disease',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-3.8221096992492676, 0), [87, 124]],
#    u'Charcot\u2013Marie\u2013Tooth disease': [(-0.7976623177528381, 0),
#     [88, 90, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169]],
#    u'Disease (The Ark song)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      187,
#      193,
#      194]],
#    u'Disease (The Terminals album)': [0,
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      239]],
#    u'Disease (album)': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      195]],
#    u'Disease (song)': [(-1.8900771141052246, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Globalization and disease': [(-0.3833257555961609, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      184,
#      188,
#      189,
#      236]],
#    u'Infection': [(-0.9088809490203857, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      161,
#      162,
#      165,
#      166,
#      169,
#      183,
#      186,
#      188,
#      191,
#      237]],
#    u'Neurological disorder': [(-0.8124707937240601, 0),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 232]],
#    u'Occupational disease': [(-0.7790541648864746, 0),
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      141,
#      182,
#      183,
#      184,
#      188,
#      189]],
#    u'Plant pathology': [(-1.470660924911499, 0),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 165, 166, 169, 170]],
#    u'XXNILXX': [0, [88]],
#    u'disease': [(-0.9614447951316833, 0), [88]]}},
#  u"was a United States Marine Corps lance corporal who was [posthumous] ly presented the nation 's highest honor '' mdash ;": {'boosted': 10.0,
#   u'gold': u'Posthumous recognition',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-4.029630661010742, 0), [87, 124]],
#    u'Posthumous': [(-0.8274016976356506, 0), [88]],
#    u'Posthumous (EP)': [0,
#     [88,
#      104,
#      106,
#      109,
#      111,
#      115,
#      116,
#      118,
#      121,
#      183,
#      184,
#      185,
#      186,
#      192,
#      193,
#      194]],
#    u'Posthumous name': [(1.441699743270874, 0),
#     [88, 95, 104, 105, 111, 112, 116, 117, 118, 119, 162, 163, 164, 165, 232]],
#    u'Posthumous recognition': [(-0.7157331705093384, 0), [88]],
#    u'Posthumous work': [(-0.7157331705093384, 0), [88]],
#    u"Shakespeare's reputation": [(1.4235198497772217, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      183,
#      186,
#      188,
#      191,
#      195]],
#    u'XXNILXX': [0, [88]],
#    u'posthumou': [0, [88]],
#    u'posthumous birth': [(0.6411186456680298, 0), [88]]}},
#  u'win their group only to lose to eventual silver medalist [France] in the quarterfinals and finish seventh .': {'boosted': 10.0,
#   u'gold': u'France national basketball team',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-0.3477175235748291, 0), [87, 124]],
#    u'A1 Team France': [(-0.5162913203239441, 0),
#     [88, 92, 94, 96, 99, 104, 106, 109, 111, 115, 116, 118, 121, 125, 176]],
#    u'Cinema of France': [(2.416459083557129, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 136]],
#    u'First French Empire': [(2.7828330993652344, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 138]],
#    u'France': [(3.9276187419891357, 0),
#     [88, 89, 91, 94, 104, 105, 111, 112, 116, 117, 118, 119]],
#    u'France national basketball team': [(-1.4013068675994873, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 317]],
#    u'France national football team': [(1.816240668296814, 0),
#     [88, 92, 94, 96, 97, 100, 104, 105, 111, 112, 116, 117, 118, 119, 122]],
#    u'France national rugby league team': [(1.5682919025421143, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 132]],
#    u'France national rugby union team': [(1.3588064908981323, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 128]],
#    u"France women's national football team": [(0.7109335064888, 0),
#     [88, 92, 94, 96, 97, 100, 104, 106, 109, 111, 112, 116, 118, 119, 134]],
#    u'French First Republic': [(3.0179145336151123, 0),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 135]],
#    u'French Football Federation': [(1.150160789489746, 0),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 123]],
#    u'French Rugby Federation': [(0.9180237650871277, 0),
#     [88, 92, 94, 98, 99, 100, 106, 108, 109, 114, 115, 121, 129, 142, 143]],
#    u'French Third Republic': [(2.3019561767578125, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 130]],
#    u'French poetry': [(1.8471473455429077, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 127]],
#    u'Kingdom of France': [(2.5991430282592773, 0),
#     [88, 92, 94, 96, 99, 104, 105, 111, 112, 116, 117, 118, 119, 125, 131]],
#    u'LNB Pro A': [(1.2752410173416138, 0),
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 523]],
#    u'Second French Empire': [(2.641774892807007, 0),
#     [88, 92, 94, 98, 99, 100, 104, 105, 111, 112, 116, 117, 118, 119, 746]],
#    u"Syndicat National de l'\xc9dition Phonographique": [0,
#     [88, 92, 94, 98, 99, 100, 104, 106, 109, 111, 112, 116, 118, 119, 133]],
#    u'XXNILXX': [0, [88]]}},
#  u'with a diverse programme mix of comedy , opera , [dance] , music and drama .': {'boosted': 10.0,
#   u'gold': u'Dance',
#   u'training': True,
#   u'vals': {u'-NIL-': [(-2.6620724201202393, 0), [87, 124]],
#    u'Dance': [(0.9089440703392029, 0),
#     [88, 93, 95, 104, 105, 111, 112, 116, 117, 118, 119, 140, 141, 170, 192]],
#    u'Dance (Gary Numan album)': [(2.2309327125549316, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      182,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194]],
#    u'Dance (Nina Girado song)': [(0.0341462679207325, 0),
#     [88,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      183,
#      184,
#      185,
#      186,
#      193,
#      194,
#      238]],
#    u'Dance Music': [(2.0593483448028564, 0), [88]],
#    u'Dance radio': [(2.6125388145446777, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      237,
#      560]],
#    u'Dance-pop': [(0.7518312335014343, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      164,
#      165,
#      183,
#      184,
#      185,
#      186,
#      232,
#      239]],
#    u'Hot Dance Club Play': [(1.3203500509262085, 0), [88]],
#    u'Indian classical dance': [(3.987327814102173, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      166,
#      167,
#      173,
#      183,
#      184,
#      188,
#      189,
#      2823]],
#    u'Irish dance': [(2.338016986846924, 0),
#     [88,
#      95,
#      104,
#      105,
#      111,
#      112,
#      116,
#      117,
#      118,
#      119,
#      141,
#      162,
#      163,
#      166,
#      167,
#      183,
#      184,
#      188,
#      189,
#      230,
#      1308]],
#    u'XXNILXX': [0, [88]],
#    u'electronic dance music': [(1.5590070486068726, 0), [88]]}}}

# %%
exp_results
# Out:
# [(0, (0.15075959757855004, 0.15075959757855004)),
#  ('training state', (16838, 0.43704715524409077)),
#  (0, (0.14573394275202456, 0.14573394275202456)),
#  ('training state', (16838, 0.41661717543651267)),
#  ('testing run', (0.13791946411895448, 0.13791946411895448)),
#  ('testing state', (15226, 0.366938132142388))]

# %%
evalCurrentStateF1(False, 5000)
# Out:
# (320, 'Prec = 104.0/285 = 0.364912280702, Rec = 104.0/299 = 0.347826086957, F1 = 0.356164383562')
# (320,
#  'Prec = 104.0/285 = 0.364912280702, Rec = 104.0/299 = 0.347826086957, F1 = 0.356164383562')

# %%
(queries_exp.linear_features_dens_l.W.get_value(borrow=True) > .00019).mean()
# Out:
# 0.010877472546506391

# %%
queries_exp.linear_features_dens_l.W.get_value(borrow=True)[0:40]
# Out:
# array([[  2.60732579e+00],
#        [  3.53522539e+00],
#        [  3.34248996e+00],
#        [ -7.38936709e-04],
#        [ -3.67235276e-03],
#        [ -4.89456579e-02],
#        [  2.66805124e-02],
#        [ -2.33040620e-02],
#        [  1.67117640e-02],
#        [  1.72123611e-02],
#        [  5.56132710e-03],
#        [  3.00122201e-02],
#        [  8.88470002e-03],
#        [ -6.31554276e-02],
#        [ -2.90955063e-02],
#        [  2.66024489e-02],
#        [ -5.00463136e-03],
#        [ -1.16568711e-02],
#        [  8.45910632e-04],
#        [ -9.44055896e-03],
#        [ -1.45682422e-02],
#        [  6.52521523e-03],
#        [ -3.08596827e-02],
#        [  1.49343954e-03],
#        [  8.07015225e-04],
#        [  8.63364339e-03],
#        [  2.65006963e-02],
#        [  8.65139533e-04],
#        [ -4.27377596e-03],
#        [ -3.66638675e-02],
#        [ -9.32722446e-03],
#        [ -1.38056064e-02],
#        [ -3.60027850e-02],
#        [  2.07976084e-02],
#        [  8.91434681e-03],
#        [ -2.56620068e-03],
#        [ -2.41660401e-02],
#        [ -8.25434737e-03],
#        [ -1.89340729e-02],
#        [  2.29891133e-03]], dtype=float32)

# %%
(abs(queries_exp.linear_features_dens_l.W.get_value(borrow=True))**2).sum()
# Out:
# 140.62112

# %%
(queries_exp.linear_features_dens_l.W.get_value(borrow=True)[3:900] > 1).sum()
# Out:
# 8

# %%
queries_exp.linear_features_dens_l.W.get_value(borrow=True)[0] = 0

# %%
queries_exp.num_training_items = 50000

# %%
queries_exp.compute_batch(False)
# Out:
# (0.043889810960610752, 0.043889810960610752)

# %%
evalCurrentState(False, queries_exp.num_training_items)
# Out:
# (22944, 0.8301516736401674)
# (22944, 0.8301516736401674)

# %%
#queries_exp.num_training_items = 50000
exp_results.append(('testing run', queries_exp.compute_batch(False)))
exp_results.append(('testing state', evalCurrentState(False, queries_exp.num_training_items)))

# %%
exp_results
# Out:
# [(0, (0.042415848140430139, 0.042415848140430139)),
#  ('training state', (100813, 0.8506145040818148)),
#  ('testing run', (0.040505639483841581, 0.040505639483841581)),
#  ('testing state', (22944, 0.8260983263598326)),
#  (1, (0.034083649006694042, 0.034083649006694042)),
#  ('training state', (100813, 0.8676063602908355)),
#  ('testing run', (0.039983913868662346, 0.039983913868662346)),
#  ('testing state', (22944, 0.827928870292887)),
#  (2, (0.032209361035501115, 0.032209361035501115)),
#  ('training state', (100813, 0.8710086992748951)),
#  ('testing run', (0.039615782901552529, 0.039615782901552529)),
#  ('testing state', (22944, 0.8300209205020921)),
#  (3, (0.03082796823178836, 0.03082796823178836)),
#  ('training state', (100813, 0.874490393104064)),
#  ('testing run', (0.039272816533898185, 0.039272816533898185)),
#  ('testing state', (22944, 0.8305003486750349)),
#  (4, (0.029458737707327584, 0.029458737707327584)),
#  ('training state', (100813, 0.8783886998700564)),
#  ('testing run', (0.039379026142145099, 0.039379026142145099)),
#  ('testing state', (22944, 0.8301516736401674))]

# %%
exp_results

# %%
surface_counts['The Silent World of Nicholas Quinn'.lower()]

# %%
surface_counts['canada']

# %%
surface_counts['urban district']

# %%
findWrongItems(True, 100)

# %%
exp_results.append(('testing run', queries_exp.compute_batch(False)))
exp_results.append(('training state', evalCurrentState(True, queries_exp.num_training_items)))
exp_results.append(('testing state', evalCurrentState(False, queries_exp.num_training_items)))

# %%
exp_results

# %%
exp_results.append(('testing run', queries_exp.compute_batch(False)))
exp_results.append(('training state', evalCurrentState(True, queries_exp.num_training_items)))
exp_results.append(('testing state', evalCurrentState(False, queries_exp.num_training_items)))

# %%
for i in xrange(4):
    res = (i, queries_exp.compute_batch())
    print res
    exp_results.append(res)

# %%
queries_exp.all_params

# %%
queries_exp.all_params[-2].get_value(borrow=True)

# %%
queries_exp.all_params[-2:][0].get_value(borrow=True)

# %%
saved_lin_layer

# %%
findWrongItems()

# %%
findWrongItems(False)

# %%
surface_counts['The Silent World of Nicholas Quinn'.lower()]

# %%
# %time for i in range(5): print queries_exp.compute_batch()

# %%
queries.values()[0]

# %%
queries_exp.all_params

# %%
queries_exp.all_params[-2].get_value(borrow=True)

# %%
queries_exp.all_params[-2].get_value(borrow=True)[0] = 20.0

# %%
len(queries_exp.page_content.values()[1])

# %%
# with open('/data/matthew/external-wiki-aida1.json') as f:
#     queries_old = json.load(f)['queries']

# %%
# Out:
# 0.8705416746137707
